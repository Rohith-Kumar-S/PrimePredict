# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import gdown
import kagglehub
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import AdaBoostRegressor

# %% [markdown]
# # Helper Functions

# %%
def fetch_dataset(key, dataset_name):
    cmd = !gdown --fuzzy {key} -O {dataset_name}
    path = pd.Series(cmd).str.extractall(r'(To.*)').reset_index()[0].iloc[0].split(': ')[1]
    print(f'{dataset_name} path: {path}')
    return path

def get_null_percentage(df):
    null_series = ((df.isnull().sum()/len(df))*100).sort_values()
    return null_series

def generate_time_features(df):
    df = df.reset_index()
    df.loc[:,'day']  = df['Order Date'].dt.day
    df.loc[:,'month']  = df['Order Date'].dt.month
    df.loc[:,'year']  = df['Order Date'].dt.year
    df.loc[:,'is_weekend']  = df['Order Date'].dt.weekday > 5
    df.loc[:,'day_of_week']  = df['Order Date'].dt.day_of_week
    df.loc[:,'day_of_year']  = df['Order Date'].dt.day_of_year
    df.loc[:,'quarter']  = df['Order Date'].dt.quarter
    df.loc[:,'is_month_start']  = df['Order Date'].dt.is_month_start
    df.loc[:,'is_month_end']  = df['Order Date'].dt.is_month_end
    df.loc[:,'is_year_start']  = df['Order Date'].dt.is_year_start
    df.loc[:,'is_year_end']  = df['Order Date'].dt.is_year_end
    df = df.set_index('Order Date')
    return df

def add_holidays_past_2021(df):

    _2022 = pd.Series(['2022-12-26', '2022-11-24', '2022-11-11', '2022-10-10', '2022-09-05', '2022-07-04', '2022-06-20', '2022-05-30', '2022-02-21', '2022-01-21', '2023-01-02', '2023-01-16', '2023-02-20']) 
    
    _2022 = pd.to_datetime(_2022)
    dates = pd.Series(['January 02 2023',
    'January 16 2023',
    'February 20 2023',
    'May 29 2023',
    'June 19 2023',
    'July 04 2023',
    'September 04 2023',
    'October 09 2023',
    'November 10 2023',
    'November 23 2023',
    'December 25 2023',
    'January 01 2024',
    'January 15 2024',
    'February 19 2024',
    'May 27 2024',
    'June 19 2024',
    'July 04 2024',
    'September 02 2024',	
    'October 14 2024',
    'November 11 2024',	
    'November 28 2024',	
    'December 25 2024',
    'January 01 2025',
    'January 20 2025',
    'January 20 2025',
    'February 17 2025',
    'May 26 2025',
    'June 19 2025',
    'July 04 2025',
    'September 01 2025',	
    'October 13 2025',
    'November 11 2025',
    'November 27 2025',
    'December 25 2025',
    'January 01 2026',
    'January 19 2026',
    'February 16 2026',
    'May 25 2026',
    'June 19 2026',
    'July 03 2026',
    'September 07 2025',
    'October 12 2026',
    'November 11 2026',
    'November 26 2026',
    'December 25 2026'
                      ])
    fedral_holidays_2023_plus = pd.to_datetime(dates)
    fedral_holdidays_22_plus = pd.concat([_2022, fedral_holidays_2023_plus], axis=0).sort_values()
    fedral_holdidays_22_plus = pd.Series(fedral_holdidays_22_plus.unique())
    fedral_holdidays_22_plus.index = range(len(fedral_holdidays_22_plus))
    fedral_holdidays_22_plus = pd.DataFrame(fedral_holdidays_22_plus).rename(columns={0:'date'})
    fedral_holdidays_22_plus['fedral_holiday'] = True
    fedral_holdidays_22_plus = fedral_holdidays_22_plus.set_index('date')
    return pd.merge(df, fedral_holdidays_22_plus, how='left', left_index = True, right_index=True)

def add_events(events_timestamps, is_repeat=False):
    dummy_date = '2017-04-10'
    events = pd.DatetimeIndex([dummy_date])
    if is_repeat:
        for i in range(len([2018,2019,2020,2021,2022,2023,2024,2025,2026])):
            events = events.append(pd.date_range(start=events_timestamps[0], end=events_timestamps[1]) \
                                   + pd.tseries.offsets.DateOffset(months=i*12))
    else:
        for event in events_timestamps:
            events = events.append(pd.date_range(start=event[0], end=event[1]))
    return events[1:]

def assign_historic_sales(df, year_till=2022):
    df = df.reset_index()
    sales = df[['Order Date', 'total_sales']]
    sales = sales.set_index('Order Date')
    past_sales = list(sales[sales.index.year <= year_till]['total_sales'])
    lag = [np.nan] * (len(sales) - len(past_sales))
    lag.extend(past_sales)
    lag = pd.Series(lag, index=sales.index)
    df = df.set_index('Order Date')
    return lag

def add_amazon_events(df):
    global amazon_events_df
    df = pd.merge(df, amazon_events_df, left_index=True, right_index=True, how='left')
    df['Amazon Events'] = df['Amazon Events'].fillna('No Events')
    df = pd.get_dummies(df, drop_first=True)
    return df

# %% [markdown]
# # Dataset imports

# %%
path = fetch_dataset("1HdJj68eO9NTZlpwZcLYqdtPqrbKs1cxj", "amazon_purchases.csv")
purchases = pd.read_csv(path)
purchases = purchases[purchases['Shipping Address State'].notnull()]
purchases.rename(columns={'ASIN/ISBN (Product Code)': 'product_code'}, inplace=True)

path = kagglehub.dataset_download("donnetew/us-holiday-dates-2004-2021")
holidays = pd.read_csv(os.path.join(path,'US Holiday Dates (2004-2021).csv'))
holidays['is_holiday'] = True
holidays['Date'] = pd.to_datetime(holidays['Date'])
holidays.set_index('Date', inplace=True)

path = fetch_dataset("19167R4OV0GWNiCHTh3w9T07616S91enj", "amazon_categories.csv")
categories = pd.read_csv(path)

path = fetch_dataset("1yoaKl-7wctxH315gH_M15fS5WERnFlHe", "amazon_products.csv")
products = pd.read_csv(path)
products = products.rename(columns={'asin':'product_code'})
# Out:
# amazon_purchases.csv path: C:\Users\rohit\5010\project\AmazonSalesPredictor\amazon_purchases.csv
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.11)
# amazon_categories.csv path: C:\Users\rohit\5010\project\AmazonSalesPredictor\amazon_categories.csv
# amazon_products.csv path: C:\Users\rohit\5010\project\AmazonSalesPredictor\amazon_products.csv

# %% [markdown]
# ## Data Cleaning

# %%
products = pd.merge(products, categories, how='inner', left_on='category_id', right_on='id').drop('id', axis=1)
product_codes_category_null = purchases[purchases['Category'].isnull()]['product_code']

data_replacements = products[products['product_code'].isin(product_codes_category_null.unique())][['product_code','title','category_name']]

purchases = pd.merge(purchases, data_replacements, on='product_code', how='left')

purchases.loc[(purchases['Category'].isnull())&(purchases['category_name'].notnull()), 'Category'] = purchases.loc[(purchases['Category'].isnull())&(purchases['category_name'].notnull()), 'category_name']

purchases.loc[(purchases['Title'].isnull()) & (purchases['title'].notnull()), 'Title'] = purchases.loc[(purchases['Title'].isnull()) & (purchases['title'].notnull()), 'title']
purchases.drop(['title', 'category_name'], axis=1, inplace=True)
purchases.dropna(axis=0,subset= ['Shipping Address State','Category'], inplace=True)

# %%
get_null_percentage(purchases)
# Out:
# Order Date                 0.000000
# Purchase Price Per Unit    0.000000
# Quantity                   0.000000
# Shipping Address State     0.000000
# Survey ResponseID          0.000000
# Category                   0.000000
# product_code               0.016695
# Title                      0.033391
# dtype: float64

# %%
purchases
# Out:
#          Order Date  Purchase Price Per Unit  Quantity Shipping Address State  \
# 0        2018-12-04                     7.98       1.0                     NJ
# 1        2018-12-22                    13.99       1.0                     NJ
# 3        2018-12-25                    10.45       1.0                     NJ
# 4        2018-12-25                    10.00       1.0                     NJ
# 5        2019-02-18                    10.99       1.0                     NJ
# ...             ...                      ...       ...                    ...
# 1762900  2021-04-01                    20.75       1.0                     MA
# 1762901  2021-04-01                     6.99       1.0                     MA
# 1762902  2021-04-14                    15.99       1.0                     MA
# 1762903  2021-05-22                     6.99       4.0                     MA
# 1762904  2021-12-01                     6.99       4.0                     MA
#
#                                                      Title product_code  \
# 0        SanDisk Ultra 16GB Class 10 SDHC UHS-I Memory ...   B0143RTB1E
# 1        Betron BS10 Earphones Wired Headphones in Ear ...   B01MA1MJ6H
# 3        Perfecto Stainless Steel Shaving Bowl. Durable...   B06XWF9HML
# 4                            Proraso Shaving Cream for Men   B00837ZOI0
# 5        Micro USB Cable Android Charger - Syncwire [2-...   B01GFB2E9M
# ...                                                    ...          ...
# 1762900  50 Feather (Yellow Label) Razor Blades Platinu...   B08P5K9GMJ
# 1762901  Tanner's Tasty Paste Vanilla Bling - Anticavit...   B015ZRTHVA
# 1762902  Sinland Microfiber Cleaning Cloth Dish Cloth K...   B00QGCXPRG
# 1762903  Tanner's Tasty Paste Vanilla Bling - Anticavit...   B015ZRTHVA
# 1762904  Tanner's Tasty Paste Vanilla Bling - Anticavit...   B015ZRTHVA
#
#                       Category  Survey ResponseID
# 0                 FLASH_MEMORY  R_01vNIayewjIIKMF
# 1                   HEADPHONES  R_01vNIayewjIIKMF
# 3                DISHWARE_BOWL  R_01vNIayewjIIKMF
# 4                SHAVING_AGENT  R_01vNIayewjIIKMF
# 5           COMPUTER_PROCESSOR  R_01vNIayewjIIKMF
# ...                        ...                ...
# 1762900  RAZOR_BLADE_CARTRIDGE  R_zfqnsBzlOAKibzb
# 1762901   TOOTH_CLEANING_AGENT  R_zfqnsBzlOAKibzb
# 1762902                  TOWEL  R_zfqnsBzlOAKibzb
# 1762903   TOOTH_CLEANING_AGENT  R_zfqnsBzlOAKibzb
# 1762904   TOOTH_CLEANING_AGENT  R_zfqnsBzlOAKibzb
#
# [1677119 rows x 8 columns]

# %% [markdown]
# # Feature engineering

# %%
# Best Average sales
ma_purchases = purchases.copy()
ma_purchases['Order Date'] = pd.to_datetime(ma_purchases['Order Date'])
ma_purchases.set_index('Order Date', inplace=True)
ma_purchases = ma_purchases[(ma_purchases.index.year<2023) & (ma_purchases['Shipping Address State']== 'MA')]
ma_purchases.loc[:,'total_sales'] = ma_purchases['Purchase Price Per Unit'] * ma_purchases['Quantity']

# Best Performing
ca_purchases = purchases.copy()
ca_purchases['Order Date'] = pd.to_datetime(ca_purchases['Order Date'])
ca_purchases.set_index('Order Date', inplace=True)
ca_purchases = ca_purchases[(ca_purchases.index.year<2023) & (ca_purchases['Shipping Address State']== 'CA')]
ca_purchases.loc[:,'total_sales'] = ca_purchases['Purchase Price Per Unit'] * ca_purchases['Quantity']

# Least performing
ga_purchases = purchases.copy()
ga_purchases['Order Date'] = pd.to_datetime(ga_purchases['Order Date'])
ga_purchases.set_index('Order Date', inplace=True)
ga_purchases = ga_purchases[(ga_purchases.index.year<2023) & (ga_purchases['Shipping Address State']== 'GA')]
ga_purchases.loc[:,'total_sales'] = ga_purchases['Purchase Price Per Unit'] * ga_purchases['Quantity']

# %%
ma_df = ma_purchases.copy()
ma_df = pd.DataFrame(ma_df.groupby(ma_df.index)['total_sales'].sum())

ca_df = ca_purchases.copy()
ca_df = pd.DataFrame(ca_df.groupby(ca_df.index)['total_sales'].sum())

ga_df = ga_purchases.copy()
ga_df = pd.DataFrame(ga_df.groupby(ga_df.index)['total_sales'].sum())

# %% [markdown]
# **Add time features**

# %%
ma_df = generate_time_features(ma_df)
ca_df = generate_time_features(ca_df)
ga_df = generate_time_features(ga_df)

# %%
ma_df
# Out:
#             total_sales  day  month  year  is_weekend  day_of_week  \
# Order Date
# 2018-01-01       322.36    1      1  2018       False            0
# 2018-01-02       375.45    2      1  2018       False            1
# 2018-01-03       297.77    3      1  2018       False            2
# 2018-01-04       330.45    4      1  2018       False            3
# 2018-01-05       672.18    5      1  2018       False            4
# ...                 ...  ...    ...   ...         ...          ...
# 2022-12-27       251.55   27     12  2022       False            1
# 2022-12-28       962.12   28     12  2022       False            2
# 2022-12-29       292.19   29     12  2022       False            3
# 2022-12-30       308.86   30     12  2022       False            4
# 2022-12-31       115.02   31     12  2022       False            5
#
#             day_of_year  quarter  is_month_start  is_month_end  is_year_start  \
# Order Date
# 2018-01-01            1        1            True         False           True
# 2018-01-02            2        1           False         False          False
# 2018-01-03            3        1           False         False          False
# 2018-01-04            4        1           False         False          False
# 2018-01-05            5        1           False         False          False
# ...                 ...      ...             ...           ...            ...
# 2022-12-27          361        4           False         False          False
# 2022-12-28          362        4           False         False          False
# 2022-12-29          363        4           False         False          False
# 2022-12-30          364        4           False         False          False
# 2022-12-31          365        4           False          True          False
#
#             is_year_end
# Order Date
# 2018-01-01        False
# 2018-01-02        False
# 2018-01-03        False
# 2018-01-04        False
# 2018-01-05        False
# ...                 ...
# 2022-12-27        False
# 2022-12-28        False
# 2022-12-29        False
# 2022-12-30        False
# 2022-12-31         True
#
# [1826 rows x 12 columns]

# %%
ca_df
# Out:
#             total_sales  day  month  year  is_weekend  day_of_week  \
# Order Date
# 2018-01-01      2281.01    1      1  2018       False            0
# 2018-01-02      1710.42    2      1  2018       False            1
# 2018-01-03      1053.32    3      1  2018       False            2
# 2018-01-04      1501.36    4      1  2018       False            3
# 2018-01-05      1188.93    5      1  2018       False            4
# ...                 ...  ...    ...   ...         ...          ...
# 2022-12-27      1508.82   27     12  2022       False            1
# 2022-12-28      1484.50   28     12  2022       False            2
# 2022-12-29      2122.56   29     12  2022       False            3
# 2022-12-30      1451.38   30     12  2022       False            4
# 2022-12-31      1061.83   31     12  2022       False            5
#
#             day_of_year  quarter  is_month_start  is_month_end  is_year_start  \
# Order Date
# 2018-01-01            1        1            True         False           True
# 2018-01-02            2        1           False         False          False
# 2018-01-03            3        1           False         False          False
# 2018-01-04            4        1           False         False          False
# 2018-01-05            5        1           False         False          False
# ...                 ...      ...             ...           ...            ...
# 2022-12-27          361        4           False         False          False
# 2022-12-28          362        4           False         False          False
# 2022-12-29          363        4           False         False          False
# 2022-12-30          364        4           False         False          False
# 2022-12-31          365        4           False          True          False
#
#             is_year_end
# Order Date
# 2018-01-01        False
# 2018-01-02        False
# 2018-01-03        False
# 2018-01-04        False
# 2018-01-05        False
# ...                 ...
# 2022-12-27        False
# 2022-12-28        False
# 2022-12-29        False
# 2022-12-30        False
# 2022-12-31         True
#
# [1826 rows x 12 columns]

# %%
ga_df
# Out:
#             total_sales  day  month  year  is_weekend  day_of_week  \
# Order Date
# 2018-01-01       120.85    1      1  2018       False            0
# 2018-01-02       223.69    2      1  2018       False            1
# 2018-01-03       750.11    3      1  2018       False            2
# 2018-01-04       188.71    4      1  2018       False            3
# 2018-01-05       296.01    5      1  2018       False            4
# ...                 ...  ...    ...   ...         ...          ...
# 2022-12-27       522.93   27     12  2022       False            1
# 2022-12-28       716.57   28     12  2022       False            2
# 2022-12-29       313.63   29     12  2022       False            3
# 2022-12-30       398.58   30     12  2022       False            4
# 2022-12-31       138.00   31     12  2022       False            5
#
#             day_of_year  quarter  is_month_start  is_month_end  is_year_start  \
# Order Date
# 2018-01-01            1        1            True         False           True
# 2018-01-02            2        1           False         False          False
# 2018-01-03            3        1           False         False          False
# 2018-01-04            4        1           False         False          False
# 2018-01-05            5        1           False         False          False
# ...                 ...      ...             ...           ...            ...
# 2022-12-27          361        4           False         False          False
# 2022-12-28          362        4           False         False          False
# 2022-12-29          363        4           False         False          False
# 2022-12-30          364        4           False         False          False
# 2022-12-31          365        4           False          True          False
#
#             is_year_end
# Order Date
# 2018-01-01        False
# 2018-01-02        False
# 2018-01-03        False
# 2018-01-04        False
# 2018-01-05        False
# ...                 ...
# 2022-12-27        False
# 2022-12-28        False
# 2022-12-29        False
# 2022-12-30        False
# 2022-12-31         True
#
# [1826 rows x 12 columns]

# %% [markdown]
# **Add amazon events**

# %%
amazon_events = add_events([['2024-03-20', '2024-03-25'], ['2025-03-25', '2025-03-31']])
spring_sale_event_df = pd.DataFrame({'Event Date':amazon_events,'Amazon Events':['Big Spring Sale']*len(amazon_events)}).set_index('Event Date')

# %%
amazon_events = add_events([
    ['2018-07-16', '2018-07-17'],
    ['2019-07-15', '2019-07-16'],
    ['2020-10-13', '2020-10-14'],
    ['2021-06-21', '2021-06-22'],
    ['2022-07-12', '2022-07-13'],
    ['2023-07-11', '2023-07-12'],
    ['2024-07-16', '2024-07-17'],
    ['2025-07-23', '2025-07-24']
])
prime_day_event_df = pd.DataFrame({'Event Date':amazon_events,'Amazon Events':['Amazon Prime Day']*len(amazon_events)}).set_index('Event Date')

# %%
amazon_events = add_events([
    ['2022-10-11', '2022-10-12'],  
    ['2023-10-10', '2023-10-11'],  
    ['2024-10-08', '2024-10-09'],
    ['2025-10-14', '2025-10-15']
])
prime_big_deal_event_df = pd.DataFrame({'Event Date':amazon_events,'Amazon Events':['Prime Big Deal Days']*len(amazon_events)}).set_index('Event Date')

# %%
amazon_events = add_events([
    ['2018-11-16', '2018-11-23'],
    ['2019-11-22', '2019-11-29'],
    ['2020-11-20', '2020-11-27'],
    ['2021-11-19', '2021-11-26'],
    ['2022-11-24', '2022-11-25'],
    ['2023-11-17', '2023-11-24'],
    ['2024-11-21', '2024-11-29'],
    ['2025-11-28', '2025-12-01']
]
)
black_friday_event_df = pd.DataFrame({'Event Date':amazon_events,'Amazon Events':['Black Friday']*len(amazon_events)}).set_index('Event Date')

# %%
amazon_events = add_events([
    ['2018-02-05', '2018-02-14'],
    ['2019-02-04', '2019-02-14'],
    ['2020-02-03', '2020-02-14'],
    ['2021-02-01', '2021-02-14'],
    ['2022-02-03', '2022-02-10'],
    ['2023-02-04', '2023-02-14'],
    ['2024-02-02', '2024-02-14'],
    ['2025-02-02', '2025-02-14']
])
valentines_day_event_df = pd.DataFrame({'Event Date':amazon_events,'Amazon Events':["Valentine's Day Promotions"]*len(amazon_events)}).set_index('Event Date')

# %%
amazon_events = add_events([
    ['2018-05-01', '2018-05-13'],
    ['2019-05-03', '2019-05-12'],
    ['2020-05-01', '2020-05-10'],
    ['2021-05-01', '2021-05-09'],
    ['2022-05-03', '2022-05-09'],
    ['2023-05-01', '2023-05-14'],
    ['2024-05-02', '2024-05-12'],
    ['2025-05-06', '2025-05-12']
])
mothers_day_event_df = pd.DataFrame({'Event Date':amazon_events,'Amazon Events':["Mother's Day Deals"]*len(amazon_events)}).set_index('Event Date')

# %%
amazon_events = add_events([
    ['2018-05-25', '2018-05-28'],
    ['2019-05-24', '2019-05-27'],
    ['2020-05-22', '2020-05-25'],
    ['2021-05-28', '2021-05-31'],
    ['2022-05-27', '2022-05-30'],
    ['2023-05-26', '2023-05-29'],
    ['2024-05-24', '2024-05-27'],
    ['2025-05-23', '2025-05-26']
])
memorial_day_event_df = pd.DataFrame({'Event Date':amazon_events,'Amazon Events':["Memorial Day Sales"]*len(amazon_events)}).set_index('Event Date')

# %%
amazon_events = add_events(('2018-12-02', '2018-12-13'), is_repeat=True)
_12_day_of_deals_event_df = pd.DataFrame({'Event Date':amazon_events,'Amazon Events':['12 Days of Deals']*len(amazon_events)}).set_index('Event Date')

# %%
amazon_events = add_events(('2018-12-25', '2019-01-01'), is_repeat=True)
year_end_clearance_event_df = pd.DataFrame({'Event Date':amazon_events,'Amazon Events':['Year-End Clearance Sale']*len(amazon_events)}).set_index('Event Date')

# %% [markdown]
# **concat**

# %%
amazon_events_df = pd.concat([spring_sale_event_df,prime_day_event_df,prime_big_deal_event_df,black_friday_event_df,valentines_day_event_df,mothers_day_event_df,memorial_day_event_df,_12_day_of_deals_event_df,year_end_clearance_event_df], axis=0).sort_index()

# %%
amazon_events_df
# Out:
#                          Amazon Events
# Event Date
# 2018-02-05  Valentine's Day Promotions
# 2018-02-06  Valentine's Day Promotions
# 2018-02-07  Valentine's Day Promotions
# 2018-02-08  Valentine's Day Promotions
# 2018-02-09  Valentine's Day Promotions
# ...                                ...
# 2026-12-28     Year-End Clearance Sale
# 2026-12-29     Year-End Clearance Sale
# 2026-12-30     Year-End Clearance Sale
# 2026-12-31     Year-End Clearance Sale
# 2027-01-01     Year-End Clearance Sale
#
# [477 rows x 1 columns]

# %%
sns.histplot(amazon_events_df[amazon_events_df.index.year==2018], x='Amazon Events')
plt.xticks(rotation=90);
plt.xlabel('Amazon events in 2018')
# Out:
# Text(0.5, 0, 'Amazon events in 2018')

# %%
sns.histplot(amazon_events_df, x='Amazon Events')
plt.xticks(rotation=90);
plt.xlabel('Amazon events yearly')
# Out:
# Text(0.5, 0, 'Amazon events yearly')

# %%
ma_df = pd.merge(ma_df, amazon_events_df, left_index=True, right_index=True, how='left')
ca_df = pd.merge(ca_df, amazon_events_df, left_index=True, right_index=True, how='left')
ga_df = pd.merge(ga_df, amazon_events_df, left_index=True, right_index=True, how='left')

# %%
ma_df['Amazon Events'] = ma_df['Amazon Events'].fillna('No Events')
ca_df['Amazon Events'] = ca_df['Amazon Events'].fillna('No Events')
ga_df['Amazon Events'] = ga_df['Amazon Events'].fillna('No Events')

# %%
sns.histplot(ma_df[ma_df.index.year==2022], x='Amazon Events')
plt.xticks(rotation=90);
plt.xlabel('Amazon events in 2022')
# Out:
# Text(0.5, 0, 'Amazon events in 2022')

# %%
ma_df = pd.get_dummies(ma_df, drop_first=True)
ca_df = pd.get_dummies(ca_df, drop_first=True)
ga_df = pd.get_dummies(ga_df, drop_first=True)

# %%
ma_df
# Out:
#             total_sales  day  month  year  is_weekend  day_of_week  \
# Order Date
# 2018-01-01       322.36    1      1  2018       False            0
# 2018-01-02       375.45    2      1  2018       False            1
# 2018-01-03       297.77    3      1  2018       False            2
# 2018-01-04       330.45    4      1  2018       False            3
# 2018-01-05       672.18    5      1  2018       False            4
# ...                 ...  ...    ...   ...         ...          ...
# 2022-12-27       251.55   27     12  2022       False            1
# 2022-12-28       962.12   28     12  2022       False            2
# 2022-12-29       292.19   29     12  2022       False            3
# 2022-12-30       308.86   30     12  2022       False            4
# 2022-12-31       115.02   31     12  2022       False            5
#
#             day_of_year  quarter  is_month_start  is_month_end  is_year_start  \
# Order Date
# 2018-01-01            1        1            True         False           True
# 2018-01-02            2        1           False         False          False
# 2018-01-03            3        1           False         False          False
# 2018-01-04            4        1           False         False          False
# 2018-01-05            5        1           False         False          False
# ...                 ...      ...             ...           ...            ...
# 2022-12-27          361        4           False         False          False
# 2022-12-28          362        4           False         False          False
# 2022-12-29          363        4           False         False          False
# 2022-12-30          364        4           False         False          False
# 2022-12-31          365        4           False          True          False
#
#             is_year_end  Amazon Events_Amazon Prime Day  \
# Order Date
# 2018-01-01        False                           False
# 2018-01-02        False                           False
# 2018-01-03        False                           False
# 2018-01-04        False                           False
# 2018-01-05        False                           False
# ...                 ...                             ...
# 2022-12-27        False                           False
# 2022-12-28        False                           False
# 2022-12-29        False                           False
# 2022-12-30        False                           False
# 2022-12-31         True                           False
#
#             Amazon Events_Black Friday  Amazon Events_Memorial Day Sales  \
# Order Date
# 2018-01-01                       False                             False
# 2018-01-02                       False                             False
# 2018-01-03                       False                             False
# 2018-01-04                       False                             False
# 2018-01-05                       False                             False
# ...                                ...                               ...
# 2022-12-27                       False                             False
# 2022-12-28                       False                             False
# 2022-12-29                       False                             False
# 2022-12-30                       False                             False
# 2022-12-31                       False                             False
#
#             Amazon Events_Mother's Day Deals  Amazon Events_No Events  \
# Order Date
# 2018-01-01                             False                     True
# 2018-01-02                             False                     True
# 2018-01-03                             False                     True
# 2018-01-04                             False                     True
# 2018-01-05                             False                     True
# ...                                      ...                      ...
# 2022-12-27                             False                    False
# 2022-12-28                             False                    False
# 2022-12-29                             False                    False
# 2022-12-30                             False                    False
# 2022-12-31                             False                    False
#
#             Amazon Events_Prime Big Deal Days  \
# Order Date
# 2018-01-01                              False
# 2018-01-02                              False
# 2018-01-03                              False
# 2018-01-04                              False
# 2018-01-05                              False
# ...                                       ...
# 2022-12-27                              False
# 2022-12-28                              False
# 2022-12-29                              False
# 2022-12-30                              False
# 2022-12-31                              False
#
#             Amazon Events_Valentine's Day Promotions  \
# Order Date
# 2018-01-01                                     False
# 2018-01-02                                     False
# 2018-01-03                                     False
# 2018-01-04                                     False
# 2018-01-05                                     False
# ...                                              ...
# 2022-12-27                                     False
# 2022-12-28                                     False
# 2022-12-29                                     False
# 2022-12-30                                     False
# 2022-12-31                                     False
#
#             Amazon Events_Year-End Clearance Sale
# Order Date
# 2018-01-01                                  False
# 2018-01-02                                  False
# 2018-01-03                                  False
# 2018-01-04                                  False
# 2018-01-05                                  False
# ...                                           ...
# 2022-12-27                                   True
# 2022-12-28                                   True
# 2022-12-29                                   True
# 2022-12-30                                   True
# 2022-12-31                                   True
#
# [1826 rows x 20 columns]

# %%
ca_df
# Out:
#             total_sales  day  month  year  is_weekend  day_of_week  \
# Order Date
# 2018-01-01      2281.01    1      1  2018       False            0
# 2018-01-02      1710.42    2      1  2018       False            1
# 2018-01-03      1053.32    3      1  2018       False            2
# 2018-01-04      1501.36    4      1  2018       False            3
# 2018-01-05      1188.93    5      1  2018       False            4
# ...                 ...  ...    ...   ...         ...          ...
# 2022-12-27      1508.82   27     12  2022       False            1
# 2022-12-28      1484.50   28     12  2022       False            2
# 2022-12-29      2122.56   29     12  2022       False            3
# 2022-12-30      1451.38   30     12  2022       False            4
# 2022-12-31      1061.83   31     12  2022       False            5
#
#             day_of_year  quarter  is_month_start  is_month_end  is_year_start  \
# Order Date
# 2018-01-01            1        1            True         False           True
# 2018-01-02            2        1           False         False          False
# 2018-01-03            3        1           False         False          False
# 2018-01-04            4        1           False         False          False
# 2018-01-05            5        1           False         False          False
# ...                 ...      ...             ...           ...            ...
# 2022-12-27          361        4           False         False          False
# 2022-12-28          362        4           False         False          False
# 2022-12-29          363        4           False         False          False
# 2022-12-30          364        4           False         False          False
# 2022-12-31          365        4           False          True          False
#
#             is_year_end  Amazon Events_Amazon Prime Day  \
# Order Date
# 2018-01-01        False                           False
# 2018-01-02        False                           False
# 2018-01-03        False                           False
# 2018-01-04        False                           False
# 2018-01-05        False                           False
# ...                 ...                             ...
# 2022-12-27        False                           False
# 2022-12-28        False                           False
# 2022-12-29        False                           False
# 2022-12-30        False                           False
# 2022-12-31         True                           False
#
#             Amazon Events_Black Friday  Amazon Events_Memorial Day Sales  \
# Order Date
# 2018-01-01                       False                             False
# 2018-01-02                       False                             False
# 2018-01-03                       False                             False
# 2018-01-04                       False                             False
# 2018-01-05                       False                             False
# ...                                ...                               ...
# 2022-12-27                       False                             False
# 2022-12-28                       False                             False
# 2022-12-29                       False                             False
# 2022-12-30                       False                             False
# 2022-12-31                       False                             False
#
#             Amazon Events_Mother's Day Deals  Amazon Events_No Events  \
# Order Date
# 2018-01-01                             False                     True
# 2018-01-02                             False                     True
# 2018-01-03                             False                     True
# 2018-01-04                             False                     True
# 2018-01-05                             False                     True
# ...                                      ...                      ...
# 2022-12-27                             False                    False
# 2022-12-28                             False                    False
# 2022-12-29                             False                    False
# 2022-12-30                             False                    False
# 2022-12-31                             False                    False
#
#             Amazon Events_Prime Big Deal Days  \
# Order Date
# 2018-01-01                              False
# 2018-01-02                              False
# 2018-01-03                              False
# 2018-01-04                              False
# 2018-01-05                              False
# ...                                       ...
# 2022-12-27                              False
# 2022-12-28                              False
# 2022-12-29                              False
# 2022-12-30                              False
# 2022-12-31                              False
#
#             Amazon Events_Valentine's Day Promotions  \
# Order Date
# 2018-01-01                                     False
# 2018-01-02                                     False
# 2018-01-03                                     False
# 2018-01-04                                     False
# 2018-01-05                                     False
# ...                                              ...
# 2022-12-27                                     False
# 2022-12-28                                     False
# 2022-12-29                                     False
# 2022-12-30                                     False
# 2022-12-31                                     False
#
#             Amazon Events_Year-End Clearance Sale
# Order Date
# 2018-01-01                                  False
# 2018-01-02                                  False
# 2018-01-03                                  False
# 2018-01-04                                  False
# 2018-01-05                                  False
# ...                                           ...
# 2022-12-27                                   True
# 2022-12-28                                   True
# 2022-12-29                                   True
# 2022-12-30                                   True
# 2022-12-31                                   True
#
# [1826 rows x 20 columns]

# %%
ga_df
# Out:
#             total_sales  day  month  year  is_weekend  day_of_week  \
# Order Date
# 2018-01-01       120.85    1      1  2018       False            0
# 2018-01-02       223.69    2      1  2018       False            1
# 2018-01-03       750.11    3      1  2018       False            2
# 2018-01-04       188.71    4      1  2018       False            3
# 2018-01-05       296.01    5      1  2018       False            4
# ...                 ...  ...    ...   ...         ...          ...
# 2022-12-27       522.93   27     12  2022       False            1
# 2022-12-28       716.57   28     12  2022       False            2
# 2022-12-29       313.63   29     12  2022       False            3
# 2022-12-30       398.58   30     12  2022       False            4
# 2022-12-31       138.00   31     12  2022       False            5
#
#             day_of_year  quarter  is_month_start  is_month_end  is_year_start  \
# Order Date
# 2018-01-01            1        1            True         False           True
# 2018-01-02            2        1           False         False          False
# 2018-01-03            3        1           False         False          False
# 2018-01-04            4        1           False         False          False
# 2018-01-05            5        1           False         False          False
# ...                 ...      ...             ...           ...            ...
# 2022-12-27          361        4           False         False          False
# 2022-12-28          362        4           False         False          False
# 2022-12-29          363        4           False         False          False
# 2022-12-30          364        4           False         False          False
# 2022-12-31          365        4           False          True          False
#
#             is_year_end  Amazon Events_Amazon Prime Day  \
# Order Date
# 2018-01-01        False                           False
# 2018-01-02        False                           False
# 2018-01-03        False                           False
# 2018-01-04        False                           False
# 2018-01-05        False                           False
# ...                 ...                             ...
# 2022-12-27        False                           False
# 2022-12-28        False                           False
# 2022-12-29        False                           False
# 2022-12-30        False                           False
# 2022-12-31         True                           False
#
#             Amazon Events_Black Friday  Amazon Events_Memorial Day Sales  \
# Order Date
# 2018-01-01                       False                             False
# 2018-01-02                       False                             False
# 2018-01-03                       False                             False
# 2018-01-04                       False                             False
# 2018-01-05                       False                             False
# ...                                ...                               ...
# 2022-12-27                       False                             False
# 2022-12-28                       False                             False
# 2022-12-29                       False                             False
# 2022-12-30                       False                             False
# 2022-12-31                       False                             False
#
#             Amazon Events_Mother's Day Deals  Amazon Events_No Events  \
# Order Date
# 2018-01-01                             False                     True
# 2018-01-02                             False                     True
# 2018-01-03                             False                     True
# 2018-01-04                             False                     True
# 2018-01-05                             False                     True
# ...                                      ...                      ...
# 2022-12-27                             False                    False
# 2022-12-28                             False                    False
# 2022-12-29                             False                    False
# 2022-12-30                             False                    False
# 2022-12-31                             False                    False
#
#             Amazon Events_Prime Big Deal Days  \
# Order Date
# 2018-01-01                              False
# 2018-01-02                              False
# 2018-01-03                              False
# 2018-01-04                              False
# 2018-01-05                              False
# ...                                       ...
# 2022-12-27                              False
# 2022-12-28                              False
# 2022-12-29                              False
# 2022-12-30                              False
# 2022-12-31                              False
#
#             Amazon Events_Valentine's Day Promotions  \
# Order Date
# 2018-01-01                                     False
# 2018-01-02                                     False
# 2018-01-03                                     False
# 2018-01-04                                     False
# 2018-01-05                                     False
# ...                                              ...
# 2022-12-27                                     False
# 2022-12-28                                     False
# 2022-12-29                                     False
# 2022-12-30                                     False
# 2022-12-31                                     False
#
#             Amazon Events_Year-End Clearance Sale
# Order Date
# 2018-01-01                                  False
# 2018-01-02                                  False
# 2018-01-03                                  False
# 2018-01-04                                  False
# 2018-01-05                                  False
# ...                                           ...
# 2022-12-27                                   True
# 2022-12-28                                   True
# 2022-12-29                                   True
# 2022-12-30                                   True
# 2022-12-31                                   True
#
# [1826 rows x 20 columns]

# %% [markdown]
# **Add holidays**

# %%
ma_df = pd.merge(ma_df, holidays['is_holiday'], how='left', left_index=True, right_index=True)
ma_df = add_holidays_past_2021(ma_df)
ma_df['fedral_holiday'] = ma_df['is_holiday'].fillna(False) + ma_df['fedral_holiday'].fillna(False)
ma_df.drop('is_holiday', axis=1, inplace=True)

ca_df = pd.merge(ca_df, holidays['is_holiday'], how='left', left_index=True, right_index=True)
ca_df = add_holidays_past_2021(ca_df)
ca_df['fedral_holiday'] = ca_df['is_holiday'].fillna(False) + ca_df['fedral_holiday'].fillna(False)
ca_df.drop('is_holiday', axis=1, inplace=True)

ga_df = pd.merge(ga_df, holidays['is_holiday'], how='left', left_index=True, right_index=True)
ga_df = add_holidays_past_2021(ga_df)
ga_df['fedral_holiday'] = ga_df['is_holiday'].fillna(False) + ga_df['fedral_holiday'].fillna(False)
ga_df.drop('is_holiday', axis=1, inplace=True)
# Out:
# C:\Users\rohit\AppData\Local\Temp\ipykernel_26688\1299803848.py:3: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ma_df['fedral_holiday'] = ma_df['is_holiday'].fillna(False) + ma_df['fedral_holiday'].fillna(False)
# C:\Users\rohit\AppData\Local\Temp\ipykernel_26688\1299803848.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ca_df['fedral_holiday'] = ca_df['is_holiday'].fillna(False) + ca_df['fedral_holiday'].fillna(False)
# C:\Users\rohit\AppData\Local\Temp\ipykernel_26688\1299803848.py:13: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ga_df['fedral_holiday'] = ga_df['is_holiday'].fillna(False) + ga_df['fedral_holiday'].fillna(False)

# %%
df['fedral_holiday'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[275], line 1
# ----> 1 df['fedral_holiday'].value_counts()
#
# NameError: name 'df' is not defined

# %% [markdown]
# **Add inflation**

# %% [markdown]
# **Add historic overall sales**

# %%
ma_df['Sales 1YA'] = assign_historic_sales(ma_df, year_till=2021)
ma_df['Sales 2YA'] = assign_historic_sales(ma_df, year_till=2020)
ma_df['Sales 3YA'] = assign_historic_sales(ma_df, year_till=2019)

ca_df['Sales 1YA'] = assign_historic_sales(ca_df, year_till=2021)
ca_df['Sales 2YA'] = assign_historic_sales(ca_df, year_till=2020)
ca_df['Sales 3YA'] = assign_historic_sales(ca_df, year_till=2019)

ga_df['Sales 1YA'] = assign_historic_sales(ga_df, year_till=2021)
ga_df['Sales 2YA'] = assign_historic_sales(ga_df, year_till=2020)
ga_df['Sales 3YA'] = assign_historic_sales(ga_df, year_till=2019)

# %%
ca_df

# %% [markdown]
# **Add historic state-wise sales**

# %%
def get_shift_value(year, df, forcast_df=None):
    if forcast_df is None:
        return (df[df.index.year<2023].index[-1] - df[df.index.year<=year].index[-1]).days
    else:
        return (forcast_df.index[-1] - df[df.index.year<=year].index[-1]).days

# %%
def add_category_lags(purchases, df):
    temp_df = purchases[['Category','total_sales']]
    
    temp_df = pd.DataFrame(temp_df.groupby([temp_df.index,'Category'])['total_sales'].sum()).reset_index()
    
    category_features = pd.pivot( temp_df[['Order Date', 'Category', 'total_sales']], index='Order Date', columns='Category', values='total_sales').reset_index().fillna(0)
    
    category_features = category_features.set_index('Order Date')

    scaler = MinMaxScaler()

    scaled_data = scaler.fit_transform(category_features)
    
    pca = PCA(n_components=3,random_state=101)
    
    pca_features = pca.fit_transform(scaled_data)

    category_sales_reduced = pd.DataFrame(pca_features)

    category_sales_reduced.rename(columns={0:'PC1',1:'PC2',2:'PC3'}, inplace=True)

    category_sales_reduced.set_index(df.index, inplace=True)

    category_features = pd.concat([category_sales_reduced, category_sales_reduced.shift(get_shift_value(2021,df)).rename(columns={'PC1':'PC1 1YA','PC2':'PC2 1YA','PC3':'PC3 1YA'}), category_sales_reduced.shift(get_shift_value(2020,df)).rename(columns={'PC1':'PC1 2YA','PC2':'PC2 2YA','PC3':'PC3 2YA'}), category_sales_reduced.shift(get_shift_value(2019,df)).rename(columns={'PC1':'PC1 3YA','PC2':'PC2 3YA','PC3':'PC3 3YA'})], axis=1)

    return pd.merge(df, category_features, left_index=True, right_index=True, how='left')

# %%
ca_df = add_category_lags(ca_purchases.copy(), ca_df.copy())
ma_df = add_category_lags(ma_purchases.copy(), ma_df.copy())
ga_df = add_category_lags(ga_purchases.copy(), ga_df.copy())

# %%
get_null_percentage(ca_df)
# Out:
# total_sales                                  0.000000
# day                                          0.000000
# month                                        0.000000
# year                                         0.000000
# is_weekend                                   0.000000
# day_of_week                                  0.000000
# day_of_year                                  0.000000
# quarter                                      0.000000
# is_month_start                               0.000000
# is_month_end                                 0.000000
# is_year_start                                0.000000
# is_year_end                                  0.000000
# Amazon Events_Amazon Prime Day               0.000000
# Amazon Events_Black Friday                   0.000000
# Amazon Events_Memorial Day Sales             0.000000
# Amazon Events_Mother's Day Deals             0.000000
# Amazon Events_No Events                      0.000000
# Amazon Events_Prime Big Deal Days            0.000000
# Amazon Events_Valentine's Day Promotions     0.000000
# Amazon Events_Year-End Clearance Sale        0.000000
# fedral_holiday                               0.000000
# PC3                                          0.000000
# PC2                                          0.000000
# PC1                                          0.000000
# PC2 1YA                                     19.441402
# PC3 1YA                                     19.441402
# PC1 1YA                                     19.441402
# Sales 1YA                                   19.989047
# PC1 2YA                                     39.430449
# PC2 2YA                                     39.430449
# PC3 2YA                                     39.430449
# Sales 2YA                                   39.978094
# PC2 3YA                                     59.474261
# PC1 3YA                                     59.474261
# PC3 3YA                                     59.474261
# Sales 3YA                                   60.021906
# dtype: float64

# %% [markdown]
# ## Cross Validation

# %% [markdown]
# **generate forcast dataframe**

# %%
feature_columns = list(ca_df.columns)
[feature_columns.remove(column) for column in ['total_sales','PC1','PC2','PC3']]
feature_columns
# Out:
# ['day',
#  'month',
#  'year',
#  'is_weekend',
#  'day_of_week',
#  'day_of_year',
#  'quarter',
#  'is_month_start',
#  'is_month_end',
#  'is_year_start',
#  'is_year_end',
#  'Amazon Events_Amazon Prime Day',
#  'Amazon Events_Black Friday',
#  'Amazon Events_Memorial Day Sales',
#  "Amazon Events_Mother's Day Deals",
#  'Amazon Events_No Events',
#  'Amazon Events_Prime Big Deal Days',
#  "Amazon Events_Valentine's Day Promotions",
#  'Amazon Events_Year-End Clearance Sale',
#  'fedral_holiday',
#  'Sales 1YA',
#  'Sales 2YA',
#  'Sales 3YA',
#  'PC1 1YA',
#  'PC2 1YA',
#  'PC3 1YA',
#  'PC1 2YA',
#  'PC2 2YA',
#  'PC3 2YA',
#  'PC1 3YA',
#  'PC2 3YA',
#  'PC3 3YA']

# %%
ca_forcast_df =  pd.DataFrame(pd.date_range('2023-01-01', '2023-12-31'),columns=['Order Date'])
ma_forcast_df =  pd.DataFrame(pd.date_range('2023-01-01', '2023-12-31'),columns=['Order Date'])
ga_forcast_df =  pd.DataFrame(pd.date_range('2023-01-01', '2023-12-31'),columns=['Order Date'])

# %%
ca_forcast_df = generate_time_features(ca_forcast_df)
ma_forcast_df = generate_time_features(ma_forcast_df)
ga_forcast_df = generate_time_features(ga_forcast_df)

# %%
ca_forcast_df = add_holidays_past_2021(ca_forcast_df)
ma_forcast_df = add_holidays_past_2021(ma_forcast_df)
ga_forcast_df = add_holidays_past_2021(ga_forcast_df)

# %%
ca_forcast_df['fedral_holiday'] = ca_forcast_df['fedral_holiday'].fillna(False)
ma_forcast_df['fedral_holiday'] = ma_forcast_df['fedral_holiday'].fillna(False)
ga_forcast_df['fedral_holiday'] = ga_forcast_df['fedral_holiday'].fillna(False)
# Out:
# C:\Users\rohit\AppData\Local\Temp\ipykernel_26688\2435608788.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ca_forcast_df['fedral_holiday'] = ca_forcast_df['fedral_holiday'].fillna(False)
# C:\Users\rohit\AppData\Local\Temp\ipykernel_26688\2435608788.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ma_forcast_df['fedral_holiday'] = ma_forcast_df['fedral_holiday'].fillna(False)
# C:\Users\rohit\AppData\Local\Temp\ipykernel_26688\2435608788.py:3: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ga_forcast_df['fedral_holiday'] = ga_forcast_df['fedral_holiday'].fillna(False)

# %%
ca_forcast_df = add_amazon_events(ca_forcast_df)
ma_forcast_df = add_amazon_events(ma_forcast_df)
ga_forcast_df = add_amazon_events(ga_forcast_df)

# %%
ca_forcast_df = ca_forcast_df.drop('index', axis=1)
ma_forcast_df = ma_forcast_df.drop('index', axis=1)
ga_forcast_df = ga_forcast_df.drop('index', axis=1)

# %%
ca_df
# Out:
#             total_sales  day  month  year  is_weekend  day_of_week  \
# Order Date
# 2018-01-01      2281.01    1      1  2018       False            0
# 2018-01-02      1710.42    2      1  2018       False            1
# 2018-01-03      1053.32    3      1  2018       False            2
# 2018-01-04      1501.36    4      1  2018       False            3
# 2018-01-05      1188.93    5      1  2018       False            4
# ...                 ...  ...    ...   ...         ...          ...
# 2022-12-27      1508.82   27     12  2022       False            1
# 2022-12-28      1484.50   28     12  2022       False            2
# 2022-12-29      2122.56   29     12  2022       False            3
# 2022-12-30      1451.38   30     12  2022       False            4
# 2022-12-31      1061.83   31     12  2022       False            5
#
#             day_of_year  quarter  is_month_start  is_month_end  ...   PC1 1YA  \
# Order Date                                                      ...
# 2018-01-01            1        1            True         False  ...       NaN
# 2018-01-02            2        1           False         False  ...       NaN
# 2018-01-03            3        1           False         False  ...       NaN
# 2018-01-04            4        1           False         False  ...       NaN
# 2018-01-05            5        1           False         False  ...       NaN
# ...                 ...      ...             ...           ...  ...       ...
# 2022-12-27          361        4           False         False  ...  0.142541
# 2022-12-28          362        4           False         False  ... -0.044509
# 2022-12-29          363        4           False         False  ...  0.443783
# 2022-12-30          364        4           False         False  ...  0.023085
# 2022-12-31          365        4           False          True  ...  0.084257
#
#              PC2 1YA   PC3 1YA   PC1 2YA   PC2 2YA   PC3 2YA   PC1 3YA  \
# Order Date
# 2018-01-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-01-05       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2022-12-27  0.015081 -0.076156  0.137622  0.024886  0.222053 -0.257536
# 2022-12-28 -0.030873  0.080679  0.354607 -0.024591  0.097479  0.064017
# 2022-12-29  0.132661  0.191330  0.015815 -0.147660 -0.064698 -0.112239
# 2022-12-30 -0.034949 -0.090224  0.229570  0.179315  0.134621 -0.058956
# 2022-12-31 -0.060103  0.058477  0.459988  0.383326  0.193611 -0.215386
#
#              PC2 3YA   PC3 3YA  forcasting
# Order Date
# 2018-01-01       NaN       NaN       False
# 2018-01-02       NaN       NaN       False
# 2018-01-03       NaN       NaN       False
# 2018-01-04       NaN       NaN       False
# 2018-01-05       NaN       NaN       False
# ...              ...       ...         ...
# 2022-12-27 -0.041146  0.013322       False
# 2022-12-28 -0.096644 -0.004608       False
# 2022-12-29 -0.154949  0.033027       False
# 2022-12-30  0.073815 -0.064400       False
# 2022-12-31 -0.069517 -0.048412       False
#
# [1826 rows x 37 columns]

# %%
# Add forecasting flag
ca_forcast_df['forcasting'] = True
ma_forcast_df['forcasting'] = True
ga_forcast_df['forcasting'] = True

ca_df['forcasting'] = False
ma_df['forcasting'] = False
ga_df['forcasting'] = False

# Combine historical + forecast
ca_combined_df = pd.concat([ca_df, ca_forcast_df], axis=0)
ma_combined_df = pd.concat([ma_df, ma_forcast_df], axis=0)
ga_combined_df = pd.concat([ga_df, ga_forcast_df], axis=0)

# Assign sales history
ca_combined_df['Sales 1YA'] = assign_historic_sales(ca_combined_df, year_till=2022)
ca_combined_df['Sales 2YA'] = assign_historic_sales(ca_combined_df, year_till=2021)
ca_combined_df['Sales 3YA'] = assign_historic_sales(ca_combined_df, year_till=2020)

ma_combined_df['Sales 1YA'] = assign_historic_sales(ma_combined_df, year_till=2022)
ma_combined_df['Sales 2YA'] = assign_historic_sales(ma_combined_df, year_till=2021)
ma_combined_df['Sales 3YA'] = assign_historic_sales(ma_combined_df, year_till=2020)

ga_combined_df['Sales 1YA'] = assign_historic_sales(ga_combined_df, year_till=2022)
ga_combined_df['Sales 2YA'] = assign_historic_sales(ga_combined_df, year_till=2021)
ga_combined_df['Sales 3YA'] = assign_historic_sales(ga_combined_df, year_till=2020)

# Lag PC columns
ca_combined_df[['PC1 1YA','PC2 1YA','PC3 1YA']] = ca_combined_df[['PC1','PC2','PC3']].shift(get_shift_value(2022, ca_df, ca_forcast_df)-10)
ca_combined_df[['PC1 2YA','PC2 2YA','PC3 2YA']] = ca_combined_df[['PC1','PC2','PC3']].shift(get_shift_value(2021,  ca_df, ca_forcast_df)-10)
ca_combined_df[['PC1 3YA','PC2 3YA','PC3 3YA']] = ca_combined_df[['PC1','PC2','PC3']].shift(get_shift_value(2020,  ca_df, ca_forcast_df)-10)

ma_combined_df[['PC1 1YA','PC2 1YA','PC3 1YA']] = ma_combined_df[['PC1','PC2','PC3']].shift(get_shift_value(2022, ma_df, ma_forcast_df)-10)
ma_combined_df[['PC1 2YA','PC2 2YA','PC3 2YA']] = ma_combined_df[['PC1','PC2','PC3']].shift(get_shift_value(2021, ma_df, ma_forcast_df)-10)
ma_combined_df[['PC1 3YA','PC2 3YA','PC3 3YA']] = ma_combined_df[['PC1','PC2','PC3']].shift(get_shift_value(2020, ma_df, ma_forcast_df)-10)

ga_combined_df[['PC1 1YA','PC2 1YA','PC3 1YA']] = ga_combined_df[['PC1','PC2','PC3']].shift(get_shift_value(2022, ga_df, ga_forcast_df)-10)
ga_combined_df[['PC1 2YA','PC2 2YA','PC3 2YA']] = ga_combined_df[['PC1','PC2','PC3']].shift(get_shift_value(2021, ga_df, ga_forcast_df)-10)
ga_combined_df[['PC1 3YA','PC2 3YA','PC3 3YA']] = ga_combined_df[['PC1','PC2','PC3']].shift(get_shift_value(2020, ga_df, ga_forcast_df)-10)

# Assign forecast data back
forecast_cols = ['Sales 1YA', 'Sales 2YA', 'Sales 3YA',
                 'PC1 1YA','PC2 1YA','PC3 1YA',
                 'PC1 2YA','PC2 2YA','PC3 2YA',
                 'PC1 3YA','PC2 3YA','PC3 3YA']

ca_forcast_df[forecast_cols] = ca_combined_df[ca_combined_df['forcasting'] == True][forecast_cols].values
ma_forcast_df[forecast_cols] = ma_combined_df[ma_combined_df['forcasting'] == True][forecast_cols].values
ga_forcast_df[forecast_cols] = ga_combined_df[ga_combined_df['forcasting'] == True][forecast_cols].values

# Drop flag
ca_forcast_df = ca_forcast_df.drop('forcasting', axis=1)
ma_forcast_df = ma_forcast_df.drop('forcasting', axis=1)
ga_forcast_df = ga_forcast_df.drop('forcasting', axis=1)

ca_df = ca_df.drop('forcasting', axis=1)
ma_df = ma_df.drop('forcasting', axis=1)
ga_df = ga_df.drop('forcasting', axis=1)

# %%
ca_forcast_df = ca_forcast_df[feature_columns]
ma_forcast_df = ma_forcast_df[feature_columns]
ga_forcast_df = ga_forcast_df[feature_columns]

# %%
ca_forcast_df
# Out:
#             day  month  year  is_weekend  day_of_week  day_of_year  quarter  \
# Order Date
# 2023-01-01    1      1  2023        True            6            1        1
# 2023-01-02    2      1  2023       False            0            2        1
# 2023-01-03    3      1  2023       False            1            3        1
# 2023-01-04    4      1  2023       False            2            4        1
# 2023-01-05    5      1  2023       False            3            5        1
# ...         ...    ...   ...         ...          ...          ...      ...
# 2023-12-27   27     12  2023       False            2          361        4
# 2023-12-28   28     12  2023       False            3          362        4
# 2023-12-29   29     12  2023       False            4          363        4
# 2023-12-30   30     12  2023       False            5          364        4
# 2023-12-31   31     12  2023        True            6          365        4
#
#             is_month_start  is_month_end  is_year_start  ...  Sales 3YA  \
# Order Date                                               ...
# 2023-01-01            True         False           True  ...    2688.41
# 2023-01-02           False         False          False  ...    2239.30
# 2023-01-03           False         False          False  ...    1727.67
# 2023-01-04           False         False          False  ...    2422.77
# 2023-01-05           False         False          False  ...    1026.17
# ...                    ...           ...            ...  ...        ...
# 2023-12-27           False         False          False  ...    2883.14
# 2023-12-28           False         False          False  ...    2891.85
# 2023-12-29           False         False          False  ...    3035.74
# 2023-12-30           False         False          False  ...    2898.60
# 2023-12-31           False          True          False  ...    2070.13
#
#              PC1 1YA   PC2 1YA   PC3 1YA   PC1 2YA   PC2 2YA   PC3 2YA  \
# Order Date
# 2023-01-01 -0.105176 -0.007257  0.011129 -0.033283  0.085444  0.023546
# 2023-01-02  0.094978  0.119305  0.070811  0.024386 -0.035400  0.070328
# 2023-01-03  0.187456  0.014040 -0.020315  0.128985 -0.089676  0.014714
# 2023-01-04 -0.049206  0.028003 -0.148841  0.235749  0.078987 -0.069394
# 2023-01-05  0.103064 -0.087345  0.121954  0.065011  0.006317 -0.010026
# ...              ...       ...       ...       ...       ...       ...
# 2023-12-27       NaN       NaN       NaN  0.142541  0.015081 -0.076156
# 2023-12-28       NaN       NaN       NaN -0.044509 -0.030873  0.080679
# 2023-12-29       NaN       NaN       NaN  0.443783  0.132661  0.191330
# 2023-12-30       NaN       NaN       NaN  0.023085 -0.034949 -0.090224
# 2023-12-31       NaN       NaN       NaN  0.084257 -0.060103  0.058477
#
#              PC1 3YA   PC2 3YA   PC3 3YA
# Order Date
# 2023-01-01 -0.090643  0.149654 -0.057485
# 2023-01-02 -0.232275 -0.074538  0.008150
# 2023-01-03 -0.107966 -0.130035 -0.073201
# 2023-01-04 -0.191607 -0.093524 -0.052243
# 2023-01-05 -0.080150 -0.075757  0.012610
# ...              ...       ...       ...
# 2023-12-27  0.137622  0.024886  0.222053
# 2023-12-28  0.354607 -0.024591  0.097479
# 2023-12-29  0.015815 -0.147660 -0.064698
# 2023-12-30  0.229570  0.179315  0.134621
# 2023-12-31  0.459988  0.383326  0.193611
#
# [365 rows x 32 columns]

# %%
ca_df[feature_columns]
# Out:
#             day  month  year  is_weekend  day_of_week  day_of_year  quarter  \
# Order Date
# 2018-01-01    1      1  2018       False            0            1        1
# 2018-01-02    2      1  2018       False            1            2        1
# 2018-01-03    3      1  2018       False            2            3        1
# 2018-01-04    4      1  2018       False            3            4        1
# 2018-01-05    5      1  2018       False            4            5        1
# ...         ...    ...   ...         ...          ...          ...      ...
# 2022-12-27   27     12  2022       False            1          361        4
# 2022-12-28   28     12  2022       False            2          362        4
# 2022-12-29   29     12  2022       False            3          363        4
# 2022-12-30   30     12  2022       False            4          364        4
# 2022-12-31   31     12  2022       False            5          365        4
#
#             is_month_start  is_month_end  is_year_start  ...  Sales 3YA  \
# Order Date                                               ...
# 2018-01-01            True         False           True  ...        NaN
# 2018-01-02           False         False          False  ...        NaN
# 2018-01-03           False         False          False  ...        NaN
# 2018-01-04           False         False          False  ...        NaN
# 2018-01-05           False         False          False  ...        NaN
# ...                    ...           ...            ...  ...        ...
# 2022-12-27           False         False          False  ...    1779.99
# 2022-12-28           False         False          False  ...    1661.71
# 2022-12-29           False         False          False  ...    1603.16
# 2022-12-30           False         False          False  ...    2007.28
# 2022-12-31           False          True          False  ...    1872.59
#
#              PC1 1YA   PC2 1YA   PC3 1YA   PC1 2YA   PC2 2YA   PC3 2YA  \
# Order Date
# 2018-01-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-01-05       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2022-12-27  0.142541  0.015081 -0.076156  0.137622  0.024886  0.222053
# 2022-12-28 -0.044509 -0.030873  0.080679  0.354607 -0.024591  0.097479
# 2022-12-29  0.443783  0.132661  0.191330  0.015815 -0.147660 -0.064698
# 2022-12-30  0.023085 -0.034949 -0.090224  0.229570  0.179315  0.134621
# 2022-12-31  0.084257 -0.060103  0.058477  0.459988  0.383326  0.193611
#
#              PC1 3YA   PC2 3YA   PC3 3YA
# Order Date
# 2018-01-01       NaN       NaN       NaN
# 2018-01-02       NaN       NaN       NaN
# 2018-01-03       NaN       NaN       NaN
# 2018-01-04       NaN       NaN       NaN
# 2018-01-05       NaN       NaN       NaN
# ...              ...       ...       ...
# 2022-12-27 -0.257536 -0.041146  0.013322
# 2022-12-28  0.064017 -0.096644 -0.004608
# 2022-12-29 -0.112239 -0.154949  0.033027
# 2022-12-30 -0.058956  0.073815 -0.064400
# 2022-12-31 -0.215386 -0.069517 -0.048412
#
# [1826 rows x 32 columns]

# %% [markdown]
# **cross validate**

# %%
def cross_validate(df, forcastdf, feature_columns):
    scores = []
    preds = []
    feature_importances = []
    sales = []
    tss = TimeSeriesSplit(n_splits=3, test_size=365, gap=0)
    feature_columns = sorted(feature_columns)
    for train_idx, val_idx in tss.split(df):
        scaler = StandardScaler()
        train = df.iloc[train_idx]
        test = df.iloc[val_idx]
        X_train = train[feature_columns]
        y_train = train['total_sales']
        X_test = test[feature_columns]
        y_test = test['total_sales']
        reg_model = xgb.XGBRegressor(base_score=0.5, booster='gblinear',  n_estimators=1000, early_stopping_rounds=50, objective='reg:squarederror', learning_rate=0.01)
        reg_model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_test, y_test)], verbose=True)
        feature_importances.append(reg_model.feature_importances_)
        y_preds = reg_model.predict(X_train)
        score = np.sqrt(mean_squared_error(y_train, y_preds))
        print('train: ',score)
        ds =  pd.concat([y_train.reset_index(),pd.Series(y_preds)], axis=1)
        ds = ds.set_index('Order Date')
        ds['total_sales'].plot(label='true data')
        ds[0].plot(label='prediction')
        plt.legend()
        plt.show()
        y_preds = reg_model.predict(X_test)
        ds =  pd.concat([y_test.reset_index(),pd.Series(y_preds)], axis=1)
        ds = ds.set_index('Order Date')
        ds['total_sales'].plot(label='true data')
        ds[0].plot(label='prediction')
        plt.legend()
        plt.show()
        forcast_preds = reg_model.predict(forcastdf[feature_columns])
        ds =  pd.Series(forcast_preds, index=forcastdf.index)
        ds.plot(label='prediction')
        plt.legend()
        plt.show()
        
        preds.append(y_preds)
        score = np.sqrt(mean_squared_error(y_test, y_preds))
        print('test: ',score)
        scores.append(score)

    return preds, scores, feature_importances

# %%
preds, scores, feature_importances = cross_validate(ga_df, ga_forcast_df, feature_columns)
# Out:
# [0]	validation_0-rmse:459.88833	validation_1-rmse:741.87185
# [1]	validation_0-rmse:440.31271	validation_1-rmse:707.56222
# [2]	validation_0-rmse:422.97622	validation_1-rmse:676.55745
# [3]	validation_0-rmse:407.65669	validation_1-rmse:648.61834
# [4]	validation_0-rmse:394.15805	validation_1-rmse:623.47277
# [5]	validation_0-rmse:382.27848	validation_1-rmse:600.82508
# [6]	validation_0-rmse:371.85651	validation_1-rmse:580.44927
# [7]	validation_0-rmse:362.77369	validation_1-rmse:562.16141
# [8]	validation_0-rmse:354.83814	validation_1-rmse:545.83140
# [9]	validation_0-rmse:347.92830	validation_1-rmse:531.12930
# [10]	validation_0-rmse:341.92115	validation_1-rmse:517.96988
# [11]	validation_0-rmse:336.70253	validation_1-rmse:506.17538
# [12]	validation_0-rmse:332.16169	validation_1-rmse:495.57635
# [13]	validation_0-rmse:328.20997	validation_1-rmse:486.06274
# [14]	validation_0-rmse:324.79535	validation_1-rmse:477.58061
# [15]	validation_0-rmse:321.83486	validation_1-rmse:469.98922
# [16]	validation_0-rmse:319.26099	validation_1-rmse:463.18056
# [17]	validation_0-rmse:317.02213	validation_1-rmse:457.05932
# [18]	validation_0-rmse:315.07338	validation_1-rmse:451.55727
# [19]	validation_0-rmse:313.37202	validation_1-rmse:446.60915
# [20]	validation_0-rmse:311.87818	validation_1-rmse:442.12793
# [21]	validation_0-rmse:310.56586	validation_1-rmse:438.08752
# [22]	validation_0-rmse:309.41269	validation_1-rmse:434.44258
# [23]	validation_0-rmse:308.39467	validation_1-rmse:431.15354
# [24]	validation_0-rmse:307.49291	validation_1-rmse:428.17154
# [25]	validation_0-rmse:306.69074	validation_1-rmse:425.46171
# [26]	validation_0-rmse:305.97540	validation_1-rmse:423.00716
# [27]	validation_0-rmse:305.33146	validation_1-rmse:420.76681
# [28]	validation_0-rmse:304.74976	validation_1-rmse:418.72095
# [29]	validation_0-rmse:304.22231	validation_1-rmse:416.85348
# [30]	validation_0-rmse:303.74242	validation_1-rmse:415.14696
# [31]	validation_0-rmse:303.30274	validation_1-rmse:413.58228
# [32]	validation_0-rmse:302.89759	validation_1-rmse:412.14682
# [33]	validation_0-rmse:302.52331	validation_1-rmse:410.82744
# [34]	validation_0-rmse:302.17547	validation_1-rmse:409.61077
# [35]	validation_0-rmse:301.85085	validation_1-rmse:408.49122
# [36]	validation_0-rmse:301.54613	validation_1-rmse:407.45711
# [37]	validation_0-rmse:301.25945	validation_1-rmse:406.50195
# [38]	validation_0-rmse:300.98807	validation_1-rmse:405.61741
# [39]	validation_0-rmse:300.73053	validation_1-rmse:404.79572
# [40]	validation_0-rmse:300.48510	validation_1-rmse:404.03209
# [41]	validation_0-rmse:300.25065	validation_1-rmse:403.32262
# [42]	validation_0-rmse:300.02613	validation_1-rmse:402.66395
# [43]	validation_0-rmse:299.81053	validation_1-rmse:402.05059
# [44]	validation_0-rmse:299.60291	validation_1-rmse:401.47933
# [45]	validation_0-rmse:299.40265	validation_1-rmse:400.94756
# [46]	validation_0-rmse:299.20903	validation_1-rmse:400.45172
# [47]	validation_0-rmse:299.02158	validation_1-rmse:399.98696
# [48]	validation_0-rmse:298.83987	validation_1-rmse:399.55753
# [49]	validation_0-rmse:298.66340	validation_1-rmse:399.15607
# [50]	validation_0-rmse:298.49193	validation_1-rmse:398.78245
# [51]	validation_0-rmse:298.32506	validation_1-rmse:398.43675
# [52]	validation_0-rmse:298.16254	validation_1-rmse:398.11388
# [53]	validation_0-rmse:298.00420	validation_1-rmse:397.81016
# [54]	validation_0-rmse:297.84977	validation_1-rmse:397.53504
# [55]	validation_0-rmse:297.69907	validation_1-rmse:397.28081
# [56]	validation_0-rmse:297.55203	validation_1-rmse:397.04730
# [57]	validation_0-rmse:297.40841	validation_1-rmse:396.82948
# [58]	validation_0-rmse:297.26806	validation_1-rmse:396.63464
# [59]	validation_0-rmse:297.13090	validation_1-rmse:396.45632
# [60]	validation_0-rmse:296.99677	validation_1-rmse:396.30149
# [61]	validation_0-rmse:296.86558	validation_1-rmse:396.16162
# [62]	validation_0-rmse:296.73730	validation_1-rmse:396.04070
# [63]	validation_0-rmse:296.61175	validation_1-rmse:395.93753
# [64]	validation_0-rmse:296.48893	validation_1-rmse:395.85090
# [65]	validation_0-rmse:296.36863	validation_1-rmse:395.78320
# [66]	validation_0-rmse:296.25093	validation_1-rmse:395.73142
# [67]	validation_0-rmse:296.13565	validation_1-rmse:395.69428
# [68]	validation_0-rmse:296.02282	validation_1-rmse:395.67230
# [69]	validation_0-rmse:295.91232	validation_1-rmse:395.66868
# [70]	validation_0-rmse:295.80412	validation_1-rmse:395.67903
# [71]	validation_0-rmse:295.69818	validation_1-rmse:395.70656
# [72]	validation_0-rmse:295.59436	validation_1-rmse:395.75160
# [73]	validation_0-rmse:295.49271	validation_1-rmse:395.81225
# [74]	validation_0-rmse:295.39308	validation_1-rmse:395.88697
# [75]	validation_0-rmse:295.29554	validation_1-rmse:395.97964
# [76]	validation_0-rmse:295.19990	validation_1-rmse:396.08882
# [77]	validation_0-rmse:295.10621	validation_1-rmse:396.21333
# [78]	validation_0-rmse:295.01446	validation_1-rmse:396.35313
# [79]	validation_0-rmse:294.92451	validation_1-rmse:396.50930
# [80]	validation_0-rmse:294.83641	validation_1-rmse:396.68261
# [81]	validation_0-rmse:294.75006	validation_1-rmse:396.86968
# [82]	validation_0-rmse:294.66546	validation_1-rmse:397.07177
# [83]	validation_0-rmse:294.58256	validation_1-rmse:397.28899
# [84]	validation_0-rmse:294.50133	validation_1-rmse:397.52302
# [85]	validation_0-rmse:294.42168	validation_1-rmse:397.77325
# [86]	validation_0-rmse:294.34362	validation_1-rmse:398.03753
# [87]	validation_0-rmse:294.26707	validation_1-rmse:398.31954
# [88]	validation_0-rmse:294.19209	validation_1-rmse:398.61667
# [89]	validation_0-rmse:294.11859	validation_1-rmse:398.93336
# [90]	validation_0-rmse:294.04649	validation_1-rmse:399.26194
# [91]	validation_0-rmse:293.97582	validation_1-rmse:399.60926
# [92]	validation_0-rmse:293.90661	validation_1-rmse:399.96812
# [93]	validation_0-rmse:293.83874	validation_1-rmse:400.34624
# [94]	validation_0-rmse:293.77220	validation_1-rmse:400.73711
# [95]	validation_0-rmse:293.70696	validation_1-rmse:401.14506
# [96]	validation_0-rmse:293.64301	validation_1-rmse:401.56566
# [97]	validation_0-rmse:293.58032	validation_1-rmse:402.00262
# [98]	validation_0-rmse:293.51883	validation_1-rmse:402.45987
# [99]	validation_0-rmse:293.45855	validation_1-rmse:402.92748
# [100]	validation_0-rmse:293.39945	validation_1-rmse:403.41057
# [101]	validation_0-rmse:293.34150	validation_1-rmse:403.90874
# [102]	validation_0-rmse:293.28469	validation_1-rmse:404.42090
# [103]	validation_0-rmse:293.22895	validation_1-rmse:404.94781
# [104]	validation_0-rmse:293.17431	validation_1-rmse:405.49782
# [105]	validation_0-rmse:293.12070	validation_1-rmse:406.05421
# [106]	validation_0-rmse:293.06814	validation_1-rmse:406.63066
# [107]	validation_0-rmse:293.01658	validation_1-rmse:407.21979
# [108]	validation_0-rmse:292.96602	validation_1-rmse:407.82161
# [109]	validation_0-rmse:292.91643	validation_1-rmse:408.43758
# [110]	validation_0-rmse:292.86777	validation_1-rmse:409.06758
# [111]	validation_0-rmse:292.82005	validation_1-rmse:409.72026
# [112]	validation_0-rmse:292.77322	validation_1-rmse:410.37740
# [113]	validation_0-rmse:292.72729	validation_1-rmse:411.04948
# [114]	validation_0-rmse:292.68223	validation_1-rmse:411.73538
# [115]	validation_0-rmse:292.63804	validation_1-rmse:412.43741
# [116]	validation_0-rmse:292.59468	validation_1-rmse:413.14983
# [117]	validation_0-rmse:292.55212	validation_1-rmse:413.87629
# [118]	validation_0-rmse:292.51037	validation_1-rmse:414.61792
# [119]	validation_0-rmse:292.46941	validation_1-rmse:415.37084
# train:  292.4694089228331
# test:  415.37084081330556
# [0]	validation_0-rmse:564.75253	validation_1-rmse:1042.32084
# [1]	validation_0-rmse:535.29521	validation_1-rmse:1002.09056
# [2]	validation_0-rmse:509.24100	validation_1-rmse:965.79078
# [3]	validation_0-rmse:486.28118	validation_1-rmse:933.17135
# [4]	validation_0-rmse:466.14150	validation_1-rmse:903.96435
# [5]	validation_0-rmse:448.52564	validation_1-rmse:877.63911
# [6]	validation_0-rmse:433.12282	validation_1-rmse:853.82498
# [7]	validation_0-rmse:419.70145	validation_1-rmse:832.41920
# [8]	validation_0-rmse:408.07875	validation_1-rmse:813.23315
# [9]	validation_0-rmse:398.01905	validation_1-rmse:795.95767
# [10]	validation_0-rmse:389.31688	validation_1-rmse:780.34102
# [11]	validation_0-rmse:381.80446	validation_1-rmse:766.33036
# [12]	validation_0-rmse:375.32531	validation_1-rmse:753.72645
# [13]	validation_0-rmse:369.72515	validation_1-rmse:742.29498
# [14]	validation_0-rmse:364.91060	validation_1-rmse:732.00272
# [15]	validation_0-rmse:360.74267	validation_1-rmse:722.70762
# [16]	validation_0-rmse:357.15266	validation_1-rmse:714.30345
# [17]	validation_0-rmse:354.03790	validation_1-rmse:706.67070
# [18]	validation_0-rmse:351.33650	validation_1-rmse:699.75668
# [19]	validation_0-rmse:348.99182	validation_1-rmse:693.46977
# [20]	validation_0-rmse:346.95340	validation_1-rmse:687.78277
# [21]	validation_0-rmse:345.16497	validation_1-rmse:682.59662
# [22]	validation_0-rmse:343.59915	validation_1-rmse:677.88066
# [23]	validation_0-rmse:342.21265	validation_1-rmse:673.58836
# [24]	validation_0-rmse:340.98563	validation_1-rmse:669.68289
# [25]	validation_0-rmse:339.89209	validation_1-rmse:666.08126
# [26]	validation_0-rmse:338.91077	validation_1-rmse:662.79716
# [27]	validation_0-rmse:338.02992	validation_1-rmse:659.79774
# [28]	validation_0-rmse:337.23150	validation_1-rmse:657.03680
# [29]	validation_0-rmse:336.50401	validation_1-rmse:654.51553
# [30]	validation_0-rmse:335.83706	validation_1-rmse:652.18576
# [31]	validation_0-rmse:335.22252	validation_1-rmse:650.04621
# [32]	validation_0-rmse:334.65272	validation_1-rmse:648.07088
# [33]	validation_0-rmse:334.12160	validation_1-rmse:646.25040
# [34]	validation_0-rmse:333.62468	validation_1-rmse:644.55957
# [35]	validation_0-rmse:333.15738	validation_1-rmse:643.00321
# [36]	validation_0-rmse:332.71595	validation_1-rmse:641.54886
# [37]	validation_0-rmse:332.29706	validation_1-rmse:640.20338
# [38]	validation_0-rmse:331.89813	validation_1-rmse:638.94743
# [39]	validation_0-rmse:331.51719	validation_1-rmse:637.77806
# [40]	validation_0-rmse:331.15220	validation_1-rmse:636.69203
# [41]	validation_0-rmse:330.80154	validation_1-rmse:635.67268
# [42]	validation_0-rmse:330.46404	validation_1-rmse:634.71635
# [43]	validation_0-rmse:330.13848	validation_1-rmse:633.81521
# [44]	validation_0-rmse:329.82379	validation_1-rmse:632.97228
# [45]	validation_0-rmse:329.51913	validation_1-rmse:632.18103
# [46]	validation_0-rmse:329.22396	validation_1-rmse:631.43165
# [47]	validation_0-rmse:328.93734	validation_1-rmse:630.73103
# [48]	validation_0-rmse:328.65882	validation_1-rmse:630.06464
# [49]	validation_0-rmse:328.38786	validation_1-rmse:629.43751
# [50]	validation_0-rmse:328.12410	validation_1-rmse:628.83693
# [51]	validation_0-rmse:327.86716	validation_1-rmse:628.27614
# [52]	validation_0-rmse:327.61673	validation_1-rmse:627.73757
# [53]	validation_0-rmse:327.37254	validation_1-rmse:627.22209
# [54]	validation_0-rmse:327.13414	validation_1-rmse:626.73667
# [55]	validation_0-rmse:326.90130	validation_1-rmse:626.27384
# [56]	validation_0-rmse:326.67413	validation_1-rmse:625.82343
# [57]	validation_0-rmse:326.45221	validation_1-rmse:625.39451
# [58]	validation_0-rmse:326.23526	validation_1-rmse:624.97833
# [59]	validation_0-rmse:326.02331	validation_1-rmse:624.58560
# [60]	validation_0-rmse:325.81645	validation_1-rmse:624.20685
# [61]	validation_0-rmse:325.61391	validation_1-rmse:623.84526
# [62]	validation_0-rmse:325.41601	validation_1-rmse:623.49328
# [63]	validation_0-rmse:325.22249	validation_1-rmse:623.15332
# [64]	validation_0-rmse:325.03328	validation_1-rmse:622.82834
# [65]	validation_0-rmse:324.84819	validation_1-rmse:622.51504
# [66]	validation_0-rmse:324.66711	validation_1-rmse:622.21136
# [67]	validation_0-rmse:324.49003	validation_1-rmse:621.91465
# [68]	validation_0-rmse:324.31679	validation_1-rmse:621.62825
# [69]	validation_0-rmse:324.14725	validation_1-rmse:621.35077
# [70]	validation_0-rmse:323.98143	validation_1-rmse:621.08101
# [71]	validation_0-rmse:323.81919	validation_1-rmse:620.81891
# [72]	validation_0-rmse:323.66039	validation_1-rmse:620.56613
# [73]	validation_0-rmse:323.50488	validation_1-rmse:620.32313
# [74]	validation_0-rmse:323.35284	validation_1-rmse:620.08139
# [75]	validation_0-rmse:323.20402	validation_1-rmse:619.84702
# [76]	validation_0-rmse:323.05832	validation_1-rmse:619.62278
# [77]	validation_0-rmse:322.91585	validation_1-rmse:619.40072
# [78]	validation_0-rmse:322.77627	validation_1-rmse:619.18173
# [79]	validation_0-rmse:322.63974	validation_1-rmse:618.97659
# [80]	validation_0-rmse:322.50608	validation_1-rmse:618.77367
# [81]	validation_0-rmse:322.37532	validation_1-rmse:618.57794
# [82]	validation_0-rmse:322.24730	validation_1-rmse:618.38922
# [83]	validation_0-rmse:322.12194	validation_1-rmse:618.20345
# [84]	validation_0-rmse:321.99912	validation_1-rmse:618.02113
# [85]	validation_0-rmse:321.87896	validation_1-rmse:617.84482
# [86]	validation_0-rmse:321.76134	validation_1-rmse:617.67555
# [87]	validation_0-rmse:321.64622	validation_1-rmse:617.51269
# [88]	validation_0-rmse:321.53352	validation_1-rmse:617.35209
# [89]	validation_0-rmse:321.42321	validation_1-rmse:617.19477
# [90]	validation_0-rmse:321.31519	validation_1-rmse:617.04249
# [91]	validation_0-rmse:321.20946	validation_1-rmse:616.89486
# [92]	validation_0-rmse:321.10590	validation_1-rmse:616.75129
# [93]	validation_0-rmse:321.00448	validation_1-rmse:616.61530
# [94]	validation_0-rmse:320.90520	validation_1-rmse:616.48183
# [95]	validation_0-rmse:320.80802	validation_1-rmse:616.35416
# [96]	validation_0-rmse:320.71284	validation_1-rmse:616.22842
# [97]	validation_0-rmse:320.61964	validation_1-rmse:616.10447
# [98]	validation_0-rmse:320.52840	validation_1-rmse:615.98879
# [99]	validation_0-rmse:320.43905	validation_1-rmse:615.87801
# [100]	validation_0-rmse:320.35152	validation_1-rmse:615.77046
# [101]	validation_0-rmse:320.26580	validation_1-rmse:615.66646
# [102]	validation_0-rmse:320.18186	validation_1-rmse:615.56729
# [103]	validation_0-rmse:320.09965	validation_1-rmse:615.47155
# [104]	validation_0-rmse:320.01913	validation_1-rmse:615.38141
# [105]	validation_0-rmse:319.94023	validation_1-rmse:615.29115
# [106]	validation_0-rmse:319.86294	validation_1-rmse:615.20592
# [107]	validation_0-rmse:319.78723	validation_1-rmse:615.12498
# [108]	validation_0-rmse:319.71307	validation_1-rmse:615.04771
# [109]	validation_0-rmse:319.64043	validation_1-rmse:614.97480
# [110]	validation_0-rmse:319.56929	validation_1-rmse:614.90550
# [111]	validation_0-rmse:319.49958	validation_1-rmse:614.84122
# [112]	validation_0-rmse:319.43128	validation_1-rmse:614.78139
# [113]	validation_0-rmse:319.36436	validation_1-rmse:614.72293
# [114]	validation_0-rmse:319.29881	validation_1-rmse:614.66920
# [115]	validation_0-rmse:319.23457	validation_1-rmse:614.61826
# [116]	validation_0-rmse:319.17166	validation_1-rmse:614.57211
# [117]	validation_0-rmse:319.10995	validation_1-rmse:614.53203
# [118]	validation_0-rmse:319.04953	validation_1-rmse:614.49050
# [119]	validation_0-rmse:318.99031	validation_1-rmse:614.45412
# [120]	validation_0-rmse:318.93227	validation_1-rmse:614.42018
# [121]	validation_0-rmse:318.87539	validation_1-rmse:614.38915
# [122]	validation_0-rmse:318.81965	validation_1-rmse:614.36365
# [123]	validation_0-rmse:318.76501	validation_1-rmse:614.34525
# [124]	validation_0-rmse:318.71148	validation_1-rmse:614.32470
# [125]	validation_0-rmse:318.65900	validation_1-rmse:614.30659
# [126]	validation_0-rmse:318.60756	validation_1-rmse:614.29753
# [127]	validation_0-rmse:318.55715	validation_1-rmse:614.28715
# [128]	validation_0-rmse:318.50773	validation_1-rmse:614.28188
# [129]	validation_0-rmse:318.45930	validation_1-rmse:614.27969
# [130]	validation_0-rmse:318.41179	validation_1-rmse:614.27702
# [131]	validation_0-rmse:318.36524	validation_1-rmse:614.27921
# [132]	validation_0-rmse:318.31960	validation_1-rmse:614.28459
# [133]	validation_0-rmse:318.27484	validation_1-rmse:614.29134
# [134]	validation_0-rmse:318.23097	validation_1-rmse:614.30406
# [135]	validation_0-rmse:318.18792	validation_1-rmse:614.32198
# [136]	validation_0-rmse:318.14574	validation_1-rmse:614.33863
# [137]	validation_0-rmse:318.10438	validation_1-rmse:614.35849
# [138]	validation_0-rmse:318.06381	validation_1-rmse:614.38125
# [139]	validation_0-rmse:318.02403	validation_1-rmse:614.40504
# [140]	validation_0-rmse:317.98500	validation_1-rmse:614.43173
# [141]	validation_0-rmse:317.94673	validation_1-rmse:614.46109
# [142]	validation_0-rmse:317.90921	validation_1-rmse:614.49595
# [143]	validation_0-rmse:317.87239	validation_1-rmse:614.53196
# [144]	validation_0-rmse:317.83628	validation_1-rmse:614.57162
# [145]	validation_0-rmse:317.80085	validation_1-rmse:614.61384
# [146]	validation_0-rmse:317.76610	validation_1-rmse:614.65795
# [147]	validation_0-rmse:317.73200	validation_1-rmse:614.70366
# [148]	validation_0-rmse:317.69857	validation_1-rmse:614.75190
# [149]	validation_0-rmse:317.66575	validation_1-rmse:614.80266
# [150]	validation_0-rmse:317.63353	validation_1-rmse:614.85601
# [151]	validation_0-rmse:317.60195	validation_1-rmse:614.91149
# [152]	validation_0-rmse:317.57093	validation_1-rmse:614.96925
# [153]	validation_0-rmse:317.54049	validation_1-rmse:615.03036
# [154]	validation_0-rmse:317.51064	validation_1-rmse:615.09503
# [155]	validation_0-rmse:317.48133	validation_1-rmse:615.15856
# [156]	validation_0-rmse:317.45256	validation_1-rmse:615.22668
# [157]	validation_0-rmse:317.42432	validation_1-rmse:615.29605
# [158]	validation_0-rmse:317.39659	validation_1-rmse:615.36667
# [159]	validation_0-rmse:317.36937	validation_1-rmse:615.43914
# [160]	validation_0-rmse:317.34267	validation_1-rmse:615.51447
# [161]	validation_0-rmse:317.31645	validation_1-rmse:615.59163
# [162]	validation_0-rmse:317.29069	validation_1-rmse:615.67030
# [163]	validation_0-rmse:317.26539	validation_1-rmse:615.75062
# [164]	validation_0-rmse:317.24058	validation_1-rmse:615.83350
# [165]	validation_0-rmse:317.21619	validation_1-rmse:615.91684
# [166]	validation_0-rmse:317.19224	validation_1-rmse:616.00341
# [167]	validation_0-rmse:317.16873	validation_1-rmse:616.09264
# [168]	validation_0-rmse:317.14564	validation_1-rmse:616.18439
# [169]	validation_0-rmse:317.12296	validation_1-rmse:616.27684
# [170]	validation_0-rmse:317.10069	validation_1-rmse:616.37083
# [171]	validation_0-rmse:317.07881	validation_1-rmse:616.46643
# [172]	validation_0-rmse:317.05731	validation_1-rmse:616.56364
# [173]	validation_0-rmse:317.03618	validation_1-rmse:616.66360
# [174]	validation_0-rmse:317.01542	validation_1-rmse:616.76302
# [175]	validation_0-rmse:316.99502	validation_1-rmse:616.86312
# [176]	validation_0-rmse:316.97499	validation_1-rmse:616.96638
# [177]	validation_0-rmse:316.95531	validation_1-rmse:617.07090
# [178]	validation_0-rmse:316.93597	validation_1-rmse:617.17727
# [179]	validation_0-rmse:316.91696	validation_1-rmse:617.28511
# train:  316.8982587299194
# test:  617.3952883175907
# [0]	validation_0-rmse:705.53739	validation_1-rmse:847.28858
# [1]	validation_0-rmse:665.55183	validation_1-rmse:793.94541
# [2]	validation_0-rmse:630.37651	validation_1-rmse:746.87651
# [3]	validation_0-rmse:599.43929	validation_1-rmse:705.45656
# [4]	validation_0-rmse:572.35797	validation_1-rmse:669.43635
# [5]	validation_0-rmse:548.67752	validation_1-rmse:638.04394
# [6]	validation_0-rmse:528.10212	validation_1-rmse:610.87343
# [7]	validation_0-rmse:510.22791	validation_1-rmse:587.53355
# [8]	validation_0-rmse:494.73962	validation_1-rmse:567.51000
# [9]	validation_0-rmse:481.33618	validation_1-rmse:550.47381
# [10]	validation_0-rmse:469.82116	validation_1-rmse:536.14897
# [11]	validation_0-rmse:459.89721	validation_1-rmse:524.10342
# [12]	validation_0-rmse:451.36991	validation_1-rmse:514.12984
# [13]	validation_0-rmse:444.01371	validation_1-rmse:505.82101
# [14]	validation_0-rmse:437.69613	validation_1-rmse:499.03824
# [15]	validation_0-rmse:432.23998	validation_1-rmse:493.51188
# [16]	validation_0-rmse:427.52916	validation_1-rmse:489.03579
# [17]	validation_0-rmse:423.45439	validation_1-rmse:485.48343
# [18]	validation_0-rmse:419.93413	validation_1-rmse:482.69062
# [19]	validation_0-rmse:416.87380	validation_1-rmse:480.53098
# [20]	validation_0-rmse:414.20293	validation_1-rmse:478.89745
# [21]	validation_0-rmse:411.85844	validation_1-rmse:477.69111
# [22]	validation_0-rmse:409.79723	validation_1-rmse:476.83653
# [23]	validation_0-rmse:407.96683	validation_1-rmse:476.27374
# [24]	validation_0-rmse:406.34055	validation_1-rmse:475.95027
# [25]	validation_0-rmse:404.88559	validation_1-rmse:475.81978
# [26]	validation_0-rmse:403.57372	validation_1-rmse:475.83836
# [27]	validation_0-rmse:402.38629	validation_1-rmse:475.98323
# [28]	validation_0-rmse:401.30264	validation_1-rmse:476.22890
# [29]	validation_0-rmse:400.30941	validation_1-rmse:476.54803
# [30]	validation_0-rmse:399.39384	validation_1-rmse:476.92724
# [31]	validation_0-rmse:398.54488	validation_1-rmse:477.34858
# [32]	validation_0-rmse:397.75425	validation_1-rmse:477.80673
# [33]	validation_0-rmse:397.01380	validation_1-rmse:478.28890
# [34]	validation_0-rmse:396.31765	validation_1-rmse:478.78830
# [35]	validation_0-rmse:395.65950	validation_1-rmse:479.29647
# [36]	validation_0-rmse:395.03530	validation_1-rmse:479.81043
# [37]	validation_0-rmse:394.44179	validation_1-rmse:480.32751
# [38]	validation_0-rmse:393.87474	validation_1-rmse:480.84332
# [39]	validation_0-rmse:393.33249	validation_1-rmse:481.35493
# [40]	validation_0-rmse:392.81272	validation_1-rmse:481.86317
# [41]	validation_0-rmse:392.31266	validation_1-rmse:482.36116
# [42]	validation_0-rmse:391.83133	validation_1-rmse:482.84990
# [43]	validation_0-rmse:391.36702	validation_1-rmse:483.33154
# [44]	validation_0-rmse:390.91793	validation_1-rmse:483.80387
# [45]	validation_0-rmse:390.48323	validation_1-rmse:484.26591
# [46]	validation_0-rmse:390.06273	validation_1-rmse:484.71906
# [47]	validation_0-rmse:389.65514	validation_1-rmse:485.16409
# [48]	validation_0-rmse:389.25950	validation_1-rmse:485.59827
# [49]	validation_0-rmse:388.87532	validation_1-rmse:486.02239
# [50]	validation_0-rmse:388.50188	validation_1-rmse:486.43482
# [51]	validation_0-rmse:388.13900	validation_1-rmse:486.83885
# [52]	validation_0-rmse:387.78627	validation_1-rmse:487.23555
# [53]	validation_0-rmse:387.44278	validation_1-rmse:487.62117
# [54]	validation_0-rmse:387.10835	validation_1-rmse:488.00208
# [55]	validation_0-rmse:386.78274	validation_1-rmse:488.37246
# [56]	validation_0-rmse:386.46560	validation_1-rmse:488.73244
# [57]	validation_0-rmse:386.15689	validation_1-rmse:489.08687
# [58]	validation_0-rmse:385.85592	validation_1-rmse:489.43521
# [59]	validation_0-rmse:385.56264	validation_1-rmse:489.77354
# [60]	validation_0-rmse:385.27669	validation_1-rmse:490.10622
# [61]	validation_0-rmse:384.99784	validation_1-rmse:490.43230
# [62]	validation_0-rmse:384.72600	validation_1-rmse:490.75264
# [63]	validation_0-rmse:384.46078	validation_1-rmse:491.06491
# [64]	validation_0-rmse:384.20216	validation_1-rmse:491.37092
# [65]	validation_0-rmse:383.94985	validation_1-rmse:491.67176
# [66]	validation_0-rmse:383.70375	validation_1-rmse:491.96967
# [67]	validation_0-rmse:383.46366	validation_1-rmse:492.26358
# [68]	validation_0-rmse:383.22936	validation_1-rmse:492.55027
# [69]	validation_0-rmse:383.00079	validation_1-rmse:492.82833
# [70]	validation_0-rmse:382.77766	validation_1-rmse:493.10466
# [71]	validation_0-rmse:382.55990	validation_1-rmse:493.37165
# [72]	validation_0-rmse:382.34737	validation_1-rmse:493.63717
# [73]	validation_0-rmse:382.13985	validation_1-rmse:493.89692
# [74]	validation_0-rmse:381.93727	validation_1-rmse:494.15223
# [75]	validation_0-rmse:381.73964	validation_1-rmse:494.40070
# train:  381.7396432308402
# test:  494.40070411729266

# %%
preds, scores, feature_importances = cross_validate(ca_df, ca_forcast_df, feature_columns)
# Out:
# [0]	validation_0-rmse:1623.24220	validation_1-rmse:2546.57595
# [1]	validation_0-rmse:1522.62184	validation_1-rmse:2411.64799
# [2]	validation_0-rmse:1432.54254	validation_1-rmse:2291.48496
# [3]	validation_0-rmse:1351.94971	validation_1-rmse:2183.30876
# [4]	validation_0-rmse:1280.24125	validation_1-rmse:2087.29028
# [5]	validation_0-rmse:1216.31445	validation_1-rmse:2002.43172
# [6]	validation_0-rmse:1159.61998	validation_1-rmse:1926.83894
# [7]	validation_0-rmse:1109.56993	validation_1-rmse:1859.77568
# [8]	validation_0-rmse:1065.41834	validation_1-rmse:1800.23911
# [9]	validation_0-rmse:1026.62467	validation_1-rmse:1747.37032
# [10]	validation_0-rmse:992.54418	validation_1-rmse:1700.64625
# [11]	validation_0-rmse:962.67553	validation_1-rmse:1659.25049
# [12]	validation_0-rmse:936.63252	validation_1-rmse:1622.97947
# [13]	validation_0-rmse:913.92597	validation_1-rmse:1590.99563
# [14]	validation_0-rmse:894.15298	validation_1-rmse:1562.51975
# [15]	validation_0-rmse:876.96403	validation_1-rmse:1537.57256
# [16]	validation_0-rmse:862.03761	validation_1-rmse:1515.47907
# [17]	validation_0-rmse:849.02529	validation_1-rmse:1495.87782
# [18]	validation_0-rmse:837.73205	validation_1-rmse:1478.66492
# [19]	validation_0-rmse:827.84816	validation_1-rmse:1463.33423
# [20]	validation_0-rmse:819.21850	validation_1-rmse:1449.81424
# [21]	validation_0-rmse:811.69993	validation_1-rmse:1437.85809
# [22]	validation_0-rmse:805.09565	validation_1-rmse:1427.33042
# [23]	validation_0-rmse:799.29384	validation_1-rmse:1418.04089
# [24]	validation_0-rmse:794.17665	validation_1-rmse:1409.81118
# [25]	validation_0-rmse:789.64770	validation_1-rmse:1402.59388
# [26]	validation_0-rmse:785.61685	validation_1-rmse:1396.24553
# [27]	validation_0-rmse:782.00875	validation_1-rmse:1390.66619
# [28]	validation_0-rmse:778.76567	validation_1-rmse:1385.81079
# [29]	validation_0-rmse:775.83940	validation_1-rmse:1381.59836
# [30]	validation_0-rmse:773.17853	validation_1-rmse:1377.90191
# [31]	validation_0-rmse:770.74598	validation_1-rmse:1374.69166
# [32]	validation_0-rmse:768.51176	validation_1-rmse:1371.94187
# [33]	validation_0-rmse:766.44738	validation_1-rmse:1369.57066
# [34]	validation_0-rmse:764.53095	validation_1-rmse:1367.57551
# [35]	validation_0-rmse:762.74215	validation_1-rmse:1365.88351
# [36]	validation_0-rmse:761.06479	validation_1-rmse:1364.48787
# [37]	validation_0-rmse:759.48433	validation_1-rmse:1363.36221
# [38]	validation_0-rmse:757.98788	validation_1-rmse:1362.47136
# [39]	validation_0-rmse:756.56836	validation_1-rmse:1361.81217
# [40]	validation_0-rmse:755.21548	validation_1-rmse:1361.34335
# [41]	validation_0-rmse:753.92090	validation_1-rmse:1361.04291
# [42]	validation_0-rmse:752.68011	validation_1-rmse:1360.90867
# [43]	validation_0-rmse:751.48615	validation_1-rmse:1360.90767
# [44]	validation_0-rmse:750.33548	validation_1-rmse:1361.04896
# [45]	validation_0-rmse:749.22367	validation_1-rmse:1361.30418
# [46]	validation_0-rmse:748.14717	validation_1-rmse:1361.65964
# [47]	validation_0-rmse:747.10357	validation_1-rmse:1362.09548
# [48]	validation_0-rmse:746.09055	validation_1-rmse:1362.61365
# [49]	validation_0-rmse:745.10550	validation_1-rmse:1363.22489
# [50]	validation_0-rmse:744.14666	validation_1-rmse:1363.89537
# [51]	validation_0-rmse:743.21234	validation_1-rmse:1364.63361
# [52]	validation_0-rmse:742.30074	validation_1-rmse:1365.40667
# [53]	validation_0-rmse:741.41140	validation_1-rmse:1366.24456
# [54]	validation_0-rmse:740.54255	validation_1-rmse:1367.10481
# [55]	validation_0-rmse:739.69361	validation_1-rmse:1367.99490
# [56]	validation_0-rmse:738.86337	validation_1-rmse:1368.92472
# [57]	validation_0-rmse:738.05172	validation_1-rmse:1369.85317
# [58]	validation_0-rmse:737.25751	validation_1-rmse:1370.84058
# [59]	validation_0-rmse:736.48015	validation_1-rmse:1371.83416
# [60]	validation_0-rmse:735.71909	validation_1-rmse:1372.83586
# [61]	validation_0-rmse:734.97377	validation_1-rmse:1373.85056
# [62]	validation_0-rmse:734.24346	validation_1-rmse:1374.86813
# [63]	validation_0-rmse:733.52810	validation_1-rmse:1375.88414
# [64]	validation_0-rmse:732.82692	validation_1-rmse:1376.90616
# [65]	validation_0-rmse:732.13990	validation_1-rmse:1377.92486
# [66]	validation_0-rmse:731.46673	validation_1-rmse:1378.95158
# [67]	validation_0-rmse:730.80679	validation_1-rmse:1379.96439
# [68]	validation_0-rmse:730.15979	validation_1-rmse:1380.97535
# [69]	validation_0-rmse:729.52542	validation_1-rmse:1381.98999
# [70]	validation_0-rmse:728.90333	validation_1-rmse:1382.98400
# [71]	validation_0-rmse:728.29349	validation_1-rmse:1383.96447
# [72]	validation_0-rmse:727.69529	validation_1-rmse:1384.93955
# [73]	validation_0-rmse:727.10863	validation_1-rmse:1385.89440
# [74]	validation_0-rmse:726.53335	validation_1-rmse:1386.85832
# [75]	validation_0-rmse:725.96916	validation_1-rmse:1387.80858
# [76]	validation_0-rmse:725.41553	validation_1-rmse:1388.74542
# [77]	validation_0-rmse:724.87269	validation_1-rmse:1389.67363
# [78]	validation_0-rmse:724.34007	validation_1-rmse:1390.58882
# [79]	validation_0-rmse:723.81758	validation_1-rmse:1391.48982
# [80]	validation_0-rmse:723.30496	validation_1-rmse:1392.37268
# [81]	validation_0-rmse:722.80209	validation_1-rmse:1393.24554
# [82]	validation_0-rmse:722.30872	validation_1-rmse:1394.10251
# [83]	validation_0-rmse:721.82471	validation_1-rmse:1394.93954
# [84]	validation_0-rmse:721.34989	validation_1-rmse:1395.77075
# [85]	validation_0-rmse:720.88387	validation_1-rmse:1396.57910
# [86]	validation_0-rmse:720.42675	validation_1-rmse:1397.37369
# [87]	validation_0-rmse:719.97825	validation_1-rmse:1398.15324
# [88]	validation_0-rmse:719.53807	validation_1-rmse:1398.92881
# [89]	validation_0-rmse:719.10608	validation_1-rmse:1399.67643
# [90]	validation_0-rmse:718.68230	validation_1-rmse:1400.41156
# [91]	validation_0-rmse:718.26647	validation_1-rmse:1401.14237
# [92]	validation_0-rmse:717.85825	validation_1-rmse:1401.83831
# [93]	validation_0-rmse:717.45764	validation_1-rmse:1402.53333
# train:  717.4576294214392
# test:  1402.5333142497566
# [0]	validation_0-rmse:1954.95629	validation_1-rmse:2870.83756
# [1]	validation_0-rmse:1821.78674	validation_1-rmse:2689.82620
# [2]	validation_0-rmse:1703.78345	validation_1-rmse:2528.63494
# [3]	validation_0-rmse:1599.48679	validation_1-rmse:2385.27487
# [4]	validation_0-rmse:1507.60864	validation_1-rmse:2258.36278
# [5]	validation_0-rmse:1427.18934	validation_1-rmse:2146.72965
# [6]	validation_0-rmse:1356.84485	validation_1-rmse:2047.67816
# [7]	validation_0-rmse:1295.68246	validation_1-rmse:1960.67616
# [8]	validation_0-rmse:1242.56175	validation_1-rmse:1884.54028
# [9]	validation_0-rmse:1196.67634	validation_1-rmse:1817.73886
# [10]	validation_0-rmse:1157.15609	validation_1-rmse:1759.41863
# [11]	validation_0-rmse:1123.19473	validation_1-rmse:1708.41933
# [12]	validation_0-rmse:1094.02715	validation_1-rmse:1664.14098
# [13]	validation_0-rmse:1069.04722	validation_1-rmse:1625.39583
# [14]	validation_0-rmse:1047.66088	validation_1-rmse:1591.58233
# [15]	validation_0-rmse:1029.40496	validation_1-rmse:1562.09489
# [16]	validation_0-rmse:1013.75397	validation_1-rmse:1536.26629
# [17]	validation_0-rmse:1000.38075	validation_1-rmse:1513.70818
# [18]	validation_0-rmse:988.90902	validation_1-rmse:1493.97539
# [19]	validation_0-rmse:979.06015	validation_1-rmse:1476.67878
# [20]	validation_0-rmse:970.56569	validation_1-rmse:1461.46150
# [21]	validation_0-rmse:963.22234	validation_1-rmse:1448.10157
# [22]	validation_0-rmse:956.83564	validation_1-rmse:1436.22998
# [23]	validation_0-rmse:951.26412	validation_1-rmse:1425.72201
# [24]	validation_0-rmse:946.37157	validation_1-rmse:1416.37588
# [25]	validation_0-rmse:942.05174	validation_1-rmse:1408.03533
# [26]	validation_0-rmse:938.20546	validation_1-rmse:1400.56159
# [27]	validation_0-rmse:934.77186	validation_1-rmse:1393.84211
# [28]	validation_0-rmse:931.68134	validation_1-rmse:1387.77209
# [29]	validation_0-rmse:928.87844	validation_1-rmse:1382.28038
# [30]	validation_0-rmse:926.31580	validation_1-rmse:1377.28548
# [31]	validation_0-rmse:923.96246	validation_1-rmse:1372.71772
# [32]	validation_0-rmse:921.78787	validation_1-rmse:1368.54342
# [33]	validation_0-rmse:919.76271	validation_1-rmse:1364.71027
# [34]	validation_0-rmse:917.86683	validation_1-rmse:1361.16276
# [35]	validation_0-rmse:916.08170	validation_1-rmse:1357.87690
# [36]	validation_0-rmse:914.39177	validation_1-rmse:1354.82223
# [37]	validation_0-rmse:912.78624	validation_1-rmse:1351.97172
# [38]	validation_0-rmse:911.25322	validation_1-rmse:1349.30554
# [39]	validation_0-rmse:909.78591	validation_1-rmse:1346.80252
# [40]	validation_0-rmse:908.37563	validation_1-rmse:1344.44833
# [41]	validation_0-rmse:907.01703	validation_1-rmse:1342.22738
# [42]	validation_0-rmse:905.70480	validation_1-rmse:1340.12424
# [43]	validation_0-rmse:904.43466	validation_1-rmse:1338.12824
# [44]	validation_0-rmse:903.20302	validation_1-rmse:1336.23033
# [45]	validation_0-rmse:902.00633	validation_1-rmse:1334.42396
# [46]	validation_0-rmse:900.84247	validation_1-rmse:1332.69901
# [47]	validation_0-rmse:899.70843	validation_1-rmse:1331.04888
# [48]	validation_0-rmse:898.60379	validation_1-rmse:1329.46708
# [49]	validation_0-rmse:897.52559	validation_1-rmse:1327.94854
# [50]	validation_0-rmse:896.47322	validation_1-rmse:1326.49469
# [51]	validation_0-rmse:895.44470	validation_1-rmse:1325.09166
# [52]	validation_0-rmse:894.43953	validation_1-rmse:1323.74004
# [53]	validation_0-rmse:893.45624	validation_1-rmse:1322.43555
# [54]	validation_0-rmse:892.49410	validation_1-rmse:1321.17743
# [55]	validation_0-rmse:891.55246	validation_1-rmse:1319.96588
# [56]	validation_0-rmse:890.63054	validation_1-rmse:1318.78541
# [57]	validation_0-rmse:889.72795	validation_1-rmse:1317.64379
# [58]	validation_0-rmse:888.84401	validation_1-rmse:1316.53430
# [59]	validation_0-rmse:887.97781	validation_1-rmse:1315.45780
# [60]	validation_0-rmse:887.12904	validation_1-rmse:1314.41288
# [61]	validation_0-rmse:886.29742	validation_1-rmse:1313.39876
# [62]	validation_0-rmse:885.48251	validation_1-rmse:1312.41390
# [63]	validation_0-rmse:884.68366	validation_1-rmse:1311.45301
# [64]	validation_0-rmse:883.90042	validation_1-rmse:1310.51857
# [65]	validation_0-rmse:883.13309	validation_1-rmse:1309.60985
# [66]	validation_0-rmse:882.38061	validation_1-rmse:1308.72432
# [67]	validation_0-rmse:881.64300	validation_1-rmse:1307.86072
# [68]	validation_0-rmse:880.91963	validation_1-rmse:1307.01772
# [69]	validation_0-rmse:880.21053	validation_1-rmse:1306.19774
# [70]	validation_0-rmse:879.51533	validation_1-rmse:1305.39861
# [71]	validation_0-rmse:878.83352	validation_1-rmse:1304.61891
# [72]	validation_0-rmse:878.16478	validation_1-rmse:1303.85726
# [73]	validation_0-rmse:877.50896	validation_1-rmse:1303.11090
# [74]	validation_0-rmse:876.86561	validation_1-rmse:1302.38182
# [75]	validation_0-rmse:876.23470	validation_1-rmse:1301.67111
# [76]	validation_0-rmse:875.61595	validation_1-rmse:1300.97916
# [77]	validation_0-rmse:875.00932	validation_1-rmse:1300.30329
# [78]	validation_0-rmse:874.41390	validation_1-rmse:1299.64302
# [79]	validation_0-rmse:873.83009	validation_1-rmse:1298.99957
# [80]	validation_0-rmse:873.25740	validation_1-rmse:1298.36963
# [81]	validation_0-rmse:872.69548	validation_1-rmse:1297.75132
# [82]	validation_0-rmse:872.14447	validation_1-rmse:1297.14982
# [83]	validation_0-rmse:871.60381	validation_1-rmse:1296.56545
# [84]	validation_0-rmse:871.07346	validation_1-rmse:1295.99100
# [85]	validation_0-rmse:870.55300	validation_1-rmse:1295.43041
# [86]	validation_0-rmse:870.04225	validation_1-rmse:1294.88125
# [87]	validation_0-rmse:869.54119	validation_1-rmse:1294.34570
# [88]	validation_0-rmse:869.04954	validation_1-rmse:1293.82241
# [89]	validation_0-rmse:868.56728	validation_1-rmse:1293.31120
# [90]	validation_0-rmse:868.09416	validation_1-rmse:1292.81144
# [91]	validation_0-rmse:867.62980	validation_1-rmse:1292.32464
# [92]	validation_0-rmse:867.17418	validation_1-rmse:1291.84882
# [93]	validation_0-rmse:866.72714	validation_1-rmse:1291.38349
# [94]	validation_0-rmse:866.28846	validation_1-rmse:1290.93018
# [95]	validation_0-rmse:865.85796	validation_1-rmse:1290.48423
# [96]	validation_0-rmse:865.43535	validation_1-rmse:1290.05161
# [97]	validation_0-rmse:865.02071	validation_1-rmse:1289.62899
# [98]	validation_0-rmse:864.61370	validation_1-rmse:1289.21470
# [99]	validation_0-rmse:864.21408	validation_1-rmse:1288.81034
# [100]	validation_0-rmse:863.82205	validation_1-rmse:1288.41517
# [101]	validation_0-rmse:863.43723	validation_1-rmse:1288.02702
# [102]	validation_0-rmse:863.05945	validation_1-rmse:1287.65193
# [103]	validation_0-rmse:862.68865	validation_1-rmse:1287.28338
# [104]	validation_0-rmse:862.32462	validation_1-rmse:1286.92228
# [105]	validation_0-rmse:861.96714	validation_1-rmse:1286.57187
# [106]	validation_0-rmse:861.61628	validation_1-rmse:1286.23013
# [107]	validation_0-rmse:861.27182	validation_1-rmse:1285.89575
# [108]	validation_0-rmse:860.93367	validation_1-rmse:1285.57107
# [109]	validation_0-rmse:860.60166	validation_1-rmse:1285.25292
# [110]	validation_0-rmse:860.27565	validation_1-rmse:1284.94046
# [111]	validation_0-rmse:859.95553	validation_1-rmse:1284.63746
# [112]	validation_0-rmse:859.64119	validation_1-rmse:1284.34136
# [113]	validation_0-rmse:859.33255	validation_1-rmse:1284.05253
# [114]	validation_0-rmse:859.02944	validation_1-rmse:1283.77133
# [115]	validation_0-rmse:858.73171	validation_1-rmse:1283.49464
# [116]	validation_0-rmse:858.43945	validation_1-rmse:1283.22757
# [117]	validation_0-rmse:858.15250	validation_1-rmse:1282.96604
# [118]	validation_0-rmse:857.87057	validation_1-rmse:1282.71153
# [119]	validation_0-rmse:857.59369	validation_1-rmse:1282.46231
# [120]	validation_0-rmse:857.32165	validation_1-rmse:1282.21810
# [121]	validation_0-rmse:857.05447	validation_1-rmse:1281.98141
# [122]	validation_0-rmse:856.79205	validation_1-rmse:1281.74937
# [123]	validation_0-rmse:856.53415	validation_1-rmse:1281.52450
# [124]	validation_0-rmse:856.28093	validation_1-rmse:1281.30606
# [125]	validation_0-rmse:856.03219	validation_1-rmse:1281.09275
# [126]	validation_0-rmse:855.78778	validation_1-rmse:1280.88313
# [127]	validation_0-rmse:855.54772	validation_1-rmse:1280.68085
# [128]	validation_0-rmse:855.31168	validation_1-rmse:1280.48218
# [129]	validation_0-rmse:855.07977	validation_1-rmse:1280.28975
# [130]	validation_0-rmse:854.85206	validation_1-rmse:1280.10252
# [131]	validation_0-rmse:854.62813	validation_1-rmse:1279.91823
# [132]	validation_0-rmse:854.40825	validation_1-rmse:1279.73901
# [133]	validation_0-rmse:854.19200	validation_1-rmse:1279.56625
# [134]	validation_0-rmse:853.97948	validation_1-rmse:1279.39621
# [135]	validation_0-rmse:853.77062	validation_1-rmse:1279.23250
# [136]	validation_0-rmse:853.56534	validation_1-rmse:1279.07312
# [137]	validation_0-rmse:853.36374	validation_1-rmse:1278.91799
# [138]	validation_0-rmse:853.16540	validation_1-rmse:1278.76739
# [139]	validation_0-rmse:852.97042	validation_1-rmse:1278.62045
# [140]	validation_0-rmse:852.77890	validation_1-rmse:1278.47775
# [141]	validation_0-rmse:852.59062	validation_1-rmse:1278.33932
# [142]	validation_0-rmse:852.40550	validation_1-rmse:1278.20144
# [143]	validation_0-rmse:852.22344	validation_1-rmse:1278.06745
# [144]	validation_0-rmse:852.04439	validation_1-rmse:1277.93993
# [145]	validation_0-rmse:851.86848	validation_1-rmse:1277.81533
# [146]	validation_0-rmse:851.69538	validation_1-rmse:1277.69322
# [147]	validation_0-rmse:851.52517	validation_1-rmse:1277.57427
# [148]	validation_0-rmse:851.35780	validation_1-rmse:1277.45871
# [149]	validation_0-rmse:851.19319	validation_1-rmse:1277.34803
# [150]	validation_0-rmse:851.03129	validation_1-rmse:1277.24037
# [151]	validation_0-rmse:850.87206	validation_1-rmse:1277.13534
# [152]	validation_0-rmse:850.71544	validation_1-rmse:1277.03418
# [153]	validation_0-rmse:850.56139	validation_1-rmse:1276.93507
# [154]	validation_0-rmse:850.40996	validation_1-rmse:1276.83949
# [155]	validation_0-rmse:850.26095	validation_1-rmse:1276.74705
# [156]	validation_0-rmse:850.11438	validation_1-rmse:1276.65720
# [157]	validation_0-rmse:849.97012	validation_1-rmse:1276.56969
# [158]	validation_0-rmse:849.82825	validation_1-rmse:1276.48550
# [159]	validation_0-rmse:849.68872	validation_1-rmse:1276.40206
# [160]	validation_0-rmse:849.55129	validation_1-rmse:1276.32217
# [161]	validation_0-rmse:849.41604	validation_1-rmse:1276.24461
# [162]	validation_0-rmse:849.28296	validation_1-rmse:1276.17013
# [163]	validation_0-rmse:849.15207	validation_1-rmse:1276.09663
# [164]	validation_0-rmse:849.02327	validation_1-rmse:1276.02366
# [165]	validation_0-rmse:848.89650	validation_1-rmse:1275.95486
# [166]	validation_0-rmse:848.77174	validation_1-rmse:1275.88766
# [167]	validation_0-rmse:848.64889	validation_1-rmse:1275.82221
# [168]	validation_0-rmse:848.52789	validation_1-rmse:1275.75976
# [169]	validation_0-rmse:848.40884	validation_1-rmse:1275.69934
# [170]	validation_0-rmse:848.29159	validation_1-rmse:1275.64050
# [171]	validation_0-rmse:848.17612	validation_1-rmse:1275.58523
# [172]	validation_0-rmse:848.06243	validation_1-rmse:1275.53105
# [173]	validation_0-rmse:847.95046	validation_1-rmse:1275.47743
# [174]	validation_0-rmse:847.84028	validation_1-rmse:1275.42614
# [175]	validation_0-rmse:847.73178	validation_1-rmse:1275.37646
# [176]	validation_0-rmse:847.62491	validation_1-rmse:1275.32782
# [177]	validation_0-rmse:847.51965	validation_1-rmse:1275.28078
# [178]	validation_0-rmse:847.41598	validation_1-rmse:1275.23489
# [179]	validation_0-rmse:847.31392	validation_1-rmse:1275.19069
# [180]	validation_0-rmse:847.21330	validation_1-rmse:1275.14855
# [181]	validation_0-rmse:847.11426	validation_1-rmse:1275.10714
# [182]	validation_0-rmse:847.01666	validation_1-rmse:1275.06479
# [183]	validation_0-rmse:846.92042	validation_1-rmse:1275.02792
# [184]	validation_0-rmse:846.82570	validation_1-rmse:1274.98913
# [185]	validation_0-rmse:846.73235	validation_1-rmse:1274.95361
# [186]	validation_0-rmse:846.64031	validation_1-rmse:1274.91949
# [187]	validation_0-rmse:846.54963	validation_1-rmse:1274.88626
# [188]	validation_0-rmse:846.46022	validation_1-rmse:1274.85313
# [189]	validation_0-rmse:846.37217	validation_1-rmse:1274.81898
# [190]	validation_0-rmse:846.28535	validation_1-rmse:1274.78878
# [191]	validation_0-rmse:846.19978	validation_1-rmse:1274.75863
# [192]	validation_0-rmse:846.11540	validation_1-rmse:1274.73105
# [193]	validation_0-rmse:846.03220	validation_1-rmse:1274.70372
# [194]	validation_0-rmse:845.95018	validation_1-rmse:1274.67838
# [195]	validation_0-rmse:845.86929	validation_1-rmse:1274.65337
# [196]	validation_0-rmse:845.78964	validation_1-rmse:1274.62673
# [197]	validation_0-rmse:845.71105	validation_1-rmse:1274.60235
# [198]	validation_0-rmse:845.63350	validation_1-rmse:1274.57982
# [199]	validation_0-rmse:845.55704	validation_1-rmse:1274.55810
# [200]	validation_0-rmse:845.48161	validation_1-rmse:1274.53724
# [201]	validation_0-rmse:845.40727	validation_1-rmse:1274.51692
# [202]	validation_0-rmse:845.33388	validation_1-rmse:1274.49755
# [203]	validation_0-rmse:845.26152	validation_1-rmse:1274.47927
# [204]	validation_0-rmse:845.19015	validation_1-rmse:1274.45922
# [205]	validation_0-rmse:845.11973	validation_1-rmse:1274.44104
# [206]	validation_0-rmse:845.05025	validation_1-rmse:1274.42350
# [207]	validation_0-rmse:844.98166	validation_1-rmse:1274.40619
# [208]	validation_0-rmse:844.91397	validation_1-rmse:1274.38802
# [209]	validation_0-rmse:844.84722	validation_1-rmse:1274.37093
# [210]	validation_0-rmse:844.78129	validation_1-rmse:1274.35541
# [211]	validation_0-rmse:844.71623	validation_1-rmse:1274.33904
# [212]	validation_0-rmse:844.65208	validation_1-rmse:1274.32320
# [213]	validation_0-rmse:844.58874	validation_1-rmse:1274.30847
# [214]	validation_0-rmse:844.52620	validation_1-rmse:1274.29372
# [215]	validation_0-rmse:844.46444	validation_1-rmse:1274.27941
# [216]	validation_0-rmse:844.40349	validation_1-rmse:1274.26473
# [217]	validation_0-rmse:844.34334	validation_1-rmse:1274.25134
# [218]	validation_0-rmse:844.28391	validation_1-rmse:1274.23759
# [219]	validation_0-rmse:844.22524	validation_1-rmse:1274.22320
# [220]	validation_0-rmse:844.16725	validation_1-rmse:1274.21160
# [221]	validation_0-rmse:844.11001	validation_1-rmse:1274.19966
# [222]	validation_0-rmse:844.05342	validation_1-rmse:1274.18887
# [223]	validation_0-rmse:843.99762	validation_1-rmse:1274.17646
# [224]	validation_0-rmse:843.94243	validation_1-rmse:1274.16591
# [225]	validation_0-rmse:843.88789	validation_1-rmse:1274.15557
# [226]	validation_0-rmse:843.83402	validation_1-rmse:1274.14384
# [227]	validation_0-rmse:843.78081	validation_1-rmse:1274.13350
# [228]	validation_0-rmse:843.72827	validation_1-rmse:1274.12041
# [229]	validation_0-rmse:843.67627	validation_1-rmse:1274.10889
# [230]	validation_0-rmse:843.62495	validation_1-rmse:1274.09785
# [231]	validation_0-rmse:843.57420	validation_1-rmse:1274.08666
# [232]	validation_0-rmse:843.52404	validation_1-rmse:1274.07568
# [233]	validation_0-rmse:843.47448	validation_1-rmse:1274.06491
# [234]	validation_0-rmse:843.42547	validation_1-rmse:1274.05437
# [235]	validation_0-rmse:843.37700	validation_1-rmse:1274.04420
# [236]	validation_0-rmse:843.32902	validation_1-rmse:1274.03480
# [237]	validation_0-rmse:843.28164	validation_1-rmse:1274.02302
# [238]	validation_0-rmse:843.23479	validation_1-rmse:1274.01253
# [239]	validation_0-rmse:843.18845	validation_1-rmse:1274.00137
# [240]	validation_0-rmse:843.14265	validation_1-rmse:1273.99135
# [241]	validation_0-rmse:843.09734	validation_1-rmse:1273.98009
# [242]	validation_0-rmse:843.05251	validation_1-rmse:1273.96986
# [243]	validation_0-rmse:843.00815	validation_1-rmse:1273.96012
# [244]	validation_0-rmse:842.96427	validation_1-rmse:1273.95083
# [245]	validation_0-rmse:842.92087	validation_1-rmse:1273.94041
# [246]	validation_0-rmse:842.87793	validation_1-rmse:1273.92897
# [247]	validation_0-rmse:842.83549	validation_1-rmse:1273.91794
# [248]	validation_0-rmse:842.79346	validation_1-rmse:1273.90706
# [249]	validation_0-rmse:842.75183	validation_1-rmse:1273.89551
# [250]	validation_0-rmse:842.71063	validation_1-rmse:1273.88448
# [251]	validation_0-rmse:842.66988	validation_1-rmse:1273.87339
# [252]	validation_0-rmse:842.62954	validation_1-rmse:1273.86214
# [253]	validation_0-rmse:842.58963	validation_1-rmse:1273.85076
# [254]	validation_0-rmse:842.55016	validation_1-rmse:1273.83875
# [255]	validation_0-rmse:842.51104	validation_1-rmse:1273.82768
# [256]	validation_0-rmse:842.47234	validation_1-rmse:1273.81548
# [257]	validation_0-rmse:842.43399	validation_1-rmse:1273.80306
# [258]	validation_0-rmse:842.39597	validation_1-rmse:1273.79113
# [259]	validation_0-rmse:842.35840	validation_1-rmse:1273.77843
# [260]	validation_0-rmse:842.32116	validation_1-rmse:1273.76558
# [261]	validation_0-rmse:842.28426	validation_1-rmse:1273.75295
# [262]	validation_0-rmse:842.24780	validation_1-rmse:1273.73827
# [263]	validation_0-rmse:842.21164	validation_1-rmse:1273.72494
# [264]	validation_0-rmse:842.17582	validation_1-rmse:1273.71068
# [265]	validation_0-rmse:842.14035	validation_1-rmse:1273.69651
# [266]	validation_0-rmse:842.10516	validation_1-rmse:1273.68255
# [267]	validation_0-rmse:842.07030	validation_1-rmse:1273.66835
# [268]	validation_0-rmse:842.03575	validation_1-rmse:1273.65480
# [269]	validation_0-rmse:842.00157	validation_1-rmse:1273.64045
# [270]	validation_0-rmse:841.96768	validation_1-rmse:1273.62508
# [271]	validation_0-rmse:841.93408	validation_1-rmse:1273.61110
# [272]	validation_0-rmse:841.90077	validation_1-rmse:1273.59623
# [273]	validation_0-rmse:841.86777	validation_1-rmse:1273.57898
# [274]	validation_0-rmse:841.83512	validation_1-rmse:1273.56168
# [275]	validation_0-rmse:841.80269	validation_1-rmse:1273.54442
# [276]	validation_0-rmse:841.77054	validation_1-rmse:1273.52761
# [277]	validation_0-rmse:841.73865	validation_1-rmse:1273.51089
# [278]	validation_0-rmse:841.70702	validation_1-rmse:1273.49491
# [279]	validation_0-rmse:841.67569	validation_1-rmse:1273.47770
# [280]	validation_0-rmse:841.64459	validation_1-rmse:1273.46125
# [281]	validation_0-rmse:841.61378	validation_1-rmse:1273.44430
# [282]	validation_0-rmse:841.58318	validation_1-rmse:1273.42742
# [283]	validation_0-rmse:841.55291	validation_1-rmse:1273.40885
# [284]	validation_0-rmse:841.52287	validation_1-rmse:1273.38982
# [285]	validation_0-rmse:841.49304	validation_1-rmse:1273.37017
# [286]	validation_0-rmse:841.46349	validation_1-rmse:1273.35037
# [287]	validation_0-rmse:841.43416	validation_1-rmse:1273.32982
# [288]	validation_0-rmse:841.40503	validation_1-rmse:1273.31021
# [289]	validation_0-rmse:841.37614	validation_1-rmse:1273.29008
# [290]	validation_0-rmse:841.34747	validation_1-rmse:1273.26980
# [291]	validation_0-rmse:841.31901	validation_1-rmse:1273.24897
# [292]	validation_0-rmse:841.29080	validation_1-rmse:1273.22856
# [293]	validation_0-rmse:841.26278	validation_1-rmse:1273.20813
# [294]	validation_0-rmse:841.23498	validation_1-rmse:1273.18707
# [295]	validation_0-rmse:841.20742	validation_1-rmse:1273.16283
# [296]	validation_0-rmse:841.18001	validation_1-rmse:1273.14218
# [297]	validation_0-rmse:841.15279	validation_1-rmse:1273.12001
# [298]	validation_0-rmse:841.12581	validation_1-rmse:1273.09677
# [299]	validation_0-rmse:841.09898	validation_1-rmse:1273.07453
# [300]	validation_0-rmse:841.07237	validation_1-rmse:1273.05215
# [301]	validation_0-rmse:841.04598	validation_1-rmse:1273.02823
# [302]	validation_0-rmse:841.01973	validation_1-rmse:1273.00441
# [303]	validation_0-rmse:840.99365	validation_1-rmse:1272.98110
# [304]	validation_0-rmse:840.96779	validation_1-rmse:1272.95489
# [305]	validation_0-rmse:840.94210	validation_1-rmse:1272.92933
# [306]	validation_0-rmse:840.91656	validation_1-rmse:1272.90546
# [307]	validation_0-rmse:840.89118	validation_1-rmse:1272.88090
# [308]	validation_0-rmse:840.86601	validation_1-rmse:1272.85570
# [309]	validation_0-rmse:840.84100	validation_1-rmse:1272.82921
# [310]	validation_0-rmse:840.81613	validation_1-rmse:1272.80416
# [311]	validation_0-rmse:840.79148	validation_1-rmse:1272.77659
# [312]	validation_0-rmse:840.76698	validation_1-rmse:1272.74881
# [313]	validation_0-rmse:840.74263	validation_1-rmse:1272.72236
# [314]	validation_0-rmse:840.71841	validation_1-rmse:1272.69414
# [315]	validation_0-rmse:840.69437	validation_1-rmse:1272.66575
# [316]	validation_0-rmse:840.67049	validation_1-rmse:1272.63676
# [317]	validation_0-rmse:840.64676	validation_1-rmse:1272.60764
# [318]	validation_0-rmse:840.62320	validation_1-rmse:1272.57949
# [319]	validation_0-rmse:840.59973	validation_1-rmse:1272.55218
# [320]	validation_0-rmse:840.57641	validation_1-rmse:1272.52358
# [321]	validation_0-rmse:840.55321	validation_1-rmse:1272.49399
# [322]	validation_0-rmse:840.53016	validation_1-rmse:1272.46519
# [323]	validation_0-rmse:840.50729	validation_1-rmse:1272.43513
# [324]	validation_0-rmse:840.48454	validation_1-rmse:1272.40345
# [325]	validation_0-rmse:840.46186	validation_1-rmse:1272.37487
# [326]	validation_0-rmse:840.43937	validation_1-rmse:1272.34497
# [327]	validation_0-rmse:840.41697	validation_1-rmse:1272.31433
# [328]	validation_0-rmse:840.39473	validation_1-rmse:1272.28262
# [329]	validation_0-rmse:840.37259	validation_1-rmse:1272.25189
# [330]	validation_0-rmse:840.35061	validation_1-rmse:1272.21919
# [331]	validation_0-rmse:840.32873	validation_1-rmse:1272.18687
# [332]	validation_0-rmse:840.30697	validation_1-rmse:1272.15446
# [333]	validation_0-rmse:840.28532	validation_1-rmse:1272.12223
# [334]	validation_0-rmse:840.26379	validation_1-rmse:1272.09030
# [335]	validation_0-rmse:840.24241	validation_1-rmse:1272.05561
# [336]	validation_0-rmse:840.22118	validation_1-rmse:1272.02139
# [337]	validation_0-rmse:840.20004	validation_1-rmse:1271.98682
# [338]	validation_0-rmse:840.17900	validation_1-rmse:1271.95264
# [339]	validation_0-rmse:840.15804	validation_1-rmse:1271.91594
# [340]	validation_0-rmse:840.13722	validation_1-rmse:1271.88142
# [341]	validation_0-rmse:840.11649	validation_1-rmse:1271.84604
# [342]	validation_0-rmse:840.09590	validation_1-rmse:1271.81005
# [343]	validation_0-rmse:840.07538	validation_1-rmse:1271.77488
# [344]	validation_0-rmse:840.05497	validation_1-rmse:1271.73854
# [345]	validation_0-rmse:840.03469	validation_1-rmse:1271.70177
# [346]	validation_0-rmse:840.01445	validation_1-rmse:1271.66415
# [347]	validation_0-rmse:839.99437	validation_1-rmse:1271.62728
# [348]	validation_0-rmse:839.97433	validation_1-rmse:1271.58998
# [349]	validation_0-rmse:839.95445	validation_1-rmse:1271.55344
# [350]	validation_0-rmse:839.93460	validation_1-rmse:1271.51689
# [351]	validation_0-rmse:839.91488	validation_1-rmse:1271.48043
# [352]	validation_0-rmse:839.89523	validation_1-rmse:1271.44201
# [353]	validation_0-rmse:839.87566	validation_1-rmse:1271.40429
# [354]	validation_0-rmse:839.85622	validation_1-rmse:1271.36591
# [355]	validation_0-rmse:839.83685	validation_1-rmse:1271.32700
# [356]	validation_0-rmse:839.81760	validation_1-rmse:1271.28755
# [357]	validation_0-rmse:839.79841	validation_1-rmse:1271.24824
# [358]	validation_0-rmse:839.77931	validation_1-rmse:1271.20948
# [359]	validation_0-rmse:839.76032	validation_1-rmse:1271.16828
# [360]	validation_0-rmse:839.74141	validation_1-rmse:1271.12869
# [361]	validation_0-rmse:839.72255	validation_1-rmse:1271.08665
# [362]	validation_0-rmse:839.70381	validation_1-rmse:1271.04616
# [363]	validation_0-rmse:839.68518	validation_1-rmse:1271.00496
# [364]	validation_0-rmse:839.66657	validation_1-rmse:1270.96418
# [365]	validation_0-rmse:839.64806	validation_1-rmse:1270.92386
# [366]	validation_0-rmse:839.62967	validation_1-rmse:1270.88179
# [367]	validation_0-rmse:839.61130	validation_1-rmse:1270.84154
# [368]	validation_0-rmse:839.59299	validation_1-rmse:1270.80055
# [369]	validation_0-rmse:839.57478	validation_1-rmse:1270.76000
# [370]	validation_0-rmse:839.55665	validation_1-rmse:1270.71768
# [371]	validation_0-rmse:839.53856	validation_1-rmse:1270.67675
# [372]	validation_0-rmse:839.52054	validation_1-rmse:1270.63572
# [373]	validation_0-rmse:839.50262	validation_1-rmse:1270.59356
# [374]	validation_0-rmse:839.48474	validation_1-rmse:1270.55158
# [375]	validation_0-rmse:839.46695	validation_1-rmse:1270.50838
# [376]	validation_0-rmse:839.44921	validation_1-rmse:1270.46500
# [377]	validation_0-rmse:839.43154	validation_1-rmse:1270.42195
# [378]	validation_0-rmse:839.41397	validation_1-rmse:1270.37945
# [379]	validation_0-rmse:839.39642	validation_1-rmse:1270.33559
# [380]	validation_0-rmse:839.37899	validation_1-rmse:1270.29104
# [381]	validation_0-rmse:839.36158	validation_1-rmse:1270.24784
# [382]	validation_0-rmse:839.34426	validation_1-rmse:1270.20337
# [383]	validation_0-rmse:839.32702	validation_1-rmse:1270.15748
# [384]	validation_0-rmse:839.30981	validation_1-rmse:1270.11434
# [385]	validation_0-rmse:839.29269	validation_1-rmse:1270.06871
# [386]	validation_0-rmse:839.27558	validation_1-rmse:1270.02470
# [387]	validation_0-rmse:839.25856	validation_1-rmse:1269.97973
# [388]	validation_0-rmse:839.24159	validation_1-rmse:1269.93505
# [389]	validation_0-rmse:839.22469	validation_1-rmse:1269.89052
# [390]	validation_0-rmse:839.20785	validation_1-rmse:1269.84590
# [391]	validation_0-rmse:839.19109	validation_1-rmse:1269.80059
# [392]	validation_0-rmse:839.17438	validation_1-rmse:1269.75378
# [393]	validation_0-rmse:839.15773	validation_1-rmse:1269.70782
# [394]	validation_0-rmse:839.14116	validation_1-rmse:1269.66125
# [395]	validation_0-rmse:839.12461	validation_1-rmse:1269.61492
# [396]	validation_0-rmse:839.10812	validation_1-rmse:1269.56706
# [397]	validation_0-rmse:839.09172	validation_1-rmse:1269.52032
# [398]	validation_0-rmse:839.07534	validation_1-rmse:1269.47347
# [399]	validation_0-rmse:839.05904	validation_1-rmse:1269.42637
# [400]	validation_0-rmse:839.04280	validation_1-rmse:1269.37843
# [401]	validation_0-rmse:839.02658	validation_1-rmse:1269.32913
# [402]	validation_0-rmse:839.01041	validation_1-rmse:1269.28194
# [403]	validation_0-rmse:838.99430	validation_1-rmse:1269.23523
# [404]	validation_0-rmse:838.97826	validation_1-rmse:1269.18575
# [405]	validation_0-rmse:838.96225	validation_1-rmse:1269.13803
# [406]	validation_0-rmse:838.94630	validation_1-rmse:1269.08876
# [407]	validation_0-rmse:838.93043	validation_1-rmse:1269.03773
# [408]	validation_0-rmse:838.91457	validation_1-rmse:1268.98883
# [409]	validation_0-rmse:838.89878	validation_1-rmse:1268.94061
# [410]	validation_0-rmse:838.88305	validation_1-rmse:1268.89031
# [411]	validation_0-rmse:838.86733	validation_1-rmse:1268.84162
# [412]	validation_0-rmse:838.85169	validation_1-rmse:1268.79249
# [413]	validation_0-rmse:838.83609	validation_1-rmse:1268.74266
# [414]	validation_0-rmse:838.82054	validation_1-rmse:1268.69264
# [415]	validation_0-rmse:838.80500	validation_1-rmse:1268.64278
# [416]	validation_0-rmse:838.78953	validation_1-rmse:1268.59290
# [417]	validation_0-rmse:838.77415	validation_1-rmse:1268.54150
# [418]	validation_0-rmse:838.75876	validation_1-rmse:1268.49190
# [419]	validation_0-rmse:838.74342	validation_1-rmse:1268.44175
# [420]	validation_0-rmse:838.72814	validation_1-rmse:1268.39079
# [421]	validation_0-rmse:838.71290	validation_1-rmse:1268.33926
# [422]	validation_0-rmse:838.69770	validation_1-rmse:1268.28689
# [423]	validation_0-rmse:838.68252	validation_1-rmse:1268.23528
# [424]	validation_0-rmse:838.66740	validation_1-rmse:1268.18419
# [425]	validation_0-rmse:838.65230	validation_1-rmse:1268.13434
# [426]	validation_0-rmse:838.63732	validation_1-rmse:1268.08157
# [427]	validation_0-rmse:838.62231	validation_1-rmse:1268.03159
# [428]	validation_0-rmse:838.60735	validation_1-rmse:1267.98116
# [429]	validation_0-rmse:838.59242	validation_1-rmse:1267.92979
# [430]	validation_0-rmse:838.57755	validation_1-rmse:1267.87884
# [431]	validation_0-rmse:838.56270	validation_1-rmse:1267.82768
# [432]	validation_0-rmse:838.54793	validation_1-rmse:1267.77506
# [433]	validation_0-rmse:838.53320	validation_1-rmse:1267.72315
# [434]	validation_0-rmse:838.51846	validation_1-rmse:1267.67248
# [435]	validation_0-rmse:838.50379	validation_1-rmse:1267.62163
# [436]	validation_0-rmse:838.48918	validation_1-rmse:1267.56881
# [437]	validation_0-rmse:838.47457	validation_1-rmse:1267.51609
# [438]	validation_0-rmse:838.46002	validation_1-rmse:1267.46259
# [439]	validation_0-rmse:838.44550	validation_1-rmse:1267.41001
# [440]	validation_0-rmse:838.43099	validation_1-rmse:1267.35823
# [441]	validation_0-rmse:838.41655	validation_1-rmse:1267.30609
# [442]	validation_0-rmse:838.40215	validation_1-rmse:1267.25319
# [443]	validation_0-rmse:838.38777	validation_1-rmse:1267.19906
# [444]	validation_0-rmse:838.37345	validation_1-rmse:1267.14659
# [445]	validation_0-rmse:838.35915	validation_1-rmse:1267.09263
# [446]	validation_0-rmse:838.34490	validation_1-rmse:1267.03895
# [447]	validation_0-rmse:838.33070	validation_1-rmse:1266.98400
# [448]	validation_0-rmse:838.31648	validation_1-rmse:1266.93166
# [449]	validation_0-rmse:838.30232	validation_1-rmse:1266.87754
# [450]	validation_0-rmse:838.28820	validation_1-rmse:1266.82348
# [451]	validation_0-rmse:838.27412	validation_1-rmse:1266.77013
# [452]	validation_0-rmse:838.26005	validation_1-rmse:1266.71638
# [453]	validation_0-rmse:838.24606	validation_1-rmse:1266.66217
# [454]	validation_0-rmse:838.23209	validation_1-rmse:1266.60854
# [455]	validation_0-rmse:838.21812	validation_1-rmse:1266.55568
# [456]	validation_0-rmse:838.20419	validation_1-rmse:1266.50245
# [457]	validation_0-rmse:838.19031	validation_1-rmse:1266.44808
# [458]	validation_0-rmse:838.17643	validation_1-rmse:1266.39303
# [459]	validation_0-rmse:838.16261	validation_1-rmse:1266.33889
# [460]	validation_0-rmse:838.14881	validation_1-rmse:1266.28414
# [461]	validation_0-rmse:838.13506	validation_1-rmse:1266.23005
# [462]	validation_0-rmse:838.12134	validation_1-rmse:1266.17522
# [463]	validation_0-rmse:838.10763	validation_1-rmse:1266.12177
# [464]	validation_0-rmse:838.09395	validation_1-rmse:1266.06624
# [465]	validation_0-rmse:838.08032	validation_1-rmse:1266.01137
# [466]	validation_0-rmse:838.06670	validation_1-rmse:1265.95921
# [467]	validation_0-rmse:838.05312	validation_1-rmse:1265.90407
# [468]	validation_0-rmse:838.03959	validation_1-rmse:1265.85016
# [469]	validation_0-rmse:838.02609	validation_1-rmse:1265.79455
# [470]	validation_0-rmse:838.01258	validation_1-rmse:1265.73974
# [471]	validation_0-rmse:837.99911	validation_1-rmse:1265.68461
# [472]	validation_0-rmse:837.98571	validation_1-rmse:1265.62895
# [473]	validation_0-rmse:837.97233	validation_1-rmse:1265.57373
# [474]	validation_0-rmse:837.95897	validation_1-rmse:1265.51987
# [475]	validation_0-rmse:837.94563	validation_1-rmse:1265.46429
# [476]	validation_0-rmse:837.93233	validation_1-rmse:1265.41017
# [477]	validation_0-rmse:837.91904	validation_1-rmse:1265.35546
# [478]	validation_0-rmse:837.90579	validation_1-rmse:1265.30031
# [479]	validation_0-rmse:837.89257	validation_1-rmse:1265.24562
# [480]	validation_0-rmse:837.87939	validation_1-rmse:1265.18975
# [481]	validation_0-rmse:837.86625	validation_1-rmse:1265.13383
# [482]	validation_0-rmse:837.85311	validation_1-rmse:1265.07961
# [483]	validation_0-rmse:837.84000	validation_1-rmse:1265.02498
# [484]	validation_0-rmse:837.82691	validation_1-rmse:1264.96970
# [485]	validation_0-rmse:837.81388	validation_1-rmse:1264.91489
# [486]	validation_0-rmse:837.80084	validation_1-rmse:1264.85932
# [487]	validation_0-rmse:837.78785	validation_1-rmse:1264.80324
# [488]	validation_0-rmse:837.77487	validation_1-rmse:1264.74752
# [489]	validation_0-rmse:837.76189	validation_1-rmse:1264.69343
# [490]	validation_0-rmse:837.74895	validation_1-rmse:1264.63899
# [491]	validation_0-rmse:837.73605	validation_1-rmse:1264.58431
# [492]	validation_0-rmse:837.72318	validation_1-rmse:1264.52868
# [493]	validation_0-rmse:837.71030	validation_1-rmse:1264.47452
# [494]	validation_0-rmse:837.69748	validation_1-rmse:1264.41863
# [495]	validation_0-rmse:837.68470	validation_1-rmse:1264.36238
# [496]	validation_0-rmse:837.67191	validation_1-rmse:1264.30796
# [497]	validation_0-rmse:837.65917	validation_1-rmse:1264.25212
# [498]	validation_0-rmse:837.64644	validation_1-rmse:1264.19617
# [499]	validation_0-rmse:837.63374	validation_1-rmse:1264.14083
# [500]	validation_0-rmse:837.62107	validation_1-rmse:1264.08470
# [501]	validation_0-rmse:837.60842	validation_1-rmse:1264.02847
# [502]	validation_0-rmse:837.59577	validation_1-rmse:1263.97377
# [503]	validation_0-rmse:837.58317	validation_1-rmse:1263.91749
# [504]	validation_0-rmse:837.57063	validation_1-rmse:1263.86080
# [505]	validation_0-rmse:837.55810	validation_1-rmse:1263.80509
# [506]	validation_0-rmse:837.54558	validation_1-rmse:1263.75009
# [507]	validation_0-rmse:837.53308	validation_1-rmse:1263.69429
# [508]	validation_0-rmse:837.52059	validation_1-rmse:1263.63862
# [509]	validation_0-rmse:837.50814	validation_1-rmse:1263.58326
# [510]	validation_0-rmse:837.49570	validation_1-rmse:1263.52748
# [511]	validation_0-rmse:837.48332	validation_1-rmse:1263.47158
# [512]	validation_0-rmse:837.47095	validation_1-rmse:1263.41565
# [513]	validation_0-rmse:837.45858	validation_1-rmse:1263.36117
# [514]	validation_0-rmse:837.44623	validation_1-rmse:1263.30531
# [515]	validation_0-rmse:837.43394	validation_1-rmse:1263.24907
# [516]	validation_0-rmse:837.42166	validation_1-rmse:1263.19386
# [517]	validation_0-rmse:837.40938	validation_1-rmse:1263.13869
# [518]	validation_0-rmse:837.39713	validation_1-rmse:1263.08293
# [519]	validation_0-rmse:837.38490	validation_1-rmse:1263.02732
# [520]	validation_0-rmse:837.37269	validation_1-rmse:1262.97208
# [521]	validation_0-rmse:837.36049	validation_1-rmse:1262.91752
# [522]	validation_0-rmse:837.34833	validation_1-rmse:1262.86276
# [523]	validation_0-rmse:837.33618	validation_1-rmse:1262.80881
# [524]	validation_0-rmse:837.32406	validation_1-rmse:1262.75462
# [525]	validation_0-rmse:837.31199	validation_1-rmse:1262.69876
# [526]	validation_0-rmse:837.29992	validation_1-rmse:1262.64294
# [527]	validation_0-rmse:837.28786	validation_1-rmse:1262.58834
# [528]	validation_0-rmse:837.27582	validation_1-rmse:1262.53416
# [529]	validation_0-rmse:837.26382	validation_1-rmse:1262.47950
# [530]	validation_0-rmse:837.25181	validation_1-rmse:1262.42627
# [531]	validation_0-rmse:837.23986	validation_1-rmse:1262.37155
# [532]	validation_0-rmse:837.22790	validation_1-rmse:1262.31682
# [533]	validation_0-rmse:837.21599	validation_1-rmse:1262.26163
# [534]	validation_0-rmse:837.20408	validation_1-rmse:1262.20671
# [535]	validation_0-rmse:837.19219	validation_1-rmse:1262.15132
# [536]	validation_0-rmse:837.18031	validation_1-rmse:1262.09602
# [537]	validation_0-rmse:837.16847	validation_1-rmse:1262.04008
# [538]	validation_0-rmse:837.15663	validation_1-rmse:1261.98478
# [539]	validation_0-rmse:837.14482	validation_1-rmse:1261.93111
# [540]	validation_0-rmse:837.13302	validation_1-rmse:1261.87762
# [541]	validation_0-rmse:837.12124	validation_1-rmse:1261.82272
# [542]	validation_0-rmse:837.10948	validation_1-rmse:1261.76751
# [543]	validation_0-rmse:837.09773	validation_1-rmse:1261.71416
# [544]	validation_0-rmse:837.08604	validation_1-rmse:1261.65970
# [545]	validation_0-rmse:837.07434	validation_1-rmse:1261.60462
# [546]	validation_0-rmse:837.06265	validation_1-rmse:1261.54929
# [547]	validation_0-rmse:837.05100	validation_1-rmse:1261.49545
# [548]	validation_0-rmse:837.03936	validation_1-rmse:1261.43997
# [549]	validation_0-rmse:837.02774	validation_1-rmse:1261.38599
# [550]	validation_0-rmse:837.01613	validation_1-rmse:1261.33220
# [551]	validation_0-rmse:837.00456	validation_1-rmse:1261.27880
# [552]	validation_0-rmse:836.99300	validation_1-rmse:1261.22481
# [553]	validation_0-rmse:836.98147	validation_1-rmse:1261.16965
# [554]	validation_0-rmse:836.96994	validation_1-rmse:1261.11518
# [555]	validation_0-rmse:836.95843	validation_1-rmse:1261.06046
# [556]	validation_0-rmse:836.94696	validation_1-rmse:1261.00544
# [557]	validation_0-rmse:836.93549	validation_1-rmse:1260.95196
# [558]	validation_0-rmse:836.92405	validation_1-rmse:1260.89820
# [559]	validation_0-rmse:836.91260	validation_1-rmse:1260.84518
# [560]	validation_0-rmse:836.90119	validation_1-rmse:1260.79041
# [561]	validation_0-rmse:836.88982	validation_1-rmse:1260.73556
# [562]	validation_0-rmse:836.87844	validation_1-rmse:1260.68142
# [563]	validation_0-rmse:836.86710	validation_1-rmse:1260.62803
# [564]	validation_0-rmse:836.85578	validation_1-rmse:1260.57433
# [565]	validation_0-rmse:836.84449	validation_1-rmse:1260.51995
# [566]	validation_0-rmse:836.83317	validation_1-rmse:1260.46596
# [567]	validation_0-rmse:836.82189	validation_1-rmse:1260.41147
# [568]	validation_0-rmse:836.81064	validation_1-rmse:1260.35717
# [569]	validation_0-rmse:836.79938	validation_1-rmse:1260.30369
# [570]	validation_0-rmse:836.78816	validation_1-rmse:1260.25107
# [571]	validation_0-rmse:836.77695	validation_1-rmse:1260.19847
# [572]	validation_0-rmse:836.76573	validation_1-rmse:1260.14448
# [573]	validation_0-rmse:836.75458	validation_1-rmse:1260.09036
# [574]	validation_0-rmse:836.74342	validation_1-rmse:1260.03725
# [575]	validation_0-rmse:836.73229	validation_1-rmse:1259.98400
# [576]	validation_0-rmse:836.72115	validation_1-rmse:1259.93122
# [577]	validation_0-rmse:836.71005	validation_1-rmse:1259.87871
# [578]	validation_0-rmse:836.69896	validation_1-rmse:1259.82618
# [579]	validation_0-rmse:836.68789	validation_1-rmse:1259.77289
# [580]	validation_0-rmse:836.67685	validation_1-rmse:1259.72077
# [581]	validation_0-rmse:836.66581	validation_1-rmse:1259.66774
# [582]	validation_0-rmse:836.65479	validation_1-rmse:1259.61566
# [583]	validation_0-rmse:836.64378	validation_1-rmse:1259.56347
# [584]	validation_0-rmse:836.63277	validation_1-rmse:1259.51231
# [585]	validation_0-rmse:836.62180	validation_1-rmse:1259.46093
# [586]	validation_0-rmse:836.61083	validation_1-rmse:1259.40901
# [587]	validation_0-rmse:836.59989	validation_1-rmse:1259.35675
# [588]	validation_0-rmse:836.58894	validation_1-rmse:1259.30536
# [589]	validation_0-rmse:836.57802	validation_1-rmse:1259.25242
# [590]	validation_0-rmse:836.56713	validation_1-rmse:1259.19935
# [591]	validation_0-rmse:836.55628	validation_1-rmse:1259.14722
# [592]	validation_0-rmse:836.54541	validation_1-rmse:1259.09563
# [593]	validation_0-rmse:836.53455	validation_1-rmse:1259.04285
# [594]	validation_0-rmse:836.52372	validation_1-rmse:1258.99038
# [595]	validation_0-rmse:836.51290	validation_1-rmse:1258.93787
# [596]	validation_0-rmse:836.50211	validation_1-rmse:1258.88647
# [597]	validation_0-rmse:836.49131	validation_1-rmse:1258.83397
# [598]	validation_0-rmse:836.48055	validation_1-rmse:1258.78131
# [599]	validation_0-rmse:836.46982	validation_1-rmse:1258.72974
# [600]	validation_0-rmse:836.45907	validation_1-rmse:1258.67787
# [601]	validation_0-rmse:836.44833	validation_1-rmse:1258.62579
# [602]	validation_0-rmse:836.43762	validation_1-rmse:1258.57541
# [603]	validation_0-rmse:836.42692	validation_1-rmse:1258.52370
# [604]	validation_0-rmse:836.41627	validation_1-rmse:1258.47171
# [605]	validation_0-rmse:836.40561	validation_1-rmse:1258.42094
# [606]	validation_0-rmse:836.39498	validation_1-rmse:1258.36898
# [607]	validation_0-rmse:836.38435	validation_1-rmse:1258.31803
# [608]	validation_0-rmse:836.37373	validation_1-rmse:1258.26596
# [609]	validation_0-rmse:836.36314	validation_1-rmse:1258.21408
# [610]	validation_0-rmse:836.35256	validation_1-rmse:1258.16277
# [611]	validation_0-rmse:836.34197	validation_1-rmse:1258.11205
# [612]	validation_0-rmse:836.33144	validation_1-rmse:1258.06142
# [613]	validation_0-rmse:836.32089	validation_1-rmse:1258.01022
# [614]	validation_0-rmse:836.31037	validation_1-rmse:1257.95902
# [615]	validation_0-rmse:836.29987	validation_1-rmse:1257.90778
# [616]	validation_0-rmse:836.28936	validation_1-rmse:1257.85770
# [617]	validation_0-rmse:836.27887	validation_1-rmse:1257.80809
# [618]	validation_0-rmse:836.26840	validation_1-rmse:1257.75722
# [619]	validation_0-rmse:836.25798	validation_1-rmse:1257.70628
# [620]	validation_0-rmse:836.24753	validation_1-rmse:1257.65682
# [621]	validation_0-rmse:836.23709	validation_1-rmse:1257.60775
# [622]	validation_0-rmse:836.22670	validation_1-rmse:1257.55686
# [623]	validation_0-rmse:836.21631	validation_1-rmse:1257.50650
# [624]	validation_0-rmse:836.20592	validation_1-rmse:1257.45701
# [625]	validation_0-rmse:836.19557	validation_1-rmse:1257.40680
# [626]	validation_0-rmse:836.18524	validation_1-rmse:1257.35716
# [627]	validation_0-rmse:836.17491	validation_1-rmse:1257.30746
# [628]	validation_0-rmse:836.16459	validation_1-rmse:1257.25749
# [629]	validation_0-rmse:836.15428	validation_1-rmse:1257.20841
# [630]	validation_0-rmse:836.14398	validation_1-rmse:1257.15902
# [631]	validation_0-rmse:836.13370	validation_1-rmse:1257.10942
# [632]	validation_0-rmse:836.12346	validation_1-rmse:1257.05945
# [633]	validation_0-rmse:836.11322	validation_1-rmse:1257.00964
# [634]	validation_0-rmse:836.10300	validation_1-rmse:1256.96037
# [635]	validation_0-rmse:836.09277	validation_1-rmse:1256.91172
# [636]	validation_0-rmse:836.08256	validation_1-rmse:1256.86256
# [637]	validation_0-rmse:836.07238	validation_1-rmse:1256.81436
# [638]	validation_0-rmse:836.06220	validation_1-rmse:1256.76530
# [639]	validation_0-rmse:836.05202	validation_1-rmse:1256.71709
# [640]	validation_0-rmse:836.04186	validation_1-rmse:1256.66907
# [641]	validation_0-rmse:836.03170	validation_1-rmse:1256.62050
# [642]	validation_0-rmse:836.02156	validation_1-rmse:1256.57175
# [643]	validation_0-rmse:836.01146	validation_1-rmse:1256.52261
# [644]	validation_0-rmse:836.00134	validation_1-rmse:1256.47523
# [645]	validation_0-rmse:835.99126	validation_1-rmse:1256.42682
# [646]	validation_0-rmse:835.98119	validation_1-rmse:1256.37814
# [647]	validation_0-rmse:835.97115	validation_1-rmse:1256.32969
# [648]	validation_0-rmse:835.96111	validation_1-rmse:1256.28183
# [649]	validation_0-rmse:835.95108	validation_1-rmse:1256.23321
# [650]	validation_0-rmse:835.94106	validation_1-rmse:1256.18472
# [651]	validation_0-rmse:835.93106	validation_1-rmse:1256.13624
# [652]	validation_0-rmse:835.92107	validation_1-rmse:1256.08831
# [653]	validation_0-rmse:835.91108	validation_1-rmse:1256.04116
# [654]	validation_0-rmse:835.90110	validation_1-rmse:1255.99420
# [655]	validation_0-rmse:835.89115	validation_1-rmse:1255.94718
# [656]	validation_0-rmse:835.88120	validation_1-rmse:1255.89945
# [657]	validation_0-rmse:835.87126	validation_1-rmse:1255.85255
# [658]	validation_0-rmse:835.86133	validation_1-rmse:1255.80649
# [659]	validation_0-rmse:835.85142	validation_1-rmse:1255.76079
# [660]	validation_0-rmse:835.84153	validation_1-rmse:1255.71309
# [661]	validation_0-rmse:835.83165	validation_1-rmse:1255.66607
# [662]	validation_0-rmse:835.82179	validation_1-rmse:1255.61910
# [663]	validation_0-rmse:835.81193	validation_1-rmse:1255.57317
# [664]	validation_0-rmse:835.80209	validation_1-rmse:1255.52605
# [665]	validation_0-rmse:835.79227	validation_1-rmse:1255.47897
# [666]	validation_0-rmse:835.78245	validation_1-rmse:1255.43284
# [667]	validation_0-rmse:835.77265	validation_1-rmse:1255.38744
# [668]	validation_0-rmse:835.76286	validation_1-rmse:1255.34153
# [669]	validation_0-rmse:835.75309	validation_1-rmse:1255.29450
# ...
# [747]	validation_0-rmse:924.51918	validation_1-rmse:1324.09288
# [748]	validation_0-rmse:924.50895	validation_1-rmse:1324.07830
# [749]	validation_0-rmse:924.49876	validation_1-rmse:1324.06335
# [750]	validation_0-rmse:924.48855	validation_1-rmse:1324.04870
# [751]	validation_0-rmse:924.47838	validation_1-rmse:1324.03481
# [752]	validation_0-rmse:924.46820	validation_1-rmse:1324.02013
# [753]	validation_0-rmse:924.45806	validation_1-rmse:1324.00547
# [754]	validation_0-rmse:924.44794	validation_1-rmse:1323.99091
# [755]	validation_0-rmse:924.43782	validation_1-rmse:1323.97648
# [756]	validation_0-rmse:924.42769	validation_1-rmse:1323.96199
# [757]	validation_0-rmse:924.41758	validation_1-rmse:1323.94694
# [758]	validation_0-rmse:924.40749	validation_1-rmse:1323.93211
# [759]	validation_0-rmse:924.39741	validation_1-rmse:1323.91726
# [760]	validation_0-rmse:924.38736	validation_1-rmse:1323.90277
# [761]	validation_0-rmse:924.37730	validation_1-rmse:1323.88797
# [762]	validation_0-rmse:924.36726	validation_1-rmse:1323.87403
# [763]	validation_0-rmse:924.35723	validation_1-rmse:1323.85897
# [764]	validation_0-rmse:924.34724	validation_1-rmse:1323.84361
# [765]	validation_0-rmse:924.33723	validation_1-rmse:1323.82859
# [766]	validation_0-rmse:924.32725	validation_1-rmse:1323.81404
# [767]	validation_0-rmse:924.31728	validation_1-rmse:1323.79927
# [768]	validation_0-rmse:924.30733	validation_1-rmse:1323.78486
# [769]	validation_0-rmse:924.29737	validation_1-rmse:1323.76984
# [770]	validation_0-rmse:924.28745	validation_1-rmse:1323.75517
# [771]	validation_0-rmse:924.27752	validation_1-rmse:1323.74026
# [772]	validation_0-rmse:924.26761	validation_1-rmse:1323.72520
# [773]	validation_0-rmse:924.25771	validation_1-rmse:1323.71040
# [774]	validation_0-rmse:924.24780	validation_1-rmse:1323.69561
# [775]	validation_0-rmse:924.23793	validation_1-rmse:1323.68094
# [776]	validation_0-rmse:924.22808	validation_1-rmse:1323.66655
# [777]	validation_0-rmse:924.21821	validation_1-rmse:1323.65157
# [778]	validation_0-rmse:924.20839	validation_1-rmse:1323.63749
# [779]	validation_0-rmse:924.19858	validation_1-rmse:1323.62320
# [780]	validation_0-rmse:924.18877	validation_1-rmse:1323.60863
# [781]	validation_0-rmse:924.17898	validation_1-rmse:1323.59389
# [782]	validation_0-rmse:924.16920	validation_1-rmse:1323.57939
# [783]	validation_0-rmse:924.15942	validation_1-rmse:1323.56472
# [784]	validation_0-rmse:924.14965	validation_1-rmse:1323.54955
# [785]	validation_0-rmse:924.13991	validation_1-rmse:1323.53489
# [786]	validation_0-rmse:924.13018	validation_1-rmse:1323.52022
# [787]	validation_0-rmse:924.12045	validation_1-rmse:1323.50533
# [788]	validation_0-rmse:924.11071	validation_1-rmse:1323.49053
# [789]	validation_0-rmse:924.10103	validation_1-rmse:1323.47582
# [790]	validation_0-rmse:924.09133	validation_1-rmse:1323.46066
# [791]	validation_0-rmse:924.08164	validation_1-rmse:1323.44562
# [792]	validation_0-rmse:924.07197	validation_1-rmse:1323.43098
# [793]	validation_0-rmse:924.06234	validation_1-rmse:1323.41600
# [794]	validation_0-rmse:924.05267	validation_1-rmse:1323.40100
# [795]	validation_0-rmse:924.04305	validation_1-rmse:1323.38627
# [796]	validation_0-rmse:924.03342	validation_1-rmse:1323.37118
# [797]	validation_0-rmse:924.02383	validation_1-rmse:1323.35683
# [798]	validation_0-rmse:924.01424	validation_1-rmse:1323.34255
# [799]	validation_0-rmse:924.00466	validation_1-rmse:1323.32800
# [800]	validation_0-rmse:923.99511	validation_1-rmse:1323.31342
# [801]	validation_0-rmse:923.98554	validation_1-rmse:1323.29846
# [802]	validation_0-rmse:923.97599	validation_1-rmse:1323.28327
# [803]	validation_0-rmse:923.96646	validation_1-rmse:1323.26811
# [804]	validation_0-rmse:923.95692	validation_1-rmse:1323.25271
# [805]	validation_0-rmse:923.94740	validation_1-rmse:1323.23789
# [806]	validation_0-rmse:923.93790	validation_1-rmse:1323.22283
# [807]	validation_0-rmse:923.92839	validation_1-rmse:1323.20782
# [808]	validation_0-rmse:923.91892	validation_1-rmse:1323.19374
# [809]	validation_0-rmse:923.90945	validation_1-rmse:1323.17916
# [810]	validation_0-rmse:923.90000	validation_1-rmse:1323.16505
# [811]	validation_0-rmse:923.89057	validation_1-rmse:1323.15077
# [812]	validation_0-rmse:923.88114	validation_1-rmse:1323.13649
# [813]	validation_0-rmse:923.87172	validation_1-rmse:1323.12180
# [814]	validation_0-rmse:923.86229	validation_1-rmse:1323.10705
# [815]	validation_0-rmse:923.85288	validation_1-rmse:1323.09217
# [816]	validation_0-rmse:923.84349	validation_1-rmse:1323.07716
# [817]	validation_0-rmse:923.83411	validation_1-rmse:1323.06200
# [818]	validation_0-rmse:923.82474	validation_1-rmse:1323.04751
# [819]	validation_0-rmse:923.81540	validation_1-rmse:1323.03339
# [820]	validation_0-rmse:923.80606	validation_1-rmse:1323.01879
# [821]	validation_0-rmse:923.79674	validation_1-rmse:1323.00395
# [822]	validation_0-rmse:923.78741	validation_1-rmse:1322.98902
# [823]	validation_0-rmse:923.77809	validation_1-rmse:1322.97379
# [824]	validation_0-rmse:923.76879	validation_1-rmse:1322.95889
# [825]	validation_0-rmse:923.75949	validation_1-rmse:1322.94424
# [826]	validation_0-rmse:923.75021	validation_1-rmse:1322.93000
# [827]	validation_0-rmse:923.74092	validation_1-rmse:1322.91505
# [828]	validation_0-rmse:923.73169	validation_1-rmse:1322.90069
# [829]	validation_0-rmse:923.72244	validation_1-rmse:1322.88597
# [830]	validation_0-rmse:923.71320	validation_1-rmse:1322.87122
# [831]	validation_0-rmse:923.70396	validation_1-rmse:1322.85608
# [832]	validation_0-rmse:923.69475	validation_1-rmse:1322.84164
# [833]	validation_0-rmse:923.68554	validation_1-rmse:1322.82717
# [834]	validation_0-rmse:923.67634	validation_1-rmse:1322.81248
# [835]	validation_0-rmse:923.66716	validation_1-rmse:1322.79723
# [836]	validation_0-rmse:923.65801	validation_1-rmse:1322.78243
# [837]	validation_0-rmse:923.64884	validation_1-rmse:1322.76749
# [838]	validation_0-rmse:923.63969	validation_1-rmse:1322.75273
# [839]	validation_0-rmse:923.63055	validation_1-rmse:1322.73879
# [840]	validation_0-rmse:923.62143	validation_1-rmse:1322.72400
# [841]	validation_0-rmse:923.61231	validation_1-rmse:1322.70902
# [842]	validation_0-rmse:923.60321	validation_1-rmse:1322.69420
# [843]	validation_0-rmse:923.59411	validation_1-rmse:1322.67912
# [844]	validation_0-rmse:923.58501	validation_1-rmse:1322.66433
# [845]	validation_0-rmse:923.57593	validation_1-rmse:1322.64934
# [846]	validation_0-rmse:923.56687	validation_1-rmse:1322.63530
# [847]	validation_0-rmse:923.55782	validation_1-rmse:1322.62062
# [848]	validation_0-rmse:923.54878	validation_1-rmse:1322.60612
# [849]	validation_0-rmse:923.53976	validation_1-rmse:1322.59130
# [850]	validation_0-rmse:923.53075	validation_1-rmse:1322.57675
# [851]	validation_0-rmse:923.52171	validation_1-rmse:1322.56201
# [852]	validation_0-rmse:923.51273	validation_1-rmse:1322.54762
# [853]	validation_0-rmse:923.50373	validation_1-rmse:1322.53319
# [854]	validation_0-rmse:923.49475	validation_1-rmse:1322.51833
# [855]	validation_0-rmse:923.48580	validation_1-rmse:1322.50380
# [856]	validation_0-rmse:923.47684	validation_1-rmse:1322.48893
# [857]	validation_0-rmse:923.46789	validation_1-rmse:1322.47474
# [858]	validation_0-rmse:923.45894	validation_1-rmse:1322.45957
# [859]	validation_0-rmse:923.45003	validation_1-rmse:1322.44504
# [860]	validation_0-rmse:923.44109	validation_1-rmse:1322.43011
# [861]	validation_0-rmse:923.43219	validation_1-rmse:1322.41554
# [862]	validation_0-rmse:923.42329	validation_1-rmse:1322.40133
# [863]	validation_0-rmse:923.41441	validation_1-rmse:1322.38669
# [864]	validation_0-rmse:923.40551	validation_1-rmse:1322.37170
# [865]	validation_0-rmse:923.39666	validation_1-rmse:1322.35721
# [866]	validation_0-rmse:923.38779	validation_1-rmse:1322.34255
# [867]	validation_0-rmse:923.37894	validation_1-rmse:1322.32772
# [868]	validation_0-rmse:923.37010	validation_1-rmse:1322.31275
# [869]	validation_0-rmse:923.36127	validation_1-rmse:1322.29816
# [870]	validation_0-rmse:923.35243	validation_1-rmse:1322.28366
# [871]	validation_0-rmse:923.34361	validation_1-rmse:1322.26928
# [872]	validation_0-rmse:923.33480	validation_1-rmse:1322.25462
# [873]	validation_0-rmse:923.32601	validation_1-rmse:1322.24011
# [874]	validation_0-rmse:923.31724	validation_1-rmse:1322.22589
# [875]	validation_0-rmse:923.30844	validation_1-rmse:1322.21088
# [876]	validation_0-rmse:923.29969	validation_1-rmse:1322.19640
# [877]	validation_0-rmse:923.29093	validation_1-rmse:1322.18178
# [878]	validation_0-rmse:923.28219	validation_1-rmse:1322.16659
# [879]	validation_0-rmse:923.27346	validation_1-rmse:1322.15199
# [880]	validation_0-rmse:923.26473	validation_1-rmse:1322.13738
# [881]	validation_0-rmse:923.25602	validation_1-rmse:1322.12291
# [882]	validation_0-rmse:923.24730	validation_1-rmse:1322.10837
# [883]	validation_0-rmse:923.23861	validation_1-rmse:1322.09340
# [884]	validation_0-rmse:923.22993	validation_1-rmse:1322.07878
# [885]	validation_0-rmse:923.22127	validation_1-rmse:1322.06385
# [886]	validation_0-rmse:923.21261	validation_1-rmse:1322.05004
# [887]	validation_0-rmse:923.20395	validation_1-rmse:1322.03603
# [888]	validation_0-rmse:923.19530	validation_1-rmse:1322.02211
# [889]	validation_0-rmse:923.18667	validation_1-rmse:1322.00755
# [890]	validation_0-rmse:923.17807	validation_1-rmse:1321.99314
# [891]	validation_0-rmse:923.16945	validation_1-rmse:1321.97871
# [892]	validation_0-rmse:923.16085	validation_1-rmse:1321.96426
# [893]	validation_0-rmse:923.15225	validation_1-rmse:1321.94983
# [894]	validation_0-rmse:923.14366	validation_1-rmse:1321.93541
# [895]	validation_0-rmse:923.13509	validation_1-rmse:1321.92099
# [896]	validation_0-rmse:923.12652	validation_1-rmse:1321.90650
# [897]	validation_0-rmse:923.11797	validation_1-rmse:1321.89193
# [898]	validation_0-rmse:923.10942	validation_1-rmse:1321.87768
# [899]	validation_0-rmse:923.10087	validation_1-rmse:1321.86298
# [900]	validation_0-rmse:923.09236	validation_1-rmse:1321.84842
# [901]	validation_0-rmse:923.08383	validation_1-rmse:1321.83350
# [902]	validation_0-rmse:923.07533	validation_1-rmse:1321.81933
# [903]	validation_0-rmse:923.06682	validation_1-rmse:1321.80444
# [904]	validation_0-rmse:923.05834	validation_1-rmse:1321.79001
# [905]	validation_0-rmse:923.04986	validation_1-rmse:1321.77568
# [906]	validation_0-rmse:923.04138	validation_1-rmse:1321.76087
# [907]	validation_0-rmse:923.03292	validation_1-rmse:1321.74656
# [908]	validation_0-rmse:923.02446	validation_1-rmse:1321.73176
# [909]	validation_0-rmse:923.01602	validation_1-rmse:1321.71725
# [910]	validation_0-rmse:923.00758	validation_1-rmse:1321.70268
# [911]	validation_0-rmse:922.99915	validation_1-rmse:1321.68859
# [912]	validation_0-rmse:922.99073	validation_1-rmse:1321.67390
# [913]	validation_0-rmse:922.98233	validation_1-rmse:1321.65919
# [914]	validation_0-rmse:922.97392	validation_1-rmse:1321.64449
# [915]	validation_0-rmse:922.96553	validation_1-rmse:1321.62972
# [916]	validation_0-rmse:922.95716	validation_1-rmse:1321.61574
# [917]	validation_0-rmse:922.94878	validation_1-rmse:1321.60138
# [918]	validation_0-rmse:922.94043	validation_1-rmse:1321.58749
# [919]	validation_0-rmse:922.93207	validation_1-rmse:1321.57322
# [920]	validation_0-rmse:922.92373	validation_1-rmse:1321.55877
# [921]	validation_0-rmse:922.91537	validation_1-rmse:1321.54443
# [922]	validation_0-rmse:922.90703	validation_1-rmse:1321.53003
# [923]	validation_0-rmse:922.89871	validation_1-rmse:1321.51616
# [924]	validation_0-rmse:922.89041	validation_1-rmse:1321.50195
# [925]	validation_0-rmse:922.88212	validation_1-rmse:1321.48760
# [926]	validation_0-rmse:922.87382	validation_1-rmse:1321.47355
# [927]	validation_0-rmse:922.86553	validation_1-rmse:1321.45920
# [928]	validation_0-rmse:922.85726	validation_1-rmse:1321.44522
# [929]	validation_0-rmse:922.84901	validation_1-rmse:1321.43104
# [930]	validation_0-rmse:922.84073	validation_1-rmse:1321.41658
# [931]	validation_0-rmse:922.83251	validation_1-rmse:1321.40232
# [932]	validation_0-rmse:922.82426	validation_1-rmse:1321.38811
# [933]	validation_0-rmse:922.81603	validation_1-rmse:1321.37389
# [934]	validation_0-rmse:922.80782	validation_1-rmse:1321.35979
# [935]	validation_0-rmse:922.79960	validation_1-rmse:1321.34503
# [936]	validation_0-rmse:922.79139	validation_1-rmse:1321.33074
# [937]	validation_0-rmse:922.78320	validation_1-rmse:1321.31631
# [938]	validation_0-rmse:922.77501	validation_1-rmse:1321.30255
# [939]	validation_0-rmse:922.76684	validation_1-rmse:1321.28819
# [940]	validation_0-rmse:922.75866	validation_1-rmse:1321.27429
# [941]	validation_0-rmse:922.75052	validation_1-rmse:1321.26006
# [942]	validation_0-rmse:922.74235	validation_1-rmse:1321.24594
# [943]	validation_0-rmse:922.73423	validation_1-rmse:1321.23198
# [944]	validation_0-rmse:922.72609	validation_1-rmse:1321.21784
# [945]	validation_0-rmse:922.71796	validation_1-rmse:1321.20351
# [946]	validation_0-rmse:922.70986	validation_1-rmse:1321.18933
# [947]	validation_0-rmse:922.70175	validation_1-rmse:1321.17515
# [948]	validation_0-rmse:922.69364	validation_1-rmse:1321.16063
# [949]	validation_0-rmse:922.68555	validation_1-rmse:1321.14695
# [950]	validation_0-rmse:922.67746	validation_1-rmse:1321.13217
# [951]	validation_0-rmse:922.66939	validation_1-rmse:1321.11809
# [952]	validation_0-rmse:922.66132	validation_1-rmse:1321.10368
# [953]	validation_0-rmse:922.65327	validation_1-rmse:1321.08903
# [954]	validation_0-rmse:922.64521	validation_1-rmse:1321.07525
# [955]	validation_0-rmse:922.63718	validation_1-rmse:1321.06110
# [956]	validation_0-rmse:922.62913	validation_1-rmse:1321.04636
# [957]	validation_0-rmse:922.62112	validation_1-rmse:1321.03243
# [958]	validation_0-rmse:922.61310	validation_1-rmse:1321.01852
# [959]	validation_0-rmse:922.60509	validation_1-rmse:1321.00421
# [960]	validation_0-rmse:922.59708	validation_1-rmse:1320.98986
# [961]	validation_0-rmse:922.58910	validation_1-rmse:1320.97599
# [962]	validation_0-rmse:922.58112	validation_1-rmse:1320.96204
# [963]	validation_0-rmse:922.57314	validation_1-rmse:1320.94815
# [964]	validation_0-rmse:922.56517	validation_1-rmse:1320.93449
# [965]	validation_0-rmse:922.55723	validation_1-rmse:1320.92091
# [966]	validation_0-rmse:922.54927	validation_1-rmse:1320.90715
# [967]	validation_0-rmse:922.54134	validation_1-rmse:1320.89275
# [968]	validation_0-rmse:922.53340	validation_1-rmse:1320.87834
# [969]	validation_0-rmse:922.52546	validation_1-rmse:1320.86398
# [970]	validation_0-rmse:922.51755	validation_1-rmse:1320.85016
# [971]	validation_0-rmse:922.50964	validation_1-rmse:1320.83592
# [972]	validation_0-rmse:922.50172	validation_1-rmse:1320.82156
# [973]	validation_0-rmse:922.49384	validation_1-rmse:1320.80787
# [974]	validation_0-rmse:922.48595	validation_1-rmse:1320.79390
# [975]	validation_0-rmse:922.47806	validation_1-rmse:1320.77940
# [976]	validation_0-rmse:922.47018	validation_1-rmse:1320.76564
# [977]	validation_0-rmse:922.46234	validation_1-rmse:1320.75160
# [978]	validation_0-rmse:922.45447	validation_1-rmse:1320.73778
# [979]	validation_0-rmse:922.44661	validation_1-rmse:1320.72409
# [980]	validation_0-rmse:922.43879	validation_1-rmse:1320.71070
# [981]	validation_0-rmse:922.43097	validation_1-rmse:1320.69688
# [982]	validation_0-rmse:922.42315	validation_1-rmse:1320.68277
# [983]	validation_0-rmse:922.41534	validation_1-rmse:1320.66905
# [984]	validation_0-rmse:922.40753	validation_1-rmse:1320.65550
# [985]	validation_0-rmse:922.39973	validation_1-rmse:1320.64180
# [986]	validation_0-rmse:922.39194	validation_1-rmse:1320.62772
# [987]	validation_0-rmse:922.38418	validation_1-rmse:1320.61442
# [988]	validation_0-rmse:922.37640	validation_1-rmse:1320.60061
# [989]	validation_0-rmse:922.36865	validation_1-rmse:1320.58711
# [990]	validation_0-rmse:922.36090	validation_1-rmse:1320.57364
# [991]	validation_0-rmse:922.35315	validation_1-rmse:1320.55982
# [992]	validation_0-rmse:922.34540	validation_1-rmse:1320.54645
# [993]	validation_0-rmse:922.33768	validation_1-rmse:1320.53218
# [994]	validation_0-rmse:922.32995	validation_1-rmse:1320.51812
# [995]	validation_0-rmse:922.32221	validation_1-rmse:1320.50442
# [996]	validation_0-rmse:922.31449	validation_1-rmse:1320.49051
# [997]	validation_0-rmse:922.30679	validation_1-rmse:1320.47586
# [998]	validation_0-rmse:922.29911	validation_1-rmse:1320.46193
# [999]	validation_0-rmse:922.29140	validation_1-rmse:1320.44814
# train:  922.2913979065266
# test:  1320.4481457164543

# %%
feature_importances_df = pd.DataFrame([feature_columns, feature_importances[-1]*100]).transpose().sort_values(by=1).rename(columns={0:'features',1:'importances'})

plt.figure(figsize=(20,20), dpi=200)
sns.barplot(feature_importances_df, x = 'features', y = 'importances')
plt.xticks(rotation=90);

# %%
int(np.sum(preds[0]))
# Out:
# 247266

# %% [markdown]
# ## XGBOOST Train with full data

# %%
# scores = []
# for i in range(1000):
#     reg_model = xgb.XGBRegressor(base_score=0.5, booster='gblinear',  n_estimators=i, early_stopping_rounds=50, objective='reg:squarederror', learning_rate=0.01)
#     reg_model.fit(df[feature_columns], df['total_sales'], eval_set=[(df[feature_columns], df['total_sales'])], verbose=False)
#     y_preds = reg_model.predict(df[feature_columns])
#     scores.append(np.sqrt(mean_squared_error(df['total_sales'], y_preds)))

# %%
plt.plot(range(1000),scores)

# %%
scores[400:]
# Out:
# [np.float64(6374.965908550386),
#  np.float64(6374.715140657594),
#  np.float64(6374.4709074214725),
#  np.float64(6373.939785274374),
#  np.float64(6373.536706190039),
#  np.float64(6373.342264636992),
#  np.float64(6372.947992905537),
#  np.float64(6372.524911469348),
#  np.float64(6372.127686423257),
#  np.float64(6371.830631449345),
#  np.float64(6371.525035654685),
#  np.float64(6370.798544554597),
#  np.float64(6370.807244637683),
#  np.float64(6368.142108846003),
#  np.float64(6370.138476672374),
#  np.float64(6369.587217321131),
#  np.float64(6368.972809924169),
#  np.float64(6368.69989777866),
#  np.float64(6367.822934021289),
#  np.float64(6368.206527645821),
#  np.float64(6367.814348460745),
#  np.float64(6367.717962748952),
#  np.float64(6367.176433375279),
#  np.float64(6366.667279837056),
#  np.float64(6366.765364297513),
#  np.float64(6366.236680895148),
#  np.float64(6365.745220363884),
#  np.float64(6365.6851935814),
#  np.float64(6365.485372707566),
#  np.float64(6364.8935038527925),
#  np.float64(6364.579066256987),
#  np.float64(6364.161230292112),
#  np.float64(6364.118409849318),
#  np.float64(6363.906794952556),
#  np.float64(6363.556916581539),
#  np.float64(6363.282048964656),
#  np.float64(6363.0995556981225),
#  np.float64(6362.563848656943),
#  np.float64(6361.862494144588),
#  np.float64(6362.008443425753),
#  np.float64(6361.704402318843),
#  np.float64(6360.874348666074),
#  np.float64(6360.661834874813),
#  np.float64(6360.517243473639),
#  np.float64(6360.449734182716),
#  np.float64(6360.054459517455),
#  np.float64(6359.789358354055),
#  np.float64(6359.4264542282735),
#  np.float64(6359.21625812749),
#  np.float64(6358.904256646294),
#  np.float64(6358.631423428587),
#  np.float64(6358.306378278968),
#  np.float64(6357.992196254793),
#  np.float64(6357.457561337847),
#  np.float64(6357.414729049303),
#  np.float64(6356.995600299131),
#  np.float64(6356.722426001663),
#  np.float64(6356.541168364882),
#  np.float64(6356.050910998466),
#  np.float64(6355.886026543031),
#  np.float64(6355.637123684631),
#  np.float64(6355.365155245746),
#  np.float64(6354.971935528946),
#  np.float64(6354.7377126383935),
#  np.float64(6354.526050436035),
#  np.float64(6354.119332620972),
#  np.float64(6353.832549112053),
#  np.float64(6353.539045094684),
#  np.float64(6353.130162640552),
#  np.float64(6352.937988185967),
#  np.float64(6352.502629161325),
#  np.float64(6351.991705172262),
#  np.float64(6351.993866460017),
#  np.float64(6351.676822172038),
#  np.float64(6351.140319327872),
#  np.float64(6351.394702577709),
#  np.float64(6350.523019895681),
#  np.float64(6350.557327940329),
#  np.float64(6349.991287611355),
#  np.float64(6349.691819833712),
#  np.float64(6349.672648018902),
#  np.float64(6349.450289172413),
#  np.float64(6348.991805100926),
#  np.float64(6348.615775648849),
#  np.float64(6348.215371084821),
#  np.float64(6347.834474704147),
#  np.float64(6347.694910246691),
#  np.float64(6347.978447917681),
#  np.float64(6347.607367011281),
#  np.float64(6347.405743621357),
#  np.float64(6347.127680447042),
#  np.float64(6346.898386050186),
#  np.float64(6346.665129632111),
#  np.float64(6346.410628873657),
#  np.float64(6346.085191067977),
#  np.float64(6345.758005003548),
#  np.float64(6344.585611571459),
#  np.float64(6345.008108470782),
#  np.float64(6344.930734243231),
#  np.float64(6344.676058255111),
#  np.float64(6344.1587126879485),
#  np.float64(6344.238527775861),
#  np.float64(6343.981381380111),
#  np.float64(6343.784212189962),
#  np.float64(6343.474814194938),
#  np.float64(6342.986535681857),
#  np.float64(6342.818875445796),
#  np.float64(6342.609836397461),
#  np.float64(6342.281161847157),
#  np.float64(6342.16127079897),
#  np.float64(6341.93541017942),
#  np.float64(6341.666576317188),
#  np.float64(6341.467485652612),
#  np.float64(6341.216443445896),
#  np.float64(6340.823051571982),
#  np.float64(6340.660968361772),
#  np.float64(6340.399708892133),
#  np.float64(6340.104824006444),
#  np.float64(6339.902112780394),
#  np.float64(6339.596880918368),
#  np.float64(6339.418797264104),
#  np.float64(6336.9426453176775),
#  np.float64(6338.666495658259),
#  np.float64(6338.4955255358955),
#  np.float64(6338.401210587012),
#  np.float64(6337.8811866923925),
#  np.float64(6337.6886251786755),
#  np.float64(6337.330371326899),
#  np.float64(6337.27386042818),
#  np.float64(6336.6445813677),
#  np.float64(6336.951497139993),
#  np.float64(6336.030351408095),
#  np.float64(6335.99266000875),
#  np.float64(6335.929736282782),
#  np.float64(6335.87233889921),
#  np.float64(6335.688547903475),
#  np.float64(6335.459511135943),
#  np.float64(6335.142903062824),
#  np.float64(6334.931060240257),
#  np.float64(6334.649297831756),
#  np.float64(6334.496171501625),
#  np.float64(6334.314631550383),
#  np.float64(6334.101035353747),
#  np.float64(6333.855387291954),
#  np.float64(6333.6620931734815),
#  np.float64(6333.398714015042),
#  np.float64(6333.1335086005665),
#  np.float64(6332.550381173866),
#  np.float64(6332.717884450932),
#  np.float64(6332.266667068914),
#  np.float64(6331.938920875196),
#  np.float64(6331.629932243413),
#  np.float64(6331.333273639507),
#  np.float64(6331.325747690778),
#  np.float64(6331.279812250726),
#  np.float64(6331.013561715),
#  np.float64(6330.802025705519),
#  np.float64(6330.543819858289),
#  np.float64(6330.337727396623),
#  np.float64(6330.208320025284),
#  np.float64(6329.910286100671),
#  np.float64(6329.736083757181),
#  np.float64(6329.452125920737),
#  np.float64(6329.13959213767),
#  np.float64(6329.02754892635),
#  np.float64(6328.624563510399),
#  np.float64(6328.552883560893),
#  np.float64(6327.89859221048),
#  np.float64(6328.1469896025055),
#  np.float64(6327.394418534365),
#  np.float64(6327.591492802335),
#  np.float64(6327.320291875517),
#  np.float64(6327.144099563745),
#  np.float64(6326.203316762045),
#  np.float64(6326.613135916385),
#  np.float64(6326.432691589907),
#  np.float64(6326.247864025462),
#  np.float64(6325.981018618787),
#  np.float64(6325.6693750049535),
#  np.float64(6325.38931556108),
#  np.float64(6325.322496757395),
#  np.float64(6325.201726871057),
#  np.float64(6325.125228573976),
#  np.float64(6324.833865376752),
#  np.float64(6324.660031276046),
#  np.float64(6324.412894915201),
#  np.float64(6324.2689408502265),
#  np.float64(6323.98922729051),
#  np.float64(6323.7061380083505),
#  np.float64(6323.60000074506),
#  np.float64(6323.290326362675),
#  np.float64(6323.158121621694),
#  np.float64(6322.879379942111),
#  np.float64(6322.757530126394),
#  np.float64(6322.577645452791),
#  np.float64(6322.294438885345),
#  np.float64(6322.105732579642),
#  np.float64(6321.719488579894),
#  np.float64(6321.682967461086),
#  np.float64(6321.470879685918),
#  np.float64(6321.108899272069),
#  np.float64(6320.988664524972),
#  np.float64(6320.896443029205),
#  np.float64(6320.156681467813),
#  np.float64(6320.263600177216),
#  np.float64(6320.107448048677),
#  np.float64(6319.6669421737015),
#  np.float64(6318.674129020501),
#  np.float64(6319.584966808789),
#  np.float64(6319.321278664811),
#  np.float64(6318.96455551649),
#  np.float64(6318.056882411244),
#  np.float64(6318.796680458918),
#  np.float64(6318.386650575922),
#  np.float64(6318.309810922895),
#  np.float64(6317.812783616246),
#  np.float64(6317.548937846181),
#  np.float64(6317.382155295385),
#  np.float64(6317.135478209921),
#  np.float64(6317.1488105152),
#  np.float64(6316.9527828372375),
#  np.float64(6317.062675620166),
#  np.float64(6316.784767443782),
#  np.float64(6316.701391235815),
#  np.float64(6316.434965788151),
#  np.float64(6316.227440131603),
#  np.float64(6316.005406969869),
#  np.float64(6315.904742699966),
#  np.float64(6315.67739781022),
#  np.float64(6315.470904156326),
#  np.float64(6315.286417306588),
#  np.float64(6315.137739766784),
#  np.float64(6314.948408623173),
#  np.float64(6314.78136541816),
#  np.float64(6314.478578146063),
#  np.float64(6314.370690374121),
#  np.float64(6314.1138951535295),
#  np.float64(6313.889379127863),
#  np.float64(6313.759727458242),
#  np.float64(6313.512785327193),
#  np.float64(6313.390933318942),
#  np.float64(6313.182287495228),
#  np.float64(6312.729438344691),
#  np.float64(6312.617648733294),
#  np.float64(6312.3197384829455),
#  np.float64(6312.336073536094),
#  np.float64(6312.317338714133),
#  np.float64(6311.9452444384515),
#  np.float64(6311.905458468891),
#  np.float64(6311.2953344426205),
#  np.float64(6311.3514809717235),
#  np.float64(6311.125518885479),
#  np.float64(6310.8377213637405),
#  np.float64(6310.361841053476),
#  np.float64(6310.535893247179),
#  np.float64(6310.34162756284),
#  np.float64(6310.010666313627),
#  np.float64(6310.064843271937),
#  np.float64(6309.963425556392),
#  np.float64(6309.359407730767),
#  np.float64(6309.453049354925),
#  np.float64(6309.493575160295),
#  np.float64(6309.350106875008),
#  np.float64(6309.186653731218),
#  np.float64(6308.990256862043),
#  np.float64(6308.781824888373),
#  np.float64(6308.617195961232),
#  np.float64(6308.385933060256),
#  np.float64(6308.311391858435),
#  np.float64(6308.1042093836095),
#  np.float64(6307.9477982287035),
#  np.float64(6307.774522493972),
#  np.float64(6307.343729608994),
#  np.float64(6307.385811279582),
#  np.float64(6307.142055648871),
#  np.float64(6307.068684367634),
#  np.float64(6306.812506779088),
#  np.float64(6306.666032942512),
#  np.float64(6306.482507181577),
#  np.float64(6306.097202316657),
#  np.float64(6306.089305768203),
#  np.float64(6305.970952314389),
#  np.float64(6305.805379527081),
#  np.float64(6305.685046675843),
#  np.float64(6305.505971603954),
#  np.float64(6305.278993891277),
#  np.float64(6305.0849359483955),
#  np.float64(6304.9032508919),
#  np.float64(6304.647791012292),
#  np.float64(6304.1652372668),
#  np.float64(6304.231943896429),
#  np.float64(6304.157935240755),
#  np.float64(6303.72388919768),
#  np.float64(6303.268222551037),
#  np.float64(6303.563569991425),
#  np.float64(6303.075602981884),
#  np.float64(6303.063598308028),
#  np.float64(6303.125830965587),
#  np.float64(6302.569618468938),
#  np.float64(6302.783482910259),
#  np.float64(6302.72499998812),
#  np.float64(6302.587867081103),
#  np.float64(6302.400525893099),
#  np.float64(6302.251452812427),
#  np.float64(6302.036079591976),
#  np.float64(6301.899212676002),
#  np.float64(6301.69579552632),
#  np.float64(6301.502455539347),
#  np.float64(6301.39422630071),
#  np.float64(6301.279489452539),
#  np.float64(6301.026878806807),
#  np.float64(6300.915927696274),
#  np.float64(6300.708817412643),
#  np.float64(6300.590480912526),
#  np.float64(6300.435478729801),
#  np.float64(6300.261460673222),
#  np.float64(6300.092054467627),
#  np.float64(6299.95111455044),
#  np.float64(6299.373670404072),
#  np.float64(6299.160666499456),
#  np.float64(6299.276203925776),
#  np.float64(6299.111357138021),
#  np.float64(6299.146738722203),
#  np.float64(6298.953415915293),
#  np.float64(6298.6933682038825),
#  np.float64(6298.145412088343),
#  np.float64(6298.367281148435),
#  np.float64(6298.010547062693),
#  np.float64(6297.684585127531),
#  np.float64(6297.903848040756),
#  np.float64(6297.6829013013075),
#  np.float64(6297.274564940846),
#  np.float64(6297.206905206754),
#  np.float64(6297.222135272768),
#  np.float64(6297.089663371318),
#  np.float64(6297.118942147498),
#  np.float64(6296.892131352905),
#  np.float64(6296.727902125344),
#  np.float64(6296.590397514486),
#  np.float64(6296.462822852082),
#  np.float64(6296.010785124144),
#  np.float64(6296.139528309848),
#  np.float64(6296.000412248021),
#  np.float64(6295.833399710622),
#  np.float64(6295.637927235551),
#  np.float64(6295.385837078572),
#  np.float64(6295.3182926153995),
#  np.float64(6295.201643947766),
#  np.float64(6295.031559785721),
#  np.float64(6294.903143421113),
#  np.float64(6294.732651249277),
#  np.float64(6294.6664975807635),
#  np.float64(6294.471463167545),
#  np.float64(6294.340658403822),
#  np.float64(6293.757783766704),
#  np.float64(6294.028207072417),
#  np.float64(6293.8839212714065),
#  np.float64(6293.2374095031855),
#  np.float64(6293.383574076902),
#  np.float64(6292.805449966578),
#  np.float64(6292.965000294211),
#  np.float64(6292.66572151016),
#  np.float64(6292.875102292347),
#  np.float64(6292.6497172925565),
#  np.float64(6292.336565030804),
#  np.float64(6292.380279241537),
#  np.float64(6292.104841026451),
#  np.float64(6291.924073662934),
#  np.float64(6291.7555906220205),
#  np.float64(6291.901970524594),
#  np.float64(6291.693031264059),
#  np.float64(6291.647467087626),
#  np.float64(6291.45969758874),
#  np.float64(6291.3175567516455),
#  np.float64(6291.187899694239),
#  np.float64(6291.034877870934),
#  np.float64(6290.814140532773),
#  np.float64(6290.775577399099),
#  np.float64(6290.565744209954),
#  np.float64(6290.496201157297),
#  np.float64(6290.338994446504),
#  np.float64(6290.1340960896605),
#  np.float64(6290.025806075615),
#  np.float64(6289.927421012648),
#  np.float64(6289.739456075144),
#  np.float64(6289.62797454623),
#  np.float64(6289.390567086968),
#  np.float64(6289.334331850517),
#  np.float64(6289.113629803316),
#  np.float64(6289.085105174934),
#  np.float64(6288.710137657224),
#  np.float64(6288.778339254872),
#  np.float64(6288.608457730635),
#  np.float64(6288.412889796566),
#  np.float64(6288.228965974599),
#  np.float64(6287.356729029397),
#  np.float64(6287.50400749307),
#  np.float64(6287.607046300449),
#  np.float64(6287.133696074852),
#  np.float64(6287.201375874433),
#  np.float64(6287.152393790303),
#  np.float64(6287.27404390871),
#  np.float64(6287.131031758938),
#  np.float64(6287.033884562599),
#  np.float64(6286.908718764958),
#  np.float64(6286.792960667107),
#  np.float64(6286.512324802627),
#  np.float64(6286.546573520507),
#  np.float64(6286.415853221444),
#  np.float64(6286.264353408288),
#  np.float64(6286.118767397281),
#  np.float64(6285.973619054464),
#  np.float64(6285.872770184707),
#  np.float64(6285.742544465098),
#  np.float64(6285.573261349972),
#  np.float64(6285.25177236321),
#  np.float64(6285.188446986974),
#  np.float64(6284.992626372535),
#  np.float64(6284.884193160609),
#  np.float64(6284.787306235834),
#  np.float64(6284.792883409806),
#  np.float64(6284.4295322088265),
#  np.float64(6284.194640986395),
#  np.float64(6283.7376112033235),
#  np.float64(6283.576275091579),
#  np.float64(6283.854035461487),
#  np.float64(6282.879790966452),
#  np.float64(6283.6541131801705),
#  np.float64(6283.419299125696),
#  np.float64(6283.155445130906),
#  np.float64(6283.219631531183),
#  np.float64(6283.098059833185),
#  np.float64(6283.051277854878),
#  np.float64(6283.0554218903835),
#  np.float64(6282.961993897355),
#  np.float64(6282.7574681884835),
#  np.float64(6282.6521507155985),
#  np.float64(6282.490442475785),
#  np.float64(6282.385585918968),
#  np.float64(6282.272320019512),
#  np.float64(6282.149135697121),
#  np.float64(6282.030656962257),
#  np.float64(6281.878320584915),
#  np.float64(6281.780891358927),
#  np.float64(6281.611884243603),
#  np.float64(6281.404526118401),
#  np.float64(6281.3393962193295),
#  np.float64(6281.089936277465),
#  np.float64(6281.116681066966),
#  np.float64(6280.875322374683),
#  np.float64(6280.865318378005),
#  np.float64(6280.6882751344265),
#  np.float64(6280.553091247312),
#  np.float64(6280.425381240386),
#  np.float64(6280.311345714416),
#  np.float64(6279.977747268405),
#  np.float64(6279.792999872757),
#  np.float64(6279.797857362104),
#  np.float64(6279.680867996192),
#  np.float64(6279.119530952254),
#  np.float64(6279.4873607231475),
#  np.float64(6279.397125034033),
#  np.float64(6279.340904372561),
#  np.float64(6279.127477340196),
#  np.float64(6279.1089634412065),
#  np.float64(6278.9503586384935),
#  np.float64(6278.792160106166),
#  np.float64(6278.565817409828),
#  np.float64(6278.406923252902),
#  np.float64(6278.2849848918395),
#  np.float64(6278.23778565929),
#  np.float64(6278.228885192059),
#  np.float64(6278.100953037024),
#  np.float64(6278.010675707072),
#  np.float64(6277.559445871233),
#  np.float64(6277.746186545557),
#  np.float64(6277.540154664722),
#  np.float64(6277.463968712766),
#  np.float64(6277.4086712678445),
#  np.float64(6277.190203612554),
#  np.float64(6277.058073215036),
#  np.float64(6276.999626068287),
#  np.float64(6276.911750771042),
#  np.float64(6276.7067702088525),
#  np.float64(6276.628561883864),
#  np.float64(6276.216334205723),
#  np.float64(6276.207985921495),
#  np.float64(6275.93636376197),
#  np.float64(6275.7884611743),
#  np.float64(6275.966432555777),
#  np.float64(6275.538042571643),
#  np.float64(6275.692383195974),
#  np.float64(6275.4021175914),
#  np.float64(6275.5628279638795),
#  np.float64(6275.426182604251),
#  np.float64(6275.2957157394485),
#  np.float64(6274.999369853844),
#  np.float64(6275.107765362814),
#  np.float64(6274.945320247287),
#  np.float64(6274.847633102385),
#  np.float64(6274.723960622954),
#  np.float64(6274.647300587975),
#  np.float64(6274.4487097207175),
#  np.float64(6274.334065056221),
#  np.float64(6274.243354906442),
#  np.float64(6274.157817745542),
#  np.float64(6273.608473716328),
#  np.float64(6273.900308145249),
#  np.float64(6273.812791152813),
#  np.float64(6273.6898638527255),
#  np.float64(6273.536858626924),
#  np.float64(6273.479803853408),
#  np.float64(6273.312144042969),
#  np.float64(6273.229597651997),
#  np.float64(6272.889159583698),
#  np.float64(6272.700901279532),
#  np.float64(6272.333849589057),
#  np.float64(6271.784943898789),
#  np.float64(6272.403318342978),
#  np.float64(6272.371464515578),
#  np.float64(6272.066927958804),
#  np.float64(6272.03038373478),
#  np.float64(6271.916324265907),
#  np.float64(6271.945327081559),
#  np.float64(6271.956931587053),
#  np.float64(6271.857629292484),
#  np.float64(6271.641809866009),
#  np.float64(6271.5793805805315),
#  np.float64(6271.536423877941),
#  np.float64(6271.286352186262),
#  np.float64(6271.044692704558),
#  np.float64(6271.082063242535),
#  np.float64(6271.088488840339),
#  np.float64(6270.949014926046),
#  np.float64(6270.851104715673),
#  np.float64(6270.691374383697),
#  np.float64(6270.596633986419),
#  np.float64(6270.481164007104),
#  np.float64(6270.353835210093),
#  np.float64(6270.17845735466),
#  np.float64(6270.155925932848),
#  np.float64(6269.972505796617),
#  np.float64(6269.73907104955),
#  np.float64(6269.689808529274),
#  np.float64(6269.575313492683),
#  np.float64(6269.176846319875),
#  np.float64(6269.2907941624035),
#  np.float64(6269.1692527166615),
#  np.float64(6268.951685421508),
#  np.float64(6268.847452473567),
#  np.float64(6269.035493061609),
#  np.float64(6268.882922106166),
#  np.float64(6268.784536728754),
#  np.float64(6268.773826394491),
#  np.float64(6268.644097022736),
#  np.float64(6268.533657670741),
#  np.float64(6268.17364892163),
#  np.float64(6267.918548693629),
#  np.float64(6268.221287501794),
#  np.float64(6267.93978387595),
#  np.float64(6267.886308147083),
#  np.float64(6267.884569899225),
#  np.float64(6267.740489696081),
#  np.float64(6267.66921060317),
#  np.float64(6267.586531713031),
#  np.float64(6267.485042870739),
#  np.float64(6267.274830206944),
#  np.float64(6267.076307265786),
#  np.float64(6267.164670609031),
#  np.float64(6266.881127486182),
#  np.float64(6266.574421900398),
#  np.float64(6266.706803476306),
#  np.float64(6266.236229416337),
#  np.float64(6266.673818196627),
#  np.float64(6266.311285578458),
#  np.float64(6266.064608796701),
#  np.float64(6266.159338803782),
#  np.float64(6266.031589137843),
#  np.float64(6265.9043571320235),
#  np.float64(6265.999143260997),
#  np.float64(6265.875858697937),
#  np.float64(6265.662001710645),
#  np.float64(6265.655733848155),
#  np.float64(6265.5628413945315),
#  np.float64(6265.475293071647),
#  np.float64(6265.294471004558),
#  np.float64(6265.264080151263),
#  np.float64(6265.178857492787),
#  np.float64(6265.055057570717),
#  np.float64(6264.918684516053),
#  np.float64(6264.850012670697),
#  np.float64(6264.572416718394),
#  np.float64(6264.039498047739),
#  np.float64(6264.350116479834),
#  np.float64(6264.426398868976),
#  np.float64(6263.994903272308),
#  np.float64(6264.224303935465),
#  np.float64(6264.059475501302),
#  np.float64(6263.895017109645),
#  np.float64(6263.857021169524)]

# %%
reg_model = xgb.XGBRegressor(base_score=0.5, booster='gblinear',  n_estimators=400, early_stopping_rounds=50, objective='reg:squarederror', learning_rate=0.01)
reg_model.fit(df[feature_columns], df['total_sales'], eval_set=[(df[feature_columns], df['total_sales'])], verbose=False)
# Out:
# XGBRegressor(base_score=0.5, booster='gblinear', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.01, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=400,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
feature_importances_df = pd.DataFrame([feature_columns, reg_model.feature_importances_*100]).transpose().sort_values(by=1).rename(columns={0:'features',1:'importances'})

plt.figure(figsize=(20,20), dpi=200)
sns.barplot(feature_importances_df, x = 'features', y = 'importances')
plt.xticks(rotation=90);

# %%
y_preds = reg_model.predict(forcast_df[feature_columns])
ds =  pd.Series(y_preds, index=forcast_df.index)
ds.plot(label='prediction')
plt.legend()
plt.show()

# %%
from catboost import CatBoostRegressor

# %%
def cross_validate(df, forcastdf, feature_columns):
    feature_importances = []
    tss = TimeSeriesSplit(n_splits=3, test_size=365, gap=0)
    param_grid = {'depth':[3], 'l2_leaf_reg':[2] ,'learning_rate':[0.01, 0.05],'n_estimators':[600, 800, 1000, 2000]}
    feature_columns = sorted(feature_columns)
    for train_idx, val_idx in tss.split(df):
        scaler = StandardScaler()
        train = df.iloc[train_idx]
        test = df.iloc[val_idx]
        X_train = train[feature_columns]
        y_train = train['total_sales']
        X_test = test[feature_columns]
        y_test = test['total_sales']
        reg_model = GridSearchCV(CatBoostRegressor(silent=True), param_grid, scoring='neg_root_mean_squared_error')
        # reg_model = CatBoostRegressor(depth= 3, l2_leaf_reg= 2, learning_rate= 0.01, n_estimators= 800, silent=True)
        reg_model.fit(X_train, y_train,early_stopping_rounds=50)
        print(reg_model.best_params_)
        y_preds = reg_model.predict(X_train)
        score = np.sqrt(mean_squared_error(y_train, y_preds))
        print('training error: ',score)
        ds =  pd.concat([y_train.reset_index(),pd.Series(y_preds)], axis=1)
        ds = ds.set_index('Order Date')
        ds['total_sales'].plot(label='true data')
        ds[0].plot(label='prediction')
        plt.legend()
        plt.show()
        y_preds = reg_model.predict(X_test)
        score = np.sqrt(mean_squared_error(y_test, y_preds))
        print('test error: ',score)
        ds =  pd.concat([y_test.reset_index(),pd.Series(y_preds)], axis=1)
        ds = ds.set_index('Order Date')
        ds['total_sales'].plot(label='true data')
        ds[0].plot(label='prediction')
        plt.legend()
        plt.show()
        forcast_preds = reg_model.predict(forcastdf[feature_columns])
        ds =  pd.Series(forcast_preds, index=forcastdf.index)
        ds.plot(label='prediction')
        plt.legend()
        plt.show()
        preds.append(y_preds)

    return feature_importances

# %%
cross_validate(ga_df, ga_forcast_df, feature_columns)
# Out:
# {'depth': 3, 'l2_leaf_reg': 2, 'learning_rate': 0.01, 'n_estimators': 800}
# training error:  240.87937581215542
# test error:  473.68665192464
# {'depth': 3, 'l2_leaf_reg': 2, 'learning_rate': 0.01, 'n_estimators': 1000}
# training error:  268.6285535243523
# test error:  596.8467354237329
# {'depth': 3, 'l2_leaf_reg': 2, 'learning_rate': 0.01, 'n_estimators': 2000}
# training error:  282.69755645443746
# test error:  500.05402636191036
# []

# %%
cross_validate(ca_df, ca_forcast_df, feature_columns)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[277], line 1
# ----> 1 cross_validate(ca_df, ca_forcast_df, feature_columns)
#
# Cell In[276], line 10, in cross_validate(df, forcastdf, feature_columns)
#       8 train = df.iloc[train_idx]
#       9 test = df.iloc[val_idx]
# ---> 10 X_train = train[feature_columns]
#      11 y_train = train['total_sales']
#      12 X_test = test[feature_columns]
#
# File ~\anaconda3\envs\cv_env\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\envs\cv_env\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\envs\cv_env\Lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['PC1 1YA', 'PC1 2YA', 'PC1 3YA', 'PC2 1YA', 'PC2 2YA', 'PC2 3YA', 'PC3 1YA', 'PC3 2YA', 'PC3 3YA', 'Sales 1YA', 'Sales 2YA', 'Sales 3YA'] not in index"

# %% [markdown]
# # Train Catboost with full data

# %%
reg_model = CatBoostRegressor(depth= 3, l2_leaf_reg= 2, learning_rate= 0.01, n_estimators= 1000, silent=True)
reg_model.fit(df[sorted(feature_columns)], df['total_sales'])

# %%
y_preds = reg_model.predict(forcast_df[sorted(feature_columns)])
ds =  pd.Series(y_preds, index=forcast_df.index)
ds.plot(label='prediction')
plt.legend()
plt.show()

# %%
y_preds = reg_model.predict(df[sorted(feature_columns)])
ds =  pd.Series(y_preds, index=df.index)
ds.plot(label='prediction')
plt.legend()
plt.show()
