# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import gdown
import kagglehub
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import AdaBoostRegressor

# %% [markdown]
# # Helper Functions

# %%
def fetch_dataset(key, dataset_name):
    cmd = !gdown --fuzzy {key} -O {dataset_name}
    path = pd.Series(cmd).str.extractall(r'(To.*)').reset_index()[0].iloc[0].split(': ')[1]
    print(f'{dataset_name} path: {path}')
    return path

def get_null_percentage(df):
    null_series = ((df.isnull().sum()/len(df))*100).sort_values()
    return null_series

def generate_time_features(df):
    df = df.reset_index()
    df.loc[:,'day']  = df['Order Date'].dt.day
    df.loc[:,'month']  = df['Order Date'].dt.month
    df.loc[:,'year']  = df['Order Date'].dt.year
    df.loc[:,'is_weekend']  = df['Order Date'].dt.weekday > 5
    df.loc[:,'day_of_week']  = df['Order Date'].dt.day_of_week
    df.loc[:,'day_of_year']  = df['Order Date'].dt.day_of_year
    df.loc[:,'quarter']  = df['Order Date'].dt.quarter
    df.loc[:,'is_month_start']  = df['Order Date'].dt.is_month_start
    df.loc[:,'is_month_end']  = df['Order Date'].dt.is_month_end
    df.loc[:,'is_year_start']  = df['Order Date'].dt.is_year_start
    df.loc[:,'is_year_end']  = df['Order Date'].dt.is_year_end
    df = df.set_index('Order Date')
    return df

def add_holidays_past_2021(df):

    _2022 = pd.Series(['2022-12-26', '2022-11-24', '2022-11-11', '2022-10-10', '2022-09-05', '2022-07-04', '2022-06-20', '2022-05-30', '2022-02-21', '2022-01-21', '2023-01-02', '2023-01-16', '2023-02-20']) 
    
    _2022 = pd.to_datetime(_2022)
    dates = pd.Series(['January 02 2023',
    'January 16 2023',
    'February 20 2023',
    'May 29 2023',
    'June 19 2023',
    'July 04 2023',
    'September 04 2023',
    'October 09 2023',
    'November 10 2023',
    'November 23 2023',
    'December 25 2023',
    'January 01 2024',
    'January 15 2024',
    'February 19 2024',
    'May 27 2024',
    'June 19 2024',
    'July 04 2024',
    'September 02 2024',	
    'October 14 2024',
    'November 11 2024',	
    'November 28 2024',	
    'December 25 2024',
    'January 01 2025',
    'January 20 2025',
    'January 20 2025',
    'February 17 2025',
    'May 26 2025',
    'June 19 2025',
    'July 04 2025',
    'September 01 2025',	
    'October 13 2025',
    'November 11 2025',
    'November 27 2025',
    'December 25 2025',
    'January 01 2026',
    'January 19 2026',
    'February 16 2026',
    'May 25 2026',
    'June 19 2026',
    'July 03 2026',
    'September 07 2025',
    'October 12 2026',
    'November 11 2026',
    'November 26 2026',
    'December 25 2026'
                      ])
    fedral_holidays_2023_plus = pd.to_datetime(dates)
    fedral_holdidays_22_plus = pd.concat([_2022, fedral_holidays_2023_plus], axis=0).sort_values()
    fedral_holdidays_22_plus = pd.Series(fedral_holdidays_22_plus.unique())
    fedral_holdidays_22_plus.index = range(len(fedral_holdidays_22_plus))
    fedral_holdidays_22_plus = pd.DataFrame(fedral_holdidays_22_plus).rename(columns={0:'date'})
    fedral_holdidays_22_plus['fedral_holiday'] = True
    fedral_holdidays_22_plus = fedral_holdidays_22_plus.set_index('date')
    return pd.merge(df, fedral_holdidays_22_plus, how='left', left_index = True, right_index=True)

def add_events(events_timestamps, is_repeat=False):
    dummy_date = '2017-04-10'
    events = pd.DatetimeIndex([dummy_date])
    if is_repeat:
        for i in range(len([2018,2019,2020,2021,2022,2023,2024,2025,2026])):
            events = events.append(pd.date_range(start=events_timestamps[0], end=events_timestamps[1]) \
                                   + pd.tseries.offsets.DateOffset(months=i*12))
    else:
        for event in events_timestamps:
            events = events.append(pd.date_range(start=event[0], end=event[1]))
    return events[1:]

def assign_historic_sales(df, year_till=2022):
    df = df.reset_index()
    sales = df[['Order Date', 'total_sales']]
    sales = sales.set_index('Order Date')
    past_sales = list(sales[sales.index.year <= year_till]['total_sales'])
    lag = [np.nan] * (len(sales) - len(past_sales))
    lag.extend(past_sales)
    lag = pd.Series(lag, index=sales.index)
    df = df.set_index('Order Date')
    return lag

def add_amazon_events(df):
    global amazon_events_df
    df = pd.merge(df, amazon_events_df, left_index=True, right_index=True, how='left')
    df['Amazon Events'] = df['Amazon Events'].fillna('No Events')
    df = pd.get_dummies(df, drop_first=True)
    return df

# %% [markdown]
# # Dataset imports

# %%
path = fetch_dataset("1HdJj68eO9NTZlpwZcLYqdtPqrbKs1cxj", "amazon_purchases.csv")
purchases = pd.read_csv(path)
purchases = purchases[purchases['Shipping Address State'].notnull()]

path = kagglehub.dataset_download("donnetew/us-holiday-dates-2004-2021")
holidays = pd.read_csv(os.path.join(path,'US Holiday Dates (2004-2021).csv'))
holidays['is_holiday'] = True
holidays['Date'] = pd.to_datetime(holidays['Date'])
holidays.set_index('Date', inplace=True)

path = fetch_dataset("1uuTBlEA2caOIyv4-R_G2OlekBCw-i_Le", "inflation.csv")
inflation_df = pd.read_csv(path)
inflation_df['observation_date'] = pd.to_datetime(inflation_df['observation_date'])
inflation_df = inflation_df.rename(columns={'T10YIEM':'inflation_rate'}).set_index('observation_date')
# Out:
# amazon_purchases.csv path: C:\Users\rohit\5010\project\AmazonSalesPredictor\amazon_purchases.csv
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.11)
# inflation.csv path: C:\Users\rohit\5010\project\AmazonSalesPredictor\inflation.csv

# %% [markdown]
# # Feature engineering

# %%
purchases['Order Date'] = pd.to_datetime(purchases['Order Date'])
purchases.set_index('Order Date', inplace=True)
purchases = purchases[purchases.index.year<2023]
purchases.loc[:,'total_sales'] = purchases['Purchase Price Per Unit'] * purchases['Quantity']

# %%
df = purchases.copy()
df = pd.DataFrame(df.groupby(df.index)['total_sales'].sum())

# %% [markdown]
# **Add time features**

# %%
df = generate_time_features(df)

# %%
df
# Out:
#             total_sales  day  month  year  is_weekend  day_of_week  \
# Order Date
# 2018-01-01     16122.06    1      1  2018       False            0
# 2018-01-02     17006.00    2      1  2018       False            1
# 2018-01-03     13315.58    3      1  2018       False            2
# 2018-01-04     15820.10    4      1  2018       False            3
# 2018-01-05     17752.51    5      1  2018       False            4
# ...                 ...  ...    ...   ...         ...          ...
# 2022-12-27     19584.77   27     12  2022       False            1
# 2022-12-28     16875.12   28     12  2022       False            2
# 2022-12-29     18348.89   29     12  2022       False            3
# 2022-12-30     16886.45   30     12  2022       False            4
# 2022-12-31     12634.59   31     12  2022       False            5
#
#             day_of_year  quarter  is_month_start  is_month_end  is_year_start  \
# Order Date
# 2018-01-01            1        1            True         False           True
# 2018-01-02            2        1           False         False          False
# 2018-01-03            3        1           False         False          False
# 2018-01-04            4        1           False         False          False
# 2018-01-05            5        1           False         False          False
# ...                 ...      ...             ...           ...            ...
# 2022-12-27          361        4           False         False          False
# 2022-12-28          362        4           False         False          False
# 2022-12-29          363        4           False         False          False
# 2022-12-30          364        4           False         False          False
# 2022-12-31          365        4           False          True          False
#
#             is_year_end
# Order Date
# 2018-01-01        False
# 2018-01-02        False
# 2018-01-03        False
# 2018-01-04        False
# 2018-01-05        False
# ...                 ...
# 2022-12-27        False
# 2022-12-28        False
# 2022-12-29        False
# 2022-12-30        False
# 2022-12-31         True
#
# [1826 rows x 12 columns]

# %% [markdown]
# **Add amazon events**

# %%
amazon_events = add_events([['2024-03-20', '2024-03-25'], ['2025-03-25', '2025-03-31']])
spring_sale_event_df = pd.DataFrame({'Event Date':amazon_events,'Amazon Events':['Big Spring Sale']*len(amazon_events)}).set_index('Event Date')

# %%
amazon_events = add_events([
    ['2018-07-16', '2018-07-17'],
    ['2019-07-15', '2019-07-16'],
    ['2020-10-13', '2020-10-14'],
    ['2021-06-21', '2021-06-22'],
    ['2022-07-12', '2022-07-13'],
    ['2023-07-11', '2023-07-12'],
    ['2024-07-16', '2024-07-17'],
    ['2025-07-23', '2025-07-24']
])
prime_day_event_df = pd.DataFrame({'Event Date':amazon_events,'Amazon Events':['Amazon Prime Day']*len(amazon_events)}).set_index('Event Date')

# %%
amazon_events = add_events([
    ['2022-10-11', '2022-10-12'],  
    ['2023-10-10', '2023-10-11'],  
    ['2024-10-08', '2024-10-09'],
    ['2025-10-14', '2025-10-15']
])
prime_big_deal_event_df = pd.DataFrame({'Event Date':amazon_events,'Amazon Events':['Prime Big Deal Days']*len(amazon_events)}).set_index('Event Date')

# %%
amazon_events = add_events([
    ['2018-11-16', '2018-11-23'],
    ['2019-11-22', '2019-11-29'],
    ['2020-11-20', '2020-11-27'],
    ['2021-11-19', '2021-11-26'],
    ['2022-11-24', '2022-11-25'],
    ['2023-11-17', '2023-11-24'],
    ['2024-11-21', '2024-11-29'],
    ['2025-11-28', '2025-12-01']
]
)
black_friday_event_df = pd.DataFrame({'Event Date':amazon_events,'Amazon Events':['Black Friday']*len(amazon_events)}).set_index('Event Date')

# %%
amazon_events = add_events([
    ['2018-02-05', '2018-02-14'],
    ['2019-02-04', '2019-02-14'],
    ['2020-02-03', '2020-02-14'],
    ['2021-02-01', '2021-02-14'],
    ['2022-02-03', '2022-02-10'],
    ['2023-02-04', '2023-02-14'],
    ['2024-02-02', '2024-02-14'],
    ['2025-02-02', '2025-02-14']
])
valentines_day_event_df = pd.DataFrame({'Event Date':amazon_events,'Amazon Events':["Valentine's Day Promotions"]*len(amazon_events)}).set_index('Event Date')

# %%
amazon_events = add_events([
    ['2018-05-01', '2018-05-13'],
    ['2019-05-03', '2019-05-12'],
    ['2020-05-01', '2020-05-10'],
    ['2021-05-01', '2021-05-09'],
    ['2022-05-03', '2022-05-09'],
    ['2023-05-01', '2023-05-14'],
    ['2024-05-02', '2024-05-12'],
    ['2025-05-06', '2025-05-12']
])
mothers_day_event_df = pd.DataFrame({'Event Date':amazon_events,'Amazon Events':["Mother's Day Deals"]*len(amazon_events)}).set_index('Event Date')

# %%
amazon_events = add_events([
    ['2018-05-25', '2018-05-28'],
    ['2019-05-24', '2019-05-27'],
    ['2020-05-22', '2020-05-25'],
    ['2021-05-28', '2021-05-31'],
    ['2022-05-27', '2022-05-30'],
    ['2023-05-26', '2023-05-29'],
    ['2024-05-24', '2024-05-27'],
    ['2025-05-23', '2025-05-26']
])
memorial_day_event_df = pd.DataFrame({'Event Date':amazon_events,'Amazon Events':["Memorial Day Sales"]*len(amazon_events)}).set_index('Event Date')

# %%
amazon_events = add_events(('2018-12-02', '2018-12-13'), is_repeat=True)
_12_day_of_deals_event_df = pd.DataFrame({'Event Date':amazon_events,'Amazon Events':['12 Days of Deals']*len(amazon_events)}).set_index('Event Date')

# %%
amazon_events = add_events(('2018-12-25', '2019-01-01'), is_repeat=True)
year_end_clearance_event_df = pd.DataFrame({'Event Date':amazon_events,'Amazon Events':['Year-End Clearance Sale']*len(amazon_events)}).set_index('Event Date')

# %% [markdown]
# **concat**

# %%
amazon_events_df = pd.concat([spring_sale_event_df,prime_day_event_df,prime_big_deal_event_df,black_friday_event_df,valentines_day_event_df,mothers_day_event_df,memorial_day_event_df,_12_day_of_deals_event_df,year_end_clearance_event_df], axis=0).sort_index()

# %%
amazon_events_df
# Out:
#                          Amazon Events
# Event Date
# 2018-02-05  Valentine's Day Promotions
# 2018-02-06  Valentine's Day Promotions
# 2018-02-07  Valentine's Day Promotions
# 2018-02-08  Valentine's Day Promotions
# 2018-02-09  Valentine's Day Promotions
# ...                                ...
# 2026-12-28     Year-End Clearance Sale
# 2026-12-29     Year-End Clearance Sale
# 2026-12-30     Year-End Clearance Sale
# 2026-12-31     Year-End Clearance Sale
# 2027-01-01     Year-End Clearance Sale
#
# [477 rows x 1 columns]

# %%
sns.histplot(amazon_events_df[amazon_events_df.index.year==2018], x='Amazon Events')
plt.xticks(rotation=90);
plt.xlabel('Amazon events in 2018')
# Out:
# Text(0.5, 0, 'Amazon events in 2018')

# %%
sns.histplot(amazon_events_df, x='Amazon Events')
plt.xticks(rotation=90);
plt.xlabel('Amazon events yearly')
# Out:
# Text(0.5, 0, 'Amazon events yearly')

# %%
df = pd.merge(df, amazon_events_df, left_index=True, right_index=True, how='left')

# %%
df['Amazon Events'].value_counts()
# Out:
# Amazon Events
# 12 Days of Deals              60
# Valentine's Day Promotions    55
# Mother's Day Deals            49
# Year-End Clearance Sale       39
# Black Friday                  34
# Memorial Day Sales            20
# Amazon Prime Day              10
# Prime Big Deal Days            2
# Name: count, dtype: int64

# %%
df['Amazon Events'] = df['Amazon Events'].fillna('No Events')

# %%
sns.histplot(df[df.index.year==2022], x='Amazon Events')
plt.xticks(rotation=90);
plt.xlabel('Amazon events in 2022')
# Out:
# Text(0.5, 0, 'Amazon events in 2022')

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
df
# Out:
#             total_sales  day  month  year  is_weekend  day_of_week  \
# Order Date
# 2018-01-01     16122.06    1      1  2018       False            0
# 2018-01-02     17006.00    2      1  2018       False            1
# 2018-01-03     13315.58    3      1  2018       False            2
# 2018-01-04     15820.10    4      1  2018       False            3
# 2018-01-05     17752.51    5      1  2018       False            4
# ...                 ...  ...    ...   ...         ...          ...
# 2022-12-27     19584.77   27     12  2022       False            1
# 2022-12-28     16875.12   28     12  2022       False            2
# 2022-12-29     18348.89   29     12  2022       False            3
# 2022-12-30     16886.45   30     12  2022       False            4
# 2022-12-31     12634.59   31     12  2022       False            5
#
#             day_of_year  quarter  is_month_start  is_month_end  is_year_start  \
# Order Date
# 2018-01-01            1        1            True         False           True
# 2018-01-02            2        1           False         False          False
# 2018-01-03            3        1           False         False          False
# 2018-01-04            4        1           False         False          False
# 2018-01-05            5        1           False         False          False
# ...                 ...      ...             ...           ...            ...
# 2022-12-27          361        4           False         False          False
# 2022-12-28          362        4           False         False          False
# 2022-12-29          363        4           False         False          False
# 2022-12-30          364        4           False         False          False
# 2022-12-31          365        4           False          True          False
#
#             is_year_end  Amazon Events_Amazon Prime Day  \
# Order Date
# 2018-01-01        False                           False
# 2018-01-02        False                           False
# 2018-01-03        False                           False
# 2018-01-04        False                           False
# 2018-01-05        False                           False
# ...                 ...                             ...
# 2022-12-27        False                           False
# 2022-12-28        False                           False
# 2022-12-29        False                           False
# 2022-12-30        False                           False
# 2022-12-31         True                           False
#
#             Amazon Events_Black Friday  Amazon Events_Memorial Day Sales  \
# Order Date
# 2018-01-01                       False                             False
# 2018-01-02                       False                             False
# 2018-01-03                       False                             False
# 2018-01-04                       False                             False
# 2018-01-05                       False                             False
# ...                                ...                               ...
# 2022-12-27                       False                             False
# 2022-12-28                       False                             False
# 2022-12-29                       False                             False
# 2022-12-30                       False                             False
# 2022-12-31                       False                             False
#
#             Amazon Events_Mother's Day Deals  Amazon Events_No Events  \
# Order Date
# 2018-01-01                             False                     True
# 2018-01-02                             False                     True
# 2018-01-03                             False                     True
# 2018-01-04                             False                     True
# 2018-01-05                             False                     True
# ...                                      ...                      ...
# 2022-12-27                             False                    False
# 2022-12-28                             False                    False
# 2022-12-29                             False                    False
# 2022-12-30                             False                    False
# 2022-12-31                             False                    False
#
#             Amazon Events_Prime Big Deal Days  \
# Order Date
# 2018-01-01                              False
# 2018-01-02                              False
# 2018-01-03                              False
# 2018-01-04                              False
# 2018-01-05                              False
# ...                                       ...
# 2022-12-27                              False
# 2022-12-28                              False
# 2022-12-29                              False
# 2022-12-30                              False
# 2022-12-31                              False
#
#             Amazon Events_Valentine's Day Promotions  \
# Order Date
# 2018-01-01                                     False
# 2018-01-02                                     False
# 2018-01-03                                     False
# 2018-01-04                                     False
# 2018-01-05                                     False
# ...                                              ...
# 2022-12-27                                     False
# 2022-12-28                                     False
# 2022-12-29                                     False
# 2022-12-30                                     False
# 2022-12-31                                     False
#
#             Amazon Events_Year-End Clearance Sale
# Order Date
# 2018-01-01                                  False
# 2018-01-02                                  False
# 2018-01-03                                  False
# 2018-01-04                                  False
# 2018-01-05                                  False
# ...                                           ...
# 2022-12-27                                   True
# 2022-12-28                                   True
# 2022-12-29                                   True
# 2022-12-30                                   True
# 2022-12-31                                   True
#
# [1826 rows x 20 columns]

# %% [markdown]
# **Add holidays**

# %%
df = pd.merge(df, holidays['is_holiday'], how='left', left_index=True, right_index=True)
df = add_holidays_past_2021(df)
df['fedral_holiday'] = df['is_holiday'].fillna(False) + df['fedral_holiday'].fillna(False)
df.drop('is_holiday', axis=1,inplace= True)
# Out:
# C:\Users\rohit\AppData\Local\Temp\ipykernel_17076\3289957183.py:3: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['fedral_holiday'] = df['is_holiday'].fillna(False) + df['fedral_holiday'].fillna(False)

# %%
df['fedral_holiday'].value_counts()
# Out:
# fedral_holiday
# False    1740
# True       86
# Name: count, dtype: int64

# %% [markdown]
# **Add inflation**

# %%
df = pd.merge(df, inflation_df, left_index=True, right_index=True, how='left')
df['inflation_rate'] = df['inflation_rate'].interpolate()

# %%
df
# Out:
#             total_sales  day  month  year  is_weekend  day_of_week  \
# Order Date
# 2018-01-01     16122.06    1      1  2018       False            0
# 2018-01-02     17006.00    2      1  2018       False            1
# 2018-01-03     13315.58    3      1  2018       False            2
# 2018-01-04     15820.10    4      1  2018       False            3
# 2018-01-05     17752.51    5      1  2018       False            4
# ...                 ...  ...    ...   ...         ...          ...
# 2022-12-27     19584.77   27     12  2022       False            1
# 2022-12-28     16875.12   28     12  2022       False            2
# 2022-12-29     18348.89   29     12  2022       False            3
# 2022-12-30     16886.45   30     12  2022       False            4
# 2022-12-31     12634.59   31     12  2022       False            5
#
#             day_of_year  quarter  is_month_start  is_month_end  ...  \
# Order Date                                                      ...
# 2018-01-01            1        1            True         False  ...
# 2018-01-02            2        1           False         False  ...
# 2018-01-03            3        1           False         False  ...
# 2018-01-04            4        1           False         False  ...
# 2018-01-05            5        1           False         False  ...
# ...                 ...      ...             ...           ...  ...
# 2022-12-27          361        4           False         False  ...
# 2022-12-28          362        4           False         False  ...
# 2022-12-29          363        4           False         False  ...
# 2022-12-30          364        4           False         False  ...
# 2022-12-31          365        4           False          True  ...
#
#             Amazon Events_Amazon Prime Day  Amazon Events_Black Friday  \
# Order Date
# 2018-01-01                           False                       False
# 2018-01-02                           False                       False
# 2018-01-03                           False                       False
# 2018-01-04                           False                       False
# 2018-01-05                           False                       False
# ...                                    ...                         ...
# 2022-12-27                           False                       False
# 2022-12-28                           False                       False
# 2022-12-29                           False                       False
# 2022-12-30                           False                       False
# 2022-12-31                           False                       False
#
#             Amazon Events_Memorial Day Sales  \
# Order Date
# 2018-01-01                             False
# 2018-01-02                             False
# 2018-01-03                             False
# 2018-01-04                             False
# 2018-01-05                             False
# ...                                      ...
# 2022-12-27                             False
# 2022-12-28                             False
# 2022-12-29                             False
# 2022-12-30                             False
# 2022-12-31                             False
#
#             Amazon Events_Mother's Day Deals  Amazon Events_No Events  \
# Order Date
# 2018-01-01                             False                     True
# 2018-01-02                             False                     True
# 2018-01-03                             False                     True
# 2018-01-04                             False                     True
# 2018-01-05                             False                     True
# ...                                      ...                      ...
# 2022-12-27                             False                    False
# 2022-12-28                             False                    False
# 2022-12-29                             False                    False
# 2022-12-30                             False                    False
# 2022-12-31                             False                    False
#
#             Amazon Events_Prime Big Deal Days  \
# Order Date
# 2018-01-01                              False
# 2018-01-02                              False
# 2018-01-03                              False
# 2018-01-04                              False
# 2018-01-05                              False
# ...                                       ...
# 2022-12-27                              False
# 2022-12-28                              False
# 2022-12-29                              False
# 2022-12-30                              False
# 2022-12-31                              False
#
#             Amazon Events_Valentine's Day Promotions  \
# Order Date
# 2018-01-01                                     False
# 2018-01-02                                     False
# 2018-01-03                                     False
# 2018-01-04                                     False
# 2018-01-05                                     False
# ...                                              ...
# 2022-12-27                                     False
# 2022-12-28                                     False
# 2022-12-29                                     False
# 2022-12-30                                     False
# 2022-12-31                                     False
#
#             Amazon Events_Year-End Clearance Sale  fedral_holiday  \
# Order Date
# 2018-01-01                                  False            True
# 2018-01-02                                  False           False
# 2018-01-03                                  False           False
# 2018-01-04                                  False           False
# 2018-01-05                                  False           False
# ...                                           ...             ...
# 2022-12-27                                   True           False
# 2022-12-28                                   True           False
# 2022-12-29                                   True           False
# 2022-12-30                                   True           False
# 2022-12-31                                   True           False
#
#             inflation_rate
# Order Date
# 2018-01-01        2.040000
# 2018-01-02        2.041935
# 2018-01-03        2.043871
# 2018-01-04        2.045806
# 2018-01-05        2.047742
# ...                    ...
# 2022-12-27        2.260000
# 2022-12-28        2.260000
# 2022-12-29        2.260000
# 2022-12-30        2.260000
# 2022-12-31        2.260000
#
# [1826 rows x 22 columns]

# %% [markdown]
# **Add historic overall sales**

# %%
df['Sales 1YA'] = assign_historic_sales(df, year_till=2021)
df['Sales 2YA'] = assign_historic_sales(df, year_till=2020)
df['Sales 3YA'] = assign_historic_sales(df, year_till=2019)

# %%
df
# Out:
#             total_sales  day  month  year  is_weekend  day_of_week  \
# Order Date
# 2018-01-01     16122.06    1      1  2018       False            0
# 2018-01-02     17006.00    2      1  2018       False            1
# 2018-01-03     13315.58    3      1  2018       False            2
# 2018-01-04     15820.10    4      1  2018       False            3
# 2018-01-05     17752.51    5      1  2018       False            4
# ...                 ...  ...    ...   ...         ...          ...
# 2022-12-27     19584.77   27     12  2022       False            1
# 2022-12-28     16875.12   28     12  2022       False            2
# 2022-12-29     18348.89   29     12  2022       False            3
# 2022-12-30     16886.45   30     12  2022       False            4
# 2022-12-31     12634.59   31     12  2022       False            5
#
#             day_of_year  quarter  is_month_start  is_month_end  ...  \
# Order Date                                                      ...
# 2018-01-01            1        1            True         False  ...
# 2018-01-02            2        1           False         False  ...
# 2018-01-03            3        1           False         False  ...
# 2018-01-04            4        1           False         False  ...
# 2018-01-05            5        1           False         False  ...
# ...                 ...      ...             ...           ...  ...
# 2022-12-27          361        4           False         False  ...
# 2022-12-28          362        4           False         False  ...
# 2022-12-29          363        4           False         False  ...
# 2022-12-30          364        4           False         False  ...
# 2022-12-31          365        4           False          True  ...
#
#             Amazon Events_Mother's Day Deals  Amazon Events_No Events  \
# Order Date
# 2018-01-01                             False                     True
# 2018-01-02                             False                     True
# 2018-01-03                             False                     True
# 2018-01-04                             False                     True
# 2018-01-05                             False                     True
# ...                                      ...                      ...
# 2022-12-27                             False                    False
# 2022-12-28                             False                    False
# 2022-12-29                             False                    False
# 2022-12-30                             False                    False
# 2022-12-31                             False                    False
#
#             Amazon Events_Prime Big Deal Days  \
# Order Date
# 2018-01-01                              False
# 2018-01-02                              False
# 2018-01-03                              False
# 2018-01-04                              False
# 2018-01-05                              False
# ...                                       ...
# 2022-12-27                              False
# 2022-12-28                              False
# 2022-12-29                              False
# 2022-12-30                              False
# 2022-12-31                              False
#
#             Amazon Events_Valentine's Day Promotions  \
# Order Date
# 2018-01-01                                     False
# 2018-01-02                                     False
# 2018-01-03                                     False
# 2018-01-04                                     False
# 2018-01-05                                     False
# ...                                              ...
# 2022-12-27                                     False
# 2022-12-28                                     False
# 2022-12-29                                     False
# 2022-12-30                                     False
# 2022-12-31                                     False
#
#             Amazon Events_Year-End Clearance Sale  fedral_holiday  \
# Order Date
# 2018-01-01                                  False            True
# 2018-01-02                                  False           False
# 2018-01-03                                  False           False
# 2018-01-04                                  False           False
# 2018-01-05                                  False           False
# ...                                           ...             ...
# 2022-12-27                                   True           False
# 2022-12-28                                   True           False
# 2022-12-29                                   True           False
# 2022-12-30                                   True           False
# 2022-12-31                                   True           False
#
#             inflation_rate  Sales 1YA  Sales 2YA  Sales 3YA
# Order Date
# 2018-01-01        2.040000        NaN        NaN        NaN
# 2018-01-02        2.041935        NaN        NaN        NaN
# 2018-01-03        2.043871        NaN        NaN        NaN
# 2018-01-04        2.045806        NaN        NaN        NaN
# 2018-01-05        2.047742        NaN        NaN        NaN
# ...                    ...        ...        ...        ...
# 2022-12-27        2.260000   32904.27   28083.85   18605.45
# 2022-12-28        2.260000   28271.32   28408.56   18191.95
# 2022-12-29        2.260000   32067.50   30703.10   19580.33
# 2022-12-30        2.260000   31030.66   27021.29   17788.55
# 2022-12-31        2.260000   23616.71   27404.00   14808.73
#
# [1826 rows x 25 columns]

# %% [markdown]
# **Add historic state-wise sales**

# %%
def get_shift_value(year, forcast_df=None):
    global df
    if forcast_df is None:
        return (df[df.index.year<2023].index[-1] - df[df.index.year<=year].index[-1]).days
    else:
        return (forcast_df.index[-1] - df[df.index.year<=year].index[-1]).days

# %%
def add_states_lags():
    global purchases, df
    temp_df = purchases[['Shipping Address State','Category','total_sales']]
    
    temp_df = pd.DataFrame(temp_df.groupby([temp_df.index,'Shipping Address State'])['total_sales'].sum()).reset_index()
    
    states_features = pd.pivot( temp_df[['Order Date', 'Shipping Address State', 'total_sales']], index='Order Date', columns='Shipping Address State', values='total_sales').reset_index().fillna(0)
    
    states_features = states_features.set_index('Order Date')

    scaler = MinMaxScaler()

    scaled_data = scaler.fit_transform(states_features)
    
    pca = PCA(n_components=3,random_state=101)
    
    pca_features = pca.fit_transform(scaled_data)

    state_sales_reduced = pd.DataFrame(pca_features)

    state_sales_reduced.rename(columns={0:'SS1',1:'SS2',2:'SS3'}, inplace=True)

    state_sales_reduced.set_index(df.index, inplace=True)

    states_features = pd.concat([state_sales_reduced, state_sales_reduced.shift(get_shift_value(2021)-10).rename(columns={'SS1':'SS1 1YA','SS2':'SS2 1YA','SS3':'SS3 1YA'}), state_sales_reduced.shift(get_shift_value(2020)-10).rename(columns={'SS1':'SS1 2YA','SS2':'SS2 2YA','SS3':'SS3 2YA'}), state_sales_reduced.shift(get_shift_value(2019)-10).rename(columns={'SS1':'SS1 3YA','SS2':'SS2 3YA','SS3':'SS3 3YA'})], axis=1)

    return pd.merge(df, states_features, left_index=True, right_index=True, how='left')

# %%
get_shift_value(2020)-1
# Out:
# 729

# %%
df = add_states_lags()

# %%
get_null_percentage(df)
# Out:
# total_sales                                  0.000000
# day                                          0.000000
# month                                        0.000000
# year                                         0.000000
# is_weekend                                   0.000000
# day_of_week                                  0.000000
# day_of_year                                  0.000000
# quarter                                      0.000000
# is_month_start                               0.000000
# is_month_end                                 0.000000
# is_year_start                                0.000000
# is_year_end                                  0.000000
# Amazon Events_Amazon Prime Day               0.000000
# Amazon Events_Black Friday                   0.000000
# Amazon Events_Memorial Day Sales             0.000000
# Amazon Events_Mother's Day Deals             0.000000
# Amazon Events_No Events                      0.000000
# Amazon Events_Prime Big Deal Days            0.000000
# Amazon Events_Valentine's Day Promotions     0.000000
# Amazon Events_Year-End Clearance Sale        0.000000
# fedral_holiday                               0.000000
# inflation_rate                               0.000000
# SS2                                          0.000000
# SS1                                          0.000000
# SS3                                          0.000000
# SS2 1YA                                     19.441402
# SS3 1YA                                     19.441402
# SS1 1YA                                     19.441402
# Sales 1YA                                   19.989047
# SS1 2YA                                     39.430449
# SS3 2YA                                     39.430449
# SS2 2YA                                     39.430449
# Sales 2YA                                   39.978094
# SS3 3YA                                     59.474261
# SS1 3YA                                     59.474261
# SS2 3YA                                     59.474261
# Sales 3YA                                   60.021906
# dtype: float64

# %% [markdown]
# ## Cross Validation

# %% [markdown]
# **generate forcast dataframe**

# %%
feature_columns = list(df.columns)
[feature_columns.remove(column) for column in ['total_sales','SS1','SS2','SS3']]
feature_columns
# Out:
# ['day',
#  'month',
#  'year',
#  'is_weekend',
#  'day_of_week',
#  'day_of_year',
#  'quarter',
#  'is_month_start',
#  'is_month_end',
#  'is_year_start',
#  'is_year_end',
#  'Amazon Events_Amazon Prime Day',
#  'Amazon Events_Black Friday',
#  'Amazon Events_Memorial Day Sales',
#  "Amazon Events_Mother's Day Deals",
#  'Amazon Events_No Events',
#  'Amazon Events_Prime Big Deal Days',
#  "Amazon Events_Valentine's Day Promotions",
#  'Amazon Events_Year-End Clearance Sale',
#  'fedral_holiday',
#  'inflation_rate',
#  'Sales 1YA',
#  'Sales 2YA',
#  'Sales 3YA',
#  'SS1 1YA',
#  'SS2 1YA',
#  'SS3 1YA',
#  'SS1 2YA',
#  'SS2 2YA',
#  'SS3 2YA',
#  'SS1 3YA',
#  'SS2 3YA',
#  'SS3 3YA']

# %%
forcast_df =  pd.DataFrame(pd.date_range('2023-01-01', '2023-12-31'),columns=['Order Date'])

# %%
forcast_df = generate_time_features(forcast_df)

# %%
forcast_df = add_holidays_past_2021(forcast_df)

# %%
forcast_df['fedral_holiday'] = forcast_df['fedral_holiday'].fillna(False)
# Out:
# C:\Users\rohit\AppData\Local\Temp\ipykernel_17076\2162938522.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   forcast_df['fedral_holiday'] = forcast_df['fedral_holiday'].fillna(False)

# %%
forcast_df = add_amazon_events(forcast_df)

# %%
forcast_df = forcast_df.drop('index',axis=1)

# %%
forcast_df['forcasting'] = True
df['forcasting'] = False

combined_df = pd.concat([df, forcast_df], axis=0)

combined_df['Sales 1YA'] = assign_historic_sales(combined_df, year_till=2022)
combined_df['Sales 2YA'] = assign_historic_sales(combined_df, year_till=2021)
combined_df['Sales 3YA'] = assign_historic_sales(combined_df, year_till=2020)

combined_df[['SS1 1YA','SS2 1YA','SS3 1YA']] = combined_df[['SS1','SS2','SS3']].shift(get_shift_value(2022, forcast_df)-10)
combined_df[['SS1 2YA','SS2 2YA','SS3 2YA']] = combined_df[['SS1','SS2','SS3']].shift(get_shift_value(2021, forcast_df)-10)
combined_df[['SS1 3YA','SS2 3YA','SS3 3YA']] = combined_df[['SS1','SS2','SS3']].shift(get_shift_value(2020, forcast_df)-10)

forcast_df[['Sales 1YA', 'Sales 2YA', 'Sales 3YA','SS1 1YA','SS2 1YA','SS3 1YA','SS1 2YA','SS2 2YA','SS3 2YA','SS1 3YA','SS2 3YA','SS3 3YA']] = combined_df[combined_df['forcasting'] == True][['Sales 1YA', 'Sales 2YA', 'Sales 3YA','SS1 1YA','SS2 1YA','SS3 1YA','SS1 2YA','SS2 2YA','SS3 2YA','SS1 3YA','SS2 3YA','SS3 3YA']]

forcast_df = forcast_df.drop('forcasting',axis=1)
df = df.drop('forcasting',axis=1)

# %%
forcast_df['inflation_rate'] = df['inflation_rate'].mean()

# %%
forcast_df = pd.concat([df[sorted(feature_columns)].iloc[-30:],forcast_df[sorted(feature_columns)]], axis=0)

# %%
forcast_df = forcast_df[feature_columns]

# %%
forcast_df
# Out:
#             day  month  year  is_weekend  day_of_week  day_of_year  quarter  \
# Order Date
# 2022-12-02    2     12  2022       False            4          336        4
# 2022-12-03    3     12  2022       False            5          337        4
# 2022-12-04    4     12  2022        True            6          338        4
# 2022-12-05    5     12  2022       False            0          339        4
# 2022-12-06    6     12  2022       False            1          340        4
# ...         ...    ...   ...         ...          ...          ...      ...
# 2023-12-27   27     12  2023       False            2          361        4
# 2023-12-28   28     12  2023       False            3          362        4
# 2023-12-29   29     12  2023       False            4          363        4
# 2023-12-30   30     12  2023       False            5          364        4
# 2023-12-31   31     12  2023        True            6          365        4
#
#             is_month_start  is_month_end  is_year_start  ...  Sales 3YA  \
# Order Date                                               ...
# 2022-12-02           False         False          False  ...   68580.09
# 2022-12-03           False         False          False  ...   19426.56
# 2022-12-04           False         False          False  ...   21674.11
# 2022-12-05           False         False          False  ...   22322.26
# 2022-12-06           False         False          False  ...   24400.10
# ...                    ...           ...            ...  ...        ...
# 2023-12-27           False         False          False  ...   28083.85
# 2023-12-28           False         False          False  ...   28408.56
# 2023-12-29           False         False          False  ...   30703.10
# 2023-12-30           False         False          False  ...   27021.29
# 2023-12-31           False          True          False  ...   27404.00
#
#              SS1 1YA   SS2 1YA   SS3 1YA   SS1 2YA   SS2 2YA   SS3 2YA  \
# Order Date
# 2022-12-02  0.390799 -0.084732  0.011374  0.528721  0.111993 -0.014622
# 2022-12-03  0.589301 -0.070354 -0.148633  0.501165 -0.168356 -0.163615
# 2022-12-04  0.575905  0.002422  0.037183  0.500846 -0.035116  0.207645
# 2022-12-05  0.781905  0.041588  0.295036  0.476775  0.043697 -0.068057
# 2022-12-06  0.687362 -0.216649  0.221436  0.674633 -0.046609  0.088321
# ...              ...       ...       ...       ...       ...       ...
# 2023-12-27       NaN       NaN       NaN -0.039552 -0.065894  0.009674
# 2023-12-28       NaN       NaN       NaN  0.146726 -0.065005  0.080304
# 2023-12-29       NaN       NaN       NaN  0.105093 -0.020891  0.066558
# 2023-12-30       NaN       NaN       NaN  0.105740 -0.081221 -0.115929
# 2023-12-31       NaN       NaN       NaN  0.027166 -0.057971  0.005497
#
#              SS1 3YA   SS2 3YA   SS3 3YA
# Order Date
# 2022-12-02  0.316070 -0.053215 -0.196227
# 2022-12-03  0.318811 -0.110406 -0.109510
# 2022-12-04  0.312876  0.071322 -0.069005
# 2022-12-05  0.351064  0.116608 -0.166644
# 2022-12-06  0.400270  0.047092 -0.143028
# ...              ...       ...       ...
# 2023-12-27  0.076311  0.101759  0.266981
# 2023-12-28  0.056957 -0.014689 -0.005521
# 2023-12-29  0.058295 -0.075090 -0.017525
# 2023-12-30  0.069207  0.079294 -0.016494
# 2023-12-31  0.327201 -0.126362  0.026496
#
# [395 rows x 33 columns]

# %%
df[feature_columns]
# Out:
#             day  month  year  is_weekend  day_of_week  day_of_year  quarter  \
# Order Date
# 2018-01-01    1      1  2018       False            0            1        1
# 2018-01-02    2      1  2018       False            1            2        1
# 2018-01-03    3      1  2018       False            2            3        1
# 2018-01-04    4      1  2018       False            3            4        1
# 2018-01-05    5      1  2018       False            4            5        1
# ...         ...    ...   ...         ...          ...          ...      ...
# 2022-12-27   27     12  2022       False            1          361        4
# 2022-12-28   28     12  2022       False            2          362        4
# 2022-12-29   29     12  2022       False            3          363        4
# 2022-12-30   30     12  2022       False            4          364        4
# 2022-12-31   31     12  2022       False            5          365        4
#
#             is_month_start  is_month_end  is_year_start  ...  Sales 3YA  \
# Order Date                                               ...
# 2018-01-01            True         False           True  ...        NaN
# 2018-01-02           False         False          False  ...        NaN
# 2018-01-03           False         False          False  ...        NaN
# 2018-01-04           False         False          False  ...        NaN
# 2018-01-05           False         False          False  ...        NaN
# ...                    ...           ...            ...  ...        ...
# 2022-12-27           False         False          False  ...   18605.45
# 2022-12-28           False         False          False  ...   18191.95
# 2022-12-29           False         False          False  ...   19580.33
# 2022-12-30           False         False          False  ...   17788.55
# 2022-12-31           False          True          False  ...   14808.73
#
#              SS1 1YA   SS2 1YA   SS3 1YA   SS1 2YA   SS2 2YA   SS3 2YA  \
# Order Date
# 2018-01-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-01-05       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2022-12-27 -0.039552 -0.065894  0.009674  0.076311  0.101759  0.266981
# 2022-12-28  0.146726 -0.065005  0.080304  0.056957 -0.014689 -0.005521
# 2022-12-29  0.105093 -0.020891  0.066558  0.058295 -0.075090 -0.017525
# 2022-12-30  0.105740 -0.081221 -0.115929  0.069207  0.079294 -0.016494
# 2022-12-31  0.027166 -0.057971  0.005497  0.327201 -0.126362  0.026496
#
#              SS1 3YA   SS2 3YA   SS3 3YA
# Order Date
# 2018-01-01       NaN       NaN       NaN
# 2018-01-02       NaN       NaN       NaN
# 2018-01-03       NaN       NaN       NaN
# 2018-01-04       NaN       NaN       NaN
# 2018-01-05       NaN       NaN       NaN
# ...              ...       ...       ...
# 2022-12-27 -0.066376 -0.165988 -0.427192
# 2022-12-28 -0.199835 -0.027518 -0.055484
# 2022-12-29 -0.119714 -0.040575 -0.076681
# 2022-12-30 -0.112761 -0.106674 -0.031974
# 2022-12-31 -0.060067 -0.100797 -0.375271
#
# [1826 rows x 33 columns]

# %% [markdown]
# **cross validate**

# %%
def cross_validate(df, forcastdf, feature_columns):
    scores = []
    preds = []
    feature_importances = []
    sales = []
    tss = TimeSeriesSplit(n_splits=3, test_size=365, gap=0)
    feature_columns = sorted(feature_columns)
    for train_idx, val_idx in tss.split(df):
        scaler = StandardScaler()
        train = df.iloc[train_idx]
        test = df.iloc[val_idx]
        X_train = train[feature_columns]
        y_train = train['total_sales']
        X_test = test[feature_columns]
        y_test = test['total_sales']
        reg_model = xgb.XGBRegressor(base_score=0.5, booster='gblinear',  n_estimators=1000, early_stopping_rounds=50, objective='reg:squarederror', learning_rate=0.01)
        reg_model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_test, y_test)], verbose=True)
        feature_importances.append(reg_model.feature_importances_)
        y_preds = reg_model.predict(X_train)
        score = np.sqrt(mean_squared_error(y_train, y_preds))
        print('train: ',score)
        ds =  pd.concat([y_train.reset_index(),pd.Series(y_preds)], axis=1)
        ds = ds.set_index('Order Date')
        ds['total_sales'].plot(label='true data')
        ds[0].plot(label='prediction')
        plt.legend()
        plt.show()
        y_preds = reg_model.predict(X_test)
        ds =  pd.concat([y_test.reset_index(),pd.Series(y_preds)], axis=1)
        ds = ds.set_index('Order Date')
        ds['total_sales'].plot(label='true data')
        ds[0].plot(label='prediction')
        plt.legend()
        plt.show()
        forcast_preds = reg_model.predict(forcastdf[feature_columns])
        ds =  pd.Series(forcast_preds, index=forcastdf.index)
        ds.plot(label='prediction')
        plt.legend()
        plt.show()
        
        preds.append(y_preds)
        score = np.sqrt(mean_squared_error(y_test, y_preds))
        print('test: ',score)
        scores.append(score)

    return preds, scores, feature_importances

# %%
preds, scores, feature_importances = cross_validate(df, forcast_df, feature_columns)
# Out:
# [0]	validation_0-rmse:15773.12435	validation_1-rmse:24082.54581
# [1]	validation_0-rmse:14644.53557	validation_1-rmse:22582.94054
# [2]	validation_0-rmse:13630.30460	validation_1-rmse:21242.01755
# [3]	validation_0-rmse:12727.35105	validation_1-rmse:20035.12264
# [4]	validation_0-rmse:11921.98803	validation_1-rmse:18952.01791
# [5]	validation_0-rmse:11206.49705	validation_1-rmse:17982.78357
# [6]	validation_0-rmse:10571.74960	validation_1-rmse:17114.77973
# [7]	validation_0-rmse:10010.12190	validation_1-rmse:16338.02709
# [8]	validation_0-rmse:9515.33951	validation_1-rmse:15643.83948
# [9]	validation_0-rmse:9080.72154	validation_1-rmse:15023.92883
# [10]	validation_0-rmse:8699.27999	validation_1-rmse:14469.41524
# [11]	validation_0-rmse:8365.77566	validation_1-rmse:13974.60362
# [12]	validation_0-rmse:8075.06711	validation_1-rmse:13532.98368
# [13]	validation_0-rmse:7821.45835	validation_1-rmse:13138.66172
# [14]	validation_0-rmse:7600.54724	validation_1-rmse:12785.54042
# [15]	validation_0-rmse:7408.86522	validation_1-rmse:12470.64307
# [16]	validation_0-rmse:7241.89177	validation_1-rmse:12188.49384
# [17]	validation_0-rmse:7096.44648	validation_1-rmse:11935.81471
# [18]	validation_0-rmse:6969.37741	validation_1-rmse:11710.00318
# [19]	validation_0-rmse:6858.14611	validation_1-rmse:11507.13277
# [20]	validation_0-rmse:6760.54665	validation_1-rmse:11324.98203
# [21]	validation_0-rmse:6674.95963	validation_1-rmse:11161.48842
# [22]	validation_0-rmse:6599.42966	validation_1-rmse:11014.05691
# [23]	validation_0-rmse:6532.24328	validation_1-rmse:10881.16552
# [24]	validation_0-rmse:6472.43496	validation_1-rmse:10761.03785
# [70]	validation_0-rmse:5552.15569	validation_1-rmse:9392.87697
# [71]	validation_0-rmse:5542.16958	validation_1-rmse:9381.41874
# [72]	validation_0-rmse:5532.36865	validation_1-rmse:9369.88563
# [73]	validation_0-rmse:5522.75458	validation_1-rmse:9358.19635
# [74]	validation_0-rmse:5513.32410	validation_1-rmse:9346.55854
# [75]	validation_0-rmse:5504.07409	validation_1-rmse:9334.97386
# [76]	validation_0-rmse:5494.99936	validation_1-rmse:9323.10777
# [77]	validation_0-rmse:5486.08818	validation_1-rmse:9311.40567
# [78]	validation_0-rmse:5477.34509	validation_1-rmse:9299.76687
# [79]	validation_0-rmse:5468.76955	validation_1-rmse:9288.10400
# [80]	validation_0-rmse:5460.35107	validation_1-rmse:9276.15880
# [81]	validation_0-rmse:5452.08941	validation_1-rmse:9264.36517
# [82]	validation_0-rmse:5443.98485	validation_1-rmse:9252.40298
# [83]	validation_0-rmse:5436.02536	validation_1-rmse:9240.38932
# [84]	validation_0-rmse:5428.21626	validation_1-rmse:9228.44522
# [85]	validation_0-rmse:5420.55432	validation_1-rmse:9216.39389
# [86]	validation_0-rmse:5413.03230	validation_1-rmse:9204.17344
# [87]	validation_0-rmse:5405.65157	validation_1-rmse:9192.09664
# [88]	validation_0-rmse:5398.41045	validation_1-rmse:9179.82633
# [89]	validation_0-rmse:5391.30670	validation_1-rmse:9167.86386
# [90]	validation_0-rmse:5384.33082	validation_1-rmse:9155.75377
# [91]	validation_0-rmse:5377.48427	validation_1-rmse:9143.64231
# [92]	validation_0-rmse:5370.76510	validation_1-rmse:9131.56002
# [93]	validation_0-rmse:5364.16931	validation_1-rmse:9119.28278
# [94]	validation_0-rmse:5357.69538	validation_1-rmse:9106.99585
# [95]	validation_0-rmse:5351.34004	validation_1-rmse:9094.75551
# [96]	validation_0-rmse:5345.10105	validation_1-rmse:9082.63350
# [97]	validation_0-rmse:5338.97819	validation_1-rmse:9070.54544
# [98]	validation_0-rmse:5332.96744	validation_1-rmse:9058.46850
# [99]	validation_0-rmse:5327.07060	validation_1-rmse:9046.42205
# [100]	validation_0-rmse:5321.28256	validation_1-rmse:9034.39605
# [101]	validation_0-rmse:5315.60016	validation_1-rmse:9022.34375
# [102]	validation_0-rmse:5310.01869	validation_1-rmse:9010.32297
# [103]	validation_0-rmse:5304.53997	validation_1-rmse:8998.30025
# [104]	validation_0-rmse:5299.16145	validation_1-rmse:8986.13266
# [105]	validation_0-rmse:5293.88278	validation_1-rmse:8974.18365
# [106]	validation_0-rmse:5288.69999	validation_1-rmse:8962.41187
# [107]	validation_0-rmse:5283.61011	validation_1-rmse:8950.56337
# [108]	validation_0-rmse:5278.61307	validation_1-rmse:8938.78779
# [109]	validation_0-rmse:5273.70630	validation_1-rmse:8927.03984
# [110]	validation_0-rmse:5268.89045	validation_1-rmse:8915.29708
# [111]	validation_0-rmse:5264.16321	validation_1-rmse:8903.68633
# [112]	validation_0-rmse:5259.51905	validation_1-rmse:8892.05262
# [113]	validation_0-rmse:5254.96061	validation_1-rmse:8880.67063
# [203]	validation_0-rmse:5047.89176	validation_1-rmse:8189.35684
# [204]	validation_0-rmse:5046.84088	validation_1-rmse:8185.25658
# [205]	validation_0-rmse:5045.80326	validation_1-rmse:8181.26047
# [206]	validation_0-rmse:5044.77857	validation_1-rmse:8177.26480
# [207]	validation_0-rmse:5043.76726	validation_1-rmse:8173.38272
# [208]	validation_0-rmse:5042.76922	validation_1-rmse:8169.54290
# [209]	validation_0-rmse:5041.78392	validation_1-rmse:8165.77493
# [210]	validation_0-rmse:5040.81139	validation_1-rmse:8162.04422
# [211]	validation_0-rmse:5039.85096	validation_1-rmse:8158.37437
# [212]	validation_0-rmse:5038.90235	validation_1-rmse:8154.76635
# [213]	validation_0-rmse:5037.96452	validation_1-rmse:8151.19219
# [214]	validation_0-rmse:5037.03905	validation_1-rmse:8147.73583
# [215]	validation_0-rmse:5036.12500	validation_1-rmse:8144.31731
# [216]	validation_0-rmse:5035.22345	validation_1-rmse:8140.95376
# [217]	validation_0-rmse:5034.33183	validation_1-rmse:8137.64606
# [218]	validation_0-rmse:5033.45039	validation_1-rmse:8134.36260
# [219]	validation_0-rmse:5032.57865	validation_1-rmse:8131.14762
# [220]	validation_0-rmse:5031.71945	validation_1-rmse:8128.01542
# [221]	validation_0-rmse:5030.86894	validation_1-rmse:8124.93161
# [222]	validation_0-rmse:5030.02774	validation_1-rmse:8121.86141
# [223]	validation_0-rmse:5029.19697	validation_1-rmse:8118.84784
# [224]	validation_0-rmse:5028.37572	validation_1-rmse:8115.87968
# [225]	validation_0-rmse:5027.56494	validation_1-rmse:8112.94125
# [226]	validation_0-rmse:5026.76262	validation_1-rmse:8110.11663
# [227]	validation_0-rmse:5025.96870	validation_1-rmse:8107.32353
# [228]	validation_0-rmse:5025.18406	validation_1-rmse:8104.57713
# [229]	validation_0-rmse:5024.40876	validation_1-rmse:8101.85620
# [230]	validation_0-rmse:5023.64122	validation_1-rmse:8099.20917
# [231]	validation_0-rmse:5022.88235	validation_1-rmse:8096.60129
# [232]	validation_0-rmse:5022.13173	validation_1-rmse:8094.06058
# [233]	validation_0-rmse:5021.38961	validation_1-rmse:8091.52811
# [234]	validation_0-rmse:5020.65471	validation_1-rmse:8089.06282
# [235]	validation_0-rmse:5019.92664	validation_1-rmse:8086.60313
# [236]	validation_0-rmse:5019.20713	validation_1-rmse:8084.21895
# [237]	validation_0-rmse:5018.49561	validation_1-rmse:8081.87488
# [238]	validation_0-rmse:5017.79093	validation_1-rmse:8079.60757
# [239]	validation_0-rmse:5017.09389	validation_1-rmse:8077.33829
# [240]	validation_0-rmse:5016.40402	validation_1-rmse:8075.13085
# [241]	validation_0-rmse:5015.72096	validation_1-rmse:8073.00290
# [242]	validation_0-rmse:5015.04424	validation_1-rmse:8070.94617
# [243]	validation_0-rmse:5014.37443	validation_1-rmse:8068.87556
# [244]	validation_0-rmse:5013.71132	validation_1-rmse:8066.83356
# [245]	validation_0-rmse:5013.05493	validation_1-rmse:8064.81408
# [246]	validation_0-rmse:5012.40507	validation_1-rmse:8062.83472
# [292]	validation_0-rmse:4987.76756	validation_1-rmse:8008.51132
# [293]	validation_0-rmse:4987.31916	validation_1-rmse:8007.95513
# [294]	validation_0-rmse:4986.87364	validation_1-rmse:8007.44784
# [295]	validation_0-rmse:4986.43176	validation_1-rmse:8006.93370
# [296]	validation_0-rmse:4985.99166	validation_1-rmse:8006.44567
# [297]	validation_0-rmse:4985.55500	validation_1-rmse:8006.00852
# [298]	validation_0-rmse:4985.12052	validation_1-rmse:8005.56279
# [299]	validation_0-rmse:4984.68879	validation_1-rmse:8005.15396
# [300]	validation_0-rmse:4984.25942	validation_1-rmse:8004.77710
# [301]	validation_0-rmse:4983.83278	validation_1-rmse:8004.42339
# [302]	validation_0-rmse:4983.40819	validation_1-rmse:8004.07689
# [303]	validation_0-rmse:4982.98628	validation_1-rmse:8003.75961
# [304]	validation_0-rmse:4982.56688	validation_1-rmse:8003.46789
# [305]	validation_0-rmse:4982.14990	validation_1-rmse:8003.16397
# [306]	validation_0-rmse:4981.73453	validation_1-rmse:8002.88940
# [307]	validation_0-rmse:4981.32153	validation_1-rmse:8002.63978
# [308]	validation_0-rmse:4980.91080	validation_1-rmse:8002.38802
# [309]	validation_0-rmse:4980.50247	validation_1-rmse:8002.12227
# [310]	validation_0-rmse:4980.09686	validation_1-rmse:8001.92710
# [311]	validation_0-rmse:4979.69253	validation_1-rmse:8001.67968
# [312]	validation_0-rmse:4979.29029	validation_1-rmse:8001.53563
# [313]	validation_0-rmse:4978.89145	validation_1-rmse:8001.41485
# [314]	validation_0-rmse:4978.49362	validation_1-rmse:8001.24032
# [315]	validation_0-rmse:4978.09692	validation_1-rmse:8001.14718
# [316]	validation_0-rmse:4977.70340	validation_1-rmse:8001.06764
# [317]	validation_0-rmse:4977.31160	validation_1-rmse:8001.04691
# [318]	validation_0-rmse:4976.92110	validation_1-rmse:8001.02765
# [319]	validation_0-rmse:4976.53371	validation_1-rmse:8001.02424
# [320]	validation_0-rmse:4976.14776	validation_1-rmse:8001.01724
# [321]	validation_0-rmse:4975.76405	validation_1-rmse:8001.02784
# [322]	validation_0-rmse:4975.38211	validation_1-rmse:8001.05766
# [323]	validation_0-rmse:4975.00188	validation_1-rmse:8001.09918
# [324]	validation_0-rmse:4974.62371	validation_1-rmse:8001.14946
# [325]	validation_0-rmse:4974.24668	validation_1-rmse:8001.23595
# [326]	validation_0-rmse:4973.87148	validation_1-rmse:8001.32585
# [327]	validation_0-rmse:4973.49822	validation_1-rmse:8001.42731
# [328]	validation_0-rmse:4973.12683	validation_1-rmse:8001.55177
# [329]	validation_0-rmse:4972.75713	validation_1-rmse:8001.68307
# [330]	validation_0-rmse:4972.38897	validation_1-rmse:8001.82853
# [331]	validation_0-rmse:4972.02244	validation_1-rmse:8001.98432
# [332]	validation_0-rmse:4971.65732	validation_1-rmse:8002.13571
# [333]	validation_0-rmse:4971.29388	validation_1-rmse:8002.27448
# [334]	validation_0-rmse:4970.93296	validation_1-rmse:8002.55273
# [335]	validation_0-rmse:4970.57177	validation_1-rmse:8002.77561
# [275]	validation_0-rmse:5306.34135	validation_1-rmse:9038.54536
# [276]	validation_0-rmse:5305.80805	validation_1-rmse:9037.21207
# [277]	validation_0-rmse:5305.28000	validation_1-rmse:9035.88148
# [278]	validation_0-rmse:5304.75622	validation_1-rmse:9034.58366
# [279]	validation_0-rmse:5304.23525	validation_1-rmse:9033.24346
# [280]	validation_0-rmse:5303.72026	validation_1-rmse:9031.94377
# [281]	validation_0-rmse:5303.21003	validation_1-rmse:9030.65997
# [282]	validation_0-rmse:5302.70361	validation_1-rmse:9029.37890
# [283]	validation_0-rmse:5302.20159	validation_1-rmse:9028.10912
# [284]	validation_0-rmse:5301.70318	validation_1-rmse:9026.85465
# [285]	validation_0-rmse:5301.20779	validation_1-rmse:9025.60733
# [286]	validation_0-rmse:5300.71753	validation_1-rmse:9024.35714
# [287]	validation_0-rmse:5300.23107	validation_1-rmse:9023.10676
# [288]	validation_0-rmse:5299.74851	validation_1-rmse:9021.87226
# [289]	validation_0-rmse:5299.26999	validation_1-rmse:9020.64106
# [290]	validation_0-rmse:5298.79491	validation_1-rmse:9019.41736
# [291]	validation_0-rmse:5298.32380	validation_1-rmse:9018.23344
# [292]	validation_0-rmse:5297.85611	validation_1-rmse:9017.01734
# [293]	validation_0-rmse:5297.39125	validation_1-rmse:9015.79063
# [294]	validation_0-rmse:5296.93091	validation_1-rmse:9014.59100
# [295]	validation_0-rmse:5296.47385	validation_1-rmse:9013.40338
# [296]	validation_0-rmse:5296.02010	validation_1-rmse:9012.21666
# [297]	validation_0-rmse:5295.56967	validation_1-rmse:9011.05237
# [298]	validation_0-rmse:5295.12280	validation_1-rmse:9009.89027
# [299]	validation_0-rmse:5294.67853	validation_1-rmse:9008.73997
# [300]	validation_0-rmse:5294.23837	validation_1-rmse:9007.58789
# [301]	validation_0-rmse:5293.80041	validation_1-rmse:9006.46050
# [302]	validation_0-rmse:5293.36671	validation_1-rmse:9005.31468
# [303]	validation_0-rmse:5292.93559	validation_1-rmse:9004.18121
# [304]	validation_0-rmse:5292.50720	validation_1-rmse:9003.08363
# [305]	validation_0-rmse:5292.08222	validation_1-rmse:9001.95323
# [306]	validation_0-rmse:5291.65970	validation_1-rmse:9000.81757
# [307]	validation_0-rmse:5291.23999	validation_1-rmse:8999.68935
# [308]	validation_0-rmse:5290.82357	validation_1-rmse:8998.58361
# [309]	validation_0-rmse:5290.41007	validation_1-rmse:8997.47585
# [310]	validation_0-rmse:5289.99902	validation_1-rmse:8996.36808
# [311]	validation_0-rmse:5289.59075	validation_1-rmse:8995.27483
# [312]	validation_0-rmse:5289.18533	validation_1-rmse:8994.18960
# [313]	validation_0-rmse:5288.78249	validation_1-rmse:8993.10675
# [314]	validation_0-rmse:5288.38267	validation_1-rmse:8992.03517
# [315]	validation_0-rmse:5287.98423	validation_1-rmse:8990.93822
# [316]	validation_0-rmse:5287.58886	validation_1-rmse:8989.88805
# [317]	validation_0-rmse:5287.19647	validation_1-rmse:8988.83958
# [318]	validation_0-rmse:5286.80657	validation_1-rmse:8987.80245
# [319]	validation_0-rmse:5286.41919	validation_1-rmse:8986.76043
# [320]	validation_0-rmse:5286.03381	validation_1-rmse:8985.72758
# [321]	validation_0-rmse:5285.65110	validation_1-rmse:8984.69096
# [322]	validation_0-rmse:5285.27063	validation_1-rmse:8983.65863
# [323]	validation_0-rmse:5284.89247	validation_1-rmse:8982.63457
# [324]	validation_0-rmse:5284.51685	validation_1-rmse:8981.61238
# [325]	validation_0-rmse:5284.14286	validation_1-rmse:8980.59450
# [326]	validation_0-rmse:5283.77178	validation_1-rmse:8979.58879
# [327]	validation_0-rmse:5283.40226	validation_1-rmse:8978.60045
# [328]	validation_0-rmse:5283.03538	validation_1-rmse:8977.61207
# [329]	validation_0-rmse:5282.67069	validation_1-rmse:8976.62213
# [330]	validation_0-rmse:5282.30798	validation_1-rmse:8975.62774
# [331]	validation_0-rmse:5281.94728	validation_1-rmse:8974.63283
# [332]	validation_0-rmse:5281.58906	validation_1-rmse:8973.66452
# [333]	validation_0-rmse:5281.23235	validation_1-rmse:8972.68963
# [334]	validation_0-rmse:5280.87802	validation_1-rmse:8971.74688
# [335]	validation_0-rmse:5280.52551	validation_1-rmse:8970.77891
# [336]	validation_0-rmse:5280.17488	validation_1-rmse:8969.81692
# [337]	validation_0-rmse:5279.82584	validation_1-rmse:8968.86109
# [338]	validation_0-rmse:5279.47916	validation_1-rmse:8967.89954
# [339]	validation_0-rmse:5279.13406	validation_1-rmse:8966.94659
# [340]	validation_0-rmse:5278.79095	validation_1-rmse:8966.00401
# [341]	validation_0-rmse:5278.45005	validation_1-rmse:8965.08993
# [342]	validation_0-rmse:5278.10993	validation_1-rmse:8964.15760
# [343]	validation_0-rmse:5277.77207	validation_1-rmse:8963.22822
# [344]	validation_0-rmse:5277.43629	validation_1-rmse:8962.30733
# [345]	validation_0-rmse:5277.10234	validation_1-rmse:8961.38526
# [346]	validation_0-rmse:5276.77009	validation_1-rmse:8960.46486
# [347]	validation_0-rmse:5276.43978	validation_1-rmse:8959.55515
# [348]	validation_0-rmse:5276.11103	validation_1-rmse:8958.64130
# [349]	validation_0-rmse:5275.78403	validation_1-rmse:8957.76480
# [350]	validation_0-rmse:5275.45849	validation_1-rmse:8956.86733
# [351]	validation_0-rmse:5275.13320	validation_1-rmse:8955.99607
# [352]	validation_0-rmse:5274.81032	validation_1-rmse:8955.08553
# [353]	validation_0-rmse:5274.48951	validation_1-rmse:8954.18680
# [354]	validation_0-rmse:5274.17025	validation_1-rmse:8953.28719
# [355]	validation_0-rmse:5273.85190	validation_1-rmse:8952.42833
# [356]	validation_0-rmse:5273.53581	validation_1-rmse:8951.55054
# [357]	validation_0-rmse:5273.22125	validation_1-rmse:8950.69185
# [358]	validation_0-rmse:5272.90764	validation_1-rmse:8949.81768
# [359]	validation_0-rmse:5272.59599	validation_1-rmse:8948.94844
# [360]	validation_0-rmse:5272.28579	validation_1-rmse:8948.09210
# [361]	validation_0-rmse:5271.97665	validation_1-rmse:8947.22164
# [362]	validation_0-rmse:5271.66936	validation_1-rmse:8946.39185
# [363]	validation_0-rmse:5271.36345	validation_1-rmse:8945.54307
# [364]	validation_0-rmse:5271.05905	validation_1-rmse:8944.69908
# [365]	validation_0-rmse:5270.75615	validation_1-rmse:8943.86284
# [366]	validation_0-rmse:5270.45451	validation_1-rmse:8943.01991
# [367]	validation_0-rmse:5270.15442	validation_1-rmse:8942.18785
# [368]	validation_0-rmse:5269.85562	validation_1-rmse:8941.35768
# [369]	validation_0-rmse:5269.55762	validation_1-rmse:8940.53313
# [370]	validation_0-rmse:5269.26139	validation_1-rmse:8939.73623
# [371]	validation_0-rmse:5268.96638	validation_1-rmse:8938.91432
# [372]	validation_0-rmse:5268.67225	validation_1-rmse:8938.08069
# [373]	validation_0-rmse:5268.37957	validation_1-rmse:8937.27209
# [374]	validation_0-rmse:5268.08814	validation_1-rmse:8936.46931
# [375]	validation_0-rmse:5267.79818	validation_1-rmse:8935.66791
# [376]	validation_0-rmse:5267.50950	validation_1-rmse:8934.87023
# [377]	validation_0-rmse:5267.22179	validation_1-rmse:8934.07691
# [378]	validation_0-rmse:5266.93534	validation_1-rmse:8933.29928
# ...
# [348]	validation_0-rmse:5913.42973	validation_1-rmse:9567.40421
# [349]	validation_0-rmse:5913.05394	validation_1-rmse:9566.93497
# [350]	validation_0-rmse:5912.68002	validation_1-rmse:9566.49730
# [351]	validation_0-rmse:5912.30817	validation_1-rmse:9566.05623
# [352]	validation_0-rmse:5911.93774	validation_1-rmse:9565.63740
# [353]	validation_0-rmse:5911.56817	validation_1-rmse:9565.27701
# [354]	validation_0-rmse:5911.20110	validation_1-rmse:9564.85709
# [355]	validation_0-rmse:5910.83629	validation_1-rmse:9564.44277
# [356]	validation_0-rmse:5910.47278	validation_1-rmse:9564.02052
# [357]	validation_0-rmse:5910.11084	validation_1-rmse:9563.60914
# [358]	validation_0-rmse:5909.75039	validation_1-rmse:9563.23120
# [359]	validation_0-rmse:5909.39153	validation_1-rmse:9562.83884
# [360]	validation_0-rmse:5909.03351	validation_1-rmse:9562.40328
# [361]	validation_0-rmse:5908.67837	validation_1-rmse:9562.02454
# [362]	validation_0-rmse:5908.32473	validation_1-rmse:9561.65234
# [363]	validation_0-rmse:5907.97202	validation_1-rmse:9561.33890
# [364]	validation_0-rmse:5907.62109	validation_1-rmse:9560.94716
# [365]	validation_0-rmse:5907.27113	validation_1-rmse:9560.63258
# [366]	validation_0-rmse:5906.92297	validation_1-rmse:9560.29295
# [367]	validation_0-rmse:5906.57560	validation_1-rmse:9560.00214
# [368]	validation_0-rmse:5906.23027	validation_1-rmse:9559.70234
# [369]	validation_0-rmse:5905.88709	validation_1-rmse:9559.34024
# [370]	validation_0-rmse:5905.54542	validation_1-rmse:9558.98464
# [371]	validation_0-rmse:5905.20531	validation_1-rmse:9558.58829
# [372]	validation_0-rmse:5904.86606	validation_1-rmse:9558.26488
# [373]	validation_0-rmse:5904.52832	validation_1-rmse:9557.96841
# [374]	validation_0-rmse:5904.19180	validation_1-rmse:9557.69750
# [375]	validation_0-rmse:5903.85682	validation_1-rmse:9557.38405
# [421]	validation_0-rmse:5889.72044	validation_1-rmse:9547.36118
# [422]	validation_0-rmse:5889.43702	validation_1-rmse:9547.20161
# [423]	validation_0-rmse:5889.15520	validation_1-rmse:9547.02925
# [424]	validation_0-rmse:5888.87384	validation_1-rmse:9546.89249
# [425]	validation_0-rmse:5888.59308	validation_1-rmse:9546.72534
# [426]	validation_0-rmse:5888.31358	validation_1-rmse:9546.58750
# [427]	validation_0-rmse:5888.03408	validation_1-rmse:9546.47872
# [428]	validation_0-rmse:5887.75587	validation_1-rmse:9546.35053
# [429]	validation_0-rmse:5887.47897	validation_1-rmse:9546.21637
# [430]	validation_0-rmse:5887.20229	validation_1-rmse:9546.09205
# [431]	validation_0-rmse:5886.92657	validation_1-rmse:9545.97515
# [432]	validation_0-rmse:5886.65208	validation_1-rmse:9545.81627
# [433]	validation_0-rmse:5886.37805	validation_1-rmse:9545.68519
# [434]	validation_0-rmse:5886.10515	validation_1-rmse:9545.56759
# [435]	validation_0-rmse:5885.83318	validation_1-rmse:9545.44983
# [436]	validation_0-rmse:5885.56140	validation_1-rmse:9545.36545
# [437]	validation_0-rmse:5885.29101	validation_1-rmse:9545.25213
# [438]	validation_0-rmse:5885.02139	validation_1-rmse:9545.11199
# [439]	validation_0-rmse:5884.75241	validation_1-rmse:9545.00761
# [440]	validation_0-rmse:5884.48415	validation_1-rmse:9544.89606
# [441]	validation_0-rmse:5884.21680	validation_1-rmse:9544.77826
# [442]	validation_0-rmse:5883.95053	validation_1-rmse:9544.65691
# [443]	validation_0-rmse:5883.68499	validation_1-rmse:9544.54744
# [444]	validation_0-rmse:5883.42009	validation_1-rmse:9544.45274
# [445]	validation_0-rmse:5883.15535	validation_1-rmse:9544.34899
# [446]	validation_0-rmse:5882.89180	validation_1-rmse:9544.25039
# [447]	validation_0-rmse:5882.62903	validation_1-rmse:9544.15354
# [448]	validation_0-rmse:5882.36681	validation_1-rmse:9544.07455
# [449]	validation_0-rmse:5882.10540	validation_1-rmse:9543.99717
# [450]	validation_0-rmse:5881.84458	validation_1-rmse:9543.90508
# [451]	validation_0-rmse:5881.58488	validation_1-rmse:9543.81985
# [452]	validation_0-rmse:5881.32583	validation_1-rmse:9543.73273
# [453]	validation_0-rmse:5881.06718	validation_1-rmse:9543.65353
# [454]	validation_0-rmse:5880.80984	validation_1-rmse:9543.56325
# [455]	validation_0-rmse:5880.55303	validation_1-rmse:9543.48262
# [456]	validation_0-rmse:5880.29677	validation_1-rmse:9543.41543
# [457]	validation_0-rmse:5880.04105	validation_1-rmse:9543.34234
# [458]	validation_0-rmse:5879.78572	validation_1-rmse:9543.31842
# [459]	validation_0-rmse:5879.53120	validation_1-rmse:9543.29254
# [460]	validation_0-rmse:5879.27796	validation_1-rmse:9543.22153
# [461]	validation_0-rmse:5879.02480	validation_1-rmse:9543.18779
# [462]	validation_0-rmse:5878.77247	validation_1-rmse:9543.15656
# [463]	validation_0-rmse:5878.52061	validation_1-rmse:9543.10957
# [464]	validation_0-rmse:5878.26962	validation_1-rmse:9543.03434
# [465]	validation_0-rmse:5878.01949	validation_1-rmse:9542.96191
# [466]	validation_0-rmse:5877.76996	validation_1-rmse:9542.87463
# [467]	validation_0-rmse:5877.52120	validation_1-rmse:9542.80364
# [468]	validation_0-rmse:5877.27334	validation_1-rmse:9542.73226
# [469]	validation_0-rmse:5877.02571	validation_1-rmse:9542.67247
# [470]	validation_0-rmse:5876.77911	validation_1-rmse:9542.59209
# [471]	validation_0-rmse:5876.53240	validation_1-rmse:9542.56348
# [472]	validation_0-rmse:5876.28670	validation_1-rmse:9542.48625
# [473]	validation_0-rmse:5876.04180	validation_1-rmse:9542.42262
# [474]	validation_0-rmse:5875.79731	validation_1-rmse:9542.40159
# [475]	validation_0-rmse:5875.55340	validation_1-rmse:9542.37714
# [476]	validation_0-rmse:5875.31005	validation_1-rmse:9542.34841
# [477]	validation_0-rmse:5875.06745	validation_1-rmse:9542.28464
# [478]	validation_0-rmse:5874.82520	validation_1-rmse:9542.25062
# [479]	validation_0-rmse:5874.58415	validation_1-rmse:9542.17452
# [480]	validation_0-rmse:5874.34337	validation_1-rmse:9542.10518
# [481]	validation_0-rmse:5874.10323	validation_1-rmse:9542.08320
# [482]	validation_0-rmse:5873.86342	validation_1-rmse:9542.01732
# [483]	validation_0-rmse:5873.62456	validation_1-rmse:9541.96943
# [484]	validation_0-rmse:5873.38595	validation_1-rmse:9541.96057
# [485]	validation_0-rmse:5873.14830	validation_1-rmse:9541.95523
# [486]	validation_0-rmse:5872.91092	validation_1-rmse:9541.89958
# [487]	validation_0-rmse:5872.67417	validation_1-rmse:9541.88821
# [488]	validation_0-rmse:5872.43848	validation_1-rmse:9541.81028
# [489]	validation_0-rmse:5872.20320	validation_1-rmse:9541.74832
# [490]	validation_0-rmse:5871.96889	validation_1-rmse:9541.69124
# [491]	validation_0-rmse:5871.73524	validation_1-rmse:9541.62073
# [492]	validation_0-rmse:5871.50161	validation_1-rmse:9541.58565
# [493]	validation_0-rmse:5871.26861	validation_1-rmse:9541.58066
# [494]	validation_0-rmse:5871.03583	validation_1-rmse:9541.54665
# [495]	validation_0-rmse:5870.80403	validation_1-rmse:9541.55079
# [496]	validation_0-rmse:5870.57285	validation_1-rmse:9541.51038
# [497]	validation_0-rmse:5870.34215	validation_1-rmse:9541.48495
# [498]	validation_0-rmse:5870.11219	validation_1-rmse:9541.44465
# [499]	validation_0-rmse:5869.88234	validation_1-rmse:9541.44034
# [500]	validation_0-rmse:5869.65351	validation_1-rmse:9541.39166
# [501]	validation_0-rmse:5869.42491	validation_1-rmse:9541.35689
# [502]	validation_0-rmse:5869.19686	validation_1-rmse:9541.33002
# [503]	validation_0-rmse:5868.96908	validation_1-rmse:9541.30633
# [504]	validation_0-rmse:5868.74227	validation_1-rmse:9541.26156
# [505]	validation_0-rmse:5868.51494	validation_1-rmse:9541.28397
# [506]	validation_0-rmse:5868.28882	validation_1-rmse:9541.26156
# [507]	validation_0-rmse:5868.06363	validation_1-rmse:9541.23538
# [508]	validation_0-rmse:5867.83883	validation_1-rmse:9541.22478
# [509]	validation_0-rmse:5867.61477	validation_1-rmse:9541.18817
# [510]	validation_0-rmse:5867.39132	validation_1-rmse:9541.19474
# [511]	validation_0-rmse:5867.16808	validation_1-rmse:9541.16272
# [512]	validation_0-rmse:5866.94573	validation_1-rmse:9541.13026
# [513]	validation_0-rmse:5866.72336	validation_1-rmse:9541.10280
# [514]	validation_0-rmse:5866.50178	validation_1-rmse:9541.07435
# [515]	validation_0-rmse:5866.28004	validation_1-rmse:9541.08807
# [516]	validation_0-rmse:5866.05927	validation_1-rmse:9541.06229
# [517]	validation_0-rmse:5865.83903	validation_1-rmse:9541.07531
# [518]	validation_0-rmse:5865.61943	validation_1-rmse:9541.04176
# [519]	validation_0-rmse:5865.39989	validation_1-rmse:9541.05369
# [520]	validation_0-rmse:5865.18161	validation_1-rmse:9541.03098
# [521]	validation_0-rmse:5864.96310	validation_1-rmse:9541.00638
# [522]	validation_0-rmse:5864.74557	validation_1-rmse:9540.97432
# [523]	validation_0-rmse:5864.52879	validation_1-rmse:9540.95162
# [524]	validation_0-rmse:5864.31185	validation_1-rmse:9540.92575
# [525]	validation_0-rmse:5864.09556	validation_1-rmse:9540.87891
# [526]	validation_0-rmse:5863.87967	validation_1-rmse:9540.90097
# [527]	validation_0-rmse:5863.66410	validation_1-rmse:9540.88479
# [528]	validation_0-rmse:5863.44908	validation_1-rmse:9540.90508
# [529]	validation_0-rmse:5863.23486	validation_1-rmse:9540.89675
# [530]	validation_0-rmse:5863.02089	validation_1-rmse:9540.85268
# [531]	validation_0-rmse:5862.80735	validation_1-rmse:9540.83709
# [532]	validation_0-rmse:5862.59449	validation_1-rmse:9540.81332
# [533]	validation_0-rmse:5862.38225	validation_1-rmse:9540.82733
# [534]	validation_0-rmse:5862.17000	validation_1-rmse:9540.84940
# [535]	validation_0-rmse:5861.95837	validation_1-rmse:9540.87201
# [536]	validation_0-rmse:5861.74741	validation_1-rmse:9540.85037
# [537]	validation_0-rmse:5861.53661	validation_1-rmse:9540.86670
# [538]	validation_0-rmse:5861.32622	validation_1-rmse:9540.80559
# [539]	validation_0-rmse:5861.11660	validation_1-rmse:9540.79200
# [540]	validation_0-rmse:5860.90792	validation_1-rmse:9540.77103
# [541]	validation_0-rmse:5860.69908	validation_1-rmse:9540.77108
# [542]	validation_0-rmse:5860.49117	validation_1-rmse:9540.75432
# [543]	validation_0-rmse:5860.28305	validation_1-rmse:9540.76841
# [544]	validation_0-rmse:5860.07587	validation_1-rmse:9540.73662
# [545]	validation_0-rmse:5859.86856	validation_1-rmse:9540.67813
# [546]	validation_0-rmse:5859.66195	validation_1-rmse:9540.71793
# [547]	validation_0-rmse:5859.45562	validation_1-rmse:9540.66419
# [548]	validation_0-rmse:5859.24973	validation_1-rmse:9540.67182
# [549]	validation_0-rmse:5859.04488	validation_1-rmse:9540.69886
# [550]	validation_0-rmse:5858.83989	validation_1-rmse:9540.73912
# [551]	validation_0-rmse:5858.63522	validation_1-rmse:9540.78100
# [552]	validation_0-rmse:5858.43163	validation_1-rmse:9540.76732
# [553]	validation_0-rmse:5858.22782	validation_1-rmse:9540.76734
# [554]	validation_0-rmse:5858.02465	validation_1-rmse:9540.78250
# [555]	validation_0-rmse:5857.82210	validation_1-rmse:9540.76747
# [556]	validation_0-rmse:5857.61954	validation_1-rmse:9540.76444
# [557]	validation_0-rmse:5857.41749	validation_1-rmse:9540.72793
# [558]	validation_0-rmse:5857.21621	validation_1-rmse:9540.72635
# [559]	validation_0-rmse:5857.01519	validation_1-rmse:9540.76043
# [560]	validation_0-rmse:5856.81429	validation_1-rmse:9540.76790
# [561]	validation_0-rmse:5856.61417	validation_1-rmse:9540.76911
# [562]	validation_0-rmse:5856.41448	validation_1-rmse:9540.75804
# [563]	validation_0-rmse:5856.21528	validation_1-rmse:9540.75026
# [564]	validation_0-rmse:5856.01583	validation_1-rmse:9540.75538
# [565]	validation_0-rmse:5855.81751	validation_1-rmse:9540.74551
# [566]	validation_0-rmse:5855.61955	validation_1-rmse:9540.74202
# [567]	validation_0-rmse:5855.42190	validation_1-rmse:9540.73926
# [568]	validation_0-rmse:5855.22493	validation_1-rmse:9540.73307
# [569]	validation_0-rmse:5855.02758	validation_1-rmse:9540.73664
# [570]	validation_0-rmse:5854.83068	validation_1-rmse:9540.76916
# [571]	validation_0-rmse:5854.63469	validation_1-rmse:9540.76205
# [572]	validation_0-rmse:5854.43908	validation_1-rmse:9540.75924
# [573]	validation_0-rmse:5854.24370	validation_1-rmse:9540.75953
# [574]	validation_0-rmse:5854.04855	validation_1-rmse:9540.77269
# [575]	validation_0-rmse:5853.85416	validation_1-rmse:9540.77004
# [576]	validation_0-rmse:5853.65970	validation_1-rmse:9540.76525
# [577]	validation_0-rmse:5853.46602	validation_1-rmse:9540.76121
# [578]	validation_0-rmse:5853.27248	validation_1-rmse:9540.76784
# [579]	validation_0-rmse:5853.07911	validation_1-rmse:9540.77426
# [580]	validation_0-rmse:5852.88631	validation_1-rmse:9540.80528
# [581]	validation_0-rmse:5852.69410	validation_1-rmse:9540.79441
# [582]	validation_0-rmse:5852.50212	validation_1-rmse:9540.80019
# [583]	validation_0-rmse:5852.31048	validation_1-rmse:9540.79532
# [584]	validation_0-rmse:5852.11952	validation_1-rmse:9540.80057
# [585]	validation_0-rmse:5851.92862	validation_1-rmse:9540.79367
# [586]	validation_0-rmse:5851.73788	validation_1-rmse:9540.77945
# [587]	validation_0-rmse:5851.54781	validation_1-rmse:9540.81539
# [588]	validation_0-rmse:5851.35792	validation_1-rmse:9540.82222
# [589]	validation_0-rmse:5851.16892	validation_1-rmse:9540.78199
# [590]	validation_0-rmse:5850.97974	validation_1-rmse:9540.78542
# [591]	validation_0-rmse:5850.79116	validation_1-rmse:9540.81413
# [592]	validation_0-rmse:5850.60298	validation_1-rmse:9540.80165
# [593]	validation_0-rmse:5850.41488	validation_1-rmse:9540.80447
# [594]	validation_0-rmse:5850.22710	validation_1-rmse:9540.80147
# [595]	validation_0-rmse:5850.04002	validation_1-rmse:9540.79593
# [596]	validation_0-rmse:5849.85323	validation_1-rmse:9540.79144
# train:  5849.667063526295
# test:  9540.792716714202

# %%
feature_importances_df = pd.DataFrame([feature_columns, feature_importances[-1]*100]).transpose().sort_values(by=1).rename(columns={0:'features',1:'importances'})

plt.figure(figsize=(20,20), dpi=200)
sns.barplot(feature_importances_df, x = 'features', y = 'importances')
plt.xticks(rotation=90);

# %%
int(np.sum(preds[0]))
# Out:
# 6410402

# %% [markdown]
# ## XGBOOST Train with full data

# %%
scores = []
for i in range(1000):
    reg_model = xgb.XGBRegressor(base_score=0.5, booster='gblinear',  n_estimators=i, early_stopping_rounds=50, objective='reg:squarederror', learning_rate=0.01)
    reg_model.fit(df[feature_columns], df['total_sales'], eval_set=[(df[feature_columns], df['total_sales'])], verbose=False)
    y_preds = reg_model.predict(df[feature_columns])
    scores.append(np.sqrt(mean_squared_error(df['total_sales'], y_preds)))

# %%
plt.plot(range(1000),scores)

# %%
scores[400:]
# Out:
# [np.float64(6374.965908550386),
#  np.float64(6374.715140657594),
#  np.float64(6374.4709074214725),
#  np.float64(6373.939785274374),
#  np.float64(6373.536706190039),
#  np.float64(6373.342264636992),
#  np.float64(6372.947992905537),
#  np.float64(6372.524911469348),
#  np.float64(6372.127686423257),
#  np.float64(6371.830631449345),
#  np.float64(6371.525035654685),
#  np.float64(6370.798544554597),
#  np.float64(6370.807244637683),
#  np.float64(6368.142108846003),
#  np.float64(6370.138476672374),
#  np.float64(6369.587217321131),
#  np.float64(6368.972809924169),
#  np.float64(6368.69989777866),
#  np.float64(6367.822934021289),
#  np.float64(6368.206527645821),
#  np.float64(6367.814348460745),
#  np.float64(6367.717962748952),
#  np.float64(6367.176433375279),
#  np.float64(6366.667279837056),
#  np.float64(6366.765364297513),
#  np.float64(6366.236680895148),
#  np.float64(6365.745220363884),
#  np.float64(6365.6851935814),
#  np.float64(6365.485372707566),
#  np.float64(6364.8935038527925),
#  np.float64(6364.579066256987),
#  np.float64(6364.161230292112),
#  np.float64(6364.118409849318),
#  np.float64(6363.906794952556),
#  np.float64(6363.556916581539),
#  np.float64(6363.282048964656),
#  np.float64(6363.0995556981225),
#  np.float64(6362.563848656943),
#  np.float64(6361.862494144588),
#  np.float64(6362.008443425753),
#  np.float64(6361.704402318843),
#  np.float64(6360.874348666074),
#  np.float64(6360.661834874813),
#  np.float64(6360.517243473639),
#  np.float64(6360.449734182716),
#  np.float64(6360.054459517455),
#  np.float64(6359.789358354055),
#  np.float64(6359.4264542282735),
#  np.float64(6359.21625812749),
#  np.float64(6358.904256646294),
#  np.float64(6358.631423428587),
#  np.float64(6358.306378278968),
#  np.float64(6357.992196254793),
#  np.float64(6357.457561337847),
#  np.float64(6357.414729049303),
#  np.float64(6356.995600299131),
#  np.float64(6356.722426001663),
#  np.float64(6356.541168364882),
#  np.float64(6356.050910998466),
#  np.float64(6355.886026543031),
#  np.float64(6355.637123684631),
#  np.float64(6355.365155245746),
#  np.float64(6354.971935528946),
#  np.float64(6354.7377126383935),
#  np.float64(6354.526050436035),
#  np.float64(6354.119332620972),
#  np.float64(6353.832549112053),
#  np.float64(6353.539045094684),
#  np.float64(6353.130162640552),
#  np.float64(6352.937988185967),
#  np.float64(6352.502629161325),
#  np.float64(6351.991705172262),
#  np.float64(6351.993866460017),
#  np.float64(6351.676822172038),
#  np.float64(6351.140319327872),
#  np.float64(6268.17364892163),
#  np.float64(6267.918548693629),
#  np.float64(6268.221287501794),
#  np.float64(6267.93978387595),
#  np.float64(6267.886308147083),
#  np.float64(6267.884569899225),
#  np.float64(6267.740489696081),
#  np.float64(6267.66921060317),
#  np.float64(6267.586531713031),
#  np.float64(6267.485042870739),
#  np.float64(6267.274830206944),
#  np.float64(6267.076307265786),
#  np.float64(6267.164670609031),
#  np.float64(6266.881127486182),
#  np.float64(6266.574421900398),
#  np.float64(6266.706803476306),
#  np.float64(6266.236229416337),
#  np.float64(6266.673818196627),
#  np.float64(6266.311285578458),
#  np.float64(6266.064608796701),
#  np.float64(6266.159338803782),
#  np.float64(6266.031589137843),
#  np.float64(6265.9043571320235),
#  np.float64(6265.999143260997),
#  np.float64(6265.875858697937),
#  np.float64(6265.662001710645),
#  np.float64(6265.655733848155),
#  np.float64(6265.5628413945315),
#  np.float64(6265.475293071647),
#  np.float64(6265.294471004558),
#  np.float64(6265.264080151263),
#  np.float64(6265.178857492787),
#  np.float64(6265.055057570717),
#  np.float64(6264.918684516053),
#  np.float64(6264.850012670697),
#  np.float64(6264.572416718394),
#  np.float64(6264.039498047739),
#  np.float64(6264.350116479834),
#  np.float64(6264.426398868976),
#  np.float64(6263.994903272308),
#  np.float64(6264.224303935465),
#  np.float64(6264.059475501302),
#  np.float64(6263.895017109645),
#  np.float64(6263.857021169524)]

# %%
reg_model = xgb.XGBRegressor(base_score=0.5, booster='gblinear',  n_estimators=400, early_stopping_rounds=50, objective='reg:squarederror', learning_rate=0.01)
reg_model.fit(df[feature_columns], df['total_sales'], eval_set=[(df[feature_columns], df['total_sales'])], verbose=False)
# Out:
# XGBRegressor(base_score=0.5, booster='gblinear', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.01, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=400,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
feature_importances_df = pd.DataFrame([feature_columns, reg_model.feature_importances_*100]).transpose().sort_values(by=1).rename(columns={0:'features',1:'importances'})

plt.figure(figsize=(20,20), dpi=200)
sns.barplot(feature_importances_df, x = 'features', y = 'importances')
plt.xticks(rotation=90);

# %%
y_preds = reg_model.predict(forcast_df[feature_columns])
ds =  pd.Series(y_preds, index=forcast_df.index)
ds.plot(label='prediction')
plt.legend()
plt.show()

# %% [markdown]
# # AdaBoost

# %%
def cross_validate(df, forcastdf, feature_columns):
    scores = []
    preds = []
    feature_importances = []
    sales = []
    tss = TimeSeriesSplit(n_splits=3, test_size=365, gap=0)
    feature_columns = sorted(feature_columns)
    for train_idx, val_idx in tss.split(df):
        scaler = StandardScaler()
        train = df.iloc[train_idx]
        test = df.iloc[val_idx]
        X_train = train[feature_columns]
        y_train = train['total_sales']
        X_test = test[feature_columns]
        y_test = test['total_sales']
        reg_model = AdaBoostRegressor(random_state=101, n_estimators=33)
        reg_model.fit(X_train, y_train)
        feature_importances.append(reg_model.feature_importances_)
        y_preds = reg_model.predict(X_train)
        ds =  pd.concat([y_train.reset_index(),pd.Series(y_preds)], axis=1)
        ds = ds.set_index('Order Date')
        ds['total_sales'].plot(label='true data')
        ds[0].plot(label='prediction')
        plt.legend()
        plt.show()
        y_preds = reg_model.predict(X_test)
        ds =  pd.concat([y_test.reset_index(),pd.Series(y_preds)], axis=1)
        ds = ds.set_index('Order Date')
        ds['total_sales'].plot(label='true data')
        ds[0].plot(label='prediction')
        plt.legend()
        plt.show()
        forcast_preds = reg_model.predict(forcastdf[feature_columns])
        ds =  pd.Series(forcast_preds, index=forcastdf.index)
        ds.plot(label='prediction')
        plt.legend()
        plt.show()
        preds.append(y_preds)
        score = np.sqrt(mean_squared_error(y_test, y_preds))
        scores.append(score)

    return preds, scores, feature_importances

# %%
preds, scores, feature_importances = cross_validate(df, forcast_df, feature_columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 preds, scores, feature_importances = cross_validate(df, forcast_df, feature_columns)
#
# Cell In[61], line 17, in cross_validate(df, forcastdf, feature_columns)
#      15 y_test = test['total_sales']
#      16 reg_model = AdaBoostRegressor(random_state=101, n_estimators=33)
# ---> 17 reg_model.fit(X_train, y_train)
#      18 feature_importances.append(reg_model.feature_importances_)
#      19 y_preds = reg_model.predict(X_train)
#
# File ~\anaconda3\envs\cv_env\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\envs\cv_env\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:130, in BaseWeightBoosting.fit(self, X, y, sample_weight)
#     109 """Build a boosted classifier/regressor from the training set (X, y).
#     110
#     111 Parameters
#    (...)    127     Fitted estimator.
#     128 """
#     129 _raise_for_unsupported_routing(self, "fit", sample_weight=sample_weight)
# --> 130 X, y = validate_data(
#     131     self,
#     132     X,
#     133     y,
#     134     accept_sparse=["csr", "csc"],
#     135     ensure_2d=True,
#     136     allow_nd=True,
#     137     dtype=None,
#     138     y_numeric=is_regressor(self),
#     139 )
#     141 sample_weight = _check_sample_weight(
#     142     sample_weight, X, np.float64, copy=True, ensure_non_negative=True
#     143 )
#     144 sample_weight /= sample_weight.sum()
#
# File ~\anaconda3\envs\cv_env\Lib\site-packages\sklearn\utils\validation.py:2961, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2959         y = check_array(y, input_name="y", **check_y_params)
#    2960     else:
# -> 2961         X, y = check_X_y(X, y, **check_params)
#    2962     out = X, y
#    2964 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\anaconda3\envs\cv_env\Lib\site-packages\sklearn\utils\validation.py:1370, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1364     raise ValueError(
#    1365         f"{estimator_name} requires y to be passed, but the target y is None"
#    1366     )
#    1368 ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
# -> 1370 X = check_array(
#    1371     X,
#    1372     accept_sparse=accept_sparse,
#    1373     accept_large_sparse=accept_large_sparse,
#    1374     dtype=dtype,
#    1375     order=order,
#    1376     copy=copy,
#    1377     force_writeable=force_writeable,
#    1378     ensure_all_finite=ensure_all_finite,
#    1379     ensure_2d=ensure_2d,
#    1380     allow_nd=allow_nd,
#    1381     ensure_min_samples=ensure_min_samples,
#    1382     ensure_min_features=ensure_min_features,
#    1383     estimator=estimator,
#    1384     input_name="X",
#    1385 )
#    1387 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1389 check_consistent_length(X, y)
#
# File ~\anaconda3\envs\cv_env\Lib\site-packages\sklearn\utils\validation.py:1107, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1101     raise ValueError(
#    1102         "Found array with dim %d. %s expected <= 2."
#    1103         % (array.ndim, estimator_name)
#    1104     )
#    1106 if ensure_all_finite:
# -> 1107     _assert_all_finite(
#    1108         array,
#    1109         input_name=input_name,
#    1110         estimator_name=estimator_name,
#    1111         allow_nan=ensure_all_finite == "allow-nan",
#    1112     )
#    1114 if copy:
#    1115     if _is_numpy_namespace(xp):
#    1116         # only make a copy if `array` and `array_orig` may share memory`
#
# File ~\anaconda3\envs\cv_env\Lib\site-packages\sklearn\utils\validation.py:120, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     117 if first_pass_isfinite:
#     118     return
# --> 120 _assert_all_finite_element_wise(
#     121     X,
#     122     xp=xp,
#     123     allow_nan=allow_nan,
#     124     msg_dtype=msg_dtype,
#     125     estimator_name=estimator_name,
#     126     input_name=input_name,
#     127 )
#
# File ~\anaconda3\envs\cv_env\Lib\site-packages\sklearn\utils\validation.py:169, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     152 if estimator_name and input_name == "X" and has_nan_error:
#     153     # Improve the error message on how to handle missing values in
#     154     # scikit-learn.
#     155     msg_err += (
#     156         f"\n{estimator_name} does not accept missing values"
#     157         " encoded as NaN natively. For supervised learning, you might want"
#    (...)    167         "#estimators-that-handle-nan-values"
#     168     )
# --> 169 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# AdaBoostRegressor does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
df['Sales 2YA'].interpolate()

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer()

# %%
df.columns

# %%
forcast_df.columns

# %%
a = xgb.XGBRegressor()

# %%
a.load_model('model.json')

# %%
a.feature_importances_

# %%
df['inflation_rate']

# %%
from catboost import CatBoostRegressor

# %%
def cross_validate(df, forcastdf, feature_columns):
    feature_importances = []
    tss = TimeSeriesSplit(n_splits=3, test_size=365, gap=0)
    param_grid = {'depth':[2, 3], 'l2_leaf_reg':[ 10, 12, 13] ,'learning_rate':[0.05],'n_estimators':[500, 1000], 'bootstrap_type':[ 'Bernoulli'],
'subsample':[ 0.7]}
    feature_columns = sorted(feature_columns)
    for train_idx, val_idx in tss.split(df):
        scaler = StandardScaler()
        train = df.iloc[train_idx]
        test = df.iloc[val_idx]
        X_train = train[feature_columns]
        y_train = train['total_sales']
        X_test = test[feature_columns]
        y_test = test['total_sales']
        reg_model = GridSearchCV(CatBoostRegressor(silent=True), param_grid)
        # reg_model = CatBoostRegressor(depth=3, learning_rate=0.05,n_estimators=1000)
        reg_model.fit(X_train, y_train)
        print(reg_model.best_params_)
        y_preds = reg_model.predict(X_train)
        score = np.sqrt(mean_squared_error(y_train, y_preds))
        print('training error: ',score)
        ds =  pd.concat([y_train.reset_index(),pd.Series(y_preds)], axis=1)
        ds = ds.set_index('Order Date')
        ds['total_sales'].plot(label='true data')
        ds[0].plot(label='prediction')
        plt.legend()
        plt.show()
        y_preds = reg_model.predict(X_test)
        score = np.sqrt(mean_squared_error(y_test, y_preds))
        print('test error: ',score)
        ds =  pd.concat([y_test.reset_index(),pd.Series(y_preds)], axis=1)
        ds = ds.set_index('Order Date')
        ds['total_sales'].plot(label='true data')
        ds[0].plot(label='prediction')
        plt.legend()
        plt.show()
        forcast_preds = reg_model.predict(forcastdf[feature_columns])
        ds =  pd.Series(forcast_preds, index=forcastdf.index)
        ds.plot(label='prediction')
        plt.legend()
        plt.show()
        preds.append(y_preds)

    return feature_importances

# %%
cross_validate(df, forcast_df, feature_columns)
# Out:
# C:\Users\rohit\anaconda3\envs\cv_env\Lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 240 fits failed out of a total of 320.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 160 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\rohit\anaconda3\envs\cv_env\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rohit\anaconda3\envs\cv_env\Lib\site-packages\catboost\core.py", line 5873, in fit
#     return self._fit(X, y, cat_features, text_features, embedding_features, None, graph, sample_weight, None, None, None, None, baseline,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\rohit\anaconda3\envs\cv_env\Lib\site-packages\catboost\core.py", line 2395, in _fit
#     train_params = self._prepare_train_params(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\rohit\anaconda3\envs\cv_env\Lib\site-packages\catboost\core.py", line 2321, in _prepare_train_params
#     _check_train_params(params)
#   File "_catboost.pyx", line 6601, in _catboost._check_train_params
#   File "_catboost.pyx", line 6623, in _catboost._check_train_params
# _catboost.CatBoostError: catboost/private/libs/options/json_helper.h:41: Can't parse parameter "subsample" with value: null
#
# --------------------------------------------------------------------------------
# 80 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\rohit\anaconda3\envs\cv_env\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rohit\anaconda3\envs\cv_env\Lib\site-packages\catboost\core.py", line 5873, in fit
#     return self._fit(X, y, cat_features, text_features, embedding_features, None, graph, sample_weight, None, None, None, None, baseline,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\rohit\anaconda3\envs\cv_env\Lib\site-packages\catboost\core.py", line 2395, in _fit
#     train_params = self._prepare_train_params(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\rohit\anaconda3\envs\cv_env\Lib\site-packages\catboost\core.py", line 2321, in _prepare_train_params
#     _check_train_params(params)
#   File "_catboost.pyx", line 6601, in _catboost._check_train_params
#   File "_catboost.pyx", line 6623, in _catboost._check_train_params
# _catboost.CatBoostError: catboost/private/libs/options/json_helper.h:41: Can't parse parameter "type" with value: null
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\rohit\anaconda3\envs\cv_env\Lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.38811506        nan 0.3673967
#         nan 0.37208261        nan 0.35973956        nan 0.36921631
#         nan 0.34941495        nan 0.37519158        nan 0.36561206
#         nan 0.40878603        nan 0.41289304        nan 0.37720044
#         nan 0.38088007        nan 0.38360429        nan 0.38733178
#         nan 0.38256409        nan 0.3888877 ]
#   warnings.warn(
# training error:  1556.8480418331862
# test error:  8500.07104299897
# C:\Users\rohit\anaconda3\envs\cv_env\Lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 240 fits failed out of a total of 320.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 160 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\rohit\anaconda3\envs\cv_env\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rohit\anaconda3\envs\cv_env\Lib\site-packages\catboost\core.py", line 5873, in fit
#     return self._fit(X, y, cat_features, text_features, embedding_features, None, graph, sample_weight, None, None, None, None, baseline,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\rohit\anaconda3\envs\cv_env\Lib\site-packages\catboost\core.py", line 2395, in _fit
#     train_params = self._prepare_train_params(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\rohit\anaconda3\envs\cv_env\Lib\site-packages\catboost\core.py", line 2321, in _prepare_train_params
#     _check_train_params(params)
#   File "_catboost.pyx", line 6601, in _catboost._check_train_params
#   File "_catboost.pyx", line 6623, in _catboost._check_train_params
# _catboost.CatBoostError: catboost/private/libs/options/json_helper.h:41: Can't parse parameter "subsample" with value: null
#
# --------------------------------------------------------------------------------
# 80 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\rohit\anaconda3\envs\cv_env\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rohit\anaconda3\envs\cv_env\Lib\site-packages\catboost\core.py", line 5873, in fit
#     return self._fit(X, y, cat_features, text_features, embedding_features, None, graph, sample_weight, None, None, None, None, baseline,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\rohit\anaconda3\envs\cv_env\Lib\site-packages\catboost\core.py", line 2395, in _fit
#     train_params = self._prepare_train_params(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\rohit\anaconda3\envs\cv_env\Lib\site-packages\catboost\core.py", line 2321, in _prepare_train_params
#     _check_train_params(params)
#   File "_catboost.pyx", line 6601, in _catboost._check_train_params
#   File "_catboost.pyx", line 6623, in _catboost._check_train_params
# _catboost.CatBoostError: catboost/private/libs/options/json_helper.h:41: Can't parse parameter "type" with value: null
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\rohit\anaconda3\envs\cv_env\Lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.45194948        nan 0.44841641
#         nan 0.40067507        nan 0.40687748        nan 0.39188107
#         nan 0.39815233        nan 0.38282766        nan 0.38964784
#         nan 0.44001811        nan 0.43136824        nan 0.41272603
#         nan 0.41947795        nan 0.40200348        nan 0.39486725
#         nan 0.38475424        nan 0.3869651 ]
#   warnings.warn(
# training error:  2993.016519463837
# test error:  7628.252977264961
# C:\Users\rohit\anaconda3\envs\cv_env\Lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 240 fits failed out of a total of 320.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 160 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\rohit\anaconda3\envs\cv_env\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rohit\anaconda3\envs\cv_env\Lib\site-packages\catboost\core.py", line 5873, in fit
#     return self._fit(X, y, cat_features, text_features, embedding_features, None, graph, sample_weight, None, None, None, None, baseline,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\rohit\anaconda3\envs\cv_env\Lib\site-packages\catboost\core.py", line 2395, in _fit
#     train_params = self._prepare_train_params(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\rohit\anaconda3\envs\cv_env\Lib\site-packages\catboost\core.py", line 2321, in _prepare_train_params
#     _check_train_params(params)
#   File "_catboost.pyx", line 6601, in _catboost._check_train_params
#   File "_catboost.pyx", line 6623, in _catboost._check_train_params
# _catboost.CatBoostError: catboost/private/libs/options/json_helper.h:41: Can't parse parameter "subsample" with value: null
#
# --------------------------------------------------------------------------------
# 80 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\rohit\anaconda3\envs\cv_env\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rohit\anaconda3\envs\cv_env\Lib\site-packages\catboost\core.py", line 5873, in fit
#     return self._fit(X, y, cat_features, text_features, embedding_features, None, graph, sample_weight, None, None, None, None, baseline,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\rohit\anaconda3\envs\cv_env\Lib\site-packages\catboost\core.py", line 2395, in _fit
#     train_params = self._prepare_train_params(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\rohit\anaconda3\envs\cv_env\Lib\site-packages\catboost\core.py", line 2321, in _prepare_train_params
#     _check_train_params(params)
#   File "_catboost.pyx", line 6601, in _catboost._check_train_params
#   File "_catboost.pyx", line 6623, in _catboost._check_train_params
# _catboost.CatBoostError: catboost/private/libs/options/json_helper.h:41: Can't parse parameter "type" with value: null
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\rohit\anaconda3\envs\cv_env\Lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.39392619        nan 0.3986006
#         nan 0.3636162         nan 0.37999033        nan 0.36476876
#         nan 0.36478255        nan 0.37494087        nan 0.37282897
#         nan 0.43901604        nan 0.43912537        nan 0.42386163
#         nan 0.44029623        nan 0.4108919         nan 0.4316754
#         nan 0.40564383        nan 0.4272747 ]
#   warnings.warn(
# training error:  2661.697718241116
# test error:  9799.750985901812
# []
