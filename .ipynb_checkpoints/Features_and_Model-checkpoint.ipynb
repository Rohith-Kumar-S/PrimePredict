# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import gdown
import kagglehub
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import AdaBoostRegressor

# %% [markdown]
# # Helper Functions

# %%
def fetch_dataset(key, dataset_name):
    cmd = !gdown --fuzzy {key} -O {dataset_name}
    path = pd.Series(cmd).str.extractall(r'(To.*)').reset_index()[0].iloc[0].split(': ')[1]
    print(f'{dataset_name} path: {path}')
    return path

def get_null_percentage(df):
    null_series = ((df.isnull().sum()/len(df))*100).sort_values()
    return null_series

def generate_time_features(df):
    df = df.reset_index()
    df.loc[:,'day']  = df['Order Date'].dt.day
    df.loc[:,'month']  = df['Order Date'].dt.month
    df.loc[:,'year']  = df['Order Date'].dt.year
    df.loc[:,'is_weekend']  = df['Order Date'].dt.weekday > 5
    df.loc[:,'day_of_week']  = df['Order Date'].dt.day_of_week
    df.loc[:,'day_of_year']  = df['Order Date'].dt.day_of_year
    df.loc[:,'quarter']  = df['Order Date'].dt.quarter
    df.loc[:,'is_month_start']  = df['Order Date'].dt.is_month_start
    df.loc[:,'is_month_end']  = df['Order Date'].dt.is_month_end
    df.loc[:,'is_year_start']  = df['Order Date'].dt.is_year_start
    df.loc[:,'is_year_end']  = df['Order Date'].dt.is_year_end
    df = df.set_index('Order Date')
    return df

def add_holidays_past_2021(df):

    _2022 = pd.Series(['2022-12-26', '2022-11-24', '2022-11-11', '2022-10-10', '2022-09-05', '2022-07-04', '2022-06-20', '2022-05-30', '2022-02-21', '2022-01-21', '2023-01-02', '2023-01-16', '2023-02-20']) 
    
    _2022 = pd.to_datetime(_2022)
    dates = pd.Series(['January 02 2023',
    'January 16 2023',
    'February 20 2023',
    'May 29 2023',
    'June 19 2023',
    'July 04 2023',
    'September 04 2023',
    'October 09 2023',
    'November 10 2023',
    'November 23 2023',
    'December 25 2023',
    'January 01 2024',
    'January 15 2024',
    'February 19 2024',
    'May 27 2024',
    'June 19 2024',
    'July 04 2024',
    'September 02 2024',	
    'October 14 2024',
    'November 11 2024',	
    'November 28 2024',	
    'December 25 2024',
    'January 01 2025',
    'January 20 2025',
    'January 20 2025',
    'February 17 2025',
    'May 26 2025',
    'June 19 2025',
    'July 04 2025',
    'September 01 2025',	
    'October 13 2025',
    'November 11 2025',
    'November 27 2025',
    'December 25 2025',
    'January 01 2026',
    'January 19 2026',
    'February 16 2026',
    'May 25 2026',
    'June 19 2026',
    'July 03 2026',
    'September 07 2025',
    'October 12 2026',
    'November 11 2026',
    'November 26 2026',
    'December 25 2026'
                      ])
    fedral_holidays_2023_plus = pd.to_datetime(dates)
    fedral_holdidays_22_plus = pd.concat([_2022, fedral_holidays_2023_plus], axis=0).sort_values()
    fedral_holdidays_22_plus = pd.Series(fedral_holdidays_22_plus.unique())
    fedral_holdidays_22_plus.index = range(len(fedral_holdidays_22_plus))
    fedral_holdidays_22_plus = pd.DataFrame(fedral_holdidays_22_plus).rename(columns={0:'date'})
    fedral_holdidays_22_plus['fedral_holiday'] = True
    fedral_holdidays_22_plus = fedral_holdidays_22_plus.set_index('date')
    return pd.merge(df, fedral_holdidays_22_plus, how='left', left_index = True, right_index=True)

def add_events(events_timestamps, is_repeat=False):
    dummy_date = '2017-04-10'
    events = pd.DatetimeIndex([dummy_date])
    if is_repeat:
        for i in range(len([2018,2019,2020,2021,2022,2023,2024,2025,2026])):
            events = events.append(pd.date_range(start=events_timestamps[0], end=events_timestamps[1]) \
                                   + pd.tseries.offsets.DateOffset(months=i*12))
    else:
        for event in events_timestamps:
            events = events.append(pd.date_range(start=event[0], end=event[1]))
    return events[1:]

def assign_historic_sales(df, year_till=2022):
    df = df.reset_index()
    sales = df[['Order Date', 'total_sales']]
    sales = sales.set_index('Order Date')
    past_sales = list(sales[sales.index.year <= year_till]['total_sales'])
    lag = [np.nan] * (len(sales) - len(past_sales))
    lag.extend(past_sales)
    lag = pd.Series(lag, index=sales.index)
    df = df.set_index('Order Date')
    return lag

def add_amazon_events(df):
    global amazon_events_df
    df = pd.merge(df, amazon_events_df, left_index=True, right_index=True, how='left')
    df['Amazon Events'] = df['Amazon Events'].fillna('No Events')
    df = pd.get_dummies(df, drop_first=True)
    return df

# %% [markdown]
# # Dataset imports

# %%
path = fetch_dataset("1HdJj68eO9NTZlpwZcLYqdtPqrbKs1cxj", "amazon_purchases.csv")
purchases = pd.read_csv(path)
purchases = purchases[purchases['Shipping Address State'].notnull()]

path = kagglehub.dataset_download("donnetew/us-holiday-dates-2004-2021")
holidays = pd.read_csv(os.path.join(path,'US Holiday Dates (2004-2021).csv'))
holidays['is_holiday'] = True
holidays['Date'] = pd.to_datetime(holidays['Date'])
holidays.set_index('Date', inplace=True)

path = fetch_dataset("1uuTBlEA2caOIyv4-R_G2OlekBCw-i_Le", "inflation.csv")
inflation_df = pd.read_csv(path)
inflation_df['observation_date'] = pd.to_datetime(inflation_df['observation_date'])
inflation_df = inflation_df.rename(columns={'T10YIEM':'inflation_rate'}).set_index('observation_date')
# Out:
# amazon_purchases.csv path: C:\Users\rohit\5010\project\AmazonSalesPredictor\amazon_purchases.csv
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.11)
# inflation.csv path: C:\Users\rohit\5010\project\AmazonSalesPredictor\inflation.csv

# %% [markdown]
# # Feature engineering

# %%
purchases['Order Date'] = pd.to_datetime(purchases['Order Date'])
purchases.set_index('Order Date', inplace=True)
purchases = purchases[purchases.index.year<2023]
purchases.loc[:,'total_sales'] = purchases['Purchase Price Per Unit'] * purchases['Quantity']

# %%
df = purchases.copy()
df = pd.DataFrame(df.groupby(df.index)['total_sales'].sum())

# %% [markdown]
# **Add time features**

# %%
df = generate_time_features(df)

# %%
df
# Out:
#             total_sales  day  month  year  is_weekend  day_of_week  \
# Order Date
# 2018-01-01     16122.06    1      1  2018       False            0
# 2018-01-02     17006.00    2      1  2018       False            1
# 2018-01-03     13315.58    3      1  2018       False            2
# 2018-01-04     15820.10    4      1  2018       False            3
# 2018-01-05     17752.51    5      1  2018       False            4
# ...                 ...  ...    ...   ...         ...          ...
# 2022-12-27     19584.77   27     12  2022       False            1
# 2022-12-28     16875.12   28     12  2022       False            2
# 2022-12-29     18348.89   29     12  2022       False            3
# 2022-12-30     16886.45   30     12  2022       False            4
# 2022-12-31     12634.59   31     12  2022       False            5
#
#             day_of_year  quarter  is_month_start  is_month_end  is_year_start  \
# Order Date
# 2018-01-01            1        1            True         False           True
# 2018-01-02            2        1           False         False          False
# 2018-01-03            3        1           False         False          False
# 2018-01-04            4        1           False         False          False
# 2018-01-05            5        1           False         False          False
# ...                 ...      ...             ...           ...            ...
# 2022-12-27          361        4           False         False          False
# 2022-12-28          362        4           False         False          False
# 2022-12-29          363        4           False         False          False
# 2022-12-30          364        4           False         False          False
# 2022-12-31          365        4           False          True          False
#
#             is_year_end
# Order Date
# 2018-01-01        False
# 2018-01-02        False
# 2018-01-03        False
# 2018-01-04        False
# 2018-01-05        False
# ...                 ...
# 2022-12-27        False
# 2022-12-28        False
# 2022-12-29        False
# 2022-12-30        False
# 2022-12-31         True
#
# [1826 rows x 12 columns]

# %% [markdown]
# **Add amazon events**

# %%
amazon_events = add_events([['2024-03-20', '2024-03-25'], ['2025-03-25', '2025-03-31']])
spring_sale_event_df = pd.DataFrame({'Event Date':amazon_events,'Amazon Events':['Big Spring Sale']*len(amazon_events)}).set_index('Event Date')

# %%
amazon_events = add_events([
    ['2018-07-16', '2018-07-17'],
    ['2019-07-15', '2019-07-16'],
    ['2020-10-13', '2020-10-14'],
    ['2021-06-21', '2021-06-22'],
    ['2022-07-12', '2022-07-13'],
    ['2023-07-11', '2023-07-12'],
    ['2024-07-16', '2024-07-17'],
    ['2025-07-23', '2025-07-24']
])
prime_day_event_df = pd.DataFrame({'Event Date':amazon_events,'Amazon Events':['Amazon Prime Day']*len(amazon_events)}).set_index('Event Date')

# %%
amazon_events = add_events([
    ['2022-10-11', '2022-10-12'],  
    ['2023-10-10', '2023-10-11'],  
    ['2024-10-08', '2024-10-09'],
    ['2025-10-14', '2025-10-15']
])
prime_big_deal_event_df = pd.DataFrame({'Event Date':amazon_events,'Amazon Events':['Prime Big Deal Days']*len(amazon_events)}).set_index('Event Date')

# %%
amazon_events = add_events([
    ['2018-11-16', '2018-11-23'],
    ['2019-11-22', '2019-11-29'],
    ['2020-11-20', '2020-11-27'],
    ['2021-11-19', '2021-11-26'],
    ['2022-11-24', '2022-11-25'],
    ['2023-11-17', '2023-11-24'],
    ['2024-11-21', '2024-11-29'],
    ['2025-11-28', '2025-12-01']
]
)
black_friday_event_df = pd.DataFrame({'Event Date':amazon_events,'Amazon Events':['Black Friday']*len(amazon_events)}).set_index('Event Date')

# %%
amazon_events = add_events([
    ['2018-02-05', '2018-02-14'],
    ['2019-02-04', '2019-02-14'],
    ['2020-02-03', '2020-02-14'],
    ['2021-02-01', '2021-02-14'],
    ['2022-02-03', '2022-02-10'],
    ['2023-02-04', '2023-02-14'],
    ['2024-02-02', '2024-02-14'],
    ['2025-02-02', '2025-02-14']
])
valentines_day_event_df = pd.DataFrame({'Event Date':amazon_events,'Amazon Events':["Valentine's Day Promotions"]*len(amazon_events)}).set_index('Event Date')

# %%
amazon_events = add_events([
    ['2018-05-01', '2018-05-13'],
    ['2019-05-03', '2019-05-12'],
    ['2020-05-01', '2020-05-10'],
    ['2021-05-01', '2021-05-09'],
    ['2022-05-03', '2022-05-09'],
    ['2023-05-01', '2023-05-14'],
    ['2024-05-02', '2024-05-12'],
    ['2025-05-06', '2025-05-12']
])
mothers_day_event_df = pd.DataFrame({'Event Date':amazon_events,'Amazon Events':["Mother's Day Deals"]*len(amazon_events)}).set_index('Event Date')

# %%
amazon_events = add_events([
    ['2018-05-25', '2018-05-28'],
    ['2019-05-24', '2019-05-27'],
    ['2020-05-22', '2020-05-25'],
    ['2021-05-28', '2021-05-31'],
    ['2022-05-27', '2022-05-30'],
    ['2023-05-26', '2023-05-29'],
    ['2024-05-24', '2024-05-27'],
    ['2025-05-23', '2025-05-26']
])
memorial_day_event_df = pd.DataFrame({'Event Date':amazon_events,'Amazon Events':["Memorial Day Sales"]*len(amazon_events)}).set_index('Event Date')

# %%
amazon_events = add_events(('2018-12-02', '2018-12-13'), is_repeat=True)
_12_day_of_deals_event_df = pd.DataFrame({'Event Date':amazon_events,'Amazon Events':['12 Days of Deals']*len(amazon_events)}).set_index('Event Date')

# %%
amazon_events = add_events(('2018-12-25', '2019-01-01'), is_repeat=True)
year_end_clearance_event_df = pd.DataFrame({'Event Date':amazon_events,'Amazon Events':['Year-End Clearance Sale']*len(amazon_events)}).set_index('Event Date')

# %% [markdown]
# **concat**

# %%
amazon_events_df = pd.concat([spring_sale_event_df,prime_day_event_df,prime_big_deal_event_df,black_friday_event_df,valentines_day_event_df,mothers_day_event_df,memorial_day_event_df,_12_day_of_deals_event_df,year_end_clearance_event_df], axis=0).sort_index()

# %%
amazon_events_df
# Out:
#                          Amazon Events
# Event Date
# 2018-02-05  Valentine's Day Promotions
# 2018-02-06  Valentine's Day Promotions
# 2018-02-07  Valentine's Day Promotions
# 2018-02-08  Valentine's Day Promotions
# 2018-02-09  Valentine's Day Promotions
# ...                                ...
# 2026-12-28     Year-End Clearance Sale
# 2026-12-29     Year-End Clearance Sale
# 2026-12-30     Year-End Clearance Sale
# 2026-12-31     Year-End Clearance Sale
# 2027-01-01     Year-End Clearance Sale
#
# [477 rows x 1 columns]

# %%
sns.histplot(amazon_events_df[amazon_events_df.index.year==2018], x='Amazon Events')
plt.xticks(rotation=90);
plt.xlabel('Amazon events in 2018')
# Out:
# Text(0.5, 0, 'Amazon events in 2018')

# %%
sns.histplot(amazon_events_df, x='Amazon Events')
plt.xticks(rotation=90);
plt.xlabel('Amazon events yearly')
# Out:
# Text(0.5, 0, 'Amazon events yearly')

# %%
df = pd.merge(df, amazon_events_df, left_index=True, right_index=True, how='left')

# %%
df['Amazon Events'].value_counts()
# Out:
# Amazon Events
# 12 Days of Deals              60
# Valentine's Day Promotions    55
# Mother's Day Deals            49
# Year-End Clearance Sale       39
# Black Friday                  34
# Memorial Day Sales            20
# Amazon Prime Day              10
# Prime Big Deal Days            2
# Name: count, dtype: int64

# %%
df['Amazon Events'] = df['Amazon Events'].fillna('No Events')

# %%
sns.histplot(df[df.index.year==2022], x='Amazon Events')
plt.xticks(rotation=90);
plt.xlabel('Amazon events in 2022')
# Out:
# Text(0.5, 0, 'Amazon events in 2022')

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
df
# Out:
#             total_sales  day  month  year  is_weekend  day_of_week  \
# Order Date
# 2018-01-01     16122.06    1      1  2018       False            0
# 2018-01-02     17006.00    2      1  2018       False            1
# 2018-01-03     13315.58    3      1  2018       False            2
# 2018-01-04     15820.10    4      1  2018       False            3
# 2018-01-05     17752.51    5      1  2018       False            4
# ...                 ...  ...    ...   ...         ...          ...
# 2022-12-27     19584.77   27     12  2022       False            1
# 2022-12-28     16875.12   28     12  2022       False            2
# 2022-12-29     18348.89   29     12  2022       False            3
# 2022-12-30     16886.45   30     12  2022       False            4
# 2022-12-31     12634.59   31     12  2022       False            5
#
#             day_of_year  quarter  is_month_start  is_month_end  is_year_start  \
# Order Date
# 2018-01-01            1        1            True         False           True
# 2018-01-02            2        1           False         False          False
# 2018-01-03            3        1           False         False          False
# 2018-01-04            4        1           False         False          False
# 2018-01-05            5        1           False         False          False
# ...                 ...      ...             ...           ...            ...
# 2022-12-27          361        4           False         False          False
# 2022-12-28          362        4           False         False          False
# 2022-12-29          363        4           False         False          False
# 2022-12-30          364        4           False         False          False
# 2022-12-31          365        4           False          True          False
#
#             is_year_end  Amazon Events_Amazon Prime Day  \
# Order Date
# 2018-01-01        False                           False
# 2018-01-02        False                           False
# 2018-01-03        False                           False
# 2018-01-04        False                           False
# 2018-01-05        False                           False
# ...                 ...                             ...
# 2022-12-27        False                           False
# 2022-12-28        False                           False
# 2022-12-29        False                           False
# 2022-12-30        False                           False
# 2022-12-31         True                           False
#
#             Amazon Events_Black Friday  Amazon Events_Memorial Day Sales  \
# Order Date
# 2018-01-01                       False                             False
# 2018-01-02                       False                             False
# 2018-01-03                       False                             False
# 2018-01-04                       False                             False
# 2018-01-05                       False                             False
# ...                                ...                               ...
# 2022-12-27                       False                             False
# 2022-12-28                       False                             False
# 2022-12-29                       False                             False
# 2022-12-30                       False                             False
# 2022-12-31                       False                             False
#
#             Amazon Events_Mother's Day Deals  Amazon Events_No Events  \
# Order Date
# 2018-01-01                             False                     True
# 2018-01-02                             False                     True
# 2018-01-03                             False                     True
# 2018-01-04                             False                     True
# 2018-01-05                             False                     True
# ...                                      ...                      ...
# 2022-12-27                             False                    False
# 2022-12-28                             False                    False
# 2022-12-29                             False                    False
# 2022-12-30                             False                    False
# 2022-12-31                             False                    False
#
#             Amazon Events_Prime Big Deal Days  \
# Order Date
# 2018-01-01                              False
# 2018-01-02                              False
# 2018-01-03                              False
# 2018-01-04                              False
# 2018-01-05                              False
# ...                                       ...
# 2022-12-27                              False
# 2022-12-28                              False
# 2022-12-29                              False
# 2022-12-30                              False
# 2022-12-31                              False
#
#             Amazon Events_Valentine's Day Promotions  \
# Order Date
# 2018-01-01                                     False
# 2018-01-02                                     False
# 2018-01-03                                     False
# 2018-01-04                                     False
# 2018-01-05                                     False
# ...                                              ...
# 2022-12-27                                     False
# 2022-12-28                                     False
# 2022-12-29                                     False
# 2022-12-30                                     False
# 2022-12-31                                     False
#
#             Amazon Events_Year-End Clearance Sale
# Order Date
# 2018-01-01                                  False
# 2018-01-02                                  False
# 2018-01-03                                  False
# 2018-01-04                                  False
# 2018-01-05                                  False
# ...                                           ...
# 2022-12-27                                   True
# 2022-12-28                                   True
# 2022-12-29                                   True
# 2022-12-30                                   True
# 2022-12-31                                   True
#
# [1826 rows x 20 columns]

# %% [markdown]
# **Add holidays**

# %%
df = pd.merge(df, holidays['is_holiday'], how='left', left_index=True, right_index=True)
df = add_holidays_past_2021(df)
df['fedral_holiday'] = df['is_holiday'].fillna(False) + df['fedral_holiday'].fillna(False)
df.drop('is_holiday', axis=1,inplace= True)
# Out:
# C:\Users\rohit\AppData\Local\Temp\ipykernel_45600\3289957183.py:3: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['fedral_holiday'] = df['is_holiday'].fillna(False) + df['fedral_holiday'].fillna(False)

# %%
df['fedral_holiday'].value_counts()
# Out:
# fedral_holiday
# False    1740
# True       86
# Name: count, dtype: int64

# %% [markdown]
# **Add inflation**

# %%
df = pd.merge(df, inflation_df, left_index=True, right_index=True, how='left')
df['inflation_rate'] = df['inflation_rate'].interpolate()

# %%
df
# Out:
#             total_sales  day  month  year  is_weekend  day_of_week  \
# Order Date
# 2018-01-01     16122.06    1      1  2018       False            0
# 2018-01-02     17006.00    2      1  2018       False            1
# 2018-01-03     13315.58    3      1  2018       False            2
# 2018-01-04     15820.10    4      1  2018       False            3
# 2018-01-05     17752.51    5      1  2018       False            4
# ...                 ...  ...    ...   ...         ...          ...
# 2022-12-27     19584.77   27     12  2022       False            1
# 2022-12-28     16875.12   28     12  2022       False            2
# 2022-12-29     18348.89   29     12  2022       False            3
# 2022-12-30     16886.45   30     12  2022       False            4
# 2022-12-31     12634.59   31     12  2022       False            5
#
#             day_of_year  quarter  is_month_start  is_month_end  ...  \
# Order Date                                                      ...
# 2018-01-01            1        1            True         False  ...
# 2018-01-02            2        1           False         False  ...
# 2018-01-03            3        1           False         False  ...
# 2018-01-04            4        1           False         False  ...
# 2018-01-05            5        1           False         False  ...
# ...                 ...      ...             ...           ...  ...
# 2022-12-27          361        4           False         False  ...
# 2022-12-28          362        4           False         False  ...
# 2022-12-29          363        4           False         False  ...
# 2022-12-30          364        4           False         False  ...
# 2022-12-31          365        4           False          True  ...
#
#             Amazon Events_Amazon Prime Day  Amazon Events_Black Friday  \
# Order Date
# 2018-01-01                           False                       False
# 2018-01-02                           False                       False
# 2018-01-03                           False                       False
# 2018-01-04                           False                       False
# 2018-01-05                           False                       False
# ...                                    ...                         ...
# 2022-12-27                           False                       False
# 2022-12-28                           False                       False
# 2022-12-29                           False                       False
# 2022-12-30                           False                       False
# 2022-12-31                           False                       False
#
#             Amazon Events_Memorial Day Sales  \
# Order Date
# 2018-01-01                             False
# 2018-01-02                             False
# 2018-01-03                             False
# 2018-01-04                             False
# 2018-01-05                             False
# ...                                      ...
# 2022-12-27                             False
# 2022-12-28                             False
# 2022-12-29                             False
# 2022-12-30                             False
# 2022-12-31                             False
#
#             Amazon Events_Mother's Day Deals  Amazon Events_No Events  \
# Order Date
# 2018-01-01                             False                     True
# 2018-01-02                             False                     True
# 2018-01-03                             False                     True
# 2018-01-04                             False                     True
# 2018-01-05                             False                     True
# ...                                      ...                      ...
# 2022-12-27                             False                    False
# 2022-12-28                             False                    False
# 2022-12-29                             False                    False
# 2022-12-30                             False                    False
# 2022-12-31                             False                    False
#
#             Amazon Events_Prime Big Deal Days  \
# Order Date
# 2018-01-01                              False
# 2018-01-02                              False
# 2018-01-03                              False
# 2018-01-04                              False
# 2018-01-05                              False
# ...                                       ...
# 2022-12-27                              False
# 2022-12-28                              False
# 2022-12-29                              False
# 2022-12-30                              False
# 2022-12-31                              False
#
#             Amazon Events_Valentine's Day Promotions  \
# Order Date
# 2018-01-01                                     False
# 2018-01-02                                     False
# 2018-01-03                                     False
# 2018-01-04                                     False
# 2018-01-05                                     False
# ...                                              ...
# 2022-12-27                                     False
# 2022-12-28                                     False
# 2022-12-29                                     False
# 2022-12-30                                     False
# 2022-12-31                                     False
#
#             Amazon Events_Year-End Clearance Sale  fedral_holiday  \
# Order Date
# 2018-01-01                                  False            True
# 2018-01-02                                  False           False
# 2018-01-03                                  False           False
# 2018-01-04                                  False           False
# 2018-01-05                                  False           False
# ...                                           ...             ...
# 2022-12-27                                   True           False
# 2022-12-28                                   True           False
# 2022-12-29                                   True           False
# 2022-12-30                                   True           False
# 2022-12-31                                   True           False
#
#             inflation_rate
# Order Date
# 2018-01-01        2.040000
# 2018-01-02        2.041935
# 2018-01-03        2.043871
# 2018-01-04        2.045806
# 2018-01-05        2.047742
# ...                    ...
# 2022-12-27        2.260000
# 2022-12-28        2.260000
# 2022-12-29        2.260000
# 2022-12-30        2.260000
# 2022-12-31        2.260000
#
# [1826 rows x 22 columns]

# %% [markdown]
# **Add historic overall sales**

# %%
df['Sales 1YA'] = assign_historic_sales(df, year_till=2021)
df['Sales 2YA'] = assign_historic_sales(df, year_till=2020)
df['Sales 3YA'] = assign_historic_sales(df, year_till=2019)

# %%
df
# Out:
#             total_sales  day  month  year  is_weekend  day_of_week  \
# Order Date
# 2018-01-01     16122.06    1      1  2018       False            0
# 2018-01-02     17006.00    2      1  2018       False            1
# 2018-01-03     13315.58    3      1  2018       False            2
# 2018-01-04     15820.10    4      1  2018       False            3
# 2018-01-05     17752.51    5      1  2018       False            4
# ...                 ...  ...    ...   ...         ...          ...
# 2022-12-27     19584.77   27     12  2022       False            1
# 2022-12-28     16875.12   28     12  2022       False            2
# 2022-12-29     18348.89   29     12  2022       False            3
# 2022-12-30     16886.45   30     12  2022       False            4
# 2022-12-31     12634.59   31     12  2022       False            5
#
#             day_of_year  quarter  is_month_start  is_month_end  ...  \
# Order Date                                                      ...
# 2018-01-01            1        1            True         False  ...
# 2018-01-02            2        1           False         False  ...
# 2018-01-03            3        1           False         False  ...
# 2018-01-04            4        1           False         False  ...
# 2018-01-05            5        1           False         False  ...
# ...                 ...      ...             ...           ...  ...
# 2022-12-27          361        4           False         False  ...
# 2022-12-28          362        4           False         False  ...
# 2022-12-29          363        4           False         False  ...
# 2022-12-30          364        4           False         False  ...
# 2022-12-31          365        4           False          True  ...
#
#             Amazon Events_Mother's Day Deals  Amazon Events_No Events  \
# Order Date
# 2018-01-01                             False                     True
# 2018-01-02                             False                     True
# 2018-01-03                             False                     True
# 2018-01-04                             False                     True
# 2018-01-05                             False                     True
# ...                                      ...                      ...
# 2022-12-27                             False                    False
# 2022-12-28                             False                    False
# 2022-12-29                             False                    False
# 2022-12-30                             False                    False
# 2022-12-31                             False                    False
#
#             Amazon Events_Prime Big Deal Days  \
# Order Date
# 2018-01-01                              False
# 2018-01-02                              False
# 2018-01-03                              False
# 2018-01-04                              False
# 2018-01-05                              False
# ...                                       ...
# 2022-12-27                              False
# 2022-12-28                              False
# 2022-12-29                              False
# 2022-12-30                              False
# 2022-12-31                              False
#
#             Amazon Events_Valentine's Day Promotions  \
# Order Date
# 2018-01-01                                     False
# 2018-01-02                                     False
# 2018-01-03                                     False
# 2018-01-04                                     False
# 2018-01-05                                     False
# ...                                              ...
# 2022-12-27                                     False
# 2022-12-28                                     False
# 2022-12-29                                     False
# 2022-12-30                                     False
# 2022-12-31                                     False
#
#             Amazon Events_Year-End Clearance Sale  fedral_holiday  \
# Order Date
# 2018-01-01                                  False            True
# 2018-01-02                                  False           False
# 2018-01-03                                  False           False
# 2018-01-04                                  False           False
# 2018-01-05                                  False           False
# ...                                           ...             ...
# 2022-12-27                                   True           False
# 2022-12-28                                   True           False
# 2022-12-29                                   True           False
# 2022-12-30                                   True           False
# 2022-12-31                                   True           False
#
#             inflation_rate  Sales 1YA  Sales 2YA  Sales 3YA
# Order Date
# 2018-01-01        2.040000        NaN        NaN        NaN
# 2018-01-02        2.041935        NaN        NaN        NaN
# 2018-01-03        2.043871        NaN        NaN        NaN
# 2018-01-04        2.045806        NaN        NaN        NaN
# 2018-01-05        2.047742        NaN        NaN        NaN
# ...                    ...        ...        ...        ...
# 2022-12-27        2.260000   32904.27   28083.85   18605.45
# 2022-12-28        2.260000   28271.32   28408.56   18191.95
# 2022-12-29        2.260000   32067.50   30703.10   19580.33
# 2022-12-30        2.260000   31030.66   27021.29   17788.55
# 2022-12-31        2.260000   23616.71   27404.00   14808.73
#
# [1826 rows x 25 columns]

# %% [markdown]
# **Add historic state-wise sales**

# %%
def get_shift_value(year, forcast_df=None):
    global df
    if forcast_df is None:
        return (df[df.index.year<2023].index[-1] - df[df.index.year<=year].index[-1]).days
    else:
        return (forcast_df.index[-1] - df[df.index.year<=year].index[-1]).days

# %%
def add_states_lags():
    global purchases, df
    temp_df = purchases[['Shipping Address State','Category','total_sales']]
    
    temp_df = pd.DataFrame(temp_df.groupby([temp_df.index,'Shipping Address State'])['total_sales'].sum()).reset_index()
    
    states_features = pd.pivot( temp_df[['Order Date', 'Shipping Address State', 'total_sales']], index='Order Date', columns='Shipping Address State', values='total_sales').reset_index().fillna(0)
    
    states_features = states_features.set_index('Order Date')

    scaler = MinMaxScaler()

    scaled_data = scaler.fit_transform(states_features)
    
    pca = PCA(n_components=3,random_state=101)
    
    pca_features = pca.fit_transform(scaled_data)

    state_sales_reduced = pd.DataFrame(pca_features)

    state_sales_reduced.rename(columns={0:'SS1',1:'SS2',2:'SS3'}, inplace=True)

    state_sales_reduced.set_index(df.index, inplace=True)

    states_features = pd.concat([state_sales_reduced, state_sales_reduced.shift(get_shift_value(2021)-10).rename(columns={'SS1':'SS1 1YA','SS2':'SS2 1YA','SS3':'SS3 1YA'}), state_sales_reduced.shift(get_shift_value(2020)-10).rename(columns={'SS1':'SS1 2YA','SS2':'SS2 2YA','SS3':'SS3 2YA'}), state_sales_reduced.shift(get_shift_value(2019)-10).rename(columns={'SS1':'SS1 3YA','SS2':'SS2 3YA','SS3':'SS3 3YA'})], axis=1)

    return pd.merge(df, states_features, left_index=True, right_index=True, how='left')

# %%
get_shift_value(2020)-1
# Out:
# 729

# %%
df = add_states_lags()

# %%
get_null_percentage(df)
# Out:
# total_sales                                  0.000000
# day                                          0.000000
# month                                        0.000000
# year                                         0.000000
# is_weekend                                   0.000000
# day_of_week                                  0.000000
# day_of_year                                  0.000000
# quarter                                      0.000000
# is_month_start                               0.000000
# is_month_end                                 0.000000
# is_year_start                                0.000000
# is_year_end                                  0.000000
# Amazon Events_Amazon Prime Day               0.000000
# Amazon Events_Black Friday                   0.000000
# Amazon Events_Memorial Day Sales             0.000000
# Amazon Events_Mother's Day Deals             0.000000
# Amazon Events_No Events                      0.000000
# Amazon Events_Prime Big Deal Days            0.000000
# Amazon Events_Valentine's Day Promotions     0.000000
# Amazon Events_Year-End Clearance Sale        0.000000
# fedral_holiday                               0.000000
# inflation_rate                               0.000000
# SS2                                          0.000000
# SS1                                          0.000000
# SS3                                          0.000000
# SS2 1YA                                     19.441402
# SS3 1YA                                     19.441402
# SS1 1YA                                     19.441402
# Sales 1YA                                   19.989047
# SS1 2YA                                     39.430449
# SS3 2YA                                     39.430449
# SS2 2YA                                     39.430449
# Sales 2YA                                   39.978094
# SS3 3YA                                     59.474261
# SS1 3YA                                     59.474261
# SS2 3YA                                     59.474261
# Sales 3YA                                   60.021906
# dtype: float64

# %% [markdown]
# ## Cross Validation

# %% [markdown]
# **generate forcast dataframe**

# %%
feature_columns = list(df.columns)
[feature_columns.remove(column) for column in ['total_sales','SS1','SS2','SS3']]
feature_columns
# Out:
# ['day',
#  'month',
#  'year',
#  'is_weekend',
#  'day_of_week',
#  'day_of_year',
#  'quarter',
#  'is_month_start',
#  'is_month_end',
#  'is_year_start',
#  'is_year_end',
#  'Amazon Events_Amazon Prime Day',
#  'Amazon Events_Black Friday',
#  'Amazon Events_Memorial Day Sales',
#  "Amazon Events_Mother's Day Deals",
#  'Amazon Events_No Events',
#  'Amazon Events_Prime Big Deal Days',
#  "Amazon Events_Valentine's Day Promotions",
#  'Amazon Events_Year-End Clearance Sale',
#  'fedral_holiday',
#  'inflation_rate',
#  'Sales 1YA',
#  'Sales 2YA',
#  'Sales 3YA',
#  'SS1 1YA',
#  'SS2 1YA',
#  'SS3 1YA',
#  'SS1 2YA',
#  'SS2 2YA',
#  'SS3 2YA',
#  'SS1 3YA',
#  'SS2 3YA',
#  'SS3 3YA']

# %%
forcast_df =  pd.DataFrame(pd.date_range('2023-01-01', '2023-12-31'),columns=['Order Date'])

# %%
forcast_df = generate_time_features(forcast_df)

# %%
forcast_df = add_holidays_past_2021(forcast_df)

# %%
forcast_df['fedral_holiday'] = forcast_df['fedral_holiday'].fillna(False)
# Out:
# C:\Users\rohit\AppData\Local\Temp\ipykernel_45600\2162938522.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   forcast_df['fedral_holiday'] = forcast_df['fedral_holiday'].fillna(False)

# %%
forcast_df = add_amazon_events(forcast_df)

# %%
forcast_df = forcast_df.drop('index',axis=1)

# %%
forcast_df['forcasting'] = True
df['forcasting'] = False

combined_df = pd.concat([df, forcast_df], axis=0)

combined_df['Sales 1YA'] = assign_historic_sales(combined_df, year_till=2022)
combined_df['Sales 2YA'] = assign_historic_sales(combined_df, year_till=2021)
combined_df['Sales 3YA'] = assign_historic_sales(combined_df, year_till=2020)

combined_df[['SS1 1YA','SS2 1YA','SS3 1YA']] = combined_df[['SS1','SS2','SS3']].shift(get_shift_value(2022, forcast_df)-10)
combined_df[['SS1 2YA','SS2 2YA','SS3 2YA']] = combined_df[['SS1','SS2','SS3']].shift(get_shift_value(2021, forcast_df)-10)
combined_df[['SS1 3YA','SS2 3YA','SS3 3YA']] = combined_df[['SS1','SS2','SS3']].shift(get_shift_value(2020, forcast_df)-10)

forcast_df[['Sales 1YA', 'Sales 2YA', 'Sales 3YA','SS1 1YA','SS2 1YA','SS3 1YA','SS1 2YA','SS2 2YA','SS3 2YA','SS1 3YA','SS2 3YA','SS3 3YA']] = combined_df[combined_df['forcasting'] == True][['Sales 1YA', 'Sales 2YA', 'Sales 3YA','SS1 1YA','SS2 1YA','SS3 1YA','SS1 2YA','SS2 2YA','SS3 2YA','SS1 3YA','SS2 3YA','SS3 3YA']]
forcast_df[['Sales 1YA', 'Sales 2YA', 'Sales 3YA']] = combined_df[combined_df['forcasting'] == True][['Sales 1YA', 'Sales 2YA', 'Sales 3YA']]
forcast_df = forcast_df.drop('forcasting',axis=1)
df = df.drop('forcasting',axis=1)

# %%
forcast_df['inflation_rate'] = df['inflation_rate'].mean()

# %%
forcast_df = pd.concat([df[sorted(feature_columns)].iloc[-30:],forcast_df[sorted(feature_columns)]], axis=0)

# %%
forcast_df = forcast_df[feature_columns]

# %%
forcast_df
# Out:
#             day  month  year  is_weekend  day_of_week  day_of_year  quarter  \
# Order Date
# 2022-12-02    2     12  2022       False            4          336        4
# 2022-12-03    3     12  2022       False            5          337        4
# 2022-12-04    4     12  2022        True            6          338        4
# 2022-12-05    5     12  2022       False            0          339        4
# 2022-12-06    6     12  2022       False            1          340        4
# ...         ...    ...   ...         ...          ...          ...      ...
# 2023-12-27   27     12  2023       False            2          361        4
# 2023-12-28   28     12  2023       False            3          362        4
# 2023-12-29   29     12  2023       False            4          363        4
# 2023-12-30   30     12  2023       False            5          364        4
# 2023-12-31   31     12  2023        True            6          365        4
#
#             is_month_start  is_month_end  is_year_start  ...  Sales 3YA  \
# Order Date                                               ...
# 2022-12-02           False         False          False  ...   68580.09
# 2022-12-03           False         False          False  ...   19426.56
# 2022-12-04           False         False          False  ...   21674.11
# 2022-12-05           False         False          False  ...   22322.26
# 2022-12-06           False         False          False  ...   24400.10
# ...                    ...           ...            ...  ...        ...
# 2023-12-27           False         False          False  ...   28083.85
# 2023-12-28           False         False          False  ...   28408.56
# 2023-12-29           False         False          False  ...   30703.10
# 2023-12-30           False         False          False  ...   27021.29
# 2023-12-31           False          True          False  ...   27404.00
#
#              SS1 1YA   SS2 1YA   SS3 1YA   SS1 2YA   SS2 2YA   SS3 2YA  \
# Order Date
# 2022-12-02  0.390799 -0.084732  0.011374  0.528721  0.111993 -0.014622
# 2022-12-03  0.589301 -0.070354 -0.148633  0.501165 -0.168356 -0.163615
# 2022-12-04  0.575905  0.002422  0.037183  0.500846 -0.035116  0.207645
# 2022-12-05  0.781905  0.041588  0.295036  0.476775  0.043697 -0.068057
# 2022-12-06  0.687362 -0.216649  0.221436  0.674633 -0.046609  0.088321
# ...              ...       ...       ...       ...       ...       ...
# 2023-12-27       NaN       NaN       NaN -0.039552 -0.065894  0.009674
# 2023-12-28       NaN       NaN       NaN  0.146726 -0.065005  0.080304
# 2023-12-29       NaN       NaN       NaN  0.105093 -0.020891  0.066558
# 2023-12-30       NaN       NaN       NaN  0.105740 -0.081221 -0.115929
# 2023-12-31       NaN       NaN       NaN  0.027166 -0.057971  0.005497
#
#              SS1 3YA   SS2 3YA   SS3 3YA
# Order Date
# 2022-12-02  0.316070 -0.053215 -0.196227
# 2022-12-03  0.318811 -0.110406 -0.109510
# 2022-12-04  0.312876  0.071322 -0.069005
# 2022-12-05  0.351064  0.116608 -0.166644
# 2022-12-06  0.400270  0.047092 -0.143028
# ...              ...       ...       ...
# 2023-12-27  0.076311  0.101759  0.266981
# 2023-12-28  0.056957 -0.014689 -0.005521
# 2023-12-29  0.058295 -0.075090 -0.017525
# 2023-12-30  0.069207  0.079294 -0.016494
# 2023-12-31  0.327201 -0.126362  0.026496
#
# [395 rows x 33 columns]

# %%
df[feature_columns]
# Out:
#             day  month  year  is_weekend  day_of_week  day_of_year  quarter  \
# Order Date
# 2018-01-01    1      1  2018       False            0            1        1
# 2018-01-02    2      1  2018       False            1            2        1
# 2018-01-03    3      1  2018       False            2            3        1
# 2018-01-04    4      1  2018       False            3            4        1
# 2018-01-05    5      1  2018       False            4            5        1
# ...         ...    ...   ...         ...          ...          ...      ...
# 2022-12-27   27     12  2022       False            1          361        4
# 2022-12-28   28     12  2022       False            2          362        4
# 2022-12-29   29     12  2022       False            3          363        4
# 2022-12-30   30     12  2022       False            4          364        4
# 2022-12-31   31     12  2022       False            5          365        4
#
#             is_month_start  is_month_end  is_year_start  ...  Sales 3YA  \
# Order Date                                               ...
# 2018-01-01            True         False           True  ...        NaN
# 2018-01-02           False         False          False  ...        NaN
# 2018-01-03           False         False          False  ...        NaN
# 2018-01-04           False         False          False  ...        NaN
# 2018-01-05           False         False          False  ...        NaN
# ...                    ...           ...            ...  ...        ...
# 2022-12-27           False         False          False  ...   18605.45
# 2022-12-28           False         False          False  ...   18191.95
# 2022-12-29           False         False          False  ...   19580.33
# 2022-12-30           False         False          False  ...   17788.55
# 2022-12-31           False          True          False  ...   14808.73
#
#              SS1 1YA   SS2 1YA   SS3 1YA   SS1 2YA   SS2 2YA   SS3 2YA  \
# Order Date
# 2018-01-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-01-05       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2022-12-27 -0.039552 -0.065894  0.009674  0.076311  0.101759  0.266981
# 2022-12-28  0.146726 -0.065005  0.080304  0.056957 -0.014689 -0.005521
# 2022-12-29  0.105093 -0.020891  0.066558  0.058295 -0.075090 -0.017525
# 2022-12-30  0.105740 -0.081221 -0.115929  0.069207  0.079294 -0.016494
# 2022-12-31  0.027166 -0.057971  0.005497  0.327201 -0.126362  0.026496
#
#              SS1 3YA   SS2 3YA   SS3 3YA
# Order Date
# 2018-01-01       NaN       NaN       NaN
# 2018-01-02       NaN       NaN       NaN
# 2018-01-03       NaN       NaN       NaN
# 2018-01-04       NaN       NaN       NaN
# 2018-01-05       NaN       NaN       NaN
# ...              ...       ...       ...
# 2022-12-27 -0.066376 -0.165988 -0.427192
# 2022-12-28 -0.199835 -0.027518 -0.055484
# 2022-12-29 -0.119714 -0.040575 -0.076681
# 2022-12-30 -0.112761 -0.106674 -0.031974
# 2022-12-31 -0.060067 -0.100797 -0.375271
#
# [1826 rows x 33 columns]

# %% [markdown]
# **cross validate**

# %%
def cross_validate(df, forcastdf, feature_columns):
    scores = []
    preds = []
    feature_importances = []
    sales = []
    tss = TimeSeriesSplit(n_splits=3, test_size=365, gap=0)
    feature_columns = sorted(feature_columns)
    for train_idx, val_idx in tss.split(df):
        scaler = StandardScaler()
        train = df.iloc[train_idx]
        test = df.iloc[val_idx]
        X_train = train[feature_columns]
        y_train = train['total_sales']
        X_test = test[feature_columns]
        y_test = test['total_sales']
        reg_model = xgb.XGBRegressor(base_score=0.5, booster='gblinear',  n_estimators=1000, early_stopping_rounds=50, objective='reg:squarederror', learning_rate=0.01)
        reg_model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_test, y_test)], verbose=True)
        feature_importances.append(reg_model.feature_importances_)
        y_preds = reg_model.predict(X_train)
        ds =  pd.concat([y_train.reset_index(),pd.Series(y_preds)], axis=1)
        ds = ds.set_index('Order Date')
        ds['total_sales'].plot(label='true data')
        ds[0].plot(label='prediction')
        plt.legend()
        plt.show()
        y_preds = reg_model.predict(X_test)
        ds =  pd.concat([y_test.reset_index(),pd.Series(y_preds)], axis=1)
        ds = ds.set_index('Order Date')
        ds['total_sales'].plot(label='true data')
        ds[0].plot(label='prediction')
        plt.legend()
        plt.show()
        forcast_preds = reg_model.predict(forcastdf[feature_columns])
        ds =  pd.Series(forcast_preds, index=forcastdf.index)
        ds.plot(label='prediction')
        plt.legend()
        plt.show()
        preds.append(y_preds)
        score = np.sqrt(mean_squared_error(y_test, y_preds))
        scores.append(score)

    return preds, scores, feature_importances

# %%
preds, scores, feature_importances = cross_validate(df, forcast_df, feature_columns)
# Out:
# [0]	validation_0-rmse:15771.11414	validation_1-rmse:24083.08428
# [1]	validation_0-rmse:14633.23515	validation_1-rmse:22584.71795
# [2]	validation_0-rmse:13620.99768	validation_1-rmse:21246.86759
# [3]	validation_0-rmse:12716.28967	validation_1-rmse:20043.25992
# [4]	validation_0-rmse:11911.92525	validation_1-rmse:18975.49549
# [5]	validation_0-rmse:11196.08962	validation_1-rmse:18021.94297
# [6]	validation_0-rmse:10562.75151	validation_1-rmse:17164.06764
# [7]	validation_0-rmse:9998.52906	validation_1-rmse:16389.12429
# [8]	validation_0-rmse:9503.32898	validation_1-rmse:15698.45669
# [9]	validation_0-rmse:9070.64135	validation_1-rmse:15086.72782
# [10]	validation_0-rmse:8690.80654	validation_1-rmse:14536.39437
# [11]	validation_0-rmse:8358.23797	validation_1-rmse:14042.80582
# [12]	validation_0-rmse:8068.32060	validation_1-rmse:13604.93379
# [13]	validation_0-rmse:7816.63121	validation_1-rmse:13215.42185
# [14]	validation_0-rmse:7597.12076	validation_1-rmse:12866.43512
# [15]	validation_0-rmse:7405.78542	validation_1-rmse:12550.09558
# [16]	validation_0-rmse:7239.31756	validation_1-rmse:12268.44311
# [17]	validation_0-rmse:7094.03887	validation_1-rmse:12015.77017
# [18]	validation_0-rmse:6967.56166	validation_1-rmse:11789.64392
# [19]	validation_0-rmse:6857.18856	validation_1-rmse:11586.91314
# [20]	validation_0-rmse:6760.25649	validation_1-rmse:11404.71611
# [21]	validation_0-rmse:6675.18630	validation_1-rmse:11240.48396
# [22]	validation_0-rmse:6599.95940	validation_1-rmse:11091.99272
# [23]	validation_0-rmse:6533.11774	validation_1-rmse:10958.40648
# [24]	validation_0-rmse:6473.57817	validation_1-rmse:10837.88539
# [25]	validation_0-rmse:6420.25265	validation_1-rmse:10728.91785
# [26]	validation_0-rmse:6372.00960	validation_1-rmse:10630.23955
# [27]	validation_0-rmse:6328.44891	validation_1-rmse:10541.82442
# [28]	validation_0-rmse:6288.67146	validation_1-rmse:10461.15240
# [29]	validation_0-rmse:6252.15137	validation_1-rmse:10387.81848
# [30]	validation_0-rmse:6218.41643	validation_1-rmse:10321.11234
# [31]	validation_0-rmse:6187.07470	validation_1-rmse:10260.44758
# [32]	validation_0-rmse:6157.80069	validation_1-rmse:10205.04714
# [33]	validation_0-rmse:6130.23311	validation_1-rmse:10154.06458
# [34]	validation_0-rmse:6104.23824	validation_1-rmse:10107.73105
# [35]	validation_0-rmse:6079.59854	validation_1-rmse:10065.36622
# [80]	validation_0-rmse:5462.08155	validation_1-rmse:9327.89803
# [81]	validation_0-rmse:5453.80364	validation_1-rmse:9315.53470
# [82]	validation_0-rmse:5445.67835	validation_1-rmse:9303.11491
# [83]	validation_0-rmse:5437.70443	validation_1-rmse:9290.59575
# [84]	validation_0-rmse:5429.88275	validation_1-rmse:9278.39509
# [85]	validation_0-rmse:5422.20520	validation_1-rmse:9265.95664
# [86]	validation_0-rmse:5414.67180	validation_1-rmse:9253.55742
# [87]	validation_0-rmse:5407.27971	validation_1-rmse:9241.09446
# [88]	validation_0-rmse:5400.01807	validation_1-rmse:9228.72968
# [89]	validation_0-rmse:5392.89591	validation_1-rmse:9216.16115
# [90]	validation_0-rmse:5385.90644	validation_1-rmse:9203.49718
# [91]	validation_0-rmse:5379.04297	validation_1-rmse:9191.16036
# [92]	validation_0-rmse:5372.30832	validation_1-rmse:9178.61130
# [93]	validation_0-rmse:5365.69827	validation_1-rmse:9165.95278
# [94]	validation_0-rmse:5359.20992	validation_1-rmse:9153.62755
# [95]	validation_0-rmse:5352.83887	validation_1-rmse:9141.19892
# [96]	validation_0-rmse:5346.58881	validation_1-rmse:9128.80243
# [97]	validation_0-rmse:5340.45504	validation_1-rmse:9116.42645
# [98]	validation_0-rmse:5334.43512	validation_1-rmse:9104.13366
# [99]	validation_0-rmse:5328.52327	validation_1-rmse:9091.62146
# [100]	validation_0-rmse:5322.71947	validation_1-rmse:9079.32861
# [101]	validation_0-rmse:5317.02388	validation_1-rmse:9066.79335
# [102]	validation_0-rmse:5311.42554	validation_1-rmse:9054.40342
# [103]	validation_0-rmse:5305.93729	validation_1-rmse:9042.17677
# [104]	validation_0-rmse:5300.54593	validation_1-rmse:9029.77321
# [105]	validation_0-rmse:5295.25400	validation_1-rmse:9017.39299
# [106]	validation_0-rmse:5290.05886	validation_1-rmse:9005.25111
# [107]	validation_0-rmse:5284.95831	validation_1-rmse:8993.17566
# [108]	validation_0-rmse:5279.95090	validation_1-rmse:8980.99672
# [109]	validation_0-rmse:5275.03283	validation_1-rmse:8968.86002
# [110]	validation_0-rmse:5270.20525	validation_1-rmse:8956.82357
# [111]	validation_0-rmse:5265.46440	validation_1-rmse:8944.76842
# [112]	validation_0-rmse:5260.80824	validation_1-rmse:8932.90965
# [113]	validation_0-rmse:5256.23898	validation_1-rmse:8921.19207
# [114]	validation_0-rmse:5251.75119	validation_1-rmse:8909.68866
# [115]	validation_0-rmse:5247.34579	validation_1-rmse:8898.14504
# [116]	validation_0-rmse:5243.01683	validation_1-rmse:8886.73577
# [117]	validation_0-rmse:5238.76945	validation_1-rmse:8875.26514
# [118]	validation_0-rmse:5234.59162	validation_1-rmse:8863.90282
# [119]	validation_0-rmse:5230.49275	validation_1-rmse:8852.44799
# [120]	validation_0-rmse:5226.46720	validation_1-rmse:8841.06608
# [121]	validation_0-rmse:5222.51225	validation_1-rmse:8829.85622
# [122]	validation_0-rmse:5218.62750	validation_1-rmse:8818.62719
# [123]	validation_0-rmse:5214.81233	validation_1-rmse:8807.48980
# [124]	validation_0-rmse:5211.06435	validation_1-rmse:8796.61794
# [125]	validation_0-rmse:5207.38438	validation_1-rmse:8785.45551
# [126]	validation_0-rmse:5203.77052	validation_1-rmse:8774.64331
# [127]	validation_0-rmse:5200.22258	validation_1-rmse:8763.97218
# [128]	validation_0-rmse:5196.73317	validation_1-rmse:8753.34097
# [129]	validation_0-rmse:5193.30505	validation_1-rmse:8742.80717
# [130]	validation_0-rmse:5189.93614	validation_1-rmse:8732.31389
# [131]	validation_0-rmse:5186.62725	validation_1-rmse:8721.88264
# [132]	validation_0-rmse:5183.37648	validation_1-rmse:8711.65083
# [133]	validation_0-rmse:5180.18365	validation_1-rmse:8701.53603
# [134]	validation_0-rmse:5177.04300	validation_1-rmse:8691.48563
# [135]	validation_0-rmse:5173.95923	validation_1-rmse:8681.65502
# [136]	validation_0-rmse:5170.92801	validation_1-rmse:8671.65646
# [137]	validation_0-rmse:5167.94894	validation_1-rmse:8661.77084
# [138]	validation_0-rmse:5165.02025	validation_1-rmse:8652.00060
# [139]	validation_0-rmse:5162.14281	validation_1-rmse:8642.25027
# [140]	validation_0-rmse:5159.31192	validation_1-rmse:8632.62859
# [141]	validation_0-rmse:5156.53162	validation_1-rmse:8623.11154
# [142]	validation_0-rmse:5153.79715	validation_1-rmse:8613.67775
# [143]	validation_0-rmse:5151.11253	validation_1-rmse:8604.48664
# [144]	validation_0-rmse:5148.47164	validation_1-rmse:8595.44544
# [145]	validation_0-rmse:5145.87275	validation_1-rmse:8586.52103
# [146]	validation_0-rmse:5143.32148	validation_1-rmse:8577.60476
# [147]	validation_0-rmse:5140.81094	validation_1-rmse:8568.85638
# [148]	validation_0-rmse:5138.34577	validation_1-rmse:8560.12475
# [149]	validation_0-rmse:5135.92005	validation_1-rmse:8551.29122
# [150]	validation_0-rmse:5133.53445	validation_1-rmse:8542.61246
# [151]	validation_0-rmse:5131.18743	validation_1-rmse:8534.05904
# [152]	validation_0-rmse:5128.87920	validation_1-rmse:8525.52448
# [153]	validation_0-rmse:5126.61218	validation_1-rmse:8517.34609
# [154]	validation_0-rmse:5124.37933	validation_1-rmse:8509.16088
# [155]	validation_0-rmse:5122.18438	validation_1-rmse:8501.01559
# [156]	validation_0-rmse:5120.02496	validation_1-rmse:8492.87774
# [157]	validation_0-rmse:5117.90072	validation_1-rmse:8484.93633
# [158]	validation_0-rmse:5115.81082	validation_1-rmse:8477.12949
# [159]	validation_0-rmse:5113.75525	validation_1-rmse:8469.40123
# [160]	validation_0-rmse:5111.73244	validation_1-rmse:8461.66269
# [161]	validation_0-rmse:5109.74373	validation_1-rmse:8454.03094
# [162]	validation_0-rmse:5107.78590	validation_1-rmse:8446.58696
# [163]	validation_0-rmse:5105.85938	validation_1-rmse:8439.13497
# [164]	validation_0-rmse:5103.96400	validation_1-rmse:8431.91606
# [165]	validation_0-rmse:5102.09836	validation_1-rmse:8424.75535
# [166]	validation_0-rmse:5100.26288	validation_1-rmse:8417.68168
# [167]	validation_0-rmse:5098.45441	validation_1-rmse:8410.57535
# [212]	validation_0-rmse:5039.53811	validation_1-rmse:8174.37003
# [213]	validation_0-rmse:5038.59618	validation_1-rmse:8170.67678
# [214]	validation_0-rmse:5037.66585	validation_1-rmse:8167.06526
# [215]	validation_0-rmse:5036.74683	validation_1-rmse:8163.52605
# [216]	validation_0-rmse:5035.83850	validation_1-rmse:8159.96811
# [217]	validation_0-rmse:5034.93987	validation_1-rmse:8156.49096
# [218]	validation_0-rmse:5034.05436	validation_1-rmse:8153.09067
# [219]	validation_0-rmse:5033.18027	validation_1-rmse:8149.82307
# [220]	validation_0-rmse:5032.31613	validation_1-rmse:8146.53486
# [221]	validation_0-rmse:5031.46160	validation_1-rmse:8143.37510
# [222]	validation_0-rmse:5030.61693	validation_1-rmse:8140.16801
# [223]	validation_0-rmse:5029.78218	validation_1-rmse:8137.03075
# [224]	validation_0-rmse:5028.95640	validation_1-rmse:8133.93473
# [225]	validation_0-rmse:5028.13990	validation_1-rmse:8130.95852
# [226]	validation_0-rmse:5027.33373	validation_1-rmse:8128.09208
# [227]	validation_0-rmse:5026.53608	validation_1-rmse:8125.18408
# [228]	validation_0-rmse:5025.74822	validation_1-rmse:8122.28200
# [229]	validation_0-rmse:5024.96791	validation_1-rmse:8119.45158
# [230]	validation_0-rmse:5024.19631	validation_1-rmse:8116.63726
# [231]	validation_0-rmse:5023.43320	validation_1-rmse:8113.97636
# [232]	validation_0-rmse:5022.67821	validation_1-rmse:8111.33322
# [233]	validation_0-rmse:5021.93190	validation_1-rmse:8108.67905
# [234]	validation_0-rmse:5021.19305	validation_1-rmse:8106.07607
# [235]	validation_0-rmse:5020.46158	validation_1-rmse:8103.49283
# [236]	validation_0-rmse:5019.73945	validation_1-rmse:8101.05525
# [237]	validation_0-rmse:5019.02547	validation_1-rmse:8098.77000
# [238]	validation_0-rmse:5018.31680	validation_1-rmse:8096.35235
# [239]	validation_0-rmse:5017.61514	validation_1-rmse:8094.02394
# [240]	validation_0-rmse:5016.92046	validation_1-rmse:8091.81775
# [241]	validation_0-rmse:5016.23406	validation_1-rmse:8089.59098
# [242]	validation_0-rmse:5015.55377	validation_1-rmse:8087.31803
# [243]	validation_0-rmse:5014.88025	validation_1-rmse:8085.09063
# [244]	validation_0-rmse:5014.21320	validation_1-rmse:8082.97365
# [245]	validation_0-rmse:5013.55236	validation_1-rmse:8080.92207
# [246]	validation_0-rmse:5012.89911	validation_1-rmse:8078.92873
# [247]	validation_0-rmse:5012.25001	validation_1-rmse:8076.86932
# [248]	validation_0-rmse:5011.60932	validation_1-rmse:8074.89886
# [249]	validation_0-rmse:5010.97455	validation_1-rmse:8073.03777
# [250]	validation_0-rmse:5010.34459	validation_1-rmse:8071.06162
# [251]	validation_0-rmse:5009.71959	validation_1-rmse:8069.17469
# [252]	validation_0-rmse:5009.10212	validation_1-rmse:8067.32046
# [253]	validation_0-rmse:5008.48894	validation_1-rmse:8065.44424
# [254]	validation_0-rmse:5007.88172	validation_1-rmse:8063.69906
# [255]	validation_0-rmse:5007.28074	validation_1-rmse:8061.99631
# [256]	validation_0-rmse:5006.68423	validation_1-rmse:8060.29493
# [257]	validation_0-rmse:5006.09267	validation_1-rmse:8058.62443
# [258]	validation_0-rmse:5005.50617	validation_1-rmse:8056.99907
# [259]	validation_0-rmse:5004.92524	validation_1-rmse:8055.43258
# [260]	validation_0-rmse:5004.34951	validation_1-rmse:8053.94613
# [261]	validation_0-rmse:5003.77932	validation_1-rmse:8052.44860
# [262]	validation_0-rmse:5003.21353	validation_1-rmse:8050.97360
# [263]	validation_0-rmse:5002.65136	validation_1-rmse:8049.58678
# [264]	validation_0-rmse:5002.09504	validation_1-rmse:8048.17452
# [265]	validation_0-rmse:5001.54358	validation_1-rmse:8046.84072
# [266]	validation_0-rmse:5000.99614	validation_1-rmse:8045.56722
# [267]	validation_0-rmse:5000.45298	validation_1-rmse:8044.23239
# [268]	validation_0-rmse:4999.91416	validation_1-rmse:8042.98104
# [269]	validation_0-rmse:4999.37984	validation_1-rmse:8041.77395
# [270]	validation_0-rmse:4998.84924	validation_1-rmse:8040.59269
# [271]	validation_0-rmse:4998.32255	validation_1-rmse:8039.37687
# [272]	validation_0-rmse:4997.79976	validation_1-rmse:8038.18681
# [273]	validation_0-rmse:4997.28169	validation_1-rmse:8037.04779
# [274]	validation_0-rmse:4996.76643	validation_1-rmse:8035.90933
# [275]	validation_0-rmse:4996.25608	validation_1-rmse:8034.82397
# [276]	validation_0-rmse:4995.74909	validation_1-rmse:8033.77380
# [277]	validation_0-rmse:4995.24576	validation_1-rmse:8032.69992
# [278]	validation_0-rmse:4994.74622	validation_1-rmse:8031.75393
# [279]	validation_0-rmse:4994.25069	validation_1-rmse:8030.80110
# [280]	validation_0-rmse:4993.75769	validation_1-rmse:8029.91680
# [281]	validation_0-rmse:4993.26842	validation_1-rmse:8029.08695
# [282]	validation_0-rmse:4992.78283	validation_1-rmse:8028.22854
# [283]	validation_0-rmse:4992.30074	validation_1-rmse:8027.38566
# [284]	validation_0-rmse:4991.82216	validation_1-rmse:8026.60328
# [285]	validation_0-rmse:4991.34679	validation_1-rmse:8025.86002
# [286]	validation_0-rmse:4990.87461	validation_1-rmse:8025.11108
# [287]	validation_0-rmse:4990.40658	validation_1-rmse:8024.38767
# [288]	validation_0-rmse:4989.94088	validation_1-rmse:8023.79371
# [289]	validation_0-rmse:4989.47742	validation_1-rmse:8023.10356
# [290]	validation_0-rmse:4989.01813	validation_1-rmse:8022.45051
# [291]	validation_0-rmse:4988.56148	validation_1-rmse:8021.84513
# [292]	validation_0-rmse:4988.10754	validation_1-rmse:8021.24775
# [293]	validation_0-rmse:4987.65687	validation_1-rmse:8020.63382
# [294]	validation_0-rmse:4987.20744	validation_1-rmse:8019.99358
# [295]	validation_0-rmse:4986.76154	validation_1-rmse:8019.45512
# [296]	validation_0-rmse:4986.31755	validation_1-rmse:8019.08249
# [297]	validation_0-rmse:4985.87737	validation_1-rmse:8018.58983
# [298]	validation_0-rmse:4985.43967	validation_1-rmse:8018.21854
# [299]	validation_0-rmse:4985.00486	validation_1-rmse:8017.74749
# [300]	validation_0-rmse:4984.57293	validation_1-rmse:8017.37687
# [58]	validation_0-rmse:6133.59732	validation_1-rmse:9953.30033
# [59]	validation_0-rmse:6118.40373	validation_1-rmse:9938.60945
# [60]	validation_0-rmse:6103.50382	validation_1-rmse:9924.37966
# [61]	validation_0-rmse:6088.88713	validation_1-rmse:9910.54249
# [62]	validation_0-rmse:6074.53994	validation_1-rmse:9897.23515
# [63]	validation_0-rmse:6060.46761	validation_1-rmse:9883.75988
# [64]	validation_0-rmse:6046.66871	validation_1-rmse:9871.08842
# [65]	validation_0-rmse:6033.13195	validation_1-rmse:9858.83223
# [66]	validation_0-rmse:6019.85039	validation_1-rmse:9846.73066
# [67]	validation_0-rmse:6006.82357	validation_1-rmse:9834.97087
# [68]	validation_0-rmse:5994.03525	validation_1-rmse:9823.40013
# [69]	validation_0-rmse:5981.49553	validation_1-rmse:9812.30142
# [70]	validation_0-rmse:5969.19938	validation_1-rmse:9801.48638
# [71]	validation_0-rmse:5957.13144	validation_1-rmse:9790.89602
# [72]	validation_0-rmse:5945.28669	validation_1-rmse:9780.41122
# [73]	validation_0-rmse:5933.67320	validation_1-rmse:9770.19176
# [74]	validation_0-rmse:5922.26876	validation_1-rmse:9759.96782
# [75]	validation_0-rmse:5911.08068	validation_1-rmse:9750.19190
# [76]	validation_0-rmse:5900.10393	validation_1-rmse:9740.52336
# [77]	validation_0-rmse:5889.33933	validation_1-rmse:9731.23599
# [78]	validation_0-rmse:5878.77429	validation_1-rmse:9722.01248
# [79]	validation_0-rmse:5868.40600	validation_1-rmse:9712.93154
# [80]	validation_0-rmse:5858.23594	validation_1-rmse:9704.37007
# [81]	validation_0-rmse:5848.26731	validation_1-rmse:9695.87417
# [82]	validation_0-rmse:5838.47623	validation_1-rmse:9687.59194
# [83]	validation_0-rmse:5828.87680	validation_1-rmse:9679.28316
# [84]	validation_0-rmse:5819.44923	validation_1-rmse:9671.03370
# [85]	validation_0-rmse:5810.20689	validation_1-rmse:9663.05430
# [86]	validation_0-rmse:5801.13536	validation_1-rmse:9655.02120
# [87]	validation_0-rmse:5792.23688	validation_1-rmse:9647.37163
# [88]	validation_0-rmse:5783.50626	validation_1-rmse:9639.77724
# [89]	validation_0-rmse:5774.93827	validation_1-rmse:9632.18256
# [90]	validation_0-rmse:5766.53424	validation_1-rmse:9624.82664
# [91]	validation_0-rmse:5758.29063	validation_1-rmse:9617.57206
# [92]	validation_0-rmse:5750.19043	validation_1-rmse:9610.51925
# [93]	validation_0-rmse:5742.25082	validation_1-rmse:9603.50516
# [94]	validation_0-rmse:5734.45866	validation_1-rmse:9596.38432
# [95]	validation_0-rmse:5726.81634	validation_1-rmse:9589.61694
# [96]	validation_0-rmse:5719.31894	validation_1-rmse:9582.85891
# [97]	validation_0-rmse:5711.95416	validation_1-rmse:9576.01732
# [98]	validation_0-rmse:5704.73503	validation_1-rmse:9569.53071
# [99]	validation_0-rmse:5697.64522	validation_1-rmse:9563.13386
# [100]	validation_0-rmse:5690.68643	validation_1-rmse:9556.67731
# [101]	validation_0-rmse:5683.85956	validation_1-rmse:9550.30300
# [323]	validation_0-rmse:5286.24980	validation_1-rmse:8988.16277
# [324]	validation_0-rmse:5285.86586	validation_1-rmse:8987.12624
# [325]	validation_0-rmse:5285.48430	validation_1-rmse:8986.10611
# [326]	validation_0-rmse:5285.10559	validation_1-rmse:8985.06442
# [327]	validation_0-rmse:5284.72899	validation_1-rmse:8984.06290
# [328]	validation_0-rmse:5284.35431	validation_1-rmse:8983.02425
# [329]	validation_0-rmse:5283.98199	validation_1-rmse:8982.00141
# [330]	validation_0-rmse:5283.61226	validation_1-rmse:8981.01313
# [331]	validation_0-rmse:5283.24373	validation_1-rmse:8979.99977
# [332]	validation_0-rmse:5282.87789	validation_1-rmse:8978.99665
# [333]	validation_0-rmse:5282.51413	validation_1-rmse:8978.02515
# [334]	validation_0-rmse:5282.15264	validation_1-rmse:8977.02822
# [335]	validation_0-rmse:5281.79256	validation_1-rmse:8976.03613
# [336]	validation_0-rmse:5281.43465	validation_1-rmse:8975.04797
# [337]	validation_0-rmse:5281.07892	validation_1-rmse:8974.07905
# [338]	validation_0-rmse:5280.72462	validation_1-rmse:8973.11269
# [339]	validation_0-rmse:5280.37250	validation_1-rmse:8972.19122
# [340]	validation_0-rmse:5280.02245	validation_1-rmse:8971.22576
# [341]	validation_0-rmse:5279.67477	validation_1-rmse:8970.29773
# [342]	validation_0-rmse:5279.32766	validation_1-rmse:8969.32793
# [343]	validation_0-rmse:5278.98299	validation_1-rmse:8968.36968
# [344]	validation_0-rmse:5278.64014	validation_1-rmse:8967.44545
# [345]	validation_0-rmse:5278.29914	validation_1-rmse:8966.53362
# [346]	validation_0-rmse:5277.95987	validation_1-rmse:8965.60941
# [347]	validation_0-rmse:5277.62233	validation_1-rmse:8964.66756
# [348]	validation_0-rmse:5277.28637	validation_1-rmse:8963.74219
# [349]	validation_0-rmse:5276.95269	validation_1-rmse:8962.83652
# [350]	validation_0-rmse:5276.62030	validation_1-rmse:8961.91125
# [351]	validation_0-rmse:5276.28998	validation_1-rmse:8961.02456
# [352]	validation_0-rmse:5275.96162	validation_1-rmse:8960.14132
# [353]	validation_0-rmse:5275.63431	validation_1-rmse:8959.25700
# [354]	validation_0-rmse:5275.30827	validation_1-rmse:8958.33409
# [355]	validation_0-rmse:5274.98404	validation_1-rmse:8957.44013
# [356]	validation_0-rmse:5274.66159	validation_1-rmse:8956.56258
# [357]	validation_0-rmse:5274.33991	validation_1-rmse:8955.63458
# [358]	validation_0-rmse:5274.02032	validation_1-rmse:8954.74249
# [359]	validation_0-rmse:5273.70253	validation_1-rmse:8953.89306
# [360]	validation_0-rmse:5273.38614	validation_1-rmse:8953.03417
# [361]	validation_0-rmse:5273.07119	validation_1-rmse:8952.18127
# [362]	validation_0-rmse:5272.75747	validation_1-rmse:8951.30186
# [363]	validation_0-rmse:5272.44520	validation_1-rmse:8950.45895
# [364]	validation_0-rmse:5272.13467	validation_1-rmse:8949.61259
# [365]	validation_0-rmse:5271.82544	validation_1-rmse:8948.78101
# [366]	validation_0-rmse:5271.51772	validation_1-rmse:8947.94961
# [367]	validation_0-rmse:5271.21151	validation_1-rmse:8947.12224
# [368]	validation_0-rmse:5270.90634	validation_1-rmse:8946.25372
# [369]	validation_0-rmse:5270.60225	validation_1-rmse:8945.39977
# [370]	validation_0-rmse:5270.29951	validation_1-rmse:8944.55074
# [371]	validation_0-rmse:5269.99778	validation_1-rmse:8943.71448
# [372]	validation_0-rmse:5269.69778	validation_1-rmse:8942.87732
# [373]	validation_0-rmse:5269.39893	validation_1-rmse:8942.04674
# [374]	validation_0-rmse:5269.10145	validation_1-rmse:8941.21661
# [375]	validation_0-rmse:5268.80500	validation_1-rmse:8940.38640
# ...
# [325]	validation_0-rmse:5922.73259	validation_1-rmse:9571.40769
# [326]	validation_0-rmse:5922.30244	validation_1-rmse:9570.87331
# [327]	validation_0-rmse:5921.87506	validation_1-rmse:9570.33596
# [328]	validation_0-rmse:5921.45042	validation_1-rmse:9569.73545
# [329]	validation_0-rmse:5921.02766	validation_1-rmse:9569.20609
# [330]	validation_0-rmse:5920.60762	validation_1-rmse:9568.67780
# [331]	validation_0-rmse:5920.18985	validation_1-rmse:9568.16099
# [332]	validation_0-rmse:5919.77455	validation_1-rmse:9567.58915
# [333]	validation_0-rmse:5919.36206	validation_1-rmse:9567.01760
# [334]	validation_0-rmse:5918.95195	validation_1-rmse:9566.45238
# [335]	validation_0-rmse:5918.54419	validation_1-rmse:9565.90135
# [336]	validation_0-rmse:5918.13832	validation_1-rmse:9565.37404
# [337]	validation_0-rmse:5917.73440	validation_1-rmse:9564.85747
# [338]	validation_0-rmse:5917.33212	validation_1-rmse:9564.39095
# [339]	validation_0-rmse:5916.93216	validation_1-rmse:9563.88082
# [340]	validation_0-rmse:5916.53363	validation_1-rmse:9563.43367
# [341]	validation_0-rmse:5916.13831	validation_1-rmse:9562.93033
# [342]	validation_0-rmse:5915.74403	validation_1-rmse:9562.49215
# [343]	validation_0-rmse:5915.35248	validation_1-rmse:9562.01524
# [344]	validation_0-rmse:5914.96283	validation_1-rmse:9561.54622
# [345]	validation_0-rmse:5914.57408	validation_1-rmse:9561.13112
# [346]	validation_0-rmse:5914.18765	validation_1-rmse:9560.71772
# [347]	validation_0-rmse:5913.80358	validation_1-rmse:9560.24476
# [348]	validation_0-rmse:5913.42173	validation_1-rmse:9559.74332
# [349]	validation_0-rmse:5913.04092	validation_1-rmse:9559.35353
# [350]	validation_0-rmse:5912.66285	validation_1-rmse:9558.90073
# [351]	validation_0-rmse:5912.28539	validation_1-rmse:9558.53288
# [352]	validation_0-rmse:5911.90991	validation_1-rmse:9558.15078
# [353]	validation_0-rmse:5911.53664	validation_1-rmse:9557.76262
# [354]	validation_0-rmse:5911.16534	validation_1-rmse:9557.32420
# [355]	validation_0-rmse:5910.79540	validation_1-rmse:9556.96513
# [356]	validation_0-rmse:5910.42738	validation_1-rmse:9556.50755
# [357]	validation_0-rmse:5910.06126	validation_1-rmse:9556.09989
# [358]	validation_0-rmse:5909.69732	validation_1-rmse:9555.69867
# [359]	validation_0-rmse:5909.33469	validation_1-rmse:9555.28493
# [360]	validation_0-rmse:5908.97326	validation_1-rmse:9554.97632
# [361]	validation_0-rmse:5908.61328	validation_1-rmse:9554.61516
# [362]	validation_0-rmse:5908.25478	validation_1-rmse:9554.31470
# [363]	validation_0-rmse:5907.89820	validation_1-rmse:9553.93366
# [364]	validation_0-rmse:5907.54288	validation_1-rmse:9553.62949
# [365]	validation_0-rmse:5907.18960	validation_1-rmse:9553.28244
# [366]	validation_0-rmse:5906.83775	validation_1-rmse:9552.93563
# [367]	validation_0-rmse:5906.48755	validation_1-rmse:9552.64712
# [368]	validation_0-rmse:5906.13872	validation_1-rmse:9552.30707
# [369]	validation_0-rmse:5905.79165	validation_1-rmse:9551.97915
# [370]	validation_0-rmse:5905.44554	validation_1-rmse:9551.68494
# [371]	validation_0-rmse:5905.10088	validation_1-rmse:9551.41979
# [372]	validation_0-rmse:5904.75762	validation_1-rmse:9551.14299
# [373]	validation_0-rmse:5904.41607	validation_1-rmse:9550.79726
# [374]	validation_0-rmse:5904.07672	validation_1-rmse:9550.45285
# [375]	validation_0-rmse:5903.73781	validation_1-rmse:9550.15324
# [376]	validation_0-rmse:5903.40067	validation_1-rmse:9549.85438
# [377]	validation_0-rmse:5903.06480	validation_1-rmse:9549.55961
# [378]	validation_0-rmse:5902.72925	validation_1-rmse:9549.31692
# [379]	validation_0-rmse:5902.39554	validation_1-rmse:9549.05399
# [380]	validation_0-rmse:5902.06367	validation_1-rmse:9548.75910
# [381]	validation_0-rmse:5901.73334	validation_1-rmse:9548.43082
# [382]	validation_0-rmse:5901.40461	validation_1-rmse:9548.10678
# [383]	validation_0-rmse:5901.07712	validation_1-rmse:9547.82020
# [384]	validation_0-rmse:5900.75090	validation_1-rmse:9547.55476
# [385]	validation_0-rmse:5900.42534	validation_1-rmse:9547.33915
# [386]	validation_0-rmse:5900.10169	validation_1-rmse:9547.08187
# [387]	validation_0-rmse:5899.77839	validation_1-rmse:9546.89805
# [388]	validation_0-rmse:5899.45675	validation_1-rmse:9546.65038
# [389]	validation_0-rmse:5899.13637	validation_1-rmse:9546.41191
# [390]	validation_0-rmse:5898.81749	validation_1-rmse:9546.16116
# [391]	validation_0-rmse:5898.49974	validation_1-rmse:9545.91986
# [392]	validation_0-rmse:5898.18268	validation_1-rmse:9545.73680
# [393]	validation_0-rmse:5897.86692	validation_1-rmse:9545.51285
# [394]	validation_0-rmse:5897.55260	validation_1-rmse:9545.29509
# [395]	validation_0-rmse:5897.23896	validation_1-rmse:9545.11208
# [396]	validation_0-rmse:5896.92661	validation_1-rmse:9544.86998
# [397]	validation_0-rmse:5896.61576	validation_1-rmse:9544.65624
# [398]	validation_0-rmse:5896.30536	validation_1-rmse:9544.50002
# [399]	validation_0-rmse:5895.99667	validation_1-rmse:9544.34621
# [400]	validation_0-rmse:5895.68901	validation_1-rmse:9544.13700
# [401]	validation_0-rmse:5895.38260	validation_1-rmse:9543.86230
# [402]	validation_0-rmse:5895.07726	validation_1-rmse:9543.67335
# [403]	validation_0-rmse:5894.77334	validation_1-rmse:9543.47769
# [404]	validation_0-rmse:5894.47033	validation_1-rmse:9543.28690
# [405]	validation_0-rmse:5894.16800	validation_1-rmse:9543.10258
# [406]	validation_0-rmse:5893.86655	validation_1-rmse:9542.97410
# [407]	validation_0-rmse:5893.56713	validation_1-rmse:9542.76515
# [408]	validation_0-rmse:5893.26818	validation_1-rmse:9542.57000
# [409]	validation_0-rmse:5892.96949	validation_1-rmse:9542.45472
# [410]	validation_0-rmse:5892.67210	validation_1-rmse:9542.27374
# [411]	validation_0-rmse:5892.37635	validation_1-rmse:9542.09607
# [412]	validation_0-rmse:5892.08125	validation_1-rmse:9541.91966
# [413]	validation_0-rmse:5891.78686	validation_1-rmse:9541.80439
# [414]	validation_0-rmse:5891.49360	validation_1-rmse:9541.69951
# [415]	validation_0-rmse:5891.20070	validation_1-rmse:9541.58183
# [416]	validation_0-rmse:5890.90856	validation_1-rmse:9541.45640
# [417]	validation_0-rmse:5890.61815	validation_1-rmse:9541.33357
# [418]	validation_0-rmse:5890.32916	validation_1-rmse:9541.15637
# [419]	validation_0-rmse:5890.04104	validation_1-rmse:9541.00357
# [420]	validation_0-rmse:5889.75394	validation_1-rmse:9540.84547
# [421]	validation_0-rmse:5889.46690	validation_1-rmse:9540.73347
# [422]	validation_0-rmse:5889.18142	validation_1-rmse:9540.59853
# [423]	validation_0-rmse:5888.89664	validation_1-rmse:9540.49251
# [424]	validation_0-rmse:5888.61345	validation_1-rmse:9540.34615
# [425]	validation_0-rmse:5888.33053	validation_1-rmse:9540.19608
# [426]	validation_0-rmse:5888.04862	validation_1-rmse:9540.10067
# [427]	validation_0-rmse:5887.76742	validation_1-rmse:9539.98412
# [428]	validation_0-rmse:5887.48776	validation_1-rmse:9539.84396
# [429]	validation_0-rmse:5887.20849	validation_1-rmse:9539.71089
# [430]	validation_0-rmse:5886.93022	validation_1-rmse:9539.57778
# [431]	validation_0-rmse:5886.65260	validation_1-rmse:9539.50097
# [432]	validation_0-rmse:5886.37600	validation_1-rmse:9539.34243
# [433]	validation_0-rmse:5886.09966	validation_1-rmse:9539.26278
# [434]	validation_0-rmse:5885.82400	validation_1-rmse:9539.18627
# [435]	validation_0-rmse:5885.54971	validation_1-rmse:9539.11309
# [436]	validation_0-rmse:5885.27571	validation_1-rmse:9539.03291
# [437]	validation_0-rmse:5885.00333	validation_1-rmse:9538.91982
# [438]	validation_0-rmse:5884.73196	validation_1-rmse:9538.79294
# [439]	validation_0-rmse:5884.46092	validation_1-rmse:9538.66870
# [440]	validation_0-rmse:5884.19094	validation_1-rmse:9538.55396
# [441]	validation_0-rmse:5883.92151	validation_1-rmse:9538.45290
# [442]	validation_0-rmse:5883.65279	validation_1-rmse:9538.38777
# [443]	validation_0-rmse:5883.38493	validation_1-rmse:9538.28001
# [444]	validation_0-rmse:5883.11752	validation_1-rmse:9538.21456
# [445]	validation_0-rmse:5882.85112	validation_1-rmse:9538.16044
# [446]	validation_0-rmse:5882.58615	validation_1-rmse:9538.05766
# [447]	validation_0-rmse:5882.32086	validation_1-rmse:9537.97352
# [448]	validation_0-rmse:5882.05670	validation_1-rmse:9537.91926
# [449]	validation_0-rmse:5881.79336	validation_1-rmse:9537.86074
# [450]	validation_0-rmse:5881.53028	validation_1-rmse:9537.82217
# [451]	validation_0-rmse:5881.26831	validation_1-rmse:9537.75632
# [452]	validation_0-rmse:5881.00785	validation_1-rmse:9537.64279
# [453]	validation_0-rmse:5880.74807	validation_1-rmse:9537.54543
# [454]	validation_0-rmse:5880.48871	validation_1-rmse:9537.45665
# [455]	validation_0-rmse:5880.23046	validation_1-rmse:9537.32624
# [456]	validation_0-rmse:5879.97316	validation_1-rmse:9537.22750
# [457]	validation_0-rmse:5879.71592	validation_1-rmse:9537.18389
# [458]	validation_0-rmse:5879.45952	validation_1-rmse:9537.11446
# [459]	validation_0-rmse:5879.20371	validation_1-rmse:9537.05724
# [460]	validation_0-rmse:5878.94881	validation_1-rmse:9536.98432
# [461]	validation_0-rmse:5878.69458	validation_1-rmse:9536.91745
# [462]	validation_0-rmse:5878.44114	validation_1-rmse:9536.88192
# [463]	validation_0-rmse:5878.18855	validation_1-rmse:9536.80943
# [464]	validation_0-rmse:5877.93619	validation_1-rmse:9536.79221
# [465]	validation_0-rmse:5877.68401	validation_1-rmse:9536.77322
# [466]	validation_0-rmse:5877.43347	validation_1-rmse:9536.69573
# [467]	validation_0-rmse:5877.18368	validation_1-rmse:9536.63473
# [468]	validation_0-rmse:5876.93414	validation_1-rmse:9536.56384
# [469]	validation_0-rmse:5876.68516	validation_1-rmse:9536.50054
# [470]	validation_0-rmse:5876.43643	validation_1-rmse:9536.50655
# [471]	validation_0-rmse:5876.18875	validation_1-rmse:9536.48393
# [472]	validation_0-rmse:5875.94131	validation_1-rmse:9536.47722
# [473]	validation_0-rmse:5875.69556	validation_1-rmse:9536.41405
# [474]	validation_0-rmse:5875.44967	validation_1-rmse:9536.39677
# [475]	validation_0-rmse:5875.20459	validation_1-rmse:9536.37634
# [476]	validation_0-rmse:5874.96010	validation_1-rmse:9536.35582
# [477]	validation_0-rmse:5874.71619	validation_1-rmse:9536.28989
# [478]	validation_0-rmse:5874.47302	validation_1-rmse:9536.22451
# [479]	validation_0-rmse:5874.23108	validation_1-rmse:9536.14844
# [480]	validation_0-rmse:5873.98937	validation_1-rmse:9536.10646
# [481]	validation_0-rmse:5873.74818	validation_1-rmse:9536.04333
# [482]	validation_0-rmse:5873.50773	validation_1-rmse:9535.98546
# [483]	validation_0-rmse:5873.26767	validation_1-rmse:9535.98658
# [484]	validation_0-rmse:5873.02855	validation_1-rmse:9535.94842
# [485]	validation_0-rmse:5872.78959	validation_1-rmse:9535.94646
# [486]	validation_0-rmse:5872.55163	validation_1-rmse:9535.94271
# [487]	validation_0-rmse:5872.31470	validation_1-rmse:9535.87853
# [488]	validation_0-rmse:5872.07803	validation_1-rmse:9535.83330
# [489]	validation_0-rmse:5871.84187	validation_1-rmse:9535.77516
# [490]	validation_0-rmse:5871.60613	validation_1-rmse:9535.78077
# [491]	validation_0-rmse:5871.37132	validation_1-rmse:9535.74163
# [492]	validation_0-rmse:5871.13660	validation_1-rmse:9535.74845
# [493]	validation_0-rmse:5870.90237	validation_1-rmse:9535.70484
# [494]	validation_0-rmse:5870.66857	validation_1-rmse:9535.70984
# [495]	validation_0-rmse:5870.43558	validation_1-rmse:9535.72027
# [496]	validation_0-rmse:5870.20359	validation_1-rmse:9535.68263
# [497]	validation_0-rmse:5869.97146	validation_1-rmse:9535.69341
# [498]	validation_0-rmse:5869.74023	validation_1-rmse:9535.69794
# [499]	validation_0-rmse:5869.50966	validation_1-rmse:9535.69635
# [500]	validation_0-rmse:5869.27950	validation_1-rmse:9535.69943
# [501]	validation_0-rmse:5869.05016	validation_1-rmse:9535.70173
# [502]	validation_0-rmse:5868.82127	validation_1-rmse:9535.72489
# [503]	validation_0-rmse:5868.59265	validation_1-rmse:9535.70161
# [504]	validation_0-rmse:5868.36493	validation_1-rmse:9535.68361
# [505]	validation_0-rmse:5868.13743	validation_1-rmse:9535.68646
# [506]	validation_0-rmse:5867.91096	validation_1-rmse:9535.65434
# [507]	validation_0-rmse:5867.68480	validation_1-rmse:9535.65537
# [508]	validation_0-rmse:5867.45908	validation_1-rmse:9535.60878
# [509]	validation_0-rmse:5867.23461	validation_1-rmse:9535.58009
# [510]	validation_0-rmse:5867.01047	validation_1-rmse:9535.54147
# [511]	validation_0-rmse:5866.78586	validation_1-rmse:9535.55369
# [512]	validation_0-rmse:5866.56236	validation_1-rmse:9535.56333
# [513]	validation_0-rmse:5866.33952	validation_1-rmse:9535.57858
# [514]	validation_0-rmse:5866.11681	validation_1-rmse:9535.58637
# [515]	validation_0-rmse:5865.89494	validation_1-rmse:9535.60036
# [516]	validation_0-rmse:5865.67351	validation_1-rmse:9535.60737
# [517]	validation_0-rmse:5865.45277	validation_1-rmse:9535.57881
# [518]	validation_0-rmse:5865.23204	validation_1-rmse:9535.59880
# [519]	validation_0-rmse:5865.01232	validation_1-rmse:9535.57673
# [520]	validation_0-rmse:5864.79352	validation_1-rmse:9535.52956
# [521]	validation_0-rmse:5864.57504	validation_1-rmse:9535.52103
# [522]	validation_0-rmse:5864.35679	validation_1-rmse:9535.49783
# [523]	validation_0-rmse:5864.13916	validation_1-rmse:9535.45699
# [524]	validation_0-rmse:5863.92204	validation_1-rmse:9535.44604
# [525]	validation_0-rmse:5863.70572	validation_1-rmse:9535.42796
# [526]	validation_0-rmse:5863.48900	validation_1-rmse:9535.46066
# [527]	validation_0-rmse:5863.27328	validation_1-rmse:9535.47980
# [528]	validation_0-rmse:5863.05722	validation_1-rmse:9535.49119
# [529]	validation_0-rmse:5862.84215	validation_1-rmse:9535.50647
# [530]	validation_0-rmse:5862.62769	validation_1-rmse:9535.51681
# [531]	validation_0-rmse:5862.41357	validation_1-rmse:9535.54193
# [532]	validation_0-rmse:5862.20047	validation_1-rmse:9535.52186
# [533]	validation_0-rmse:5861.98742	validation_1-rmse:9535.51366
# [534]	validation_0-rmse:5861.77454	validation_1-rmse:9535.54118
# [535]	validation_0-rmse:5861.56239	validation_1-rmse:9535.53084
# [536]	validation_0-rmse:5861.35098	validation_1-rmse:9535.51132
# [537]	validation_0-rmse:5861.13953	validation_1-rmse:9535.54897
# [538]	validation_0-rmse:5860.92911	validation_1-rmse:9535.53806
# [539]	validation_0-rmse:5860.71960	validation_1-rmse:9535.51431
# [540]	validation_0-rmse:5860.50971	validation_1-rmse:9535.49534
# [541]	validation_0-rmse:5860.30049	validation_1-rmse:9535.49460
# [542]	validation_0-rmse:5860.09193	validation_1-rmse:9535.49700
# [543]	validation_0-rmse:5859.88340	validation_1-rmse:9535.53066
# [544]	validation_0-rmse:5859.67571	validation_1-rmse:9535.51197
# [545]	validation_0-rmse:5859.46802	validation_1-rmse:9535.49919
# [546]	validation_0-rmse:5859.26081	validation_1-rmse:9535.52974
# [547]	validation_0-rmse:5859.05455	validation_1-rmse:9535.49852
# [548]	validation_0-rmse:5858.84828	validation_1-rmse:9535.54283
# [549]	validation_0-rmse:5858.64267	validation_1-rmse:9535.57476
# [550]	validation_0-rmse:5858.43752	validation_1-rmse:9535.56622
# [551]	validation_0-rmse:5858.23300	validation_1-rmse:9535.56547
# [552]	validation_0-rmse:5858.02836	validation_1-rmse:9535.60393
# [553]	validation_0-rmse:5857.82417	validation_1-rmse:9535.63372
# [554]	validation_0-rmse:5857.62146	validation_1-rmse:9535.62110
# [555]	validation_0-rmse:5857.41872	validation_1-rmse:9535.61796
# [556]	validation_0-rmse:5857.21618	validation_1-rmse:9535.62547
# [557]	validation_0-rmse:5857.01406	validation_1-rmse:9535.61594
# [558]	validation_0-rmse:5856.81212	validation_1-rmse:9535.62103
# [559]	validation_0-rmse:5856.61089	validation_1-rmse:9535.65614
# [560]	validation_0-rmse:5856.40989	validation_1-rmse:9535.66013
# [561]	validation_0-rmse:5856.20924	validation_1-rmse:9535.65167
# [562]	validation_0-rmse:5856.00900	validation_1-rmse:9535.69199
# [563]	validation_0-rmse:5855.80883	validation_1-rmse:9535.71439
# [564]	validation_0-rmse:5855.60977	validation_1-rmse:9535.70285
# [565]	validation_0-rmse:5855.41074	validation_1-rmse:9535.74443
# [566]	validation_0-rmse:5855.21229	validation_1-rmse:9535.73270
# [567]	validation_0-rmse:5855.01409	validation_1-rmse:9535.76517
# [568]	validation_0-rmse:5854.81676	validation_1-rmse:9535.76253
# [569]	validation_0-rmse:5854.61939	validation_1-rmse:9535.75483
# [570]	validation_0-rmse:5854.42239	validation_1-rmse:9535.78936
# [571]	validation_0-rmse:5854.22560	validation_1-rmse:9535.82324
# [572]	validation_0-rmse:5854.02924	validation_1-rmse:9535.84511
# [573]	validation_0-rmse:5853.83336	validation_1-rmse:9535.87564
# [574]	validation_0-rmse:5853.63800	validation_1-rmse:9535.92001

# %%
feature_importances_df = pd.DataFrame([feature_columns, feature_importances[-1]*100]).transpose().sort_values(by=1).rename(columns={0:'features',1:'importances'})

plt.figure(figsize=(20,20), dpi=200)
sns.barplot(feature_importances_df, x = 'features', y = 'importances')
plt.xticks(rotation=90);

# %%
int(np.sum(preds[0]))
# Out:
# 7997

# %% [markdown]
# ## XGBOOST Train with full data

# %%
scores = []
for i in range(1000):
    reg_model = xgb.XGBRegressor(base_score=0.5, booster='gblinear',  n_estimators=i, early_stopping_rounds=50, objective='reg:squarederror', learning_rate=0.01)
#  np.float64(6266.972679432407),
#  np.float64(6266.84052520814),
#  np.float64(6266.717806953692),
#  np.float64(6266.402186466279),
#  np.float64(6266.467584044652),
#  np.float64(6266.43922342121),
#  np.float64(6266.516240465528),
#  np.float64(6266.444268350541),
#  np.float64(6266.274455449791),
#  np.float64(6266.262633273928),
#  np.float64(6265.988634852127),
#  np.float64(6265.989388650462),
#  np.float64(6265.87132428893),
#  np.float64(6265.8124364269825),
#  np.float64(6265.77501273994),
#  np.float64(6265.593237064709),
#  np.float64(6265.481868989082),
#  np.float64(6265.439684056458),
#  np.float64(6265.286495108188),
#  np.float64(6265.152890712186),
#  np.float64(6265.0705001373935),
#  np.float64(6264.837559440904),
#  np.float64(6264.277657456636),
#  np.float64(6264.621362867237),
#  np.float64(6264.004118832339),
#  np.float64(6264.143076941499),
#  np.float64(6264.392944356066),
#  np.float64(6264.009223177799),
#  np.float64(6264.306780697883),
#  np.float64(6264.272006020844),
#  np.float64(6264.006570651821),
#  np.float64(6264.040163264994),
#  np.float64(6263.961564038752)]

# %%
reg_model = xgb.XGBRegressor(base_score=0.5, booster='gblinear',  n_estimators=400, early_stopping_rounds=50, objective='reg:squarederror', learning_rate=0.01)
reg_model.fit(df[feature_columns], df['total_sales'], eval_set=[(df[feature_columns], df['total_sales'])], verbose=False)
# Out:
# XGBRegressor(base_score=0.5, booster='gblinear', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.01, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=400,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
feature_importances_df = pd.DataFrame([feature_columns, reg_model.feature_importances_*100]).transpose().sort_values(by=1).rename(columns={0:'features',1:'importances'})

plt.figure(figsize=(20,20), dpi=200)
sns.barplot(feature_importances_df, x = 'features', y = 'importances')
plt.xticks(rotation=90);

# %%
y_preds = reg_model.predict(forcast_df[feature_columns])
ds =  pd.Series(y_preds, index=forcast_df.index)
ds.plot(label='prediction')
plt.legend()
plt.show()

# %% [markdown]
# # AdaBoost

# %%
def cross_validate(df, forcastdf, feature_columns):
    scores = []
    preds = []
    feature_importances = []
    sales = []
    tss = TimeSeriesSplit(n_splits=3, test_size=365, gap=0)
    feature_columns = sorted(feature_columns)
    for train_idx, val_idx in tss.split(df):
        scaler = StandardScaler()
        train = df.iloc[train_idx]
        test = df.iloc[val_idx]
        X_train = train[feature_columns]
        y_train = train['total_sales']
        X_test = test[feature_columns]
        y_test = test['total_sales']
        reg_model = AdaBoostRegressor(random_state=101, n_estimators=33)
        reg_model.fit(X_train, y_train)
        feature_importances.append(reg_model.feature_importances_)
        y_preds = reg_model.predict(X_train)
        ds =  pd.concat([y_train.reset_index(),pd.Series(y_preds)], axis=1)
        ds = ds.set_index('Order Date')
        ds['total_sales'].plot(label='true data')
        ds[0].plot(label='prediction')
        plt.legend()
        plt.show()
        y_preds = reg_model.predict(X_test)
        ds =  pd.concat([y_test.reset_index(),pd.Series(y_preds)], axis=1)
        ds = ds.set_index('Order Date')
        ds['total_sales'].plot(label='true data')
        ds[0].plot(label='prediction')
        plt.legend()
        plt.show()
        forcast_preds = reg_model.predict(forcastdf[feature_columns])
        ds =  pd.Series(forcast_preds, index=forcastdf.index)
        ds.plot(label='prediction')
        plt.legend()
        plt.show()
        preds.append(y_preds)
        score = np.sqrt(mean_squared_error(y_test, y_preds))
        scores.append(score)

    return preds, scores, feature_importances

# %%
preds, scores, feature_importances = cross_validate(df, forcast_df, feature_columns)
